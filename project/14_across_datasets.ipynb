# %%
import json
from pathlib import Path
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import vaep.pandas
import vaep.nb
import vaep.models

import logging
from vaep.logging import setup_logger
logger = setup_logger(logger=logging.getLogger('vaep'), level=10)

sns.set_theme()

plt.rcParams['figure.figsize'] = [16.0, 7.0]

# %%
IDX =[['proteinGroups', 'aggPeptides', 'evidence'],
      ['median', 'interpolated', 'collab', 'DAE', 'VAE']]

REPITITION_NAME = 'dataset'

# %%
# key fully specified in path 
def key_from_fname(fname):
    key = ( fname.parents[2].name, fname.parents[1].name) 
    return key

# %%
all_metrics = vaep.models.collect_metrics(snakemake.input.metrics, key_from_fname)
metrics = pd.DataFrame(all_metrics).T
metrics.index.names = ('data level', REPITITION_NAME)
metrics
# Out:
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/proteinGroups/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('proteinGroups', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/aggPeptides/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('aggPeptides', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101/metrics/metrics_DAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101/metrics/metrics_VAE.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
# vaep.models - INFO     Load file: fname = Path('runs/across_datasets/evidence/Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101/metrics/metrics_collab.json')
# vaep.models - DEBUG    key = ('evidence', 'Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'valid_fake_na', 'interpolated', 'N')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MSE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'MAE')
# vaep.models - DEBUG    Found existing key: k = ('NA interpolated', 'test_fake_na', 'interpolated', 'N')
#                                                                   NA interpolated  \
#                                                                     valid_fake_na
#                                                                      interpolated
#                                                                               MSE
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070           1.109
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071           0.939
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075           0.614
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078           1.086
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096           0.722
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101           0.995
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070           0.863
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071           0.705
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075           0.484
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078           0.899
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096           0.594
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101           0.613
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070           0.830
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071           0.693
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075           0.444
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078           0.865
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096           0.539
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101           0.565
#
#                                                                          \
#
#
#                                                                     MAE
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.755
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.665
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.526
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.757
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.587
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.676
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.645
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.556
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.438
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.674
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.503
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.516
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.614
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.532
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.403
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.643
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.461
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.478
#
#                                                                                \
#
#
#                                                                             N
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070  97,222.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071  85,854.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075  86,560.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078  60,370.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096  67,049.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101  76,983.000
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 563,370.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 515,057.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 571,082.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 343,846.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 429,160.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 485,229.000
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 594,880.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 544,152.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 617,541.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 361,442.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 467,269.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 527,847.000
#
#                                                                                \
#
#                                                                     DAE
#                                                                     MSE   MAE
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.415 0.437
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.383 0.419
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.307 0.364
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.430 0.445
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.378 0.415
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.398 0.427
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.421 0.444
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.350 0.387
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.290 0.346
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.457 0.468
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.386 0.412
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.360 0.397
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.426 0.432
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.350 0.374
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.236 0.288
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.423 0.433
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.338 0.372
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.309 0.349
#
#                                                                                \
#
#
#                                                                             N
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070  97,222.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071  85,854.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075  86,560.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078  60,370.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096  67,049.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101  76,983.000
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 563,370.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 515,057.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 571,082.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 343,846.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 429,160.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 485,229.000
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 594,880.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 544,152.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 617,541.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 361,442.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 467,269.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 527,847.000
#
#                                                                                 \
#                                                                   test_fake_na
#                                                                   interpolated
#                                                                            MSE
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070        1.116
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071        0.939
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075        0.615
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078        1.080
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096        0.720
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101        1.016
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070        0.869
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071        0.707
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075        0.488
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078        0.897
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096        0.590
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101        0.617
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070        0.829
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071        0.690
# ...
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075        0.300
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078        0.425
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096        0.352
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101        0.374
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070        0.332
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071        0.317
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075        0.250
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078        0.345
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096        0.312
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101        0.317
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070        0.308
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071        0.295
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075        0.210
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078        0.336
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096        0.266
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101        0.265
#
#                                                                          \
#
#
#                                                                     MAE
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.424
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.393
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.364
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.442
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.400
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.406
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.377
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.368
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.313
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.387
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.359
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.363
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.340
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.331
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.264
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.369
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.307
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.305
#
#                                                                                \
#
#
#                                                                             N
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070  97,195.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071  85,839.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075  86,586.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078  60,505.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096  67,029.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101  77,032.000
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 563,228.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 515,076.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 570,847.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 343,607.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 429,363.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 485,291.000
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 595,448.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 544,662.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 617,793.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 361,768.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 467,426.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 528,012.000
#
#                                                                   NA not interpolated  \
#                                                                         valid_fake_na
#                                                                                collab
#                                                                                   MSE
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070               0.805
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071               0.676
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075               0.648
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078               0.868
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096               0.692
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101               0.718
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070               0.381
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071               0.393
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075               0.295
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078               0.412
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096               0.370
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101               0.364
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070               0.302
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071               0.298
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075               0.207
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078               0.333
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096               0.251
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101               0.249
#
#                                                                          \
#
#
#                                                                     MAE
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.621
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.573
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.560
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.636
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.582
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.586
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.414
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.420
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.353
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.430
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.401
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.400
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.361
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.359
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.289
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.400
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.331
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.328
#
#                                                                               \
#
#
#                                                                            N
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070  3,488.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071  3,041.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075  3,096.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078  2,236.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096  2,460.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101  2,884.000
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 50,842.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 45,029.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 43,050.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 31,713.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 36,484.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 42,313.000
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 58,808.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 52,444.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 50,121.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 37,040.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 43,279.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 50,134.000
#
#                                                                                 \
#                                                                   test_fake_na
#                                                                         collab
#                                                                            MSE
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070        0.822
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071        0.739
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075        0.592
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078        0.830
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096        0.656
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101        0.693
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070        0.382
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071        0.384
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075        0.315
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078        0.397
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096        0.374
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101        0.366
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070        0.298
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071        0.295
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075        0.207
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078        0.354
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096        0.247
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101        0.253
#
#                                                                          \
#
#
#                                                                     MAE
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.624
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.594
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.534
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.641
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.570
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.593
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.415
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.417
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.360
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.427
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.399
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.401
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 0.360
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 0.360
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 0.288
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 0.401
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 0.329
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 0.327
#
#
#
#
#                                                                            N
# data level    dataset
# proteinGroups Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070  3,516.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071  3,056.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075  3,071.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078  2,102.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096  2,480.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101  2,835.000
# aggPeptides   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 50,984.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 45,011.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 43,284.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 31,952.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 36,282.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 42,252.000
# evidence      Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070 58,240.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 51,934.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 49,870.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 36,715.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 43,123.000
#               Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 49,969.000
#
# [18 rows x 54 columns]

# %%
FOLDER = Path(snakemake.input.metrics[0]).parents[3]
FOLDER
# Out:
# Path('runs/across_datasets')

# %%
metrics = metrics.T.sort_index().loc[pd.IndexSlice[['NA interpolated', 'NA not interpolated'],
                                         ['valid_fake_na', 'test_fake_na'],
                                         ['median', 'interpolated', 'collab', 'DAE', 'VAE'],
                                         :]]
metrics.to_csv(FOLDER/ "metrics.csv")
metrics.to_excel(FOLDER/ "metrics.xlsx")
metrics
# Out:
# data level                                                                               proteinGroups  \
# dataset                                            Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070
# NA interpolated     valid_fake_na median       MAE                                               1.011
#                                                MSE                                               1.727
#                                                N                                            97,222.000
#                                   interpolated MAE                                               0.755
#                                                MSE                                               1.109
#                                                N                                            97,222.000
#                                   collab       MAE                                               0.424
#                                                MSE                                               0.390
#                                                N                                            97,222.000
#                                   DAE          MAE                                               0.437
#                                                MSE                                               0.415
#                                                N                                            97,222.000
#                                   VAE          MAE                                               0.439
#                                                MSE                                               0.422
#                                                N                                            97,222.000
#                     test_fake_na  median       MAE                                               1.012
#                                                MSE                                               1.719
#                                                N                                            97,195.000
#                                   interpolated MAE                                               0.757
#                                                MSE                                               1.116
#                                                N                                            97,195.000
#                                   collab       MAE                                               0.424
#                                                MSE                                               0.395
#                                                N                                            97,195.000
#                                   DAE          MAE                                               0.438
#                                                MSE                                               0.419
#                                                N                                            97,195.000
#                                   VAE          MAE                                               0.440
#                                                MSE                                               0.427
#                                                N                                            97,195.000
# NA not interpolated valid_fake_na median       MAE                                               1.194
#                                                MSE                                               2.407
#                                                N                                             3,488.000
#                                   collab       MAE                                               0.621
#                                                MSE                                               0.805
#                                                N                                             3,488.000
#                                   DAE          MAE                                               0.636
#                                                MSE                                               0.848
#                                                N                                             3,488.000
#                                   VAE          MAE                                               0.631
#                                                MSE                                               0.850
#                                                N                                             3,488.000
#                     test_fake_na  median       MAE                                               1.199
#                                                MSE                                               2.433
#                                                N                                             3,516.000
#                                   collab       MAE                                               0.624
#                                                MSE                                               0.822
#                                                N                                             3,516.000
#                                   DAE          MAE                                               0.636
#                                                MSE                                               0.863
#                                                N                                             3,516.000
#                                   VAE          MAE                                               0.640
#                                                MSE                                               0.875
#                                                N                                             3,516.000
#
# data level                                                                                              \
# dataset                                            Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071
# NA interpolated     valid_fake_na median       MAE                                               0.888
#                                                MSE                                               1.444
#                                                N                                            85,854.000
#                                   interpolated MAE                                               0.665
#                                                MSE                                               0.939
#                                                N                                            85,854.000
#                                   collab       MAE                                               0.395
#                                                MSE                                               0.352
#                                                N                                            85,854.000
#                                   DAE          MAE                                               0.419
#                                                MSE                                               0.383
#                                                N                                            85,854.000
#                                   VAE          MAE                                               0.417
#                                                MSE                                               0.386
#                                                N                                            85,854.000
#                     test_fake_na  median       MAE                                               0.891
#                                                MSE                                               1.461
#                                                N                                            85,839.000
#                                   interpolated MAE                                               0.666
#                                                MSE                                               0.939
#                                                N                                            85,839.000
#                                   collab       MAE                                               0.393
#                                                MSE                                               0.347
#                                                N                                            85,839.000
#                                   DAE          MAE                                               0.416
#                                                MSE                                               0.378
#                                                N                                            85,839.000
#                                   VAE          MAE                                               0.415
#                                                MSE                                               0.379
#                                                N                                            85,839.000
# NA not interpolated valid_fake_na median       MAE                                               1.068
#                                                MSE                                               2.088
#                                                N                                             3,041.000
#                                   collab       MAE                                               0.573
#                                                MSE                                               0.676
#                                                N                                             3,041.000
#                                   DAE          MAE                                               0.599
#                                                MSE                                               0.738
#                                                N                                             3,041.000
#                                   VAE          MAE                                               0.601
#                                                MSE                                               0.770
#                                                N                                             3,041.000
#                     test_fake_na  median       MAE                                               1.109
#                                                MSE                                               2.142
#                                                N                                             3,056.000
#                                   collab       MAE                                               0.594
#                                                MSE                                               0.739
#                                                N                                             3,056.000
#                                   DAE          MAE                                               0.616
#                                                MSE                                               0.792
#                                                N                                             3,056.000
#                                   VAE          MAE                                               0.617
#                                                MSE                                               0.798
#                                                N                                             3,056.000
#
# data level                                                                                              \
# dataset                                            Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075
# NA interpolated     valid_fake_na median       MAE                                               0.723
#                                                MSE                                               0.944
#                                                N                                            86,560.000
#                                   interpolated MAE                                               0.526
#                                                MSE                                               0.614
#                                                N                                            86,560.000
#                                   collab       MAE                                               0.362
#                                                MSE                                               0.298
#                                                N                                            86,560.000
#                                   DAE          MAE                                               0.364
#                                                MSE                                               0.307
#                                                N                                            86,560.000
#                                   VAE          MAE                                               0.397
#                                                MSE                                               0.351
#                                                N                                            86,560.000
#                     test_fake_na  median       MAE                                               0.725
#                                                MSE                                               0.950
#                                                N                                            86,586.000
#                                   interpolated MAE                                               0.528
#                                                MSE                                               0.615
#                                                N                                            86,586.000
#                                   collab       MAE                                               0.364
#                                                MSE                                               0.300
#                                                N                                            86,586.000
#                                   DAE          MAE                                               0.366
#                                                MSE                                               0.310
#                                                N                                            86,586.000
#                                   VAE          MAE                                               0.397
#                                                MSE                                               0.354
#                                                N                                            86,586.000
# NA not interpolated valid_fake_na median       MAE                                               0.909
#                                                MSE                                               1.509
#                                                N                                             3,096.000
#                                   collab       MAE                                               0.560
#                                                MSE                                               0.648
#                                                N                                             3,096.000
#                                   DAE          MAE                                               0.568
#                                                MSE                                               0.676
#                                                N                                             3,096.000
#                                   VAE          MAE                                               0.609
#                                                MSE                                               0.749
#                                                N                                             3,096.000
#                     test_fake_na  median       MAE                                               0.876
#                                                MSE                                               1.417
#                                                N                                             3,071.000
#                                   collab       MAE                                               0.534
#                                                MSE                                               0.592
#                                                N                                             3,071.000
#                                   DAE          MAE                                               0.535
#                                                MSE                                               0.598
#                                                N                                             3,071.000
#                                   VAE          MAE                                               0.575
#                                                MSE                                               0.680
#                                                N                                             3,071.000
#
# data level                                                                                              \
# dataset                                            Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078
# NA interpolated     valid_fake_na median       MAE                                               1.097
#                                                MSE                                               1.987
#                                                N                                            60,370.000
#                                   interpolated MAE                                               0.757
#                                                MSE                                               1.086
#                                                N                                            60,370.000
#                                   collab       MAE                                               0.443
#                                                MSE                                               0.426
#                                                N                                            60,370.000
#                                   DAE          MAE                                               0.445
#                                                MSE                                               0.430
#                                                N                                            60,370.000
#                                   VAE          MAE                                               0.463
#                                                MSE                                               0.461
#                                                N                                            60,370.000
#                     test_fake_na  median       MAE                                               1.092
#                                                MSE                                               1.965
#                                                N                                            60,505.000
#                                   interpolated MAE                                               0.755
#                                                MSE                                               1.080
#                                                N                                            60,505.000
#                                   collab       MAE                                               0.442
#                                                MSE                                               0.425
#                                                N                                            60,505.000
#                                   DAE          MAE                                               0.444
#                                                MSE                                               0.426
#                                                N                                            60,505.000
#                                   VAE          MAE                                               0.462
#                                                MSE                                               0.457
#                                                N                                            60,505.000
# NA not interpolated valid_fake_na median       MAE                                               1.259
#                                                MSE                                               2.710
#                                                N                                             2,236.000
#                                   collab       MAE                                               0.636
#                                                MSE                                               0.868
#                                                N                                             2,236.000
#                                   DAE          MAE                                               0.637
#                                                MSE                                               0.872
#                                                N                                             2,236.000
#                                   VAE          MAE                                               0.662
#                                                MSE                                               0.907
#                                                N                                             2,236.000
#                     test_fake_na  median       MAE                                               1.207
#                                                MSE                                               2.400
#                                                N                                             2,102.000
#                                   collab       MAE                                               0.641
#                                                MSE                                               0.830
#                                                N                                             2,102.000
#                                   DAE          MAE                                               0.638
#                                                MSE                                               0.808
#                                                N                                             2,102.000
#                                   VAE          MAE                                               0.659
#                                                MSE                                               0.869
#                                                N                                             2,102.000
#
# data level                                                                                              \
# dataset                                            Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096
# NA interpolated     valid_fake_na median       MAE                                               0.864
#                                                MSE                                               1.284
#                                                N                                            67,049.000
#                                   interpolated MAE                                               0.587
#                                                MSE                                               0.722
#                                                N                                            67,049.000
#                                   collab       MAE                                               0.402
#                                                MSE                                               0.357
#                                                N                                            67,049.000
#                                   DAE          MAE                                               0.415
#                                                MSE                                               0.378
#                                                N                                            67,049.000
#                                   VAE          MAE                                               0.435
#                                                MSE                                               0.403
#                                                N                                            67,049.000
#                     test_fake_na  median       MAE                                               0.867
#                                                MSE                                               1.291
#                                                N                                            67,029.000
#                                   interpolated MAE                                               0.586
#                                                MSE                                               0.720
#                                                N                                            67,029.000
#                                   collab       MAE                                               0.400
#                                                MSE                                               0.352
#                                                N                                            67,029.000
#                                   DAE          MAE                                               0.411
#                                                MSE                                               0.370
#                                                N                                            67,029.000
#                                   VAE          MAE                                               0.433
#                                                MSE                                               0.398
#                                                N                                            67,029.000
# NA not interpolated valid_fake_na median       MAE                                               1.028
#                                                MSE                                               1.839
#                                                N                                             2,460.000
#                                   collab       MAE                                               0.582
#                                                MSE                                               0.692
#                                                N                                             2,460.000
#                                   DAE          MAE                                               0.593
#                                                MSE                                               0.718
#                                                N                                             2,460.000
#                                   VAE          MAE                                               0.617
#                                                MSE                                               0.763
#                                                N                                             2,460.000
#                     test_fake_na  median       MAE                                               1.019
#                                                MSE                                               1.813
#                                                N                                             2,480.000
#                                   collab       MAE                                               0.570
#                                                MSE                                               0.656
#                                                N                                             2,480.000
#                                   DAE          MAE                                               0.578
#                                                MSE                                               0.669
#                                                N                                             2,480.000
#                                   VAE          MAE                                               0.596
#                                                MSE                                               0.699
#                                                N                                             2,480.000
#
# data level                                                                                              \
# dataset                                            Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101
# NA interpolated     valid_fake_na median       MAE                                               0.881
#                                                MSE                                               1.418
#                                                N                                            76,983.000
#                                   interpolated MAE                                               0.676
#                                                MSE                                               0.995
#                                                N                                            76,983.000
#                                   collab       MAE                                               0.408
#                                                MSE                                               0.371
#                                                N                                            76,983.000
#                                   DAE          MAE                                               0.427
#                                                MSE                                               0.398
#                                                N                                            76,983.000
#                                   VAE          MAE                                               0.454
#                                                MSE                                               0.447
#                                                N                                            76,983.000
#                     test_fake_na  median       MAE                                               0.879
#                                                MSE                                               1.411
#                                                N                                            77,032.000
#                                   interpolated MAE                                               0.681
#                                                MSE                                               1.016
#                                                N                                            77,032.000
#                                   collab       MAE                                               0.406
#                                                MSE                                               0.374
#                                                N                                            77,032.000
#                                   DAE          MAE                                               0.424
#                                                MSE                                               0.398
#                                                N                                            77,032.000
#                                   VAE          MAE                                               0.451
#                                                MSE                                               0.447
#                                                N                                            77,032.000
# NA not interpolated valid_fake_na median       MAE                                               1.009
#                                                MSE                                               1.866
#                                                N                                             2,884.000
#                                   collab       MAE                                               0.586
#                                                MSE                                               0.718
#                                                N                                             2,884.000
#                                   DAE          MAE                                               0.613
#                                                MSE                                               0.773
#                                                N                                             2,884.000
#                                   VAE          MAE                                               0.646
#                                                MSE                                               0.849
#                                                N                                             2,884.000
#                     test_fake_na  median       MAE                                               1.030
#                                                MSE                                               1.969
#                                                N                                             2,835.000
#                                   collab       MAE                                               0.593
#                                                MSE                                               0.693
#                                                N                                             2,835.000
#                                   DAE          MAE                                               0.611
#                                                MSE                                               0.741
#                                                N                                             2,835.000
#                                   VAE          MAE                                               0.650
#                                                MSE                                               0.843
#                                                N                                             2,835.000
#
# data level                                                                                 aggPeptides  \
# dataset                                            Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070
# NA interpolated     valid_fake_na median       MAE                                               0.961
#                                                MSE                                               1.547
#                                                N                                           563,370.000
#                                   interpolated MAE                                               0.645
#                                                MSE                                               0.863
#                                                N                                           563,370.000
#                                   collab       MAE                                               0.376
#                                                MSE                                               0.328
#                                                N                                           563,370.000
#                                   DAE          MAE                                               0.444
#                                                MSE                                               0.421
#                                                N                                           563,370.000
#                                   VAE          MAE                                               0.398
#                                                MSE                                               0.369
#                                                N                                           563,370.000
#                     test_fake_na  median       MAE                                               0.964
#                                                MSE                                               1.557
#                                                N                                           563,228.000
#                                   interpolated MAE                                               0.647
#                                                MSE                                               0.869
#                                                N                                           563,228.000
#                                   collab       MAE                                               0.377
#                                                MSE                                               0.332
#                                                N                                           563,228.000
#                                   DAE          MAE                                               0.443
#                                                MSE                                               0.423
#                                                N                                           563,228.000
#                                   VAE          MAE                                               0.398
#                                                MSE                                               0.371
#                                                N                                           563,228.000
# NA not interpolated valid_fake_na median       MAE                                               1.001
#                                                MSE                                               1.722
#                                                N                                            50,842.000
#                                   collab       MAE                                               0.414
#                                                MSE                                               0.381
#                                                N                                            50,842.000
#                                   DAE          MAE                                               0.471
#                                                MSE                                               0.478
#                                                N                                            50,842.000
#                                   VAE          MAE                                               0.436
#                                                MSE                                               0.434
#                                                N                                            50,842.000
#                     test_fake_na  median       MAE                                               1.002
#                                                MSE                                               1.724
#                                                N                                            50,984.000
#                                   collab       MAE                                               0.415
#                                                MSE                                               0.382
#                                                N                                            50,984.000
#                                   DAE          MAE                                               0.472
#                                                MSE                                               0.475
#                                                N                                            50,984.000
#                                   VAE          MAE                                               0.438
#                                                MSE                                               0.434
#                                                N                                            50,984.000
#
# data level                                                                                              \
# dataset                                            Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071
# NA interpolated     valid_fake_na median       MAE                                               0.805
#                                                MSE                                               1.200
#                                                N                                           515,057.000
#                                   interpolated MAE                                               0.556
#                                                MSE                                               0.705
#                                                N                                           515,057.000
#                                   collab       MAE                                               0.366
#                                                MSE                                               0.313
#                                                N                                           515,057.000
#                                   DAE          MAE                                               0.387
#                                                MSE                                               0.350
#                                                N                                           515,057.000
#                                   VAE          MAE                                               0.374
#                                                MSE                                               0.341
#                                                N                                           515,057.000
#                     test_fake_na  median       MAE                                               0.806
#                                                MSE                                               1.203
#                                                N                                           515,076.000
#                                   interpolated MAE                                               0.557
#                                                MSE                                               0.707
#                                                N                                           515,076.000
#                                   collab       MAE                                               0.368
#                                                MSE                                               0.317
#                                                N                                           515,076.000
#                                   DAE          MAE                                               0.389
#                                                MSE                                               0.353
#                                                N                                           515,076.000
#                                   VAE          MAE                                               0.375
#                                                MSE                                               0.343
#                                                N                                           515,076.000
# NA not interpolated valid_fake_na median       MAE                                               0.872
#                                                MSE                                               1.429
#                                                N                                            45,029.000
#                                   collab       MAE                                               0.420
#                                                MSE                                               0.393
#                                                N                                            45,029.000
#                                   DAE          MAE                                               0.434
#                                                MSE                                               0.430
#                                                N                                            45,029.000
#                                   VAE          MAE                                               0.426
#                                                MSE                                               0.430
#                                                N                                            45,029.000
#                     test_fake_na  median       MAE                                               0.865
#                                                MSE                                               1.418
#                                                N                                            45,011.000
#                                   collab       MAE                                               0.417
#                                                MSE                                               0.384
#                                                N                                            45,011.000
#                                   DAE          MAE                                               0.431
#                                                MSE                                               0.421
#                                                N                                            45,011.000
#                                   VAE          MAE                                               0.424
#                                                MSE                                               0.424
#                                                N                                            45,011.000
#
# data level                                                                                              \
# dataset                                            Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075
# NA interpolated     valid_fake_na median       MAE                                               0.653
#                                                MSE                                               0.827
# ...
#                     test_fake_na  median       MAE                                               0.974
#                                                MSE                                               1.589
#                                                N                                           361,768.000
#                                   interpolated MAE                                               0.641
#                                                MSE                                               0.855
#                                                N                                           361,768.000
#                                   collab       MAE                                               0.369
#                                                MSE                                               0.336
#                                                N                                           361,768.000
#                                   DAE          MAE                                               0.431
#                                                MSE                                               0.419
#                                                N                                           361,768.000
#                                   VAE          MAE                                               0.416
#                                                MSE                                               0.406
#                                                N                                           361,768.000
# NA not interpolated valid_fake_na median       MAE                                               0.996
#                                                MSE                                               1.670
#                                                N                                            37,040.000
#                                   collab       MAE                                               0.400
#                                                MSE                                               0.333
#                                                N                                            37,040.000
#                                   DAE          MAE                                               0.447
#                                                MSE                                               0.414
#                                                N                                            37,040.000
#                                   VAE          MAE                                               0.438
#                                                MSE                                               0.409
#                                                N                                            37,040.000
#                     test_fake_na  median       MAE                                               0.998
#                                                MSE                                               1.687
#                                                N                                            36,715.000
#                                   collab       MAE                                               0.401
#                                                MSE                                               0.354
#                                                N                                            36,715.000
#                                   DAE          MAE                                               0.450
#                                                MSE                                               0.434
#                                                N                                            36,715.000
#                                   VAE          MAE                                               0.442
#                                                MSE                                               0.431
#                                                N                                            36,715.000
#
# data level                                                                                              \
# dataset                                            Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096
# NA interpolated     valid_fake_na median       MAE                                               0.761
#                                                MSE                                               1.065
#                                                N                                           467,269.000
#                                   interpolated MAE                                               0.461
#                                                MSE                                               0.539
#                                                N                                           467,269.000
#                                   collab       MAE                                               0.308
#                                                MSE                                               0.266
#                                                N                                           467,269.000
#                                   DAE          MAE                                               0.372
#                                                MSE                                               0.338
#                                                N                                           467,269.000
#                                   VAE          MAE                                               0.342
#                                                MSE                                               0.310
#                                                N                                           467,269.000
#                     test_fake_na  median       MAE                                               0.762
#                                                MSE                                               1.066
#                                                N                                           467,426.000
#                                   interpolated MAE                                               0.461
#                                                MSE                                               0.536
#                                                N                                           467,426.000
#                                   collab       MAE                                               0.307
#                                                MSE                                               0.266
#                                                N                                           467,426.000
#                                   DAE          MAE                                               0.372
#                                                MSE                                               0.339
#                                                N                                           467,426.000
#                                   VAE          MAE                                               0.342
#                                                MSE                                               0.311
#                                                N                                           467,426.000
# NA not interpolated valid_fake_na median       MAE                                               0.793
#                                                MSE                                               1.155
#                                                N                                            43,279.000
#                                   collab       MAE                                               0.331
#                                                MSE                                               0.251
#                                                N                                            43,279.000
#                                   DAE          MAE                                               0.383
#                                                MSE                                               0.322
#                                                N                                            43,279.000
#                                   VAE          MAE                                               0.363
#                                                MSE                                               0.304
#                                                N                                            43,279.000
#                     test_fake_na  median       MAE                                               0.792
#                                                MSE                                               1.144
#                                                N                                            43,123.000
#                                   collab       MAE                                               0.329
#                                                MSE                                               0.247
#                                                N                                            43,123.000
#                                   DAE          MAE                                               0.381
#                                                MSE                                               0.316
#                                                N                                            43,123.000
#                                   VAE          MAE                                               0.360
#                                                MSE                                               0.296
#                                                N                                            43,123.000
#
# data level
# dataset                                            Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101
# NA interpolated     valid_fake_na median       MAE                                               0.774
#                                                MSE                                               1.095
#                                                N                                           527,847.000
#                                   interpolated MAE                                               0.478
#                                                MSE                                               0.565
#                                                N                                           527,847.000
#                                   collab       MAE                                               0.305
#                                                MSE                                               0.262
#                                                N                                           527,847.000
#                                   DAE          MAE                                               0.349
#                                                MSE                                               0.309
#                                                N                                           527,847.000
#                                   VAE          MAE                                               0.348
#                                                MSE                                               0.313
#                                                N                                           527,847.000
#                     test_fake_na  median       MAE                                               0.775
#                                                MSE                                               1.100
#                                                N                                           528,012.000
#                                   interpolated MAE                                               0.479
#                                                MSE                                               0.568
#                                                N                                           528,012.000
#                                   collab       MAE                                               0.305
#                                                MSE                                               0.265
#                                                N                                           528,012.000
#                                   DAE          MAE                                               0.349
#                                                MSE                                               0.312
#                                                N                                           528,012.000
#                                   VAE          MAE                                               0.348
#                                                MSE                                               0.316
#                                                N                                           528,012.000
# NA not interpolated valid_fake_na median       MAE                                               0.800
#                                                MSE                                               1.178
#                                                N                                            50,134.000
#                                   collab       MAE                                               0.328
#                                                MSE                                               0.249
#                                                N                                            50,134.000
#                                   DAE          MAE                                               0.364
#                                                MSE                                               0.300
#                                                N                                            50,134.000
#                                   VAE          MAE                                               0.370
#                                                MSE                                               0.316
#                                                N                                            50,134.000
#                     test_fake_na  median       MAE                                               0.798
#                                                MSE                                               1.172
#                                                N                                            49,969.000
#                                   collab       MAE                                               0.327
#                                                MSE                                               0.253
#                                                N                                            49,969.000
#                                   DAE          MAE                                               0.363
#                                                MSE                                               0.302
#                                                N                                            49,969.000
#                                   VAE          MAE                                               0.368
#                                                MSE                                               0.319
#                                                N                                            49,969.000

# %%
level, split = 'NA interpolated', 'valid_fake_na'
selected = metrics.loc[pd.IndexSlice[level,
                          split,
                          :, :]].stack()
selected
# Out:
# data level                                                                                    aggPeptides  \
#                                          dataset
# NA interpolated valid_fake_na median MAE Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070        0.961
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071        0.805
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075        0.653
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078        1.009
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096        0.790
# ...                                                                                                   ...
#                               VAE    N   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071  515,057.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075  571,082.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078  343,846.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096  429,160.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101  485,229.000
#
# data level                                                                                      evidence  \
#                                          dataset
# NA interpolated valid_fake_na median MAE Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070       0.957
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071       0.779
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075       0.632
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078       0.976
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096       0.761
# ...                                                                                                  ...
#                               VAE    N   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071 544,152.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075 617,541.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078 361,442.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096 467,269.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101 527,847.000
#
# data level                                                                                    proteinGroups
#                                          dataset
# NA interpolated valid_fake_na median MAE Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070          1.011
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071          0.888
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075          0.723
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078          1.097
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096          0.864
# ...                                                                                                     ...
#                               VAE    N   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071     85,854.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6075     86,560.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6078     60,370.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096     67,049.000
#                                          Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101     76,983.000
#
# [90 rows x 3 columns]

# %%
to_plot = selected.loc[level].loc[split].loc[pd.IndexSlice[:,'MAE',:]]
to_plot = to_plot.stack().unstack(REPITITION_NAME).T.describe().loc[['mean','std']].T.unstack(0)
to_plot = to_plot.loc[IDX[0], pd.IndexSlice[:, IDX[1]]]
to_plot.to_csv(FOLDER/ "model_performance_repeated_runs_avg.csv")
to_plot.to_excel(FOLDER/ "model_performance_repeated_runs_avg.xlsx")
to_plot
# Out:
#                 mean    std         mean          std   mean    std  mean  \
#               median median interpolated interpolated collab collab   DAE
# data level
# proteinGroups  0.911  0.129        0.661        0.092  0.405  0.027 0.418
# aggPeptides    0.837  0.129        0.555        0.090  0.361  0.026 0.409
# evidence       0.813  0.131        0.522        0.093  0.319  0.036 0.375
#
#                 std  mean   std
#                 DAE   VAE   VAE
# data level
# proteinGroups 0.029 0.434 0.024
# aggPeptides   0.043 0.389 0.026
# evidence      0.054 0.358 0.041

# %%
logger.setLevel(20) # reset debug
ax = to_plot['mean'].plot.bar(rot=0, width=.8, yerr=to_plot['std'])

# %%
level, split = 'NA interpolated', 'valid_fake_na'
selected = metrics.loc[pd.IndexSlice[level,
                          split,
                          :, 'MAE']].stack(1)
selected.index.names = ('x', 'split', 'model', 'metric', REPITITION_NAME)
# # selected.reset_index()
selected.stack().to_frame('MAE').reset_index()
# Out:
#                   x          split   model metric  \
# 0   NA interpolated  valid_fake_na  median    MAE
# 1   NA interpolated  valid_fake_na  median    MAE
# 2   NA interpolated  valid_fake_na  median    MAE
# 3   NA interpolated  valid_fake_na  median    MAE
# 4   NA interpolated  valid_fake_na  median    MAE
# ..              ...            ...     ...    ...
# 85  NA interpolated  valid_fake_na     VAE    MAE
# 86  NA interpolated  valid_fake_na     VAE    MAE
# 87  NA interpolated  valid_fake_na     VAE    MAE
# 88  NA interpolated  valid_fake_na     VAE    MAE
# 89  NA interpolated  valid_fake_na     VAE    MAE
#
#                                                 dataset     data level   MAE
# 0   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070    aggPeptides 0.961
# 1   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070       evidence 0.957
# 2   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6070  proteinGroups 1.011
# 3   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071    aggPeptides 0.805
# 4   Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6071       evidence 0.779
# ..                                                  ...            ...   ...
# 85  Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096       evidence 0.342
# 86  Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6096  proteinGroups 0.435
# 87  Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101    aggPeptides 0.370
# 88  Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101       evidence 0.348
# 89  Q_Exactive_HF_X_Orbitrap_Exactive_Series_slot_#6101  proteinGroups 0.454
#
# [90 rows x 7 columns]

# %%
fig = sns.barplot(x='data level',
            y='MAE',
            hue='model',
            order = IDX[0],
            ci=95,
            data=selected.stack().to_frame('MAE').reset_index())
fig = ax.get_figure()

# %%
vaep.savefig(fig, FOLDER/ "model_performance_repeated_runs.pdf" )
# Out:
# vaep.plotting - INFO     Saved Figures to runs\across_datasets\model_performance_repeated_runs.pdf

# %% [markdown]
# # Experiment 02
#
#
# The current approach for creating train, validation and test data sets is to split
# the data in long-format, i.e. one observation is an intensity value from one sample representing one peptide, into the desired splits. In this process missing values are not regarded.
#
# - [x] mask entries in larger dataset in long-format
# - [x] mask peptides based on their frequency in samples (probability of being observed)
# - [x] create *long-format* training data set without masked values for each model
#     - FNN based on embeddings of peptides and samples (long-format **without** missing values)
#     - Denoising AE (wide-format **with** missing values)
#     - VAE (wide-format **with** missing values)
# - [ ] restrict to only a training data split of consective data: Increase number of samples.
#     - focus on best reconstruction performance
#     - mean comparison
#
# ### Collaborative Filtering model
#
# - Cannot accomodate iid assumption of statistical test in current setup for embedding vectors.
#   - if pretrained model should be applied to an new batch of replicates (with a certain condition) one would need to find a way to initialize the sample embeddings without fine-tuning the model

# %%
import logging
from pprint import pprint
import seaborn
import numpy.testing as npt  # fastcore.test functionality

from pathlib import Path


import vaep.io_images
from vaep.pandas import interpolate
from vaep.model import build_df_from_pred_batches

from src.nb_imports import *
from src import metadata
from src.logging import setup_logger

logger = setup_logger(logger=logging.getLogger('vaep'))
logger.info("Experiment 02")

figures = {}  # collection of ax or figures
# Out:
# FOLDER_MQ_TXT_DATA = data\mq_out
# vaep - INFO     Experiment 02

# %%
# None takes all
N_SAMPLES: int = 1000
n_features: int = 50
ADD_TENSORBOARD: bool = False
FN_PEPTIDE_INTENSITIES: Path = (
    config.FOLDER_DATA / 'df_intensities_N07285_M01000')  # 90%
epochs_max = 10
batch_size = 32
latent_dim = 2
most_common: bool = False
most_uncommon: bool = False
out_folder: str = 'poster'
# write to read only config ? namedtuple?

# %%
# Parameters
n_feat = 300
n_epochs = 10
out_folder = "runs/2D"

# %%
BATCH_SIZE, EPOCHS = batch_size, epochs_max
folder = Path(out_folder) / f'feat_{n_features:04d}_epochs_{epochs_max:03d}'
print(f"{folder = }")

if most_common and most_uncommon:
    raise ValueError(f"Cannot be both True: {most_common = } and {most_uncommon = }")
# Out:
# folder = Path('runs/2D/feat_0050_epochs_010')

# %% [markdown]
# ## Raw data

# %%
FN_PEPTIDE_INTENSITIES = Path(FN_PEPTIDE_INTENSITIES)

# %%
analysis = AnalyzePeptides(fname=FN_PEPTIDE_INTENSITIES, nrows=None)
analysis.df.columns.name = 'peptide'
analysis.log_transform(np.log2)
analysis
# Out:
# AnalyzePeptides with attributes: M, N, df, index_col, is_log_transformed, is_wide_format, log_fct, stats

# %%
# some date are not possible in the indices
rename_indices_w_wrong_dates = {'20161131_LUMOS1_nLC13_AH_MNT_HeLa_long_03': '20161130_LUMOS1_nLC13_AH_MNT_HeLa_long_03',
                                '20180230_QE10_nLC0_MR_QC_MNT_Hela_12': '20180330_QE10_nLC0_MR_QC_MNT_Hela_12',
                                '20161131_LUMOS1_nLC13_AH_MNT_HeLa_long_01': '20161130_LUMOS1_nLC13_AH_MNT_HeLa_long_01',
                                '20180230_QE10_nLC0_MR_QC_MNT_Hela_11': '20180330_QE10_nLC0_MR_QC_MNT_Hela_11',
                                '20161131_LUMOS1_nLC13_AH_MNT_HeLa_long_02': '20161130_LUMOS1_nLC13_AH_MNT_HeLa_long_02'}
analysis.df.rename(index=rename_indices_w_wrong_dates, inplace=True)

# %% [markdown]
# ### Select N consecutive samples

# %%
analysis.get_consecutive_dates(n_samples=N_SAMPLES)
# Out:
# Get 1000 samples.
# Training data referenced unter: df_1000
# Updated attribute: df
# peptide                                       AAAAAAALQAK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                29.591
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               29.817
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  29.982
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    29.974
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              29.552
# ...                                                   ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02       31.517
# 20190805_QE1_nLC2_AB_MNT_HELA_01                   31.104
# 20190805_QE1_nLC2_AB_MNT_HELA_02                   31.248
# 20190805_QE1_nLC2_AB_MNT_HELA_03                   31.122
# 20190805_QE1_nLC2_AB_MNT_HELA_04                   30.814
#
# peptide                                       AAFDDAIAELDTLSEESYK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        31.264
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       31.354
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          31.211
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            30.238
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      31.966
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               32.278
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           31.747
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           31.923
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           31.802
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           31.892
#
# peptide                                       AAHSEGNTTAGLDMR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    28.098
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   28.132
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      24.357
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        28.022
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  28.165
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           30.832
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       28.999
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       28.643
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       28.260
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       28.546
#
# peptide                                       AAVATFLQSVQVPEFTPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       28.694
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      28.508
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         28.795
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           28.917
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     29.985
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              31.541
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          28.458
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          28.257
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          28.620
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          28.408
#
# peptide                                       AAVEEGIVLGGGCALLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      30.208
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     30.171
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        29.833
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          30.113
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    31.660
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             32.803
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         30.588
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         31.068
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         30.936
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         30.727
#
# peptide                                       AAVPSGASTGIYEALELR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       30.134
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      30.189
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         28.291
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           30.597
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     31.787
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              33.676
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          28.800
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          28.864
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          28.683
#
# peptide                                       AAVPSGASTGIYEALELRDNDK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           31.358
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          31.311
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             32.533
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               31.781
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         31.915
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  31.927
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              32.415
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              32.340
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              32.558
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              32.734
#
# peptide                                       ACANPAAGSVILLENLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      30.430
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     30.412
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        31.257
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          30.620
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    31.792
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             31.906
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         31.270
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         31.672
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         29.854
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         31.699
#
# peptide                                       ACGLVASNLNLKPGECLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       29.440
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      29.410
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         30.998
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           27.377
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     30.077
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              27.631
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          30.077
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          31.636
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          31.661
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          31.578
#
# peptide                                       ADLINNLGTIAK  ...  VVFVFGPDK  \
# Sample ID                                                   ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 31.035  ...     29.047
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                31.034  ...     28.830
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   32.087  ...     29.325
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     31.457  ...     29.409
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               31.479  ...     29.341
# ...                                                    ...  ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02        33.747  ...     31.452
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    32.357  ...     29.504
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    32.466  ...     29.728
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    32.413  ...     29.755
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    32.284  ...     29.747
#
# peptide                                       VVFVFGPDKK  VYALPEDLVEVKPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               27.827          27.149
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              27.624          27.150
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 29.346          28.907
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   27.696          27.622
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                NaN          27.327
# ...                                                  ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02      28.512          29.634
# 20190805_QE1_nLC2_AB_MNT_HELA_01                  29.435          28.424
# 20190805_QE1_nLC2_AB_MNT_HELA_02                  29.741          28.667
# 20190805_QE1_nLC2_AB_MNT_HELA_03                  29.772          28.764
# 20190805_QE1_nLC2_AB_MNT_HELA_04                  29.809          29.158
#
# peptide                                       YADLTEDQLPSCESLK  YDDMAAAMK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     28.446     29.136
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    28.537     28.643
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       29.588     28.434
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         29.104     28.151
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   29.091     29.422
# ...                                                        ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            31.134     30.690
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        29.489     29.702
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        29.647     29.555
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        29.507     29.443
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        29.274     29.575
#
# peptide                                       YDDMAACMK  YDDMATCMK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02              28.936     27.337
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01             29.347     27.980
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                28.369     27.397
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  29.017     27.815
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            29.057     26.068
# ...                                                 ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02     30.142     29.881
# 20190805_QE1_nLC2_AB_MNT_HELA_01                 29.877     28.777
# 20190805_QE1_nLC2_AB_MNT_HELA_02                 29.709     28.592
# 20190805_QE1_nLC2_AB_MNT_HELA_03                 29.544     28.643
# 20190805_QE1_nLC2_AB_MNT_HELA_04                 29.545     28.487
#
# peptide                                       YLAEVACGDDRK  YLDEDTIYHLQPSGR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 28.873           27.724
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                29.179           27.444
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   29.143           27.233
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     29.317           28.027
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               29.129           27.474
# ...                                                    ...              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02        31.508           29.884
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    30.471           27.793
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    30.776           27.955
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    30.481           27.837
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    30.467           27.935
#
# peptide                                       YRVPDVLVADPPIAR
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    28.059
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   28.035
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      29.432
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        28.516
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  28.216
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           29.468
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       29.185
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       29.272
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       29.167
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       29.139
#
# [1000 rows x 1000 columns]

# %%
assert not analysis.df._is_view

# %% [markdown]
# ## Long format
#
# - Data in long format: (peptide, sample_id, intensity)
# - no missing values kept
# -

# %%
analysis.df_long.head()
# Out:
#                                                          intensity
# Sample ID                           peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02 AAAAAAALQAK             29.591
#                                     AAFDDAIAELDTLSEESYK     31.264
#                                     AAHSEGNTTAGLDMR         28.098
#                                     AAVATFLQSVQVPEFTPK      28.694
#                                     AAVEEGIVLGGGCALLR       30.208

# %%
assert analysis.df_long.isna().sum().sum(
) == 0, "There are still missing values in the long format."

# %%
analysis.df_wide.head()
# Out:
# peptide                                AAAAAAALQAK  AAFDDAIAELDTLSEESYK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02         29.591               31.264
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01        29.817               31.354
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01           29.982               31.211
# 20181222_QE9_nLC9_QC_50CM_HeLa1             29.974               30.238
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01       29.552               31.966
#
# peptide                                AAHSEGNTTAGLDMR  AAVATFLQSVQVPEFTPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             28.098              28.694
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            28.132              28.508
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               24.357              28.795
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 28.022              28.917
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01           28.165              29.985
#
# peptide                                AAVEEGIVLGGGCALLR  AAVPSGASTGIYEALELR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               30.208              30.134
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              30.171              30.189
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 29.833              28.291
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   30.113              30.597
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01             31.660              31.787
#
# peptide                                AAVPSGASTGIYEALELRDNDK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    31.358
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   31.311
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      32.533
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        31.781
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  31.915
#
# peptide                                ACANPAAGSVILLENLR  ACGLVASNLNLKPGECLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               30.430              29.440
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              30.412              29.410
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 31.257              30.998
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   30.620              27.377
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01             31.792              30.077
#
# peptide                                ADLINNLGTIAK  ...  VVFVFGPDK  \
# Sample ID                                            ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          31.035  ...     29.047
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         31.034  ...     28.830
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01            32.087  ...     29.325
# 20181222_QE9_nLC9_QC_50CM_HeLa1              31.457  ...     29.409
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        31.479  ...     29.341
#
# peptide                                VVFVFGPDKK  VYALPEDLVEVKPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02        27.827          27.149
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01       27.624          27.150
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01          29.346          28.907
# 20181222_QE9_nLC9_QC_50CM_HeLa1            27.696          27.622
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         NaN          27.327
#
# peptide                                YADLTEDQLPSCESLK  YDDMAAAMK  YDDMAACMK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02              28.446     29.136     28.936
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01             28.537     28.643     29.347
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                29.588     28.434     28.369
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  29.104     28.151     29.017
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            29.091     29.422     29.057
#
# peptide                                YDDMATCMK  YLAEVACGDDRK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02       27.337        28.873
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01      27.980        29.179
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01         27.397        29.143
# 20181222_QE9_nLC9_QC_50CM_HeLa1           27.815        29.317
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01     26.068        29.129
#
# peptide                                YLDEDTIYHLQPSGR  YRVPDVLVADPPIAR
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             27.724           28.059
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            27.444           28.035
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               27.233           29.432
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 28.027           28.516
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01           27.474           28.216
#
# [5 rows x 1000 columns]

# %%
assert analysis.df_wide.isna().sum().sum(
) > 0, "There are no missing values left in the wide format"

# %% [markdown]
# ### Sampling peptides by their frequency (important for later)
#
# - higher count, higher probability to be sampled into training data
# - missing peptides are sampled both into training as well as into validation dataset
# - everything not in training data is validation data

# %%
# freq_per_peptide = analysis.df.unstack().to_frame('intensity').reset_index(1, drop=True)
freq_per_peptide = analysis.df_long['intensity']
freq_per_peptide = freq_per_peptide.notna().groupby(level=1).sum()
print(f"{n_features = }")
# Out:
# n_features = 50

# %% [markdown]
# ### Selecting N
#  - most common
#  - most uncommon

# %%
freq_per_pepitde = freq_per_peptide.sort_values(ascending=False)

if most_common:
    freq_per_pepitde = freq_per_pepitde.iloc[:n_features]
elif most_uncommon:
    freq_per_pepitde = freq_per_pepitde.iloc[-n_features:]
else:
    freq_per_pepitde = freq_per_pepitde.sample(n_features)
    
assert len(freq_per_pepitde.index) == n_features

freq_per_pepitde
# Out:
# peptide
# LYSVSYLLK                   961
# SDIGEVILVGGMTR              994
# GASQAGMTGYGMPR              964
# ALDVMVSTFHK                 999
# QITVNDLPVGR                 999
# KYEQGFITDPVVLSPK            998
# IPEISIQDMTAQVTSPSGK         994
# ETTDTDTADQVIASFK            980
# IIAPPERK                    940
# TIGGGDDSFTTFFCETGAGK        995
# HLNEIDLFHCIDPNDSK           997
# EILVGDVGQTVDDPYATFVK        990
# VVVQVLAEEPEAVLK             996
# EALLSSAVDHGSDEVK            968
# YHTSQSGDEMTSLSEYVSR       1,000
# TPAQYDASELK                 982
# YAPSEAGLHEMDIR              987
# DSNNLCLHFNPR                996
# HQPTAIIAK                   980
# YLMEEDEDAYKK                985
# IRYESLTDPSK                 998
# ISMPDFDLHLK                 999
# TIGTGLVTNTLAMTEEEK          989
# HQEGEIFDTEK                 998
# VFDAIMNFK                   990
# PMFIVNTNVPR               1,000
# VFITDDFHDMMPK               994
# IIYGGSVTGATCK               977
# ALIAAQYSGAQVR               986
# DDEFTHLYTLIVRPDNTYEVK       954
# GAGTGGLGLAVEGPSEAK          944
# VIVVGNPANTNCLTASK           966
# GQAAVQQLQAEGLSPR            995
# GCITIIGGGDTATCCAK           998
# IISNASCTTNCLAPLAK         1,000
# EALTYDGALLGDR               980
# FDDAVVQSDMK                 998
# LLCGLLAER                   973
# ILDSVGIEADDDRLNK          1,000
# IVSRPEELREDDVGTGAGLLEIK     997
# LVIITAGAR                   998
# ETNLDSLPLVDTHSK             975
# SYELPDGQVITIGNER          1,000
# KYEDICPSTHNMDVPNIK        1,000
# DFTVSAMHGDMDQK              997
# FNADEFEDMVAEK               991
# FDTGNLCMVTGGANLGR           999
# LSPPYSSPQEFAQDVGR           995
# HEQILVLDPPTDLK              981
# ELISNSSDALDK                983
# Name: intensity, dtype: int64

# %%
analysis.df = analysis.df[freq_per_pepitde.index]
# ToDo: clean-up other attributes needs to be integrated
del analysis._df_long  # , analysis._df_wide
analysis.df_long
# Out:
#                                                        intensity
# Sample ID                           peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02 LYSVSYLLK             28.338
#                                     SDIGEVILVGGMTR        28.157
#                                     GASQAGMTGYGMPR        28.539
#                                     ALDVMVSTFHK           30.949
#                                     QITVNDLPVGR           29.828
# ...                                                          ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04    DFTVSAMHGDMDQK        30.706
#                                     FNADEFEDMVAEK         30.555
#                                     FDTGNLCMVTGGANLGR     30.138
#                                     LSPPYSSPQEFAQDVGR     26.405
#                                     HEQILVLDPPTDLK        28.024
#
# [49360 rows x 1 columns]

# %% [markdown]
# - biological stock differences in PCA plot. Show differences in models. Only see biological variance

# %% [markdown]
# ## PCA plot of raw data

# %%
fig = analysis.plot_pca()
# Out:
# vaep - ERROR    Could not find LC instrument in 20190418_QX8_JuSc_MA_HeLa_500ng_1
# vaep - ERROR    Could not find LC instrument in 20190422_QX8_JuSc_MA_HeLa_500ng_1
# vaep - ERROR    Could not find LC instrument in 20190425_QX8_JuSc_MA_HeLa_500ng_1
# vaep - ERROR    Could not find LC instrument in 20190501_QX8_MiWi_MA_HeLa_500ng_new
# vaep - ERROR    Could not find LC instrument in 20190502_QX7_ChDe_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190502_QX8_MiWi_MA_HeLa_500ng_new
# vaep - ERROR    Could not find LC instrument in 20190502_QX8_MiWi_MA_HeLa_500ng_old
# vaep - ERROR    Could not find LC instrument in 20190506_QX7_ChDe_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190506_QX8_MiWi_MA_HeLa_500ng_new
# vaep - ERROR    Could not find LC instrument in 20190506_QX8_MiWi_MA_HeLa_500ng_old
# vaep - ERROR    Could not find LC instrument in 20190514_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190520_QX4_JoSw_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190521_QX4_JoSw_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190524_QX4_JoSw_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190526_QX4_LiSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190527_QX4_IgPa_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190530_QX4_IgPa_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190603_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190606_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190607_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190611_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190615_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190617_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190617_QX8_IgPa_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng_190618125902
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng_190619010035
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng_centroid
# vaep - ERROR    Could not find LC instrument in 20190621_QX4_JoMu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190621_QX4_JoMu_MA_HeLa_500ng_190621161214
# vaep - ERROR    Could not find LC instrument in 20190624_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190629_QX4_JiYu_MA_HeLa_500ng_MAX_ALLOWED
# vaep - ERROR    Could not find LC instrument in 20190701_QX4_MePh_MA_HeLa_500ng_MAX_ALLOWED
# vaep - ERROR    Could not find LC instrument in 20190703_QX4_MaTa_MA_HeLa_500ng_MAX_ALLOWED
# vaep - ERROR    Could not find LC instrument in 20190706_QX4_MiWi_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190706_QX4_MiWi_MA_HeLa_500ng_190707003046
# vaep - ERROR    Could not find LC instrument in 20190717_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190718_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190719_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190722_QX4_StEb_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190722_QX8_ChSc_MA_HeLa_500ng_190722174431
# vaep - ERROR    Could not find LC instrument in 20190725_QX2_MePh_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190726_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190731_QX8_ChSc_MA_HeLa_500ng
# Created metadata DataFrame attribute `df_meta`.
# Added proportion of not NA values based on `df` intensities.

# %%
# ToDo add df_meta property
analysis.df_meta.describe()
# Out:
#        prop_not_na
# count    1,000.000
# mean         0.987
# std          0.022
# min          0.840
# 25%          0.980
# 50%          1.000
# 75%          1.000
# max          1.000

# %%
vaep.io_images._savefig(fig, folder /
                        f'pca_plot_raw_data_{analysis.fname_stub}')
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\pca_plot_raw_data_N01000_M00050

# %% [markdown]
# ## Train and Validation data
#
# - use mulitindex for obtaining validation split

# %%
# analysis._df_long = analysis.df_long.reset_index(
# ).set_index(['Sample ID', 'peptide'])
analysis.df_long
# Out:
#                                                        intensity
# Sample ID                           peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02 LYSVSYLLK             28.338
#                                     SDIGEVILVGGMTR        28.157
#                                     GASQAGMTGYGMPR        28.539
#                                     ALDVMVSTFHK           30.949
#                                     QITVNDLPVGR           29.828
# ...                                                          ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04    DFTVSAMHGDMDQK        30.706
#                                     FNADEFEDMVAEK         30.555
#                                     FDTGNLCMVTGGANLGR     30.138
#                                     LSPPYSSPQEFAQDVGR     26.405
#                                     HEQILVLDPPTDLK        28.024
#
# [49360 rows x 1 columns]

# %%
# df_long = analysis.df.unstack().to_frame('intensity').reset_index(1)
analysis.df_train = analysis.df_long.reset_index(0).groupby(
    by='Sample ID',
    level=0
).sample(frac=0.90,
         weights=freq_per_peptide,
         random_state=42)
analysis.df_train = analysis.df_train.reset_index().set_index([
    'Sample ID', 'peptide'])
analysis.df_train
# Out:
#                                                               intensity
# Sample ID                                       peptide
# 20190411_QE6_LC6_AS_QC_MNT_HeLa_02              ALDVMVSTFHK      32.214
# 20190730_QE1_nLC2_GP_MNT_HELA_02                ALDVMVSTFHK      32.347
# 20190624_QE6_LC4_AS_QC_MNT_HeLa_02              ALDVMVSTFHK      29.249
# 20190528_QX2_SeVW_MA_HeLa_500ng_LC05_CTCDoff_1  ALDVMVSTFHK      29.901
# 20190208_QE2_NLC1_AB_QC_MNT_HELA_3              ALDVMVSTFHK      32.522
# ...                                                                 ...
# 20190318_QE2_NLC1_AB_MNT_HELA_06                YLMEEDEDAYKK     30.146
# 20190802_QX7_AlRe_MA_HeLa_Br14_500ng            YLMEEDEDAYKK     29.587
# 20190524_QE4_LC12_IAH_QC_MNT_HeLa_02            YLMEEDEDAYKK     31.313
# 20190701_QE1_nLC13_ANHO_QC_MNT_HELA_03          YLMEEDEDAYKK     29.685
# 20190510_QE2_NLC1_GP_MNT_HELA_01_20190510174108 YLMEEDEDAYKK     28.633
#
# [44424 rows x 1 columns]

# %%
analysis.indices_valid = analysis.df_long.index.difference(
    analysis.df_train.index)
analysis.df_valid = analysis.df_long.loc[analysis.indices_valid]

# %%
assert len(analysis.df_long) == len(analysis.df_train) + len(analysis.df_valid)

# %% [markdown]
# Check that all samples are also in the validation data

# %%
assert analysis.df_train.index.levshape == (N_SAMPLES, n_features)

try:
    assert analysis.df_valid.index.levshape == (N_SAMPLES, n_features)
except AssertionError:
    print(f'Expected shape in validation: {(N_SAMPLES, n_features)}')
    print(f'Shape in validation: {analysis.df_valid.index.levshape}')

analysis.df_train = analysis.df_train.loc[analysis.df_valid.index.levels[0]]
analysis.df_train = analysis.df_train.reset_index().set_index(
    ['Sample ID', 'peptide'])  # update index categories (there is probably a better way)
N_SAMPLES = analysis.df_valid.index.levshape[0]
analysis.df_train.index.levshape, analysis.df_valid.index.levshape
# Out:
# Expected shape in validation: (1000, 50)
# Shape in validation: (996, 50)
# ((996, 50), (996, 50))

# %% [markdown]
# ## Setup DL
#
# - [ ] move all above to separate data notebook

# %%
import vaep.models as models
from vaep.models.cmd import get_args
from vaep.models import ae

args = get_args(batch_size=BATCH_SIZE, epochs=EPOCHS,
                no_cuda=False)  # data transfer to GPU seems slow
kwargs = {'num_workers': 2, 'pin_memory': True} if args.cuda else {}

# torch.manual_seed(args.seed)
device = torch.device("cuda" if args.cuda else "cpu")
device

print(f"{args = }", f"{device = }", sep='\n')
# Out:
# args = Namespace(batch_size=32, cuda=True, epochs=10, log_interval=10, no_cuda=False, seed=43)
# device = device(type='cuda')

# %% [markdown]
# Fastai default device for computation

# %%
import fastai.torch_core
print(f"{torch.cuda.is_available() = }")  # self-documenting python 3.8
fastai.torch_core.defaults
# Out:
# torch.cuda.is_available() = True
# namespace(cpus=12,
#           use_cuda=None,
#           activation=torch.nn.modules.activation.ReLU,
#           callbacks=[fastai.callback.core.TrainEvalCallback,
#                      fastai.learner.Recorder,
#                      fastai.callback.progress.ProgressCallback],
#           lr=0.001)

# %% [markdown]
# ### Comparison data
#
# - first impute first and last row (using n=3 replicate)
# - use pandas interpolate

# %%
analysis.median_train = analysis.df_train['intensity'].unstack().median()
analysis.median_train.name = 'train_median'
analysis.averag_train = analysis.df_train['intensity'].unstack().mean()
analysis.averag_train.name = 'train_average'

df_pred = analysis.df_valid.copy()

df_pred = df_pred.join(analysis.median_train, on='peptide')
df_pred = df_pred.join(analysis.averag_train, on='peptide')


_ = interpolate(wide_df=analysis.df_train['intensity'].unstack())
df_pred = df_pred.join(_)

df_pred
# Out:
#                                                        intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK          30.949
#                                      DSNNLCLHFNPR         30.046
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR        29.496
#                                      GASQAGMTGYGMPR       29.006
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK      28.734
# ...                                                          ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR     26.757
#                                      ILDSVGIEADDDRLNK     31.576
#                                      QITVNDLPVGR          32.130
#                                      TPAQYDASELK          32.338
#                                      YAPSEAGLHEMDIR       29.643
#
#                                                        train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK             32.015
#                                      DSNNLCLHFNPR            30.842
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR           30.535
#                                      GASQAGMTGYGMPR          28.341
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK         29.123
# ...                                                             ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR        27.069
#                                      ILDSVGIEADDDRLNK        31.573
#                                      QITVNDLPVGR             32.300
#                                      TPAQYDASELK             31.807
#                                      YAPSEAGLHEMDIR          29.426
#
#                                                        train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK              31.827
#                                      DSNNLCLHFNPR             30.635
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR            30.473
#                                      GASQAGMTGYGMPR           28.219
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK          29.727
# ...                                                              ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR         27.457
#                                      ILDSVGIEADDDRLNK         31.581
#                                      QITVNDLPVGR              32.204
#                                      TPAQYDASELK              31.638
#                                      YAPSEAGLHEMDIR           29.014
#
#                                                        replicates
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK           31.491
#                                      DSNNLCLHFNPR          30.399
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR         29.931
#                                      GASQAGMTGYGMPR        28.219
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK       30.011
# ...                                                           ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR      26.385
#                                      ILDSVGIEADDDRLNK      31.516
#                                      QITVNDLPVGR           32.349
#                                      TPAQYDASELK           31.604
#                                      YAPSEAGLHEMDIR        29.642
#
# [4936 rows x 4 columns]

# %%
if any(df_pred.isna()):
    print("Consecutive NaNs are not imputed using replicates.")
    display(df_pred.loc[df_pred.isna().any(axis=1)])
# Out:
# Consecutive NaNs are not imputed using replicates.
#                                                                               intensity  \
# Sample ID                                            peptide
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                DSNNLCLHFNPR                30.136
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                     HQEGEIFDTEK                 29.947
# 20190114_QE7_nLC7_AL_QC_MNT_HeLa_01                  IPEISIQDMTAQVTSPSGK         30.848
# 20190118_QE9_nLC9_NHS_MNT_HELA_50cm_03               EILVGDVGQTVDDPYATFVK        33.075
# 20190128_QE3_nLC3_MJ_MNT_HeLa_02                     IRYESLTDPSK                 31.549
# 20190204_QE6_nLC6_MPL_QC_MNT_HeLa_01                 FDTGNLCMVTGGANLGR           29.916
# 20190208_QE2_NLC1_AB_QC_MNT_HELA_3                   ISMPDFDLHLK                 30.005
# 20190214_QE4_LC12_SCL_QC_MNT_HeLa_01                 KYEDICPSTHNMDVPNIK          32.461
# 20190214_QE4_LC12_SCL_QC_MNT_HeLa_02                 KYEDICPSTHNMDVPNIK          32.541
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_16_23   HLNEIDLFHCIDPNDSK           30.262
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01                  GAGTGGLGLAVEGPSEAK          30.458
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01_20190301161023   GAGTGGLGLAVEGPSEAK          30.458
# 20190305_QE4_LC12_JE-IAH_QC_MNT_HeLa_03              IVSRPEELREDDVGTGAGLLEIK     28.002
# 20190318_QE2_NLC1_AB_MNT_HELA_02                     ILDSVGIEADDDRLNK            32.127
# 20190318_QE2_NLC1_AB_MNT_HELA_03                     ALDVMVSTFHK                 32.028
# 20190404_QE7_nLC3_AL_QC_MNT_HeLa_02                  TIGGGDDSFTTFFCETGAGK        27.522
# 20190405_QE1_nLC2_GP_MNT_QC_hela_01                  TIGGGDDSFTTFFCETGAGK        27.839
# 20190502_QE8_nLC14_AGF_QC_MNT_HeLa_01                LVIITAGAR                   31.652
# 20190506_QX8_MiWi_MA_HeLa_500ng_new                  GASQAGMTGYGMPR              24.619
# 20190510_QE2_NLC1_GP_MNT_HELA_02                     HQEGEIFDTEK                 29.596
# 20190513_QE6_LC4_IAH_QC_MNT_HeLa_03                  VFDAIMNFK                   28.999
# 20190513_QE7_nLC7_MEM_QC_MNT_HeLa_03                 VFITDDFHDMMPK               27.601
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                 SDIGEVILVGGMTR              29.887
# 20190522_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14          IISNASCTTNCLAPLAK           34.071
# 20190524_QE4_LC12_IAH_QC_MNT_HeLa_02                 FNADEFEDMVAEK               29.574
# 20190530_QX2_SeVW_MA_HeLa_500ng_LC05_CTCDoff_1       LVIITAGAR                   33.284
# 20190604_QE8_nLC14_ASD_QC_MNT_15cm_Hela_01           GAGTGGLGLAVEGPSEAK          28.111
# 20190609_QX8_MiWi_MA_HeLa_BR14_500ng_190625212127    LYSVSYLLK                   26.889
# 20190613_QX0_MePh_MA_HeLa_500ng_LC07_Stab_02         ELISNSSDALDK                33.041
# 20190618_QX3_LiSc_MA_Hela_500ng_LC15                 ETNLDSLPLVDTHSK             32.012
# 20190619_QE1_nLC2_GP_QC_MNT_HELA_01                  HQPTAIIAK                   32.182
# 20190620_QE2_NLC1_GP_QC_MNT_HELA_01                  TPAQYDASELK                 32.309
# 20190620_QX1_JoMu_MA_HeLa__500ng_LC10                ETNLDSLPLVDTHSK             32.205
# 20190621_QE1_nLC2_ANHO_QC_MNT_HELA_01                ETNLDSLPLVDTHSK             27.885
# 20190621_QX4_JoMu_MA_HeLa_500ng                      LLCGLLAER                   24.183
# 20190624_QE4_nLC12_MM_QC_MNT_HELA_01_20190626192509  KYEQGFITDPVVLSPK            28.608
# 20190625_QE8_nLC14_GP_QC_MNT_15cm_Hela_02            HEQILVLDPPTDLK              28.437
# 20190626_QX6_ChDe_MA_HeLa_500ng_LC09                 VIVVGNPANTNCLTASK           30.464
# 20190627_QX3_MaMu_MA_Hela_500ng_LC15                 LLCGLLAER                   31.269
# 20190628_QE1_nLC13_ANHO_QC_MNT_HELA_03               ETNLDSLPLVDTHSK             28.155
# 20190630_QE9_nLC0_RG_MNT_Hela_MUC_50cm_1             IIYGGSVTGATCK               30.723
# 20190701_QE4_LC12_IAH_QC_MNT_HeLa_01                 DFTVSAMHGDMDQK              31.081
# 20190701_QX2_LiSc_MA_HeLa_500ng_LC05                 IIAPPERK                    32.429
# 20190709_QE1_nLC13_ANHO_QC_MNT_HELA_01               ALIAAQYSGAQVR               29.847
# 20190712_QE8_nLC14_AnMu_QC_MNT_50cm_Hela_01          VFITDDFHDMMPK               28.884
# 20190712_QE9_nLC9_NHS_MNT_HELA_50cm_MUC_01           VFITDDFHDMMPK               28.587
# 20190715_QE4_LC12_IAH_QC_MNT_HeLa_01                 FDDAVVQSDMK                 29.279
# 20190715_QE8_nLC14_RG_QC_MNT_50cm_Hela_02            EALLSSAVDHGSDEVK            30.462
# 20190716_QX6_MaTa_MA_HeLa_500ng_LC09                 HQPTAIIAK                   32.626
# 20190717_QX3_OzKa_MA_Hela_500ng_LC15_190720214645    EALTYDGALLGDR               30.686
# 20190719_QE2_NLC1_ANHO_MNT_HELA_02                   LSPPYSSPQEFAQDVGR           27.287
# 20190722_QE8_nLC0_BDA_QC_HeLa_50cm_02                DDEFTHLYTLIVRPDNTYEVK       30.177
# 20190723_QX1_JoMu_MA_HeLa_500ng_LC10_pack-2000bar    QITVNDLPVGR                 33.070
# 20190726_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_4thcolumn_1 IISNASCTTNCLAPLAK           33.371
# 20190731_QX8_ChSc_MA_HeLa_500ng                      FDDAVVQSDMK                 31.499
# 20190802_QX6_MaTa_MA_HeLa_500ng_LC09                 QITVNDLPVGR                 33.009
# 20190803_QE9_nLC13_RG_SA_HeLa_50cm_300ng             TPAQYDASELK                 31.184
# 20190803_QE9_nLC13_RG_SA_HeLa_50cm_400ng             LYSVSYLLK                   26.381
# 20190803_QX8_AnPi_MA_HeLa_BR14_500ng                 LYSVSYLLK                   27.455
#
#                                                                               train_median  \
# Sample ID                                            peptide
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                DSNNLCLHFNPR                   30.842
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                     HQEGEIFDTEK                    29.886
# 20190114_QE7_nLC7_AL_QC_MNT_HeLa_01                  IPEISIQDMTAQVTSPSGK            29.329
# 20190118_QE9_nLC9_NHS_MNT_HELA_50cm_03               EILVGDVGQTVDDPYATFVK           32.504
# 20190128_QE3_nLC3_MJ_MNT_HeLa_02                     IRYESLTDPSK                    31.829
# 20190204_QE6_nLC6_MPL_QC_MNT_HeLa_01                 FDTGNLCMVTGGANLGR              30.130
# 20190208_QE2_NLC1_AB_QC_MNT_HELA_3                   ISMPDFDLHLK                    29.897
# 20190214_QE4_LC12_SCL_QC_MNT_HeLa_01                 KYEDICPSTHNMDVPNIK             32.340
# 20190214_QE4_LC12_SCL_QC_MNT_HeLa_02                 KYEDICPSTHNMDVPNIK             32.340
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_16_23   HLNEIDLFHCIDPNDSK              30.423
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01                  GAGTGGLGLAVEGPSEAK             29.238
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01_20190301161023   GAGTGGLGLAVEGPSEAK             29.238
# 20190305_QE4_LC12_JE-IAH_QC_MNT_HeLa_03              IVSRPEELREDDVGTGAGLLEIK        29.926
# 20190318_QE2_NLC1_AB_MNT_HELA_02                     ILDSVGIEADDDRLNK               31.573
# 20190318_QE2_NLC1_AB_MNT_HELA_03                     ALDVMVSTFHK                    32.015
# 20190404_QE7_nLC3_AL_QC_MNT_HeLa_02                  TIGGGDDSFTTFFCETGAGK           28.590
# 20190405_QE1_nLC2_GP_MNT_QC_hela_01                  TIGGGDDSFTTFFCETGAGK           28.590
# 20190502_QE8_nLC14_AGF_QC_MNT_HeLa_01                LVIITAGAR                      31.780
# 20190506_QX8_MiWi_MA_HeLa_500ng_new                  GASQAGMTGYGMPR                 28.341
# 20190510_QE2_NLC1_GP_MNT_HELA_02                     HQEGEIFDTEK                    29.886
# 20190513_QE6_LC4_IAH_QC_MNT_HeLa_03                  VFDAIMNFK                      29.261
# 20190513_QE7_nLC7_MEM_QC_MNT_HeLa_03                 VFITDDFHDMMPK                  28.707
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                 SDIGEVILVGGMTR                 28.538
# 20190522_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14          IISNASCTTNCLAPLAK              33.165
# 20190524_QE4_LC12_IAH_QC_MNT_HeLa_02                 FNADEFEDMVAEK                  29.823
# 20190530_QX2_SeVW_MA_HeLa_500ng_LC05_CTCDoff_1       LVIITAGAR                      31.780
# 20190604_QE8_nLC14_ASD_QC_MNT_15cm_Hela_01           GAGTGGLGLAVEGPSEAK             29.238
# 20190609_QX8_MiWi_MA_HeLa_BR14_500ng_190625212127    LYSVSYLLK                      29.205
# 20190613_QX0_MePh_MA_HeLa_500ng_LC07_Stab_02         ELISNSSDALDK                   30.339
# 20190618_QX3_LiSc_MA_Hela_500ng_LC15                 ETNLDSLPLVDTHSK                29.123
# 20190619_QE1_nLC2_GP_QC_MNT_HELA_01                  HQPTAIIAK                      32.232
# 20190620_QE2_NLC1_GP_QC_MNT_HELA_01                  TPAQYDASELK                    31.807
# 20190620_QX1_JoMu_MA_HeLa__500ng_LC10                ETNLDSLPLVDTHSK                29.123
# 20190621_QE1_nLC2_ANHO_QC_MNT_HELA_01                ETNLDSLPLVDTHSK                29.123
# 20190621_QX4_JoMu_MA_HeLa_500ng                      LLCGLLAER                      31.854
# 20190624_QE4_nLC12_MM_QC_MNT_HELA_01_20190626192509  KYEQGFITDPVVLSPK               28.768
# 20190625_QE8_nLC14_GP_QC_MNT_15cm_Hela_02            HEQILVLDPPTDLK                 27.776
# 20190626_QX6_ChDe_MA_HeLa_500ng_LC09                 VIVVGNPANTNCLTASK              29.301
# 20190627_QX3_MaMu_MA_Hela_500ng_LC15                 LLCGLLAER                      31.854
# 20190628_QE1_nLC13_ANHO_QC_MNT_HELA_03               ETNLDSLPLVDTHSK                29.123
# 20190630_QE9_nLC0_RG_MNT_Hela_MUC_50cm_1             IIYGGSVTGATCK                  31.425
# 20190701_QE4_LC12_IAH_QC_MNT_HeLa_01                 DFTVSAMHGDMDQK                 30.338
# 20190701_QX2_LiSc_MA_HeLa_500ng_LC05                 IIAPPERK                       33.599
# 20190709_QE1_nLC13_ANHO_QC_MNT_HELA_01               ALIAAQYSGAQVR                  30.535
# 20190712_QE8_nLC14_AnMu_QC_MNT_50cm_Hela_01          VFITDDFHDMMPK                  28.707
# 20190712_QE9_nLC9_NHS_MNT_HELA_50cm_MUC_01           VFITDDFHDMMPK                  28.707
# 20190715_QE4_LC12_IAH_QC_MNT_HeLa_01                 FDDAVVQSDMK                    29.752
# 20190715_QE8_nLC14_RG_QC_MNT_50cm_Hela_02            EALLSSAVDHGSDEVK               29.758
# 20190716_QX6_MaTa_MA_HeLa_500ng_LC09                 HQPTAIIAK                      32.232
# 20190717_QX3_OzKa_MA_Hela_500ng_LC15_190720214645    EALTYDGALLGDR                  29.077
# 20190719_QE2_NLC1_ANHO_MNT_HELA_02                   LSPPYSSPQEFAQDVGR              27.569
# 20190722_QE8_nLC0_BDA_QC_HeLa_50cm_02                DDEFTHLYTLIVRPDNTYEVK          31.086
# 20190723_QX1_JoMu_MA_HeLa_500ng_LC10_pack-2000bar    QITVNDLPVGR                    32.300
# 20190726_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_4thcolumn_1 IISNASCTTNCLAPLAK              33.165
# 20190731_QX8_ChSc_MA_HeLa_500ng                      FDDAVVQSDMK                    29.752
# 20190802_QX6_MaTa_MA_HeLa_500ng_LC09                 QITVNDLPVGR                    32.300
# 20190803_QE9_nLC13_RG_SA_HeLa_50cm_300ng             TPAQYDASELK                    31.807
# 20190803_QE9_nLC13_RG_SA_HeLa_50cm_400ng             LYSVSYLLK                      29.205
# 20190803_QX8_AnPi_MA_HeLa_BR14_500ng                 LYSVSYLLK                      29.205
#
#                                                                               train_average  \
# Sample ID                                            peptide
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                DSNNLCLHFNPR                    30.635
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                     HQEGEIFDTEK                     30.106
# 20190114_QE7_nLC7_AL_QC_MNT_HeLa_01                  IPEISIQDMTAQVTSPSGK             29.045
# 20190118_QE9_nLC9_NHS_MNT_HELA_50cm_03               EILVGDVGQTVDDPYATFVK            32.252
# 20190128_QE3_nLC3_MJ_MNT_HeLa_02                     IRYESLTDPSK                     31.892
# 20190204_QE6_nLC6_MPL_QC_MNT_HeLa_01                 FDTGNLCMVTGGANLGR               30.074
# 20190208_QE2_NLC1_AB_QC_MNT_HELA_3                   ISMPDFDLHLK                     29.719
# 20190214_QE4_LC12_SCL_QC_MNT_HeLa_01                 KYEDICPSTHNMDVPNIK              32.274
# 20190214_QE4_LC12_SCL_QC_MNT_HeLa_02                 KYEDICPSTHNMDVPNIK              32.274
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_16_23   HLNEIDLFHCIDPNDSK               30.430
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01                  GAGTGGLGLAVEGPSEAK              29.081
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01_20190301161023   GAGTGGLGLAVEGPSEAK              29.081
# 20190305_QE4_LC12_JE-IAH_QC_MNT_HeLa_03              IVSRPEELREDDVGTGAGLLEIK         30.017
# 20190318_QE2_NLC1_AB_MNT_HELA_02                     ILDSVGIEADDDRLNK                31.581
# 20190318_QE2_NLC1_AB_MNT_HELA_03                     ALDVMVSTFHK                     31.827
# 20190404_QE7_nLC3_AL_QC_MNT_HeLa_02                  TIGGGDDSFTTFFCETGAGK            28.419
# 20190405_QE1_nLC2_GP_MNT_QC_hela_01                  TIGGGDDSFTTFFCETGAGK            28.419
# 20190502_QE8_nLC14_AGF_QC_MNT_HeLa_01                LVIITAGAR                       31.729
# 20190506_QX8_MiWi_MA_HeLa_500ng_new                  GASQAGMTGYGMPR                  28.219
# 20190510_QE2_NLC1_GP_MNT_HELA_02                     HQEGEIFDTEK                     30.106
# 20190513_QE6_LC4_IAH_QC_MNT_HeLa_03                  VFDAIMNFK                       29.861
# 20190513_QE7_nLC7_MEM_QC_MNT_HeLa_03                 VFITDDFHDMMPK                   28.898
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                 SDIGEVILVGGMTR                  28.795
# 20190522_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14          IISNASCTTNCLAPLAK               33.003
# 20190524_QE4_LC12_IAH_QC_MNT_HeLa_02                 FNADEFEDMVAEK                   29.692
# 20190530_QX2_SeVW_MA_HeLa_500ng_LC05_CTCDoff_1       LVIITAGAR                       31.729
# 20190604_QE8_nLC14_ASD_QC_MNT_15cm_Hela_01           GAGTGGLGLAVEGPSEAK              29.081
# 20190609_QX8_MiWi_MA_HeLa_BR14_500ng_190625212127    LYSVSYLLK                       28.697
# 20190613_QX0_MePh_MA_HeLa_500ng_LC07_Stab_02         ELISNSSDALDK                    30.678
# 20190618_QX3_LiSc_MA_Hela_500ng_LC15                 ETNLDSLPLVDTHSK                 29.727
# 20190619_QE1_nLC2_GP_QC_MNT_HELA_01                  HQPTAIIAK                       32.042
# 20190620_QE2_NLC1_GP_QC_MNT_HELA_01                  TPAQYDASELK                     31.638
# 20190620_QX1_JoMu_MA_HeLa__500ng_LC10                ETNLDSLPLVDTHSK                 29.727
# 20190621_QE1_nLC2_ANHO_QC_MNT_HELA_01                ETNLDSLPLVDTHSK                 29.727
# 20190621_QX4_JoMu_MA_HeLa_500ng                      LLCGLLAER                       31.710
# 20190624_QE4_nLC12_MM_QC_MNT_HELA_01_20190626192509  KYEQGFITDPVVLSPK                28.783
# 20190625_QE8_nLC14_GP_QC_MNT_15cm_Hela_02            HEQILVLDPPTDLK                  27.687
# 20190626_QX6_ChDe_MA_HeLa_500ng_LC09                 VIVVGNPANTNCLTASK               29.142
# 20190627_QX3_MaMu_MA_Hela_500ng_LC15                 LLCGLLAER                       31.710
# 20190628_QE1_nLC13_ANHO_QC_MNT_HELA_03               ETNLDSLPLVDTHSK                 29.727
# 20190630_QE9_nLC0_RG_MNT_Hela_MUC_50cm_1             IIYGGSVTGATCK                   31.319
# 20190701_QE4_LC12_IAH_QC_MNT_HeLa_01                 DFTVSAMHGDMDQK                  30.296
# 20190701_QX2_LiSc_MA_HeLa_500ng_LC05                 IIAPPERK                        33.304
# 20190709_QE1_nLC13_ANHO_QC_MNT_HELA_01               ALIAAQYSGAQVR                   30.473
# 20190712_QE8_nLC14_AnMu_QC_MNT_50cm_Hela_01          VFITDDFHDMMPK                   28.898
# 20190712_QE9_nLC9_NHS_MNT_HELA_50cm_MUC_01           VFITDDFHDMMPK                   28.898
# 20190715_QE4_LC12_IAH_QC_MNT_HeLa_01                 FDDAVVQSDMK                     29.810
# 20190715_QE8_nLC14_RG_QC_MNT_50cm_Hela_02            EALLSSAVDHGSDEVK                29.845
# 20190716_QX6_MaTa_MA_HeLa_500ng_LC09                 HQPTAIIAK                       32.042
# 20190717_QX3_OzKa_MA_Hela_500ng_LC15_190720214645    EALTYDGALLGDR                   29.071
# 20190719_QE2_NLC1_ANHO_MNT_HELA_02                   LSPPYSSPQEFAQDVGR               27.627
# 20190722_QE8_nLC0_BDA_QC_HeLa_50cm_02                DDEFTHLYTLIVRPDNTYEVK           30.820
# 20190723_QX1_JoMu_MA_HeLa_500ng_LC10_pack-2000bar    QITVNDLPVGR                     32.204
# 20190726_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_4thcolumn_1 IISNASCTTNCLAPLAK               33.003
# 20190731_QX8_ChSc_MA_HeLa_500ng                      FDDAVVQSDMK                     29.810
# 20190802_QX6_MaTa_MA_HeLa_500ng_LC09                 QITVNDLPVGR                     32.204
# 20190803_QE9_nLC13_RG_SA_HeLa_50cm_300ng             TPAQYDASELK                     31.638
# 20190803_QE9_nLC13_RG_SA_HeLa_50cm_400ng             LYSVSYLLK                       28.697
# 20190803_QX8_AnPi_MA_HeLa_BR14_500ng                 LYSVSYLLK                       28.697
#
#                                                                               replicates
# Sample ID                                            peptide
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                DSNNLCLHFNPR                    NaN
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                     HQEGEIFDTEK                     NaN
# 20190114_QE7_nLC7_AL_QC_MNT_HeLa_01                  IPEISIQDMTAQVTSPSGK             NaN
# 20190118_QE9_nLC9_NHS_MNT_HELA_50cm_03               EILVGDVGQTVDDPYATFVK            NaN
# 20190128_QE3_nLC3_MJ_MNT_HeLa_02                     IRYESLTDPSK                     NaN
# 20190204_QE6_nLC6_MPL_QC_MNT_HeLa_01                 FDTGNLCMVTGGANLGR               NaN
# 20190208_QE2_NLC1_AB_QC_MNT_HELA_3                   ISMPDFDLHLK                     NaN
# 20190214_QE4_LC12_SCL_QC_MNT_HeLa_01                 KYEDICPSTHNMDVPNIK              NaN
# 20190214_QE4_LC12_SCL_QC_MNT_HeLa_02                 KYEDICPSTHNMDVPNIK              NaN
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_16_23   HLNEIDLFHCIDPNDSK               NaN
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01                  GAGTGGLGLAVEGPSEAK              NaN
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01_20190301161023   GAGTGGLGLAVEGPSEAK              NaN
# 20190305_QE4_LC12_JE-IAH_QC_MNT_HeLa_03              IVSRPEELREDDVGTGAGLLEIK         NaN
# 20190318_QE2_NLC1_AB_MNT_HELA_02                     ILDSVGIEADDDRLNK                NaN
# 20190318_QE2_NLC1_AB_MNT_HELA_03                     ALDVMVSTFHK                     NaN
# 20190404_QE7_nLC3_AL_QC_MNT_HeLa_02                  TIGGGDDSFTTFFCETGAGK            NaN
# 20190405_QE1_nLC2_GP_MNT_QC_hela_01                  TIGGGDDSFTTFFCETGAGK            NaN
# 20190502_QE8_nLC14_AGF_QC_MNT_HeLa_01                LVIITAGAR                       NaN
# 20190506_QX8_MiWi_MA_HeLa_500ng_new                  GASQAGMTGYGMPR                  NaN
# 20190510_QE2_NLC1_GP_MNT_HELA_02                     HQEGEIFDTEK                     NaN
# 20190513_QE6_LC4_IAH_QC_MNT_HeLa_03                  VFDAIMNFK                       NaN
# 20190513_QE7_nLC7_MEM_QC_MNT_HeLa_03                 VFITDDFHDMMPK                   NaN
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                 SDIGEVILVGGMTR                  NaN
# 20190522_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14          IISNASCTTNCLAPLAK               NaN
# 20190524_QE4_LC12_IAH_QC_MNT_HeLa_02                 FNADEFEDMVAEK                   NaN
# 20190530_QX2_SeVW_MA_HeLa_500ng_LC05_CTCDoff_1       LVIITAGAR                       NaN
# 20190604_QE8_nLC14_ASD_QC_MNT_15cm_Hela_01           GAGTGGLGLAVEGPSEAK              NaN
# 20190609_QX8_MiWi_MA_HeLa_BR14_500ng_190625212127    LYSVSYLLK                       NaN
# 20190613_QX0_MePh_MA_HeLa_500ng_LC07_Stab_02         ELISNSSDALDK                    NaN
# 20190618_QX3_LiSc_MA_Hela_500ng_LC15                 ETNLDSLPLVDTHSK                 NaN
# 20190619_QE1_nLC2_GP_QC_MNT_HELA_01                  HQPTAIIAK                       NaN
# 20190620_QE2_NLC1_GP_QC_MNT_HELA_01                  TPAQYDASELK                     NaN
# 20190620_QX1_JoMu_MA_HeLa__500ng_LC10                ETNLDSLPLVDTHSK                 NaN
# 20190621_QE1_nLC2_ANHO_QC_MNT_HELA_01                ETNLDSLPLVDTHSK                 NaN
# 20190621_QX4_JoMu_MA_HeLa_500ng                      LLCGLLAER                       NaN
# 20190624_QE4_nLC12_MM_QC_MNT_HELA_01_20190626192509  KYEQGFITDPVVLSPK                NaN
# 20190625_QE8_nLC14_GP_QC_MNT_15cm_Hela_02            HEQILVLDPPTDLK                  NaN
# 20190626_QX6_ChDe_MA_HeLa_500ng_LC09                 VIVVGNPANTNCLTASK               NaN
# 20190627_QX3_MaMu_MA_Hela_500ng_LC15                 LLCGLLAER                       NaN
# 20190628_QE1_nLC13_ANHO_QC_MNT_HELA_03               ETNLDSLPLVDTHSK                 NaN
# 20190630_QE9_nLC0_RG_MNT_Hela_MUC_50cm_1             IIYGGSVTGATCK                   NaN
# 20190701_QE4_LC12_IAH_QC_MNT_HeLa_01                 DFTVSAMHGDMDQK                  NaN
# 20190701_QX2_LiSc_MA_HeLa_500ng_LC05                 IIAPPERK                        NaN
# 20190709_QE1_nLC13_ANHO_QC_MNT_HELA_01               ALIAAQYSGAQVR                   NaN
# 20190712_QE8_nLC14_AnMu_QC_MNT_50cm_Hela_01          VFITDDFHDMMPK                   NaN
# 20190712_QE9_nLC9_NHS_MNT_HELA_50cm_MUC_01           VFITDDFHDMMPK                   NaN
# 20190715_QE4_LC12_IAH_QC_MNT_HeLa_01                 FDDAVVQSDMK                     NaN
# 20190715_QE8_nLC14_RG_QC_MNT_50cm_Hela_02            EALLSSAVDHGSDEVK                NaN
# 20190716_QX6_MaTa_MA_HeLa_500ng_LC09                 HQPTAIIAK                       NaN
# 20190717_QX3_OzKa_MA_Hela_500ng_LC15_190720214645    EALTYDGALLGDR                   NaN
# 20190719_QE2_NLC1_ANHO_MNT_HELA_02                   LSPPYSSPQEFAQDVGR               NaN
# 20190722_QE8_nLC0_BDA_QC_HeLa_50cm_02                DDEFTHLYTLIVRPDNTYEVK           NaN
# 20190723_QX1_JoMu_MA_HeLa_500ng_LC10_pack-2000bar    QITVNDLPVGR                     NaN
# 20190726_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_4thcolumn_1 IISNASCTTNCLAPLAK               NaN
# 20190731_QX8_ChSc_MA_HeLa_500ng                      FDDAVVQSDMK                     NaN
# 20190802_QX6_MaTa_MA_HeLa_500ng_LC09                 QITVNDLPVGR                     NaN
# 20190803_QE9_nLC13_RG_SA_HeLa_50cm_300ng             TPAQYDASELK                     NaN
# 20190803_QE9_nLC13_RG_SA_HeLa_50cm_400ng             LYSVSYLLK                       NaN
# 20190803_QX8_AnPi_MA_HeLa_BR14_500ng                 LYSVSYLLK                       NaN

# %% [markdown]
# ## Collaboritive filtering model

# %%
from fastai.collab import CollabDataLoaders, MSELossFlat, Learner
from fastai.collab import EmbeddingDotBias

analysis.collab = Analysis()
collab = analysis.collab
collab.columns = 'peptide,Sample ID,intensity'.split(',')

# %% [markdown]
# Create data view for collaborative filtering
#
# - currently a bit hacky as the splitter does not support predefinded indices (create custum subclass providing splits to internal methods?)
#
# - Use the [`CollabDataLoaders`](https://docs.fast.ai/collab.html#CollabDataLoaders)  similar to the [`TabularDataLoaders`](https://docs.fast.ai/tabular.data.html#TabularDataLoaders).
# - Use the [`IndexSplitter`](https://docs.fast.ai/data.transforms.html#IndexSplitter) and provide splits to whatever is used in `CollabDataLoaders`

# %%
collab.df_train = analysis.df_train.reset_index()
collab.df_valid = analysis.df_valid.reset_index()
collab.df_train.head()
# Out:
#                              Sample ID                peptide  intensity
# 0  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          ALIAAQYSGAQVR     29.414
# 1  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  DDEFTHLYTLIVRPDNTYEVK     31.332
# 2  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02         DFTVSAMHGDMDQK     28.586
# 3  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02       EALLSSAVDHGSDEVK     28.830
# 4  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          EALTYDGALLGDR     27.815

# %%
collab.df_valid.head()
# Out:
#                               Sample ID          peptide  intensity
# 0   20181219_QE3_nLC3_DS_QC_MNT_HeLa_02      ALDVMVSTFHK     30.949
# 1   20181219_QE3_nLC3_DS_QC_MNT_HeLa_02     DSNNLCLHFNPR     30.046
# 2  20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01    ALIAAQYSGAQVR     29.496
# 3  20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01   GASQAGMTGYGMPR     29.006
# 4     20181221_QE8_nLC0_NHS_MNT_HeLa_01  ETNLDSLPLVDTHSK     28.734

# %%
assert (collab.df_train.intensity.isna().sum(),
        collab.df_valid.intensity.isna().sum()) == (0, 0), "Remove missing values."

# %% [markdown]
# Hacky part uses training data `Datasets` from dataloaders to recreate a custom `DataLoaders` instance

# %%
collab.dl_train = CollabDataLoaders.from_df(
    collab.df_train, valid_pct=0.0, user_name='Sample ID', item_name='peptide', rating_name='intensity', bs=args.batch_size, device=device)
collab.dl_valid = CollabDataLoaders.from_df(
    collab.df_valid, valid_pct=0.0, user_name='Sample ID', item_name='peptide', rating_name='intensity', bs=args.batch_size,
    shuffle=False, device=device)
collab.dl_train.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sample ID</th>
#       <th>peptide</th>
#       <th>intensity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20190204_QE6_nLC6_MPL_QC_MNT_HeLa_04</td>
#       <td>VFITDDFHDMMPK</td>
#       <td>28.321</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20190702_QX0_AnBr_MA_HeLa_500ng_LC07_01_190702180001</td>
#       <td>EILVGDVGQTVDDPYATFVK</td>
#       <td>33.391</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20190509_QE2_NLC1_GP_MNT_HELA_01</td>
#       <td>KYEQGFITDPVVLSPK</td>
#       <td>28.641</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20190726_QX8_ChSc_MA_HeLa_500ng</td>
#       <td>IVSRPEELREDDVGTGAGLLEIK</td>
#       <td>32.583</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20181230_QE6_nLC6_CSC_QC_HeLa_03</td>
#       <td>LSPPYSSPQEFAQDVGR</td>
#       <td>27.747</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>20190121_QE4_LC6_IAH_QC_MNT_HeLa_250ng_03</td>
#       <td>IISNASCTTNCLAPLAK</td>
#       <td>33.532</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>20190423_QE8_nLC14_AGF_QC_MNT_HeLa_01_20190430180750</td>
#       <td>ALDVMVSTFHK</td>
#       <td>31.297</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_2</td>
#       <td>HLNEIDLFHCIDPNDSK</td>
#       <td>24.956</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>20190426_QX1_JoMu_MA_HeLa_500ng_LC11</td>
#       <td>DSNNLCLHFNPR</td>
#       <td>31.449</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>20190723_QE4_LC12_IAH_QC_MNT_HeLa_01</td>
#       <td>EALLSSAVDHGSDEVK</td>
#       <td>28.772</td>
#     </tr>
#   </tbody>
# </table>

# %%
from fastai.data.core import DataLoaders
collab.dls = DataLoaders(collab.dl_train.train, collab.dl_valid.train)
if args.cuda:
    collab.dls.cuda()

# %%
collab.dl_valid.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sample ID</th>
#       <th>peptide</th>
#       <th>intensity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20190208_QE2_NLC1_AB_QC_MNT_HELA_2</td>
#       <td>ELISNSSDALDK</td>
#       <td>30.242</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20190426_QX1_JoMu_MA_HeLa_500ng_LC11</td>
#       <td>LYSVSYLLK</td>
#       <td>28.036</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20190502_QX7_ChDe_MA_HeLaBr14_500ng</td>
#       <td>IVSRPEELREDDVGTGAGLLEIK</td>
#       <td>33.486</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20190503_QX1_LiSc_MA_HeLa_500ng_LC10</td>
#       <td>VFDAIMNFK</td>
#       <td>31.359</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20190201_QE10_nLC0_NHS_MNT_HELA_45cm_01</td>
#       <td>GASQAGMTGYGMPR</td>
#       <td>27.141</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>20190201_QE1_nLC2_GP_QC_MNT_HELA_01</td>
#       <td>EALTYDGALLGDR</td>
#       <td>28.108</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>20190207_QE9_nLC9_NHS_MNT_HELA_45cm_Newcolm_01</td>
#       <td>TIGTGLVTNTLAMTEEEK</td>
#       <td>27.743</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>20190315_QE2_NLC1_GP_MNT_HELA_01</td>
#       <td>KYEDICPSTHNMDVPNIK</td>
#       <td>31.987</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>20190710_QE1_nLC13_ANHO_QC_MNT_HELA_01</td>
#       <td>DFTVSAMHGDMDQK</td>
#       <td>30.191</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>20190629_QE8_nLC14_GP_QC_MNT_15cm_Hela_01</td>
#       <td>QITVNDLPVGR</td>
#       <td>31.899</td>
#     </tr>
#   </tbody>
# </table>

# %%
len(collab.dls.classes['Sample ID']), len(collab.dls.classes['peptide'])
# Out:
# (997, 51)

# %%
len(collab.dls.train), len(collab.dls.valid)  # mini-batches
# Out:
# (1382, 155)

# %% [markdown]
# Alternatively to the hacky version, one could use a factory method, but there the sampling/Splitting methods would need to be implemented (not using [`RandomSplitter`](https://docs.fast.ai/data.transforms.html#RandomSplitter) somehow)
#
#  - [`TabDataLoader`](https://docs.fast.ai/tabular.core.html#TabDataLoader)
#  - uses [`TabularPandas`](https://docs.fast.ai/tabular.core.html#TabularPandas)
#
#  > Current problem: No custom splitter can be provided

# %% [markdown]
# ### Model

# %%
collab.model_args = {}
collab.model_args['n_samples'] = len(collab.dls.classes['Sample ID'])
collab.model_args['n_peptides'] = len(collab.dls.classes['peptide'])
collab.model_args['dim_latent_factors'] = latent_dim
collab.model_args['y_range'] = (
    int(analysis.df_train['intensity'].min()), int(analysis.df_train['intensity'].max())+1)

print("Args:")
pprint(collab.model_args)


# from vaep.models.collab import DotProductBias
# model = DotProductBias(**collab.model_args)
model = EmbeddingDotBias.from_classes(
    n_factors=collab.model_args['dim_latent_factors'], classes=collab.dls.classes, y_range=collab.model_args['y_range'])
learn = Learner(dls=collab.dls, model=model, loss_func=MSELossFlat())
if args.cuda:
    learn.cuda()
learn.summary()
# Out:
# Args:
# {'dim_latent_factors': 2,
#  'n_peptides': 51,
#  'n_samples': 997,
#  'y_range': (20, 38)}
# EmbeddingDotBias (Input shape: 32 x 2)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      32 x 2
# Embedding                                 1994       True
# Embedding                                 102        True
# ____________________________________________________________________________
#                      32 x 1
# Embedding                                 997        True
# Embedding                                 51         True
# ____________________________________________________________________________
#
# Total params: 3,144
# Total trainable params: 3,144
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001D66C536040>
# Loss function: FlattenedLoss of MSELoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %% [markdown]
# ### Training

# %%
learn.fit_one_cycle(epochs_max, 5e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.426021</td>
#       <td>1.240089</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.507862</td>
#       <td>0.477302</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.471286</td>
#       <td>0.460707</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.544459</td>
#       <td>0.441807</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.397767</td>
#       <td>0.439586</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.441695</td>
#       <td>0.420181</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.435240</td>
#       <td>0.414824</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.421531</td>
#       <td>0.405282</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.452503</td>
#       <td>0.402932</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.419101</td>
#       <td>0.402654</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
from vaep.models import plot_loss
from fastai import learner
learner.Recorder.plot_loss = plot_loss

fig, ax = plt.subplots(figsize=(15, 8))
ax.set_title('Collab loss: Reconstruction loss.')
learn.recorder.plot_loss(skip_start=5, ax=ax)
vaep.io_images._savefig(fig, name='collab_training',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_training

# %% [markdown]
# ### Evaluation

# %%
collab.dls.valid_ds.items
# Out:
#        Sample ID  peptide  intensity
# 769          155        9     30.242
# 2,188        446       36     28.036
# 2,290        466       30     33.486
# 2,317        470       44     31.359
# 498          108       16     27.141
# ...          ...      ...        ...
# 4,421        900       37     30.280
# 1,114        222        5     30.761
# 1,835        374       38     32.288
# 352           73       27     30.354
# 1,018        203       25     31.256
#
# [4936 rows x 3 columns]

# %%
df_pred = df_pred.reset_index()
pred, target = learn.get_preds()
df_pred['intensity_pred_collab'] = pd.Series(
    pred.flatten().numpy(), index=collab.dls.valid.items.index)

npt.assert_almost_equal(
    actual=collab.dls.valid.items.intensity.to_numpy(),
    desired=target.numpy().flatten()
)


df_pred = analyzers.cast_object_to_category(df_pred)
df_pred.set_index(['Sample ID', 'peptide'], inplace=True)
df_pred
# Out:
#                                                        intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK          30.949
#                                      DSNNLCLHFNPR         30.046
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR        29.496
#                                      GASQAGMTGYGMPR       29.006
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK      28.734
# ...                                                          ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR     26.757
#                                      ILDSVGIEADDDRLNK     31.576
#                                      QITVNDLPVGR          32.130
#                                      TPAQYDASELK          32.338
#                                      YAPSEAGLHEMDIR       29.643
#
#                                                        train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK             32.015
#                                      DSNNLCLHFNPR            30.842
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR           30.535
#                                      GASQAGMTGYGMPR          28.341
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK         29.123
# ...                                                             ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR        27.069
#                                      ILDSVGIEADDDRLNK        31.573
#                                      QITVNDLPVGR             32.300
#                                      TPAQYDASELK             31.807
#                                      YAPSEAGLHEMDIR          29.426
#
#                                                        train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK              31.827
#                                      DSNNLCLHFNPR             30.635
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR            30.473
#                                      GASQAGMTGYGMPR           28.219
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK          29.727
# ...                                                              ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR         27.457
#                                      ILDSVGIEADDDRLNK         31.581
#                                      QITVNDLPVGR              32.204
#                                      TPAQYDASELK              31.638
#                                      YAPSEAGLHEMDIR           29.014
#
#                                                        replicates  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK           31.491
#                                      DSNNLCLHFNPR          30.399
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR         29.931
#                                      GASQAGMTGYGMPR        28.219
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK       30.011
# ...                                                           ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR      26.385
#                                      ILDSVGIEADDDRLNK      31.516
#                                      QITVNDLPVGR           32.349
#                                      TPAQYDASELK           31.604
#                                      YAPSEAGLHEMDIR        29.642
#
#                                                        intensity_pred_collab
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK                      31.059
#                                      DSNNLCLHFNPR                     29.991
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR                    29.835
#                                      GASQAGMTGYGMPR                   27.404
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK                  28.484
# ...                                                                      ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR                 26.802
#                                      ILDSVGIEADDDRLNK                 32.065
#                                      QITVNDLPVGR                      32.164
#                                      TPAQYDASELK                      31.815
#                                      YAPSEAGLHEMDIR                   29.554
#
# [4936 rows x 5 columns]

# %%
assert (abs(target.reshape(-1) - pred.reshape(-1))).sum() / len(target) - \
    (df_pred.intensity - df_pred.intensity_pred_collab).abs().sum() / \
    len(df_pred) < 0.00001

# %% [markdown]
# ### Plot biases and embedding weigths
#
# - visualize relative order of samples and peptides

# %%
from collections import namedtuple
def get_bias(learner, indices, is_item=True) -> pd.Series:
    ret = learner.model.bias(indices.values, is_item=is_item) # user=sample
    return pd.Series(ret, index=indices)

# def get_weigths

CollabIDs = namedtuple("CollabIDs", "sample peptide")

collab.biases = CollabIDs(
    sample=get_bias(learn, indices=analysis.df_train.index.levels[0], is_item=False), # item=peptide
    peptide=get_bias(learn, indices=analysis.df_train.index.levels[1] )
)
collab.biases.sample.head()
# Out:
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02     0.060
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01    0.072
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01       0.227
# 20181222_QE9_nLC9_QC_50CM_HeLa1         0.135
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01   0.176
# dtype: float32

# %%
fig, ax = plt.subplots(figsize=(15, 15))
ax = collab.biases.sample.sort_values().plot(kind='line', rot=90, title='Sample biases', ax=ax)
vaep.io_images._savefig(fig, name='collab_bias_samples',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_bias_samples

# %%
fig, ax = plt.subplots(figsize=(15, 15))
_ = collab.biases.peptide.sort_values().plot(kind='line', rot=90, title='Sample biases', ax=ax)
vaep.io_images._savefig(fig, name='collab_bias_peptides',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_bias_peptides

# %%
def get_weight(learner, indices, is_item=True) -> pd.Series:
    ret = learner.model.weight(indices.values, is_item=is_item) # user=sample
    return pd.DataFrame(ret, index=indices, columns=[f'latent dimension {i+1}' for i in range(ret.shape[-1])])

collab.embeddings = CollabIDs(
    sample=get_weight(learn, indices=analysis.df_train.index.levels[0], is_item=False), # item=peptide
    peptide=get_weight(learn, indices=analysis.df_train.index.levels[1] )
)
collab.embeddings.sample.head()
# Out:
#                                        latent dimension 1  latent dimension 2
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                -0.002              -0.040
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                0.076               0.030
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   0.101              -0.132
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     0.032              -0.059
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               0.067              -0.095

# %%
fig, ax = plt.subplots(figsize=(15, 15))
analyzers.plot_date_map(df=collab.embeddings.sample, fig=fig, ax=ax,
                        dates=analysis.df_meta.date.loc[collab.embeddings.sample.index])
vaep.io_images._savefig(fig, name='collab_latent_by_date',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_latent_by_date

# %%
fig, ax = plt.subplots(figsize=(15, 15))
meta_col = 'ms_instrument'

df_ = collab.embeddings.sample
analyzers.seaborn_scatter(df=df_,
                          fig=fig,
                          ax=ax,
                          meta=analysis.df_meta[meta_col].loc[df_.index],
                          title='2D sample embedding weights by MS instrument')

vaep.io_images._savefig(fig, name='collab_latent_by_ms_instrument',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_latent_by_ms_instrument

# %% [markdown]
# ## Denoising Autoencoder (DAE)

# %% [markdown]
# ### Custom Transforms
#
# - [x] Shift standard normalized data around
#     - Error metrics won't be directly comparable afterwards

# %%
from fastai.tabular.all import *
from vaep.models import ae

from fastai.tabular.core import TabularPandas

# from fastai.callback.core import Callback

from fastai.data.core import DataLoaders

from fastai.learner import Learner
from fastai.losses import MSELossFlat


# https://docs.fast.ai/tabular.core.html#FillStrategy
# from fastai.tabular.core import FillMissing
# from fastai.tabular.core import TabularPandas

# %% [markdown]
# ### DataLoaders

# %%
# revert format
# undo using `stack`
analysis.df_train = analysis.df_train['intensity'].unstack()
analysis.df_valid = analysis.df_valid['intensity'].unstack()
analysis.df_valid.head()
# Out:
# peptide                                ALDVMVSTFHK  ALIAAQYSGAQVR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02         30.949            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01           NaN         29.496
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01              NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01          NaN            NaN
#
# peptide                                DDEFTHLYTLIVRPDNTYEVK  DFTVSAMHGDMDQK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      NaN             NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     NaN             NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        NaN             NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          NaN          28.755
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    NaN             NaN
#
# peptide                                DSNNLCLHFNPR  EALLSSAVDHGSDEVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          30.046               NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            NaN               NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               NaN               NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1              30.354               NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        30.136               NaN
#
# peptide                                EALTYDGALLGDR  EILVGDVGQTVDDPYATFVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02              NaN                   NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01             NaN                   NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                NaN                   NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  NaN                   NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            NaN                   NaN
#
# peptide                                ELISNSSDALDK  ETNLDSLPLVDTHSK  ...  \
# Sample ID                                                             ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             NaN              NaN  ...
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            NaN              NaN  ...
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               NaN           28.734  ...
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 NaN              NaN  ...
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        29.733              NaN  ...
#
# peptide                                TIGGGDDSFTTFFCETGAGK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN
#
# peptide                                TIGTGLVTNTLAMTEEEK  TPAQYDASELK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   NaN          NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  NaN          NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     NaN          NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       NaN          NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 NaN          NaN
#
# peptide                                VFDAIMNFK  VFITDDFHDMMPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01            NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1              NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        NaN            NaN
#
# peptide                                VIVVGNPANTNCLTASK  VVVQVLAEEPEAVLK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  NaN              NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 NaN              NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    NaN              NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      NaN              NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                NaN              NaN
#
# peptide                                YAPSEAGLHEMDIR  YHTSQSGDEMTSLSEYVSR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               NaN                  NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              NaN                  NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01              29.331                  NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   NaN                  NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01             NaN                  NaN
#
# peptide                                YLMEEDEDAYKK
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        23.993
#
# [5 rows x 50 columns]

# %% [markdown]
# Mean and std. dev. from training data

# %%
# norm = Normalize.from_stats(analysis.df_train.mean(), analysis.df_valid.std()) # copy interface?
NORMALIZER = Normalize  # dae.NormalizeShiftedMean

# %% [markdown]
# #### Training data
#
# procs passed to TabluarPandas are handled internally
#   1. not necessarily in order
#   2. with setup call (using current training data)

# %%
procs = [NORMALIZER, FillMissing(add_col=True)]
cont_names = list(analysis.df_train.columns)

to = TabularPandas(analysis.df_train, procs=procs, cont_names=cont_names)
print("Tabular object:", type(to))

to.items  # items reveals data in DataFrame
# Out:
# Tabular object: <class 'fastai.tabular.core.TabularPandas'>
# peptide                                       ALDVMVSTFHK  ALIAAQYSGAQVR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 0.191         -0.997
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.501          0.051
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  -0.300         -0.030
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -5.424         -0.678
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              -1.267         -0.949
# ...                                                   ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02       -1.412          0.686
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    0.200         -0.075
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    0.318          0.108
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    0.508          0.170
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    0.141          0.105
#
# peptide                                       DDEFTHLYTLIVRPDNTYEVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           0.379
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          0.325
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            -0.469
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               0.214
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         1.478
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  0.426
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              0.552
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              0.876
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              0.971
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              0.871
#
# peptide                                       DFTVSAMHGDMDQK  DSNNLCLHFNPR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   -1.286         0.198
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  -1.306        -0.648
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     -0.773         0.098
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        0.029         0.198
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 -1.220         0.198
# ...                                                      ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           0.551        -0.407
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       0.540         0.724
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       0.426         0.960
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       0.029         0.720
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       0.029         0.686
#
# peptide                                       EALLSSAVDHGSDEVK  EALTYDGALLGDR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     -0.778         -1.068
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    -0.998         -1.189
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       -0.800         -0.317
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         -0.558         -0.914
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   -0.824         -0.838
# ...                                                        ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             0.968          0.620
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         0.027         -0.839
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        -0.036         -0.622
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        -0.063          0.004
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         0.086          0.004
#
# peptide                                       EILVGDVGQTVDDPYATFVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         -1.222
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        -1.512
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            0.331
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             -1.002
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       -0.282
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                -0.368
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             0.079
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             0.370
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             0.175
# 20190805_QE1_nLC2_AB_MNT_HELA_04                             0.174
#
# peptide                                       ELISNSSDALDK  ETNLDSLPLVDTHSK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 -0.656           -0.040
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                -0.632           -0.098
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   -0.400           -0.266
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     -0.291            0.457
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               -0.216           -0.165
# ...                                                    ...              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         0.942            1.147
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    -0.534           -0.374
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    -0.369           -0.429
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    -0.350           -0.448
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    -0.216           -0.589
#
# peptide                                       ...  TIGGGDDSFTTFFCETGAGK_na  \
# Sample ID                                     ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02           ...                    False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01          ...                    False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01             ...                    False
# 20181222_QE9_nLC9_QC_50CM_HeLa1               ...                    False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         ...                    False
# ...                                           ...                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02  ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_01              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_02              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_03              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_04              ...                    False
#
# peptide                                       TIGTGLVTNTLAMTEEEK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         False
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              False
#
# peptide                                       TPAQYDASELK_na  VFDAIMNFK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    False         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   False         False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      False         False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        False         False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  False         False
# ...                                                      ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        True         False
#
# peptide                                       VFITDDFHDMMPK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    False
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         False
#
# peptide                                       VIVVGNPANTNCLTASK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                          False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                         False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                              False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                        False
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                 False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                             False
#
# peptide                                       VVVQVLAEEPEAVLK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      False
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           False
#
# peptide                                       YAPSEAGLHEMDIR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     False
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           True
#
# peptide                                       YHTSQSGDEMTSLSEYVSR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          False
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                   False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               False
#
# peptide                                       YLMEEDEDAYKK_na
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    True
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        False
#
# [996 rows x 100 columns]

# %% [markdown]
# Better manuelly apply `Transforms` on `Tabluar` type

# %%
cont_names = list(analysis.df_train.columns)
to = TabularPandas(analysis.df_train, cont_names=cont_names, do_setup=False)

tf_norm = NORMALIZER()
_ = tf_norm.setups(to)  # returns to
tf_fillna = FillMissing(add_col=True)
_ = tf_fillna.setup(to)

print("Tabular object:", type(to))
# _ = (procs[0]).encodes(to)
to.items  # items reveals data in DataFrame
# Out:
# Tabular object: <class 'fastai.tabular.core.TabularPandas'>
# peptide                                       ALDVMVSTFHK  ALIAAQYSGAQVR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 0.202         -0.933
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.456          0.055
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  -0.264         -0.022
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -5.132         -0.632
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              -1.183         -0.888
# ...                                                   ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02       -1.321          0.652
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    0.210         -0.064
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    0.323          0.108
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    0.503          0.166
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    0.154          0.105
#
# peptide                                       DDEFTHLYTLIVRPDNTYEVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           0.380
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          0.329
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            -0.408
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               0.227
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         1.401
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  0.424
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              0.541
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              0.842
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              0.930
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              0.837
#
# peptide                                       DFTVSAMHGDMDQK  DSNNLCLHFNPR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   -1.215         0.209
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  -1.234        -0.593
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     -0.729         0.115
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        0.030         0.209
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 -1.152         0.209
# ...                                                      ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           0.525        -0.364
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       0.514         0.708
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       0.406         0.933
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       0.030         0.705
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       0.030         0.673
#
# peptide                                       EALLSSAVDHGSDEVK  EALTYDGALLGDR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     -0.734         -1.002
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    -0.939         -1.116
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       -0.754         -0.297
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         -0.529         -0.857
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   -0.777         -0.786
# ...                                                        ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             0.895          0.582
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         0.017         -0.788
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        -0.042         -0.583
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        -0.067          0.005
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         0.072          0.005
#
# peptide                                       EILVGDVGQTVDDPYATFVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         -1.132
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        -1.407
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            0.338
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             -0.924
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       -0.242
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                -0.324
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             0.098
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             0.374
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             0.189
# 20190805_QE1_nLC2_AB_MNT_HELA_04                             0.188
#
# peptide                                       ELISNSSDALDK  ETNLDSLPLVDTHSK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 -0.646           -0.073
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                -0.623           -0.127
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   -0.404           -0.285
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     -0.301            0.396
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               -0.230           -0.190
# ...                                                    ...              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         0.862            1.045
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    -0.531           -0.387
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    -0.374           -0.439
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    -0.357           -0.457
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    -0.230           -0.589
#
# peptide                                       ...  TIGGGDDSFTTFFCETGAGK_na  \
# Sample ID                                     ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02           ...                    False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01          ...                    False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01             ...                    False
# 20181222_QE9_nLC9_QC_50CM_HeLa1               ...                    False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         ...                    False
# ...                                           ...                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02  ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_01              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_02              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_03              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_04              ...                    False
#
# peptide                                       TIGTGLVTNTLAMTEEEK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         False
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              False
#
# peptide                                       TPAQYDASELK_na  VFDAIMNFK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    False         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   False         False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      False         False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        False         False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  False         False
# ...                                                      ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        True         False
#
# peptide                                       VFITDDFHDMMPK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    False
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         False
#
# peptide                                       VIVVGNPANTNCLTASK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                          False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                         False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                              False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                        False
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                 False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                             False
#
# peptide                                       VVVQVLAEEPEAVLK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      False
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           False
#
# peptide                                       YAPSEAGLHEMDIR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     False
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           True
#
# peptide                                       YHTSQSGDEMTSLSEYVSR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          False
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                   False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               False
#
# peptide                                       YLMEEDEDAYKK_na
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    True
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        False
#
# [996 rows x 100 columns]

# %% [markdown]
# Check mean and standard deviation after normalization

# %%
to.items.iloc[:, :10].describe()  # not perferct anymore as expected
# Out:
# peptide  ALDVMVSTFHK  ALIAAQYSGAQVR  DDEFTHLYTLIVRPDNTYEVK  DFTVSAMHGDMDQK  \
# count        996.000        996.000                996.000         996.000
# mean           0.020          0.006                  0.028           0.003
# std            0.950          0.942                  0.930           0.947
# min           -5.132         -5.838                 -6.249          -5.623
# 25%           -0.397         -0.375                 -0.308          -0.380
# 50%            0.202          0.055                  0.197           0.030
# 75%            0.605          0.535                  0.561           0.476
# max            1.883          2.091                  1.868           1.995
#
# peptide  DSNNLCLHFNPR  EALLSSAVDHGSDEVK  EALTYDGALLGDR  EILVGDVGQTVDDPYATFVK  \
# count         996.000           996.000        996.000               996.000
# mean            0.022            -0.008          0.001                 0.024
# std             0.949             0.934          0.939                 0.947
# min            -4.905            -4.384         -4.546                -5.618
# 25%            -0.289            -0.454         -0.466                -0.327
# 50%             0.209            -0.063          0.005                 0.219
# 75%             0.587             0.407          0.489                 0.650
# max             1.920             2.086          2.180                 1.719
#
# peptide  ELISNSSDALDK  ETNLDSLPLVDTHSK
# count         996.000          996.000
# mean           -0.027           -0.035
# std             0.944            0.942
# min            -4.765           -2.690
# 25%            -0.514           -0.560
# 50%            -0.230           -0.285
# 75%             0.716            0.792
# max             2.068            2.309

# %% [markdown]
# Mask is added as type bool

# %%
to.items.dtypes.value_counts()
# Out:
# float64   50
# bool      50
# dtype: int64

# %% [markdown]
# with the suffix `_na` where `True` is indicating a missing value replaced by the `FillMissing` transformation

# %%
to.cont_names, to.cat_names
# Out:
# ((#50) ['ALDVMVSTFHK','ALIAAQYSGAQVR','DDEFTHLYTLIVRPDNTYEVK','DFTVSAMHGDMDQK','DSNNLCLHFNPR','EALLSSAVDHGSDEVK','EALTYDGALLGDR','EILVGDVGQTVDDPYATFVK','ELISNSSDALDK','ETNLDSLPLVDTHSK'...],
#  (#50) ['ALDVMVSTFHK_na','ALIAAQYSGAQVR_na','DDEFTHLYTLIVRPDNTYEVK_na','DFTVSAMHGDMDQK_na','DSNNLCLHFNPR_na','EALLSSAVDHGSDEVK_na','EALTYDGALLGDR_na','EILVGDVGQTVDDPYATFVK_na','ELISNSSDALDK_na','ETNLDSLPLVDTHSK_na'...])

# %%
assert len(to.valid) == 0

# %% [markdown]
# #### Validation data
#
# - reuse training data with different mask for evaluation
# - target data is the validation data
#     - switch between training and evaluation mode for setting comparison

# %%
_df_valid = TabularPandas(
    analysis.df_valid, cont_names=analysis.df_valid.columns.tolist())
# assert analysis.df_valid.isna().equals(y_valid.items.isna())
_df_valid = tf_norm.encodes(_df_valid)

# %%
_df_valid.items.iloc[:, :10].describe()
# Out:
# peptide  ALDVMVSTFHK  ALIAAQYSGAQVR  DDEFTHLYTLIVRPDNTYEVK  DFTVSAMHGDMDQK  \
# count        100.000         99.000                 95.000         100.000
# mean           0.077          0.092                 -0.128          -0.031
# std            0.828          0.986                  1.045           0.805
# min           -2.886         -4.603                 -3.591          -2.292
# 25%           -0.340         -0.342                 -0.486          -0.520
# 50%            0.201          0.151                  0.059           0.030
# 75%            0.669          0.618                  0.545           0.483
# max            1.495          1.917                  1.540           1.623
#
# peptide  DSNNLCLHFNPR  EALLSSAVDHGSDEVK  EALTYDGALLGDR  EILVGDVGQTVDDPYATFVK  \
# count         100.000            97.000         98.000                99.000
# mean            0.015            -0.019          0.211                 0.020
# std             0.944             0.924          0.807                 0.916
# min            -2.837            -3.210         -2.917                -2.879
# 25%            -0.484            -0.590         -0.233                -0.480
# 50%             0.249            -0.068          0.069                 0.281
# 75%             0.666             0.477          0.784                 0.701
# max             1.539             1.817          2.149                 1.529
#
# peptide  ELISNSSDALDK  ETNLDSLPLVDTHSK
# count          98.000           97.000
# mean            0.114            0.036
# std             1.007            0.961
# min            -2.735           -1.956
# 25%            -0.658           -0.630
# 50%            -0.220           -0.285
# 75%             1.159            1.157
# max             1.908            1.698

# %%
# Validation dataset
# build validation DataFrame with mask according to validation data
# FillNA values in data as before, but do not add categorical columns (as this is done manuelly)
_valid_df = to.conts  # same data for predictions
_valid_df = _valid_df.join(analysis.df_valid.isna(), rsuffix='_na')  # mask
_valid_df = _valid_df.join(_df_valid.items, rsuffix='_val')  # target
_valid_df
# Out:
# peptide                                       ALDVMVSTFHK  ALIAAQYSGAQVR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 0.202         -0.933
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.456          0.055
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  -0.264         -0.022
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -5.132         -0.632
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              -1.183         -0.888
# ...                                                   ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02       -1.321          0.652
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    0.210         -0.064
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    0.323          0.108
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    0.503          0.166
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    0.154          0.105
#
# peptide                                       DDEFTHLYTLIVRPDNTYEVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           0.380
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          0.329
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            -0.408
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               0.227
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         1.401
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  0.424
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              0.541
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              0.842
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              0.930
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              0.837
#
# peptide                                       DFTVSAMHGDMDQK  DSNNLCLHFNPR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   -1.215         0.209
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  -1.234        -0.593
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     -0.729         0.115
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        0.030         0.209
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 -1.152         0.209
# ...                                                      ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           0.525        -0.364
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       0.514         0.708
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       0.406         0.933
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       0.030         0.705
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       0.030         0.673
#
# peptide                                       EALLSSAVDHGSDEVK  EALTYDGALLGDR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     -0.734         -1.002
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    -0.939         -1.116
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       -0.754         -0.297
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         -0.529         -0.857
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   -0.777         -0.786
# ...                                                        ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             0.895          0.582
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         0.017         -0.788
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        -0.042         -0.583
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        -0.067          0.005
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         0.072          0.005
#
# peptide                                       EILVGDVGQTVDDPYATFVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         -1.132
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        -1.407
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            0.338
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             -0.924
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       -0.242
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                -0.324
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             0.098
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             0.374
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             0.189
# 20190805_QE1_nLC2_AB_MNT_HELA_04                             0.188
#
# peptide                                       ELISNSSDALDK  ETNLDSLPLVDTHSK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 -0.646           -0.073
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                -0.623           -0.127
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   -0.404           -0.285
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     -0.301            0.396
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               -0.230           -0.190
# ...                                                    ...              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         0.862            1.045
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    -0.531           -0.387
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    -0.374           -0.439
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    -0.357           -0.457
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    -0.230           -0.589
#
# peptide                                       ...  TIGGGDDSFTTFFCETGAGK_val  \
# Sample ID                                     ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02           ...                       NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01          ...                       NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01             ...                       NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1               ...                       NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         ...                       NaN
# ...                                           ...                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02  ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04              ...                       NaN
#
# peptide                                       TIGTGLVTNTLAMTEEEK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                            NaN
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              -0.061
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              -0.237
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                 NaN
#
# peptide                                       TPAQYDASELK_val  VFDAIMNFK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     NaN            NaN
# ...                                                       ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        0.849            NaN
#
# peptide                                       VFITDDFHDMMPK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       NaN
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            NaN
#
# peptide                                       VIVVGNPANTNCLTASK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                             NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                 NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           NaN
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                    NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                NaN
#
# peptide                                       VVVQVLAEEPEAVLK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         NaN
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            0.468
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              NaN
#
# peptide                                       YAPSEAGLHEMDIR_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                          NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                         NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          0.227
# 20181222_QE9_nLC9_QC_50CM_HeLa1                              NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                        NaN
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                 NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           0.451
#
# peptide                                       YHTSQSGDEMTSLSEYVSR_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                               NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                              NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                 NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                   NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                             NaN
# ...                                                               ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                      NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                  NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                  NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                  NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                  NaN
#
# peptide                                       YLMEEDEDAYKK_val
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   -4.180
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           NaN
#
# [996 rows x 150 columns]

# %%
# [norm, FillMissing(add_col=False)]  # mask is provided explicitly
procs = None

cont_names = list(analysis.df_train.columns)
cat_names = [f'{s}_na' for s in cont_names]
y_names = [f'{s}_val' for s in cont_names]

splits = None
y_block = None
to_valid = TabularPandas(_valid_df, procs=procs, cat_names=cat_names, cont_names=cont_names,
                         y_names=y_names, splits=splits, y_block=y_block, do_setup=True)
to_valid.items
# Out:
# peptide                                       ALDVMVSTFHK  ALIAAQYSGAQVR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 0.202         -0.933
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.456          0.055
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  -0.264         -0.022
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -5.132         -0.632
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              -1.183         -0.888
# ...                                                   ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02       -1.321          0.652
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    0.210         -0.064
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    0.323          0.108
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    0.503          0.166
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    0.154          0.105
#
# peptide                                       DDEFTHLYTLIVRPDNTYEVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           0.380
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          0.329
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            -0.408
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               0.227
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         1.401
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  0.424
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              0.541
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              0.842
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              0.930
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              0.837
#
# peptide                                       DFTVSAMHGDMDQK  DSNNLCLHFNPR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   -1.215         0.209
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  -1.234        -0.593
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     -0.729         0.115
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        0.030         0.209
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 -1.152         0.209
# ...                                                      ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           0.525        -0.364
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       0.514         0.708
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       0.406         0.933
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       0.030         0.705
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       0.030         0.673
#
# peptide                                       EALLSSAVDHGSDEVK  EALTYDGALLGDR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     -0.734         -1.002
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    -0.939         -1.116
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       -0.754         -0.297
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         -0.529         -0.857
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   -0.777         -0.786
# ...                                                        ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             0.895          0.582
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         0.017         -0.788
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        -0.042         -0.583
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        -0.067          0.005
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         0.072          0.005
#
# peptide                                       EILVGDVGQTVDDPYATFVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         -1.132
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        -1.407
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            0.338
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             -0.924
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       -0.242
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                -0.324
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             0.098
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             0.374
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             0.189
# 20190805_QE1_nLC2_AB_MNT_HELA_04                             0.188
#
# peptide                                       ELISNSSDALDK  ETNLDSLPLVDTHSK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 -0.646           -0.073
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                -0.623           -0.127
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   -0.404           -0.285
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     -0.301            0.396
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               -0.230           -0.190
# ...                                                    ...              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         0.862            1.045
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    -0.531           -0.387
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    -0.374           -0.439
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    -0.357           -0.457
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    -0.230           -0.589
#
# peptide                                       ...  TIGGGDDSFTTFFCETGAGK_val  \
# Sample ID                                     ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02           ...                       NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01          ...                       NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01             ...                       NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1               ...                       NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         ...                       NaN
# ...                                           ...                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02  ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04              ...                       NaN
#
# peptide                                       TIGTGLVTNTLAMTEEEK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                            NaN
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              -0.061
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              -0.237
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                 NaN
#
# peptide                                       TPAQYDASELK_val  VFDAIMNFK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     NaN            NaN
# ...                                                       ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        0.849            NaN
#
# peptide                                       VFITDDFHDMMPK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       NaN
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            NaN
#
# peptide                                       VIVVGNPANTNCLTASK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                             NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                 NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           NaN
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                    NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                NaN
#
# peptide                                       VVVQVLAEEPEAVLK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         NaN
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            0.468
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              NaN
#
# peptide                                       YAPSEAGLHEMDIR_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                          NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                         NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          0.227
# 20181222_QE9_nLC9_QC_50CM_HeLa1                              NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                        NaN
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                 NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           0.451
#
# peptide                                       YHTSQSGDEMTSLSEYVSR_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                               NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                              NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                 NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                   NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                             NaN
# ...                                                               ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                      NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                  NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                  NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                  NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                  NaN
#
# peptide                                       YLMEEDEDAYKK_val
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   -4.180
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           NaN
#
# [996 rows x 150 columns]

# %%
stats_valid = to_valid.targ.iloc[:, :100].describe()
stats_valid
# Out:
# peptide  ALDVMVSTFHK_val  ALIAAQYSGAQVR_val  DDEFTHLYTLIVRPDNTYEVK_val  \
# count            100.000             99.000                     95.000
# mean               0.077              0.092                     -0.128
# std                0.828              0.986                      1.045
# min               -2.886             -4.603                     -3.591
# 25%               -0.340             -0.342                     -0.486
# 50%                0.201              0.151                      0.059
# 75%                0.669              0.618                      0.545
# max                1.495              1.917                      1.540
#
# peptide  DFTVSAMHGDMDQK_val  DSNNLCLHFNPR_val  EALLSSAVDHGSDEVK_val  \
# count               100.000           100.000                97.000
# mean                 -0.031             0.015                -0.019
# std                   0.805             0.944                 0.924
# min                  -2.292            -2.837                -3.210
# 25%                  -0.520            -0.484                -0.590
# 50%                   0.030             0.249                -0.068
# 75%                   0.483             0.666                 0.477
# max                   1.623             1.539                 1.817
#
# peptide  EALTYDGALLGDR_val  EILVGDVGQTVDDPYATFVK_val  ELISNSSDALDK_val  \
# count               98.000                    99.000            98.000
# mean                 0.211                     0.020             0.114
# std                  0.807                     0.916             1.007
# min                 -2.917                    -2.879            -2.735
# 25%                 -0.233                    -0.480            -0.658
# 50%                  0.069                     0.281            -0.220
# 75%                  0.784                     0.701             1.159
# max                  2.149                     1.529             1.908
#
# peptide  ETNLDSLPLVDTHSK_val  ...  TIGGGDDSFTTFFCETGAGK_val  \
# count                 97.000  ...                    99.000
# mean                   0.036  ...                     0.067
# std                    0.961  ...                     0.902
# min                   -1.956  ...                    -2.566
# 25%                   -0.630  ...                    -0.437
# 50%                   -0.285  ...                     0.008
# 75%                    1.157  ...                     0.677
# max                    1.698  ...                     1.937
#
# peptide  TIGTGLVTNTLAMTEEEK_val  TPAQYDASELK_val  VFDAIMNFK_val  \
# count                    99.000           98.000         99.000
# mean                     -0.107           -0.051          0.154
# std                       0.955            1.095          1.061
# min                      -3.869           -4.779         -1.996
# 25%                      -0.602           -0.595         -0.609
# 50%                      -0.124            0.148         -0.327
# 75%                       0.304            0.722          1.363
# max                       1.906            1.598          1.780
#
# peptide  VFITDDFHDMMPK_val  VIVVGNPANTNCLTASK_val  VVVQVLAEEPEAVLK_val  \
# count               99.000                 97.000              100.000
# mean                -0.131                  0.160               -0.024
# std                  1.019                  0.993                1.077
# min                 -3.310                 -3.120               -5.229
# 25%                 -0.788                 -0.329               -0.578
# 50%                 -0.262                  0.285                0.130
# 75%                  0.589                  0.908                0.688
# max                  1.942                  1.775                1.690
#
# peptide  YAPSEAGLHEMDIR_val  YHTSQSGDEMTSLSEYVSR_val  YLMEEDEDAYKK_val
# count                99.000                  100.000            99.000
# mean                 -0.003                   -0.029             0.037
# std                   0.944                    1.011             0.941
# min                  -3.948                   -2.535            -4.180
# 25%                  -0.181                   -0.703            -0.333
# 50%                   0.294                   -0.150             0.196
# 75%                   0.536                    0.749             0.680
# max                   1.355                    2.039             1.398
#
# [8 rows x 50 columns]

# %%
# True = training data ("fill_na" transform sets mask to true in training data where values are replaced)
to_valid.cats
# Out:
# peptide                                       ALDVMVSTFHK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   True
# ...                                                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        True
#
# peptide                                       ALIAAQYSGAQVR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     True
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          True
#
# peptide                                       DDEFTHLYTLIVRPDNTYEVK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                               True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                              True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                 True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                   True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                             True
# ...                                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                      True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                  True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                  True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                  True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                  True
#
# peptide                                       DFTVSAMHGDMDQK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      True
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          False
#
# peptide                                       DSNNLCLHFNPR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   False
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         True
#
# peptide                                       EALLSSAVDHGSDEVK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                          True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                         True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                              True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                        True
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                             True
#
# peptide                                       EALTYDGALLGDR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     True
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         False
#
# peptide                                       EILVGDVGQTVDDPYATFVK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                            True
# ...                                                               ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                 True
#
# peptide                                       ELISNSSDALDK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   False
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         True
#
# peptide                                       ETNLDSLPLVDTHSK_na  ...  \
# Sample ID                                                         ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         True  ...
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        True  ...
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          False  ...
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             True  ...
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       True  ...
# ...                                                          ...  ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            True  ...
#
# peptide                                       TIGGGDDSFTTFFCETGAGK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                            True
# ...                                                               ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                 True
#
# peptide                                       TIGTGLVTNTLAMTEEEK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          True
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                   True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               True
#
# peptide                                       TPAQYDASELK_na  VFDAIMNFK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     True          True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    True          True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       True          True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         True          True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   True          True
# ...                                                      ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       False          True
#
# peptide                                       VFITDDFHDMMPK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     True
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          True
#
# peptide                                       VIVVGNPANTNCLTASK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         True
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              True
#
# peptide                                       VVVQVLAEEPEAVLK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       True
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            True
#
# peptide                                       YAPSEAGLHEMDIR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      True
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          False
#
# peptide                                       YHTSQSGDEMTSLSEYVSR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                             True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                            True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                 True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           True
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                    True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                True
#
# peptide                                       YLMEEDEDAYKK_na
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   False
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         True
#
# [996 rows x 50 columns]

# %%
assert list(to_valid.cat_names) == list(
    _valid_df.select_dtypes(include='bool').columns)  # 'object'
assert to_valid.cats.equals(analysis.df_valid.isna().add_suffix('_na'))

# %% [markdown]
# ### Mix and match dataloaders
#
# - train dataloader in both TabularPandas objects used
# - train dataloader in dataloaders used in both case

# %%
args.batch_size
dl_train = to.dataloaders(shuffle_train=True, shuffle=False,
                          bs=args.batch_size).train  # , after_batch=after_batch)
dl_valid = to_valid.dataloaders(
    shuffle_train=False, shuffle=False, bs=args.batch_size).train

# %%
dls = DataLoaders(dl_train, dl_valid)
b = dls.train.one_batch()
[x.shape for x in b]  # cat, cont, target
# Out:
# [torch.Size([32, 50]), torch.Size([32, 50]), torch.Size([32, 0])]

# %%
dls = DataLoaders(dl_train, dl_valid)
b = dls.valid.one_batch()
[x.shape for x in b]  # cat, cont, target
# Out:
# [torch.Size([32, 50]), torch.Size([32, 50]), torch.Size([32, 50])]

# %% [markdown]
# ### Model
#
# - standard PyTorch Model from before

# %%
M = analysis.df_train.shape[-1]
model = ae.Autoencoder(n_features=M, n_neurons=int(
    M/2), last_decoder_activation=None, dim_latent=latent_dim)

# %% [markdown]
# ### Callbacks
#
# - controll training loop
#     - set what is data
#     - what should be used for evaluation (differs for training and evaluation mode)

# %%
ae.ModelAdapter
# Out:
# vaep.models.ae.ModelAdapter

# %% [markdown]
# ### Learner: Fastai Training Loop

# %%
learn = Learner(dls=dls, model=model,
                loss_func=MSELossFlat(), cbs=ae.ModelAdapter())

# %%
learn.show_training_loop()
# Out:
# Start Fit
#    - before_fit     : [TrainEvalCallback, Recorder, ProgressCallback]
#   Start Epoch Loop
#      - before_epoch   : [Recorder, ProgressCallback]
#     Start Train
#        - before_train   : [TrainEvalCallback, Recorder, ProgressCallback]
#       Start Batch Loop
#          - before_batch   : [ModelAdapter]
#          - after_pred     : [ModelAdapter]
#          - after_loss     : []
#          - before_backward: []
#          - before_step    : []
#          - after_step     : []
#          - after_cancel_batch: []
#          - after_batch    : [TrainEvalCallback, Recorder, ProgressCallback]
#       End Batch Loop
#     End Train
#      - after_cancel_train: [Recorder]
#      - after_train    : [Recorder, ProgressCallback]
#     Start Valid
#        - before_validate: [TrainEvalCallback, ModelAdapter, Recorder, ProgressCallback]
#       Start Batch Loop
#          - **CBs same as train batch**: []
#       End Batch Loop
#     End Valid
#      - after_cancel_validate: [Recorder]
#      - after_validate : [Recorder, ProgressCallback]
#   End Epoch Loop
#    - after_cancel_epoch: []
#    - after_epoch    : [Recorder]
# End Fit
#  - after_cancel_fit: []
#  - after_fit      : [ProgressCallback]

# %%
learn.summary()
# Out:
# Autoencoder (Input shape: 32 x 50)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      32 x 25
# Linear                                    1275       True
# Tanh
# ____________________________________________________________________________
#                      32 x 2
# Linear                                    52         True
# Tanh
# ____________________________________________________________________________
#                      32 x 25
# Linear                                    75         True
# Tanh
# ____________________________________________________________________________
#                      32 x 50
# Linear                                    1300       True
# ____________________________________________________________________________
#
# Total params: 2,702
# Total trainable params: 2,702
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001D66C536040>
# Loss function: FlattenedLoss of MSELoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - ModelAdapter
#   - Recorder
#   - ProgressCallback

# %%
suggested_lr = learn.lr_find()
suggested_lr
# Out:
# SuggestedLRs(valley=0.013182567432522774)

# %% [markdown]
# ### Training

# %%
learn.fit_one_cycle(epochs_max, lr_max=suggested_lr.valley)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.944794</td>
#       <td>0.689589</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.647858</td>
#       <td>0.344155</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.466461</td>
#       <td>0.308917</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.384956</td>
#       <td>0.301918</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.340464</td>
#       <td>0.285868</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.314145</td>
#       <td>0.285941</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.295345</td>
#       <td>0.273876</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.284893</td>
#       <td>0.268750</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.276837</td>
#       <td>0.267274</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.272195</td>
#       <td>0.269358</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# learn.val_preds, learn.val_targets #

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.set_title('DAE loss: Reconstruction loss')
learn.recorder.plot_loss(skip_start=5, ax=ax)
vaep.io_images._savefig(fig, name='dae_training',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\dae_training

# %%
# L(zip(learn.recorder.iters, learn.recorder.values))

# %% [markdown]
# ### Evaluation

# %%
# reorder True: Only 500 predictions returned
pred, target = learn.get_preds(act=noop, concat_dim=0, reorder=False)
len(pred), len(target)
# Out:
# (4936, 4936)

# %% [markdown]
# MSE on transformed data is not too interesting for comparision between models if these use different standardizations

# %%
learn.loss_func(pred, target)  # MSE in transformed space not too interesting
# Out:
# TensorBase(0.2721)

# %%
# check target is in expected order
Y = dls.valid.targ

npt.assert_almost_equal(
    actual=target.numpy(),
    desired=Y.stack().to_numpy()
)

# %%
# import torch
# from fastai.tabular.core import TabularPandas

df_pred['intensity_pred_dae'] = ae.transform_preds(
    pred=pred, index=analysis.df_valid.stack().index, normalizer=tf_norm)
df_pred
# Out:
#                                                        intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK          30.949
#                                      DSNNLCLHFNPR         30.046
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR        29.496
#                                      GASQAGMTGYGMPR       29.006
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK      28.734
# ...                                                          ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR     26.757
#                                      ILDSVGIEADDDRLNK     31.576
#                                      QITVNDLPVGR          32.130
#                                      TPAQYDASELK          32.338
#                                      YAPSEAGLHEMDIR       29.643
#
#                                                        train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK             32.015
#                                      DSNNLCLHFNPR            30.842
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR           30.535
#                                      GASQAGMTGYGMPR          28.341
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK         29.123
# ...                                                             ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR        27.069
#                                      ILDSVGIEADDDRLNK        31.573
#                                      QITVNDLPVGR             32.300
#                                      TPAQYDASELK             31.807
#                                      YAPSEAGLHEMDIR          29.426
#
#                                                        train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK              31.827
#                                      DSNNLCLHFNPR             30.635
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR            30.473
#                                      GASQAGMTGYGMPR           28.219
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK          29.727
# ...                                                              ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR         27.457
#                                      ILDSVGIEADDDRLNK         31.581
#                                      QITVNDLPVGR              32.204
#                                      TPAQYDASELK              31.638
#                                      YAPSEAGLHEMDIR           29.014
#
#                                                        replicates  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK           31.491
#                                      DSNNLCLHFNPR          30.399
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR         29.931
#                                      GASQAGMTGYGMPR        28.219
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK       30.011
# ...                                                           ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR      26.385
#                                      ILDSVGIEADDDRLNK      31.516
#                                      QITVNDLPVGR           32.349
#                                      TPAQYDASELK           31.604
#                                      YAPSEAGLHEMDIR        29.642
#
#                                                        intensity_pred_collab  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK                      31.059
#                                      DSNNLCLHFNPR                     29.991
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR                    29.835
#                                      GASQAGMTGYGMPR                   27.404
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK                  28.484
# ...                                                                      ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR                 26.802
#                                      ILDSVGIEADDDRLNK                 32.065
#                                      QITVNDLPVGR                      32.164
#                                      TPAQYDASELK                      31.815
#                                      YAPSEAGLHEMDIR                   29.554
#
#                                                        intensity_pred_dae
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK                   31.041
#                                      DSNNLCLHFNPR                  30.196
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR                 29.502
#                                      GASQAGMTGYGMPR                27.200
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK               28.416
# ...                                                                   ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR              26.944
#                                      ILDSVGIEADDDRLNK              31.682
#                                      QITVNDLPVGR                   32.270
#                                      TPAQYDASELK                   32.051
#                                      YAPSEAGLHEMDIR                29.733
#
# [4936 rows x 6 columns]

# %% [markdown]
# ### 2D plot of latent space
#
# - 2 dimensional latent space: just plot
# - more than 2 dimensional: PCA, etc

# %%
latent_space = []
for b in dls.valid:
    model_input = b[1]
    latent_space.append(model.encoder(model_input).detach().numpy())

df_dae_latent = build_df_from_pred_batches(latent_space,
                                           index=_df_valid.items.index,
                                           columns=[f'latent dimension {i+1}' for i in range(latent_dim)])
df_dae_latent.head()
# Out:
#                                        latent dimension 1  latent dimension 2
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 0.500              -0.934
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                0.490              -0.935
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   0.834              -0.884
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     0.628              -0.905
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               0.696              -0.923

# %%
fig, ax = plt.subplots(figsize=(15, 15))
analyzers.plot_date_map(df=df_dae_latent, fig=fig, ax=ax,
                        dates=analysis.df_meta.date.loc[df_dae_latent.index])
vaep.io_images._savefig(fig, name='dae_latent_by_date',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\dae_latent_by_date

# %%
fig, ax = plt.subplots(figsize=(15, 15))

meta_col = 'ms_instrument'

analyzers.seaborn_scatter(df=df_dae_latent,
                          fig=fig,
                          ax=ax,
                          meta=analysis.df_meta[meta_col].loc[df_dae_latent.index],
                          title='by MS instrument')

vaep.io_images._savefig(
    fig, name=f'dae_latent_by_{meta_col}', folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\dae_latent_by_ms_instrument

# %% [markdown]
# ## Variational Autoencoder (VAE)

# %% [markdown]
# ### Scikit Learn MinMaxScaler
#
# - [docs](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html)

# %%
from vaep.transform import MinMaxScaler

args_vae = {}
args_vae['SCALER'] = MinMaxScaler
# select initial data: transformed vs not log transformed
scaler = args_vae['SCALER']().fit(analysis.df_train)
scaler.transform(analysis.df_valid.iloc[:5])
# Out:
# peptide                                ALDVMVSTFHK  ALIAAQYSGAQVR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          0.597            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01           NaN          0.628
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01              NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01          NaN            NaN
#
# peptide                                DDEFTHLYTLIVRPDNTYEVK  DFTVSAMHGDMDQK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      NaN             NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     NaN             NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        NaN             NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          NaN           0.594
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    NaN             NaN
#
# peptide                                DSNNLCLHFNPR  EALLSSAVDHGSDEVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02           0.631               NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            NaN               NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               NaN               NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1               0.677               NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         0.645               NaN
#
# peptide                                EALTYDGALLGDR  EILVGDVGQTVDDPYATFVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02              NaN                   NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01             NaN                   NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                NaN                   NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  NaN                   NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            NaN                   NaN
#
# peptide                                ELISNSSDALDK  ETNLDSLPLVDTHSK  ...  \
# Sample ID                                                             ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             NaN              NaN  ...
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            NaN              NaN  ...
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               NaN            0.444  ...
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 NaN              NaN  ...
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         0.604              NaN  ...
#
# peptide                                TIGGGDDSFTTFFCETGAGK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN
#
# peptide                                TIGTGLVTNTLAMTEEEK  TPAQYDASELK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   NaN          NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  NaN          NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     NaN          NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       NaN          NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 NaN          NaN
#
# peptide                                VFDAIMNFK  VFITDDFHDMMPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01            NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1              NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        NaN            NaN
#
# peptide                                VIVVGNPANTNCLTASK  VVVQVLAEEPEAVLK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  NaN              NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 NaN              NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    NaN              NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      NaN              NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                NaN              NaN
#
# peptide                                YAPSEAGLHEMDIR  YHTSQSGDEMTSLSEYVSR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               NaN                  NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              NaN                  NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               0.748                  NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   NaN                  NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01             NaN                  NaN
#
# peptide                                YLMEEDEDAYKK
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         0.020
#
# [5 rows x 50 columns]

# %% [markdown]
# ### DataLoaders
#
# - follow instructions for using plain PyTorch Datasets, see [tutorial](https://docs.fast.ai/tutorial.siamese.html#Preparing-the-data)

# %%
assert all(analysis.df_train.columns == analysis.df_valid.columns)
if not all(analysis.df.columns == analysis.df_train.columns):
    print("analysis.df columns are not the same as analysis.df_train")
    # ToDo: DataLoading has to be cleaned up
    # analysis.df = analysis.df_train.fillna(analysis.df_valid)
# Out:
# analysis.df columns are not the same as analysis.df_train

# %%
from vaep.io.datasets import PeptideDatasetInMemory

FILL_NA = 0.0

train_ds = PeptideDatasetInMemory(data=scaler.transform(
    analysis.df_train).to_numpy(dtype=None), fill_na=FILL_NA)
valid_ds = PeptideDatasetInMemory(data=scaler.transform(analysis.df_train.fillna(analysis.df_valid)).to_numpy(dtype=None),
                                  mask=analysis.df_valid.notna().to_numpy(), fill_na=FILL_NA)

assert (train_ds.peptides == valid_ds.peptides).all()

# %%
dls = DataLoaders.from_dsets(train_ds, valid_ds, n_inp=2)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %% [markdown]
# ### Model

# %%
from torch.nn import Sigmoid

M = analysis.df_train.shape[-1]
model = ae.VAE(n_features=M, n_neurons=int(
    M/2), last_encoder_activation=None, last_decoder_activation=Sigmoid, dim_latent=latent_dim)

# %% [markdown]
# ### Learner

# %%
learn = Learner(dls=dls,
                model=model,
                loss_func=ae.loss_fct_vae,
                cbs=ae.ModelAdapterVAE())

learn.show_training_loop()
learn.summary()
# Out:
# Start Fit
#    - before_fit     : [TrainEvalCallback, Recorder, ProgressCallback]
#   Start Epoch Loop
#      - before_epoch   : [Recorder, ProgressCallback]
#     Start Train
#        - before_train   : [TrainEvalCallback, Recorder, ProgressCallback]
#       Start Batch Loop
#          - before_batch   : [ModelAdapterVAE]
#          - after_pred     : [ModelAdapterVAE]
#          - after_loss     : []
#          - before_backward: []
#          - before_step    : []
#          - after_step     : []
#          - after_cancel_batch: []
#          - after_batch    : [TrainEvalCallback, Recorder, ProgressCallback]
#       End Batch Loop
#     End Train
#      - after_cancel_train: [Recorder]
#      - after_train    : [Recorder, ProgressCallback]
#     Start Valid
#        - before_validate: [TrainEvalCallback, Recorder, ProgressCallback]
#       Start Batch Loop
#          - **CBs same as train batch**: []
#       End Batch Loop
#     End Valid
#      - after_cancel_validate: [Recorder]
#      - after_validate : [Recorder, ProgressCallback]
#   End Epoch Loop
#    - after_cancel_epoch: []
#    - after_epoch    : [Recorder]
# End Fit
#  - after_cancel_fit: []
#  - after_fit      : [ProgressCallback]
# VAE (Input shape: 64 x 50)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      64 x 25
# Linear                                    75         True
# Tanh
# ____________________________________________________________________________
#                      64 x 50
# Linear                                    1300       True
# Sigmoid
# ____________________________________________________________________________
#                      64 x 25
# Linear                                    1275       True
# Tanh
# ____________________________________________________________________________
#                      64 x 4
# Linear                                    104        True
# ____________________________________________________________________________
#
# Total params: 2,754
# Total trainable params: 2,754
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001D66C536040>
# Loss function: <function loss_fct_vae at 0x000001D66C553940>
#
# Callbacks:
#   - TrainEvalCallback
#   - ModelAdapterVAE
#   - Recorder
#   - ProgressCallback

# %% [markdown]
# ### Training

# %%
suggested_lr = learn.lr_find()
suggested_lr
# Out:
# SuggestedLRs(valley=0.001737800776027143)

# %%
learn.fit_one_cycle(epochs_max, lr_max=suggested_lr.valley)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2007.889893</td>
#       <td>218.604111</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1980.962524</td>
#       <td>213.734177</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1939.623169</td>
#       <td>204.017441</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1893.503052</td>
#       <td>198.501846</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1853.009399</td>
#       <td>194.931259</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1821.802002</td>
#       <td>192.881714</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1797.123413</td>
#       <td>191.036530</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1778.493530</td>
#       <td>190.886398</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1765.164673</td>
#       <td>190.703674</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1755.589233</td>
#       <td>190.658005</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.set_title('VAE loss: Reconstruction loss and Kullback-Leiber-Divergence for latent space')
learn.recorder.plot_loss(skip_start=5, ax=ax)
vaep.io_images._savefig(fig, name='vae_training',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\vae_training

# %% [markdown]
# ### Evaluation

# %%
# reorder True: Only 500 predictions returned
pred, target = learn.get_preds(act=noop, concat_dim=0, reorder=False)
len(pred), len(target)
# Out:
# (3, 4936)

# %%
len(pred[0])
# Out:
# 4936

# %%
learn.loss_func(pred, target)
# Out:
# tensor(3016.6853)

# %%
_pred = pd.Series(pred[0], index=analysis.df_valid.stack().index).unstack()
_pred = scaler.inverse_transform(_pred).stack()

df_pred['intensity_pred_vae'] = _pred
df_pred
# Out:
#                                                        intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK          30.949
#                                      DSNNLCLHFNPR         30.046
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR        29.496
#                                      GASQAGMTGYGMPR       29.006
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK      28.734
# ...                                                          ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR     26.757
#                                      ILDSVGIEADDDRLNK     31.576
#                                      QITVNDLPVGR          32.130
#                                      TPAQYDASELK          32.338
#                                      YAPSEAGLHEMDIR       29.643
#
#                                                        train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK             32.015
#                                      DSNNLCLHFNPR            30.842
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR           30.535
#                                      GASQAGMTGYGMPR          28.341
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK         29.123
# ...                                                             ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR        27.069
#                                      ILDSVGIEADDDRLNK        31.573
#                                      QITVNDLPVGR             32.300
#                                      TPAQYDASELK             31.807
#                                      YAPSEAGLHEMDIR          29.426
#
#                                                        train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK              31.827
#                                      DSNNLCLHFNPR             30.635
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR            30.473
#                                      GASQAGMTGYGMPR           28.219
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK          29.727
# ...                                                              ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR         27.457
#                                      ILDSVGIEADDDRLNK         31.581
#                                      QITVNDLPVGR              32.204
#                                      TPAQYDASELK              31.638
#                                      YAPSEAGLHEMDIR           29.014
#
#                                                        replicates  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK           31.491
#                                      DSNNLCLHFNPR          30.399
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR         29.931
#                                      GASQAGMTGYGMPR        28.219
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK       30.011
# ...                                                           ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR      26.385
#                                      ILDSVGIEADDDRLNK      31.516
#                                      QITVNDLPVGR           32.349
#                                      TPAQYDASELK           31.604
#                                      YAPSEAGLHEMDIR        29.642
#
#                                                        intensity_pred_collab  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK                      31.059
#                                      DSNNLCLHFNPR                     29.991
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR                    29.835
#                                      GASQAGMTGYGMPR                   27.404
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK                  28.484
# ...                                                                      ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR                 26.802
#                                      ILDSVGIEADDDRLNK                 32.065
#                                      QITVNDLPVGR                      32.164
#                                      TPAQYDASELK                      31.815
#                                      YAPSEAGLHEMDIR                   29.554
#
#                                                        intensity_pred_dae  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK                   31.041
#                                      DSNNLCLHFNPR                  30.196
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR                 29.502
#                                      GASQAGMTGYGMPR                27.200
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK               28.416
# ...                                                                   ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR              26.944
#                                      ILDSVGIEADDDRLNK              31.682
#                                      QITVNDLPVGR                   32.270
#                                      TPAQYDASELK                   32.051
#                                      YAPSEAGLHEMDIR                29.733
#
#                                                        intensity_pred_vae
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  ALDVMVSTFHK                   31.869
#                                      DSNNLCLHFNPR                  30.797
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALIAAQYSGAQVR                 30.627
#                                      GASQAGMTGYGMPR                28.347
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01    ETNLDSLPLVDTHSK               29.828
# ...                                                                   ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     GQAAVQQLQAEGLSPR              27.594
#                                      ILDSVGIEADDDRLNK              30.776
#                                      QITVNDLPVGR                   31.360
#                                      TPAQYDASELK                   31.242
#                                      YAPSEAGLHEMDIR                29.035
#
# [4936 rows x 7 columns]

# %% [markdown]
# ### Add plot of latent space
#
# - 2 dimensional latent space: just plot
# - more than 2 dimensional: PCA, etc

# %%
latent_space = []
for b in dls.valid:
    model_input = b[0]
    b_mu, b_std = model.get_mu_and_logvar(model_input, detach=True)
    latent_space.append(b_mu)


df_vae_latent = build_df_from_pred_batches(latent_space,
                                           index=_df_valid.items.index,
                                           columns=[f'latent dimension {i+1}' for i in range(latent_dim)])
df_vae_latent.head()
# Out:
#                                        latent dimension 1  latent dimension 2
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                -0.120               0.021
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.083               0.031
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  -0.088              -0.093
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -0.143              -0.003
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              -0.183               0.010

# %%
fig, ax = plt.subplots(figsize=(15, 15))
analyzers.plot_date_map(df=df_vae_latent, fig=fig, ax=ax,
                        dates=analysis.df_meta.date.loc[df_vae_latent.index])
vaep.io_images._savefig(fig, name='vae_latent_by_date',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\vae_latent_by_date

# %%
fig, ax = plt.subplots(figsize=(15, 15))

meta_col = 'ms_instrument'

analyzers.seaborn_scatter(df=df_vae_latent,
                          fig=fig,
                          ax=ax,
                          meta=analysis.df_meta[meta_col].loc[df_vae_latent.index],
                          title='by MS instrument')

vaep.io_images._savefig(
    fig, name=f'vae_latent_by_{meta_col}', folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\vae_latent_by_ms_instrument

# %% [markdown]
# ## Compare the 3 models
#
# - replicates: replace NAs with neighbouring ("close") values
# - train average, median: Replace NA with average or median from training data

# %%
import sklearn.metrics as sklm
pred_columns = df_pred.columns[1:]
scoring = [('MSE', sklm.mean_squared_error),
           ('MAE', sklm.mean_absolute_error)]

y_true = df_pred['intensity']

metrics = {}
for col in pred_columns:
    _y_pred = df_pred[col].dropna()
    if len(df_pred[col]) > len(_y_pred):
        logger.info(
            f"Drop indices for {col}: {[(idx[0], idx[1]) for idx in df_pred[col].index.difference(_y_pred.index)]}")

    metrics[col] = dict(
        [(k, f(y_true=y_true.loc[_y_pred.index], y_pred=_y_pred))
         for k, f in scoring]
    )

metrics = pd.DataFrame(metrics)
metrics.to_csv(folder / f'exp_02_metrics.csv',
               float_format='{:.3f}'.format)
metrics.sort_values(by=[k for k, f in scoring], axis=1)
# Out:
# vaep - INFO     Drop indices for replicates: [('20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01', 'DSNNLCLHFNPR'), ('20181230_QE6_nLC6_CSC_QC_HeLa_03', 'HQEGEIFDTEK'), ('20190114_QE7_nLC7_AL_QC_MNT_HeLa_01', 'IPEISIQDMTAQVTSPSGK'), ('20190118_QE9_nLC9_NHS_MNT_HELA_50cm_03', 'EILVGDVGQTVDDPYATFVK'), ('20190128_QE3_nLC3_MJ_MNT_HeLa_02', 'IRYESLTDPSK'), ('20190204_QE6_nLC6_MPL_QC_MNT_HeLa_01', 'FDTGNLCMVTGGANLGR'), ('20190208_QE2_NLC1_AB_QC_MNT_HELA_3', 'ISMPDFDLHLK'), ('20190214_QE4_LC12_SCL_QC_MNT_HeLa_01', 'KYEDICPSTHNMDVPNIK'), ('20190214_QE4_LC12_SCL_QC_MNT_HeLa_02', 'KYEDICPSTHNMDVPNIK'), ('20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_16_23', 'HLNEIDLFHCIDPNDSK'), ('20190301_QE7_nLC7_DS_QC_MNT_HeLa_01', 'GAGTGGLGLAVEGPSEAK'), ('20190301_QE7_nLC7_DS_QC_MNT_HeLa_01_20190301161023', 'GAGTGGLGLAVEGPSEAK'), ('20190305_QE4_LC12_JE-IAH_QC_MNT_HeLa_03', 'IVSRPEELREDDVGTGAGLLEIK'), ('20190318_QE2_NLC1_AB_MNT_HELA_02', 'ILDSVGIEADDDRLNK'), ('20190318_QE2_NLC1_AB_MNT_HELA_03', 'ALDVMVSTFHK'), ('20190404_QE7_nLC3_AL_QC_MNT_HeLa_02', 'TIGGGDDSFTTFFCETGAGK'), ('20190405_QE1_nLC2_GP_MNT_QC_hela_01', 'TIGGGDDSFTTFFCETGAGK'), ('20190502_QE8_nLC14_AGF_QC_MNT_HeLa_01', 'LVIITAGAR'), ('20190506_QX8_MiWi_MA_HeLa_500ng_new', 'GASQAGMTGYGMPR'), ('20190510_QE2_NLC1_GP_MNT_HELA_02', 'HQEGEIFDTEK'), ('20190513_QE6_LC4_IAH_QC_MNT_HeLa_03', 'VFDAIMNFK'), ('20190513_QE7_nLC7_MEM_QC_MNT_HeLa_03', 'VFITDDFHDMMPK'), ('20190515_QX4_JiYu_MA_HeLa_500ng_BR14', 'SDIGEVILVGGMTR'), ('20190522_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14', 'IISNASCTTNCLAPLAK'), ('20190524_QE4_LC12_IAH_QC_MNT_HeLa_02', 'FNADEFEDMVAEK'), ('20190530_QX2_SeVW_MA_HeLa_500ng_LC05_CTCDoff_1', 'LVIITAGAR'), ('20190604_QE8_nLC14_ASD_QC_MNT_15cm_Hela_01', 'GAGTGGLGLAVEGPSEAK'), ('20190609_QX8_MiWi_MA_HeLa_BR14_500ng_190625212127', 'LYSVSYLLK'), ('20190613_QX0_MePh_MA_HeLa_500ng_LC07_Stab_02', 'ELISNSSDALDK'), ('20190618_QX3_LiSc_MA_Hela_500ng_LC15', 'ETNLDSLPLVDTHSK'), ('20190619_QE1_nLC2_GP_QC_MNT_HELA_01', 'HQPTAIIAK'), ('20190620_QE2_NLC1_GP_QC_MNT_HELA_01', 'TPAQYDASELK'), ('20190620_QX1_JoMu_MA_HeLa__500ng_LC10', 'ETNLDSLPLVDTHSK'), ('20190621_QE1_nLC2_ANHO_QC_MNT_HELA_01', 'ETNLDSLPLVDTHSK'), ('20190621_QX4_JoMu_MA_HeLa_500ng', 'LLCGLLAER'), ('20190624_QE4_nLC12_MM_QC_MNT_HELA_01_20190626192509', 'KYEQGFITDPVVLSPK'), ('20190625_QE8_nLC14_GP_QC_MNT_15cm_Hela_02', 'HEQILVLDPPTDLK'), ('20190626_QX6_ChDe_MA_HeLa_500ng_LC09', 'VIVVGNPANTNCLTASK'), ('20190627_QX3_MaMu_MA_Hela_500ng_LC15', 'LLCGLLAER'), ('20190628_QE1_nLC13_ANHO_QC_MNT_HELA_03', 'ETNLDSLPLVDTHSK'), ('20190630_QE9_nLC0_RG_MNT_Hela_MUC_50cm_1', 'IIYGGSVTGATCK'), ('20190701_QE4_LC12_IAH_QC_MNT_HeLa_01', 'DFTVSAMHGDMDQK'), ('20190701_QX2_LiSc_MA_HeLa_500ng_LC05', 'IIAPPERK'), ('20190709_QE1_nLC13_ANHO_QC_MNT_HELA_01', 'ALIAAQYSGAQVR'), ('20190712_QE8_nLC14_AnMu_QC_MNT_50cm_Hela_01', 'VFITDDFHDMMPK'), ('20190712_QE9_nLC9_NHS_MNT_HELA_50cm_MUC_01', 'VFITDDFHDMMPK'), ('20190715_QE4_LC12_IAH_QC_MNT_HeLa_01', 'FDDAVVQSDMK'), ('20190715_QE8_nLC14_RG_QC_MNT_50cm_Hela_02', 'EALLSSAVDHGSDEVK'), ('20190716_QX6_MaTa_MA_HeLa_500ng_LC09', 'HQPTAIIAK'), ('20190717_QX3_OzKa_MA_Hela_500ng_LC15_190720214645', 'EALTYDGALLGDR'), ('20190719_QE2_NLC1_ANHO_MNT_HELA_02', 'LSPPYSSPQEFAQDVGR'), ('20190722_QE8_nLC0_BDA_QC_HeLa_50cm_02', 'DDEFTHLYTLIVRPDNTYEVK'), ('20190723_QX1_JoMu_MA_HeLa_500ng_LC10_pack-2000bar', 'QITVNDLPVGR'), ('20190726_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_4thcolumn_1', 'IISNASCTTNCLAPLAK'), ('20190731_QX8_ChSc_MA_HeLa_500ng', 'FDDAVVQSDMK'), ('20190802_QX6_MaTa_MA_HeLa_500ng_LC09', 'QITVNDLPVGR'), ('20190803_QE9_nLC13_RG_SA_HeLa_50cm_300ng', 'TPAQYDASELK'), ('20190803_QE9_nLC13_RG_SA_HeLa_50cm_400ng', 'LYSVSYLLK'), ('20190803_QX8_AnPi_MA_HeLa_BR14_500ng', 'LYSVSYLLK')]
#      intensity_pred_collab  intensity_pred_dae  replicates  train_average  \
# MSE                  0.403               0.435       1.394          1.668
# MAE                  0.395               0.419       0.814          0.958
#
#      train_median  intensity_pred_vae
# MSE         1.731               1.772
# MAE         0.942               1.013

# %% [markdown]
# Save final prediction values of validation data for later comparison.

# %%
df_pred.to_csv(folder /
               f"{config.FOLDER_DATA}_valid_pred.csv")

# %% [markdown]
# ## PCA plot for imputed and denoised data
#
# two setups:
#  - impute missing values
#  - additinally change observed values

# %% [markdown]
# # Experiment 02
#
#
# The current approach for creating train, validation and test data sets is to split
# the data in long-format, i.e. one observation is an intensity value from one sample representing one peptide, into the desired splits. In this process missing values are not regarded.
#
# - [x] mask entries in larger dataset in long-format
# - [x] mask peptides based on their frequency in samples (probability of being observed)
# - [x] create *long-format* training data set without masked values for each model
#     - FNN based on embeddings of peptides and samples (long-format **without** missing values)
#     - Denoising AE (wide-format **with** missing values)
#     - VAE (wide-format **with** missing values)
# - [ ] restrict to only a training data split of consective data: Increase number of samples.
#     - focus on best reconstruction performance
#     - mean comparison
#
# ### Collaborative Filtering model
#
# - Cannot accomodate iid assumption of statistical test in current setup for embedding vectors.
#   - if pretrained model should be applied to an new batch of replicates (with a certain condition) one would need to find a way to initialize the sample embeddings without fine-tuning the model

# %%
import logging
from pprint import pprint
import seaborn
import numpy.testing as npt  # fastcore.test functionality

from pathlib import Path


import vaep.io_images
from vaep.pandas import interpolate
from vaep.model import build_df_from_pred_batches

from src.nb_imports import *
from src import metadata
from src.logging import setup_logger

logger = setup_logger(logger=logging.getLogger('vaep'))
logger.info("Experiment 02")

figures = {}  # collection of ax or figures
# Out:
# FOLDER_MQ_TXT_DATA = data\mq_out
# vaep - INFO     Experiment 02

# %%
# None takes all
N_SAMPLES: int = 1000
n_features: int = 50
ADD_TENSORBOARD: bool = False
FN_PEPTIDE_INTENSITIES: Path = (
    config.FOLDER_DATA / 'df_intensities_N07285_M01000')  # 90%
epochs_max = 10
batch_size = 32
latent_dim = 2
most_common: bool = False
most_uncommon: bool = False
out_folder: str = 'poster'
# write to read only config ? namedtuple?

# %%
# Parameters
n_feat = 75
n_epochs = 30
out_folder = "runs/2D"

# %%
BATCH_SIZE, EPOCHS = batch_size, epochs_max
folder = Path(out_folder) / f'feat_{n_features:04d}_epochs_{epochs_max:03d}'
print(f"{folder = }")

if most_common and most_uncommon:
    raise ValueError(f"Cannot be both True: {most_common = } and {most_uncommon = }")
# Out:
# folder = Path('runs/2D/feat_0050_epochs_010')

# %% [markdown]
# ## Raw data

# %%
FN_PEPTIDE_INTENSITIES = Path(FN_PEPTIDE_INTENSITIES)

# %%
analysis = AnalyzePeptides(fname=FN_PEPTIDE_INTENSITIES, nrows=None)
analysis.df.columns.name = 'peptide'
analysis.log_transform(np.log2)
analysis
# Out:
# AnalyzePeptides with attributes: M, N, df, index_col, is_log_transformed, is_wide_format, log_fct, stats

# %%
# some date are not possible in the indices
rename_indices_w_wrong_dates = {'20161131_LUMOS1_nLC13_AH_MNT_HeLa_long_03': '20161130_LUMOS1_nLC13_AH_MNT_HeLa_long_03',
                                '20180230_QE10_nLC0_MR_QC_MNT_Hela_12': '20180330_QE10_nLC0_MR_QC_MNT_Hela_12',
                                '20161131_LUMOS1_nLC13_AH_MNT_HeLa_long_01': '20161130_LUMOS1_nLC13_AH_MNT_HeLa_long_01',
                                '20180230_QE10_nLC0_MR_QC_MNT_Hela_11': '20180330_QE10_nLC0_MR_QC_MNT_Hela_11',
                                '20161131_LUMOS1_nLC13_AH_MNT_HeLa_long_02': '20161130_LUMOS1_nLC13_AH_MNT_HeLa_long_02'}
analysis.df.rename(index=rename_indices_w_wrong_dates, inplace=True)

# %% [markdown]
# ### Select N consecutive samples

# %%
analysis.get_consecutive_dates(n_samples=N_SAMPLES)
# Out:
# Get 1000 samples.
# Training data referenced unter: df_1000
# Updated attribute: df
# peptide                                       AAAAAAALQAK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                29.591
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               29.817
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  29.982
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    29.974
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              29.552
# ...                                                   ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02       31.517
# 20190805_QE1_nLC2_AB_MNT_HELA_01                   31.104
# 20190805_QE1_nLC2_AB_MNT_HELA_02                   31.248
# 20190805_QE1_nLC2_AB_MNT_HELA_03                   31.122
# 20190805_QE1_nLC2_AB_MNT_HELA_04                   30.814
#
# peptide                                       AAFDDAIAELDTLSEESYK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        31.264
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       31.354
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          31.211
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            30.238
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      31.966
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               32.278
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           31.747
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           31.923
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           31.802
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           31.892
#
# peptide                                       AAHSEGNTTAGLDMR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    28.098
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   28.132
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      24.357
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        28.022
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  28.165
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           30.832
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       28.999
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       28.643
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       28.260
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       28.546
#
# peptide                                       AAVATFLQSVQVPEFTPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       28.694
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      28.508
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         28.795
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           28.917
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     29.985
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              31.541
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          28.458
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          28.257
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          28.620
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          28.408
#
# peptide                                       AAVEEGIVLGGGCALLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      30.208
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     30.171
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        29.833
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          30.113
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    31.660
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             32.803
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         30.588
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         31.068
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         30.936
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         30.727
#
# peptide                                       AAVPSGASTGIYEALELR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       30.134
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      30.189
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         28.291
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           30.597
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     31.787
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              33.676
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          28.800
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          28.864
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          28.683
#
# peptide                                       AAVPSGASTGIYEALELRDNDK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           31.358
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          31.311
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             32.533
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               31.781
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         31.915
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  31.927
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              32.415
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              32.340
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              32.558
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              32.734
#
# peptide                                       ACANPAAGSVILLENLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      30.430
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     30.412
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        31.257
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          30.620
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    31.792
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             31.906
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         31.270
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         31.672
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         29.854
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         31.699
#
# peptide                                       ACGLVASNLNLKPGECLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       29.440
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      29.410
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         30.998
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           27.377
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     30.077
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              27.631
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          30.077
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          31.636
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          31.661
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          31.578
#
# peptide                                       ADLINNLGTIAK  ...  VVFVFGPDK  \
# Sample ID                                                   ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 31.035  ...     29.047
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                31.034  ...     28.830
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   32.087  ...     29.325
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     31.457  ...     29.409
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               31.479  ...     29.341
# ...                                                    ...  ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02        33.747  ...     31.452
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    32.357  ...     29.504
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    32.466  ...     29.728
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    32.413  ...     29.755
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    32.284  ...     29.747
#
# peptide                                       VVFVFGPDKK  VYALPEDLVEVKPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               27.827          27.149
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              27.624          27.150
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 29.346          28.907
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   27.696          27.622
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                NaN          27.327
# ...                                                  ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02      28.512          29.634
# 20190805_QE1_nLC2_AB_MNT_HELA_01                  29.435          28.424
# 20190805_QE1_nLC2_AB_MNT_HELA_02                  29.741          28.667
# 20190805_QE1_nLC2_AB_MNT_HELA_03                  29.772          28.764
# 20190805_QE1_nLC2_AB_MNT_HELA_04                  29.809          29.158
#
# peptide                                       YADLTEDQLPSCESLK  YDDMAAAMK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     28.446     29.136
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    28.537     28.643
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       29.588     28.434
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         29.104     28.151
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   29.091     29.422
# ...                                                        ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            31.134     30.690
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        29.489     29.702
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        29.647     29.555
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        29.507     29.443
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        29.274     29.575
#
# peptide                                       YDDMAACMK  YDDMATCMK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02              28.936     27.337
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01             29.347     27.980
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                28.369     27.397
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  29.017     27.815
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            29.057     26.068
# ...                                                 ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02     30.142     29.881
# 20190805_QE1_nLC2_AB_MNT_HELA_01                 29.877     28.777
# 20190805_QE1_nLC2_AB_MNT_HELA_02                 29.709     28.592
# 20190805_QE1_nLC2_AB_MNT_HELA_03                 29.544     28.643
# 20190805_QE1_nLC2_AB_MNT_HELA_04                 29.545     28.487
#
# peptide                                       YLAEVACGDDRK  YLDEDTIYHLQPSGR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 28.873           27.724
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                29.179           27.444
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   29.143           27.233
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     29.317           28.027
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               29.129           27.474
# ...                                                    ...              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02        31.508           29.884
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    30.471           27.793
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    30.776           27.955
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    30.481           27.837
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    30.467           27.935
#
# peptide                                       YRVPDVLVADPPIAR
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    28.059
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   28.035
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      29.432
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        28.516
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  28.216
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           29.468
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       29.185
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       29.272
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       29.167
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       29.139
#
# [1000 rows x 1000 columns]

# %%
assert not analysis.df._is_view

# %% [markdown]
# ## Long format
#
# - Data in long format: (peptide, sample_id, intensity)
# - no missing values kept
# -

# %%
analysis.df_long.head()
# Out:
#                                                          intensity
# Sample ID                           peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02 AAAAAAALQAK             29.591
#                                     AAFDDAIAELDTLSEESYK     31.264
#                                     AAHSEGNTTAGLDMR         28.098
#                                     AAVATFLQSVQVPEFTPK      28.694
#                                     AAVEEGIVLGGGCALLR       30.208

# %%
assert analysis.df_long.isna().sum().sum(
) == 0, "There are still missing values in the long format."

# %%
analysis.df_wide.head()
# Out:
# peptide                                AAAAAAALQAK  AAFDDAIAELDTLSEESYK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02         29.591               31.264
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01        29.817               31.354
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01           29.982               31.211
# 20181222_QE9_nLC9_QC_50CM_HeLa1             29.974               30.238
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01       29.552               31.966
#
# peptide                                AAHSEGNTTAGLDMR  AAVATFLQSVQVPEFTPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             28.098              28.694
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            28.132              28.508
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               24.357              28.795
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 28.022              28.917
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01           28.165              29.985
#
# peptide                                AAVEEGIVLGGGCALLR  AAVPSGASTGIYEALELR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               30.208              30.134
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              30.171              30.189
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 29.833              28.291
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   30.113              30.597
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01             31.660              31.787
#
# peptide                                AAVPSGASTGIYEALELRDNDK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    31.358
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   31.311
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      32.533
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        31.781
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  31.915
#
# peptide                                ACANPAAGSVILLENLR  ACGLVASNLNLKPGECLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               30.430              29.440
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              30.412              29.410
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 31.257              30.998
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   30.620              27.377
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01             31.792              30.077
#
# peptide                                ADLINNLGTIAK  ...  VVFVFGPDK  \
# Sample ID                                            ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          31.035  ...     29.047
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         31.034  ...     28.830
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01            32.087  ...     29.325
# 20181222_QE9_nLC9_QC_50CM_HeLa1              31.457  ...     29.409
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        31.479  ...     29.341
#
# peptide                                VVFVFGPDKK  VYALPEDLVEVKPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02        27.827          27.149
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01       27.624          27.150
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01          29.346          28.907
# 20181222_QE9_nLC9_QC_50CM_HeLa1            27.696          27.622
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         NaN          27.327
#
# peptide                                YADLTEDQLPSCESLK  YDDMAAAMK  YDDMAACMK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02              28.446     29.136     28.936
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01             28.537     28.643     29.347
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                29.588     28.434     28.369
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  29.104     28.151     29.017
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            29.091     29.422     29.057
#
# peptide                                YDDMATCMK  YLAEVACGDDRK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02       27.337        28.873
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01      27.980        29.179
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01         27.397        29.143
# 20181222_QE9_nLC9_QC_50CM_HeLa1           27.815        29.317
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01     26.068        29.129
#
# peptide                                YLDEDTIYHLQPSGR  YRVPDVLVADPPIAR
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             27.724           28.059
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            27.444           28.035
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               27.233           29.432
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 28.027           28.516
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01           27.474           28.216
#
# [5 rows x 1000 columns]

# %%
assert analysis.df_wide.isna().sum().sum(
) > 0, "There are no missing values left in the wide format"

# %% [markdown]
# ### Sampling peptides by their frequency (important for later)
#
# - higher count, higher probability to be sampled into training data
# - missing peptides are sampled both into training as well as into validation dataset
# - everything not in training data is validation data

# %%
# freq_per_peptide = analysis.df.unstack().to_frame('intensity').reset_index(1, drop=True)
freq_per_peptide = analysis.df_long['intensity']
freq_per_peptide = freq_per_peptide.notna().groupby(level=1).sum()
print(f"{n_features = }")
# Out:
# n_features = 50

# %% [markdown]
# ### Selecting N
#  - most common
#  - most uncommon

# %%
freq_per_pepitde = freq_per_peptide.sort_values(ascending=False)

if most_common:
    freq_per_pepitde = freq_per_pepitde.iloc[:n_features]
elif most_uncommon:
    freq_per_pepitde = freq_per_pepitde.iloc[-n_features:]
else:
    freq_per_pepitde = freq_per_pepitde.sample(n_features)
    
assert len(freq_per_pepitde.index) == n_features

freq_per_pepitde
# Out:
# peptide
# GLVLGPIHK                  986
# TEFLSFMNTELAAFTK           994
# YRVPDVLVADPPIAR            970
# TSIAIDTIINQK               993
# IALGIPLPEIK                995
# YALYDATYETK                996
# DHENIVIAK                  986
# AGGAAVVITEPEHTK            989
# GLDVDSLVIEHIQVNK           992
# SYSPYDMLESIRK              954
# DNHLLGTFDLTGIPPAPR         974
# HGESAWNLENR                986
# HLAGLGLTEAIDK              998
# LASTLVHLGEYQAAVDGAR        995
# AIVAIENPADVSVISSR          995
# VFSGLVSTGLK                990
# AFGYYGPLR                  954
# ELVTQQLPHLLK               994
# LPNLTHLNLSGNK              995
# LAAVDATVNQVLASR            996
# VNIIPLIAK                  993
# ISMPDFDLHLK                999
# AAEAAAAPAESAAPAAGEEPSK     993
# ALDTMNFDVIK                979
# GISDLAQHYLMR               999
# GYLGPEQLPDCLK              980
# IAVYSCPFDGMITETK           997
# TIGGGDDSFNTFFSETGAGK     1,000
# SQIFSTASDNQPTVTIK          994
# VSHVSTGGGASLELLEGK         999
# VVHIMDFQR                  984
# NFSDNQLQEGK                986
# NSSYFVEWIPNNVK             984
# SGGMSNELNNIISR             981
# FNAHGDANTIVCNSK            986
# AGKPVICATQMLESMIK          997
# MAPYQGPDAVPGALDYK        1,000
# HLSVNDLPVGR                993
# MTNGFSGADLTEICQR           993
# DAGEGLLAVQITDPEGKPK        989
# VVFVFGPDK                  987
# NPDDITQEEYGEFYK            980
# AAHSEGNTTAGLDMR            967
# VMTIAPGLFGTPLLTSLPEK       993
# TIAPALVSK                  997
# AGVNTVTTLVENKK             966
# EMEENFAVEAANYQDTIGR        979
# LIEEVMIGEDK                985
# GILADEDSSRPVWLK            996
# LATQSNEITIPVTFESR        1,000
# Name: intensity, dtype: int64

# %%
analysis.df = analysis.df[freq_per_pepitde.index]
# ToDo: clean-up other attributes needs to be integrated
del analysis._df_long  # , analysis._df_wide
analysis.df_long
# Out:
#                                                          intensity
# Sample ID                           peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02 GLVLGPIHK               29.275
#                                     TEFLSFMNTELAAFTK        29.808
#                                     YRVPDVLVADPPIAR         28.059
#                                     TSIAIDTIINQK            28.425
#                                     IALGIPLPEIK             29.253
# ...                                                            ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04    AGVNTVTTLVENKK          30.173
#                                     EMEENFAVEAANYQDTIGR     25.611
#                                     LIEEVMIGEDK             29.115
#                                     GILADEDSSRPVWLK         28.379
#                                     LATQSNEITIPVTFESR       31.105
#
# [49408 rows x 1 columns]

# %% [markdown]
# - biological stock differences in PCA plot. Show differences in models. Only see biological variance

# %% [markdown]
# ## PCA plot of raw data

# %%
fig = analysis.plot_pca()
# Out:
# vaep - ERROR    Could not find LC instrument in 20190418_QX8_JuSc_MA_HeLa_500ng_1
# vaep - ERROR    Could not find LC instrument in 20190422_QX8_JuSc_MA_HeLa_500ng_1
# vaep - ERROR    Could not find LC instrument in 20190425_QX8_JuSc_MA_HeLa_500ng_1
# vaep - ERROR    Could not find LC instrument in 20190501_QX8_MiWi_MA_HeLa_500ng_new
# vaep - ERROR    Could not find LC instrument in 20190502_QX7_ChDe_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190502_QX8_MiWi_MA_HeLa_500ng_new
# vaep - ERROR    Could not find LC instrument in 20190502_QX8_MiWi_MA_HeLa_500ng_old
# vaep - ERROR    Could not find LC instrument in 20190506_QX7_ChDe_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190506_QX8_MiWi_MA_HeLa_500ng_new
# vaep - ERROR    Could not find LC instrument in 20190506_QX8_MiWi_MA_HeLa_500ng_old
# vaep - ERROR    Could not find LC instrument in 20190514_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190520_QX4_JoSw_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190521_QX4_JoSw_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190524_QX4_JoSw_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190526_QX4_LiSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190527_QX4_IgPa_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190530_QX4_IgPa_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190603_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190606_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190607_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190611_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190615_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190617_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190617_QX8_IgPa_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng_190618125902
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng_190619010035
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng_centroid
# vaep - ERROR    Could not find LC instrument in 20190621_QX4_JoMu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190621_QX4_JoMu_MA_HeLa_500ng_190621161214
# vaep - ERROR    Could not find LC instrument in 20190624_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190629_QX4_JiYu_MA_HeLa_500ng_MAX_ALLOWED
# vaep - ERROR    Could not find LC instrument in 20190701_QX4_MePh_MA_HeLa_500ng_MAX_ALLOWED
# vaep - ERROR    Could not find LC instrument in 20190703_QX4_MaTa_MA_HeLa_500ng_MAX_ALLOWED
# vaep - ERROR    Could not find LC instrument in 20190706_QX4_MiWi_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190706_QX4_MiWi_MA_HeLa_500ng_190707003046
# vaep - ERROR    Could not find LC instrument in 20190717_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190718_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190719_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190722_QX4_StEb_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190722_QX8_ChSc_MA_HeLa_500ng_190722174431
# vaep - ERROR    Could not find LC instrument in 20190725_QX2_MePh_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190726_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190731_QX8_ChSc_MA_HeLa_500ng
# Created metadata DataFrame attribute `df_meta`.
# Added proportion of not NA values based on `df` intensities.

# %%
# ToDo add df_meta property
analysis.df_meta.describe()
# Out:
#        prop_not_na
# count    1,000.000
# mean         0.988
# std          0.019
# min          0.880
# 25%          0.980
# 50%          1.000
# 75%          1.000
# max          1.000

# %%
vaep.io_images._savefig(fig, folder /
                        f'pca_plot_raw_data_{analysis.fname_stub}')
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\pca_plot_raw_data_N01000_M00050

# %% [markdown]
# ## Train and Validation data
#
# - use mulitindex for obtaining validation split

# %%
# analysis._df_long = analysis.df_long.reset_index(
# ).set_index(['Sample ID', 'peptide'])
analysis.df_long
# Out:
#                                                          intensity
# Sample ID                           peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02 GLVLGPIHK               29.275
#                                     TEFLSFMNTELAAFTK        29.808
#                                     YRVPDVLVADPPIAR         28.059
#                                     TSIAIDTIINQK            28.425
#                                     IALGIPLPEIK             29.253
# ...                                                            ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04    AGVNTVTTLVENKK          30.173
#                                     EMEENFAVEAANYQDTIGR     25.611
#                                     LIEEVMIGEDK             29.115
#                                     GILADEDSSRPVWLK         28.379
#                                     LATQSNEITIPVTFESR       31.105
#
# [49408 rows x 1 columns]

# %%
# df_long = analysis.df.unstack().to_frame('intensity').reset_index(1)
analysis.df_train = analysis.df_long.reset_index(0).groupby(
    by='Sample ID',
    level=0
).sample(frac=0.90,
         weights=freq_per_peptide,
         random_state=42)
analysis.df_train = analysis.df_train.reset_index().set_index([
    'Sample ID', 'peptide'])
analysis.df_train
# Out:
#                                                                             intensity
# Sample ID                                           peptide
# 20190411_QE3_nLC5_DS_QC_MNT_HeLa_01                 AAEAAAAPAESAAPAAGEEPSK     28.643
# 20190730_QE6_nLC4_MPL_QC_MNT_HeLa_01                AAEAAAAPAESAAPAAGEEPSK     28.777
# 20190624_QE4_nLC12_MM_QC_MNT_HELA_01_20190625144904 AAEAAAAPAESAAPAAGEEPSK     28.355
# 20190527_QX4_IgPa_MA_HeLa_500ng                     AAEAAAAPAESAAPAAGEEPSK     29.058
# 20190208_QE2_NLC1_AB_QC_MNT_HELA_2                  AAEAAAAPAESAAPAAGEEPSK     29.053
# ...                                                                               ...
# 20190628_QE1_nLC13_ANHO_QC_MNT_HELA_01              YRVPDVLVADPPIAR            28.437
# 20190115_QE5_nLC5_RJC_MNT_HeLa_02                   YRVPDVLVADPPIAR            29.303
# 20190523_QX3_LiSc_MA_Hela_500ng_LC15                YRVPDVLVADPPIAR            29.107
# 20190718_QX6_MaTa_MA_HeLa_500ng_LC09                YRVPDVLVADPPIAR            30.302
# 20190131_QE10_nLC0_NHS_MNT_HELA_50cm_01             YRVPDVLVADPPIAR            28.916
#
# [44468 rows x 1 columns]

# %%
analysis.indices_valid = analysis.df_long.index.difference(
    analysis.df_train.index)
analysis.df_valid = analysis.df_long.loc[analysis.indices_valid]

# %%
assert len(analysis.df_long) == len(analysis.df_train) + len(analysis.df_valid)

# %% [markdown]
# Check that all samples are also in the validation data

# %%
assert analysis.df_train.index.levshape == (N_SAMPLES, n_features)

try:
    assert analysis.df_valid.index.levshape == (N_SAMPLES, n_features)
except AssertionError:
    print(f'Expected shape in validation: {(N_SAMPLES, n_features)}')
    print(f'Shape in validation: {analysis.df_valid.index.levshape}')

analysis.df_train = analysis.df_train.loc[analysis.df_valid.index.levels[0]]
analysis.df_train = analysis.df_train.reset_index().set_index(
    ['Sample ID', 'peptide'])  # update index categories (there is probably a better way)
N_SAMPLES = analysis.df_valid.index.levshape[0]
analysis.df_train.index.levshape, analysis.df_valid.index.levshape
# Out:
# Expected shape in validation: (1000, 50)
# Shape in validation: (997, 50)
# ((997, 50), (997, 50))

# %% [markdown]
# ## Setup DL
#
# - [ ] move all above to separate data notebook

# %%
import vaep.models as models
from vaep.models.cmd import get_args
from vaep.models import ae

args = get_args(batch_size=BATCH_SIZE, epochs=EPOCHS,
                no_cuda=False)  # data transfer to GPU seems slow
kwargs = {'num_workers': 2, 'pin_memory': True} if args.cuda else {}

# torch.manual_seed(args.seed)
device = torch.device("cuda" if args.cuda else "cpu")
device

print(f"{args = }", f"{device = }", sep='\n')
# Out:
# args = Namespace(batch_size=32, cuda=True, epochs=10, log_interval=10, no_cuda=False, seed=43)
# device = device(type='cuda')

# %% [markdown]
# Fastai default device for computation

# %%
import fastai.torch_core
print(f"{torch.cuda.is_available() = }")  # self-documenting python 3.8
fastai.torch_core.defaults
# Out:
# torch.cuda.is_available() = True
# namespace(cpus=12,
#           use_cuda=None,
#           activation=torch.nn.modules.activation.ReLU,
#           callbacks=[fastai.callback.core.TrainEvalCallback,
#                      fastai.learner.Recorder,
#                      fastai.callback.progress.ProgressCallback],
#           lr=0.001)

# %% [markdown]
# ### Comparison data
#
# - first impute first and last row (using n=3 replicate)
# - use pandas interpolate

# %%
analysis.median_train = analysis.df_train['intensity'].unstack().median()
analysis.median_train.name = 'train_median'
analysis.averag_train = analysis.df_train['intensity'].unstack().mean()
analysis.averag_train.name = 'train_average'

df_pred = analysis.df_valid.copy()

df_pred = df_pred.join(analysis.median_train, on='peptide')
df_pred = df_pred.join(analysis.averag_train, on='peptide')


_ = interpolate(wide_df=analysis.df_train['intensity'].unstack())
df_pred = df_pred.join(_)

df_pred
# Out:
#                                                              intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK     30.289
#                                      AGKPVICATQMLESMIK          31.078
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR            28.132
#                                      AIVAIENPADVSVISSR          29.228
#                                      GISDLAQHYLMR               28.584
# ...                                                                ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR          29.348
#                                      GLVLGPIHK                  30.325
#                                      GYLGPEQLPDCLK              28.443
#                                      LATQSNEITIPVTFESR          31.105
#                                      SYSPYDMLESIRK              32.088
#
#                                                              train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK        28.540
#                                      AGKPVICATQMLESMIK             32.096
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR               28.425
#                                      AIVAIENPADVSVISSR             30.157
#                                      GISDLAQHYLMR                  29.492
# ...                                                                   ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR             30.157
#                                      GLVLGPIHK                     29.962
#                                      GYLGPEQLPDCLK                 29.384
#                                      LATQSNEITIPVTFESR             31.342
#                                      SYSPYDMLESIRK                 31.373
#
#                                                              train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK         28.400
#                                      AGKPVICATQMLESMIK              31.657
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR                28.617
#                                      AIVAIENPADVSVISSR              30.189
#                                      GISDLAQHYLMR                   29.429
# ...                                                                    ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR              30.189
#                                      GLVLGPIHK                      29.875
#                                      GYLGPEQLPDCLK                  29.535
#                                      LATQSNEITIPVTFESR              31.373
#                                      SYSPYDMLESIRK                  30.940
#
#                                                              replicates
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK      29.274
#                                      AGKPVICATQMLESMIK           31.351
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR             26.228
#                                      AIVAIENPADVSVISSR           29.740
#                                      GISDLAQHYLMR                28.219
# ...                                                                 ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR           29.081
#                                      GLVLGPIHK                   30.316
#                                      GYLGPEQLPDCLK               28.884
#                                      LATQSNEITIPVTFESR           31.352
#                                      SYSPYDMLESIRK               32.325
#
# [4940 rows x 4 columns]

# %%
if any(df_pred.isna()):
    print("Consecutive NaNs are not imputed using replicates.")
    display(df_pred.loc[df_pred.isna().any(axis=1)])
# Out:
# Consecutive NaNs are not imputed using replicates.
#                                                                                  intensity  \
# Sample ID                                                  peptide
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      AGKPVICATQMLESMIK        32.277
# 20181228_QE5_nLC5_OOE_QC_MNT_HELA_15cm_250ng_RO-007        EMEENFAVEAANYQDTIGR      26.319
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                           HLAGLGLTEAIDK            29.771
# 20190118_QE9_nLC9_NHS_MNT_HELA_50cm_04                     SQIFSTASDNQPTVTIK        29.390
# 20190128_QE3_nLC3_MJ_MNT_HeLa_01                           TIAPALVSK                32.592
# 20190219_QE3_Evo2_UHG_QC_MNT_HELA_01_190219173213          EMEENFAVEAANYQDTIGR      26.305
# 20190220_QE3_nLC7_TSB_QC_MNT_HELA_02                       GILADEDSSRPVWLK          26.372
# 20190221_QE1_nLC2_ANHO_QC_MNT_HELA_02                      ISMPDFDLHLK              30.238
# 20190225_QE9_nLC0_RS_MNT_Hela_01                           ELVTQQLPHLLK             27.430
# 20190226_QE10_PhGe_Evosep_176min-30cmCol-HeLa_3            VVFVFGPDK                29.435
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_14_25         EMEENFAVEAANYQDTIGR      24.662
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_14_27         VVFVFGPDK                30.340
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_15_24         IALGIPLPEIK              29.294
# 20190226_QE1_nLC2_AB_QC_MNT_HELA_05                        VVHIMDFQR                28.991
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01                        LPNLTHLNLSGNK            28.532
# 20190305_QE4_LC12_JE-IAH_QC_MNT_HeLa_02                    GLDVDSLVIEHIQVNK         29.228
# 20190308_QE3_nLC5_MR_QC_MNT_HeLa_Easyctcdon_02             ELVTQQLPHLLK             25.045
# 20190327_QE6_LC6_SCL_QC_MNT_Hela_02                        AGKPVICATQMLESMIK        32.649
# 20190417_QE1_nLC2_GP_MNT_HELA_01                           SYSPYDMLESIRK            31.816
# 20190423_QX7_JuSc_MA_HeLa_500ng_LC01                       SGGMSNELNNIISR           29.880
# 20190425_QX4_JoSw_MA_HeLa_500ng_BR13_standard_190425181909 AGVNTVTTLVENKK           25.815
# 20190425_QX8_JuSc_MA_HeLa_500ng_1                          LAAVDATVNQVLASR          30.437
# 20190426_QE10_nLC9_LiNi_QC_MNT_15cm_HeLa_01                GLDVDSLVIEHIQVNK         29.817
# 20190429_QX6_ChDe_MA_HeLa_Br14_500ng_LC09                  AGVNTVTTLVENKK           25.766
# 20190430_QX6_ChDe_MA_HeLa_Br14_500ng_LC09                  GLDVDSLVIEHIQVNK         31.423
# 20190506_QE3_nLC3_DBJ_QC_MNT_HeLa_01                       GILADEDSSRPVWLK          27.690
# 20190506_QX7_ChDe_MA_HeLaBr14_500ng                        AGVNTVTTLVENKK           30.036
# 20190506_QX8_MiWi_MA_HeLa_500ng_old                        AIVAIENPADVSVISSR        31.269
# 20190510_QE1_nLC2_ANHO_QC_MNT_HELA_02                      VMTIAPGLFGTPLLTSLPEK     27.948
# 20190510_QE2_NLC1_GP_MNT_HELA_02                           HLAGLGLTEAIDK            29.653
# 20190515_QE4_LC12_AS_QC_MNT_HeLa_01_20190515230141         GILADEDSSRPVWLK          29.842
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                       GYLGPEQLPDCLK            31.472
# 20190522_QE10_nLC13_LiNi_QC_MNT_15cm_HeLa_01               VMTIAPGLFGTPLLTSLPEK     28.848
# 20190527_QE3_nLC3_DS_QC_MNT_HeLa_02                        SGGMSNELNNIISR           24.505
# 20190606_QE4_LC12_JE_QC_MNT_HeLa_03                        DHENIVIAK                28.936
# 20190611_QX0_MaTa_MA_HeLa_500ng_LC07_1                     NPDDITQEEYGEFYK          33.894
# 20190617_QE1_nLC2_GP_QC_MNT_HELA_01_20190617213340         AAHSEGNTTAGLDMR          27.389
# 20190624_QX3_MaMu_MA_Hela_500ng_LC15                       TIAPALVSK                33.183
# 20190628_QX6_AnPi_MA_HeLa_500ng_LC09                       AGVNTVTTLVENKK           30.488
# 20190629_QX4_JiYu_MA_HeLa_500ng_MAX_ALLOWED                SGGMSNELNNIISR           29.984
# 20190708_QX7_MaMu_MA_HeLa_Br14_500ng                       TIGGGDDSFNTFFSETGAGK     33.943
# 20190708_QX8_AnPi_MA_HeLa_BR14_500ng                       TIGGGDDSFNTFFSETGAGK     32.241
# 20190709_QE1_nLC13_ANHO_QC_MNT_HELA_02                     AAHSEGNTTAGLDMR          23.559
# 20190710_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_01                AGVNTVTTLVENKK           29.865
# 20190724_QX0_MePh_MA_HeLa_500ng_LC07_01                    DNHLLGTFDLTGIPPAPR       31.785
# 20190724_QX3_MiWi_MA_Hela_500ng_LC15                       DNHLLGTFDLTGIPPAPR       31.561
# 20190729_QX0_AsJa_MA_HeLa_500ng_LC07_01                    VNIIPLIAK                29.110
# 20190731_QX1_LiSc_MA_HeLa_500ng_LC10                       YRVPDVLVADPPIAR          30.191
# 20190731_QX8_ChSc_MA_HeLa_500ng                            ELVTQQLPHLLK             30.068
#
#                                                                                  train_median  \
# Sample ID                                                  peptide
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      AGKPVICATQMLESMIK           32.096
# 20181228_QE5_nLC5_OOE_QC_MNT_HELA_15cm_250ng_RO-007        EMEENFAVEAANYQDTIGR         26.966
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                           HLAGLGLTEAIDK               29.561
# 20190118_QE9_nLC9_NHS_MNT_HELA_50cm_04                     SQIFSTASDNQPTVTIK           30.079
# 20190128_QE3_nLC3_MJ_MNT_HeLa_01                           TIAPALVSK                   32.732
# 20190219_QE3_Evo2_UHG_QC_MNT_HELA_01_190219173213          EMEENFAVEAANYQDTIGR         26.966
# 20190220_QE3_nLC7_TSB_QC_MNT_HELA_02                       GILADEDSSRPVWLK             29.305
# 20190221_QE1_nLC2_ANHO_QC_MNT_HELA_02                      ISMPDFDLHLK                 29.869
# 20190225_QE9_nLC0_RS_MNT_Hela_01                           ELVTQQLPHLLK                28.106
# 20190226_QE10_PhGe_Evosep_176min-30cmCol-HeLa_3            VVFVFGPDK                   29.957
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_14_25         EMEENFAVEAANYQDTIGR         26.966
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_14_27         VVFVFGPDK                   29.957
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_15_24         IALGIPLPEIK                 30.028
# 20190226_QE1_nLC2_AB_QC_MNT_HELA_05                        VVHIMDFQR                   28.045
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01                        LPNLTHLNLSGNK               28.383
# 20190305_QE4_LC12_JE-IAH_QC_MNT_HeLa_02                    GLDVDSLVIEHIQVNK            29.654
# 20190308_QE3_nLC5_MR_QC_MNT_HeLa_Easyctcdon_02             ELVTQQLPHLLK                28.106
# 20190327_QE6_LC6_SCL_QC_MNT_Hela_02                        AGKPVICATQMLESMIK           32.096
# 20190417_QE1_nLC2_GP_MNT_HELA_01                           SYSPYDMLESIRK               31.373
# 20190423_QX7_JuSc_MA_HeLa_500ng_LC01                       SGGMSNELNNIISR              29.030
# 20190425_QX4_JoSw_MA_HeLa_500ng_BR13_standard_190425181909 AGVNTVTTLVENKK              29.968
# 20190425_QX8_JuSc_MA_HeLa_500ng_1                          LAAVDATVNQVLASR             29.486
# 20190426_QE10_nLC9_LiNi_QC_MNT_15cm_HeLa_01                GLDVDSLVIEHIQVNK            29.654
# 20190429_QX6_ChDe_MA_HeLa_Br14_500ng_LC09                  AGVNTVTTLVENKK              29.968
# 20190430_QX6_ChDe_MA_HeLa_Br14_500ng_LC09                  GLDVDSLVIEHIQVNK            29.654
# 20190506_QE3_nLC3_DBJ_QC_MNT_HeLa_01                       GILADEDSSRPVWLK             29.305
# 20190506_QX7_ChDe_MA_HeLaBr14_500ng                        AGVNTVTTLVENKK              29.968
# 20190506_QX8_MiWi_MA_HeLa_500ng_old                        AIVAIENPADVSVISSR           30.157
# 20190510_QE1_nLC2_ANHO_QC_MNT_HELA_02                      VMTIAPGLFGTPLLTSLPEK        29.795
# 20190510_QE2_NLC1_GP_MNT_HELA_02                           HLAGLGLTEAIDK               29.561
# 20190515_QE4_LC12_AS_QC_MNT_HeLa_01_20190515230141         GILADEDSSRPVWLK             29.305
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                       GYLGPEQLPDCLK               29.384
# 20190522_QE10_nLC13_LiNi_QC_MNT_15cm_HeLa_01               VMTIAPGLFGTPLLTSLPEK        29.795
# 20190527_QE3_nLC3_DS_QC_MNT_HeLa_02                        SGGMSNELNNIISR              29.030
# 20190606_QE4_LC12_JE_QC_MNT_HeLa_03                        DHENIVIAK                   29.975
# 20190611_QX0_MaTa_MA_HeLa_500ng_LC07_1                     NPDDITQEEYGEFYK             27.505
# 20190617_QE1_nLC2_GP_QC_MNT_HELA_01_20190617213340         AAHSEGNTTAGLDMR             28.425
# 20190624_QX3_MaMu_MA_Hela_500ng_LC15                       TIAPALVSK                   32.732
# 20190628_QX6_AnPi_MA_HeLa_500ng_LC09                       AGVNTVTTLVENKK              29.968
# 20190629_QX4_JiYu_MA_HeLa_500ng_MAX_ALLOWED                SGGMSNELNNIISR              29.030
# 20190708_QX7_MaMu_MA_HeLa_Br14_500ng                       TIGGGDDSFNTFFSETGAGK        32.110
# 20190708_QX8_AnPi_MA_HeLa_BR14_500ng                       TIGGGDDSFNTFFSETGAGK        32.110
# 20190709_QE1_nLC13_ANHO_QC_MNT_HELA_02                     AAHSEGNTTAGLDMR             28.425
# 20190710_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_01                AGVNTVTTLVENKK              29.968
# 20190724_QX0_MePh_MA_HeLa_500ng_LC07_01                    DNHLLGTFDLTGIPPAPR          28.875
# 20190724_QX3_MiWi_MA_Hela_500ng_LC15                       DNHLLGTFDLTGIPPAPR          28.875
# 20190729_QX0_AsJa_MA_HeLa_500ng_LC07_01                    VNIIPLIAK                   28.761
# 20190731_QX1_LiSc_MA_HeLa_500ng_LC10                       YRVPDVLVADPPIAR             29.262
# 20190731_QX8_ChSc_MA_HeLa_500ng                            ELVTQQLPHLLK                28.106
#
#                                                                                  train_average  \
# Sample ID                                                  peptide
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      AGKPVICATQMLESMIK            31.657
# 20181228_QE5_nLC5_OOE_QC_MNT_HELA_15cm_250ng_RO-007        EMEENFAVEAANYQDTIGR          27.809
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                           HLAGLGLTEAIDK                29.364
# 20190118_QE9_nLC9_NHS_MNT_HELA_50cm_04                     SQIFSTASDNQPTVTIK            30.319
# 20190128_QE3_nLC3_MJ_MNT_HeLa_01                           TIAPALVSK                    32.646
# 20190219_QE3_Evo2_UHG_QC_MNT_HELA_01_190219173213          EMEENFAVEAANYQDTIGR          27.809
# 20190220_QE3_nLC7_TSB_QC_MNT_HELA_02                       GILADEDSSRPVWLK              29.179
# 20190221_QE1_nLC2_ANHO_QC_MNT_HELA_02                      ISMPDFDLHLK                  29.702
# 20190225_QE9_nLC0_RS_MNT_Hela_01                           ELVTQQLPHLLK                 28.065
# 20190226_QE10_PhGe_Evosep_176min-30cmCol-HeLa_3            VVFVFGPDK                    30.221
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_14_25         EMEENFAVEAANYQDTIGR          27.809
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_14_27         VVFVFGPDK                    30.221
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_15_24         IALGIPLPEIK                  30.234
# 20190226_QE1_nLC2_AB_QC_MNT_HELA_05                        VVHIMDFQR                    28.153
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01                        LPNLTHLNLSGNK                28.756
# 20190305_QE4_LC12_JE-IAH_QC_MNT_HeLa_02                    GLDVDSLVIEHIQVNK             29.816
# 20190308_QE3_nLC5_MR_QC_MNT_HeLa_Easyctcdon_02             ELVTQQLPHLLK                 28.065
# 20190327_QE6_LC6_SCL_QC_MNT_Hela_02                        AGKPVICATQMLESMIK            31.657
# 20190417_QE1_nLC2_GP_MNT_HELA_01                           SYSPYDMLESIRK                30.940
# 20190423_QX7_JuSc_MA_HeLa_500ng_LC01                       SGGMSNELNNIISR               28.702
# 20190425_QX4_JoSw_MA_HeLa_500ng_BR13_standard_190425181909 AGVNTVTTLVENKK               29.593
# 20190425_QX8_JuSc_MA_HeLa_500ng_1                          LAAVDATVNQVLASR              29.559
# 20190426_QE10_nLC9_LiNi_QC_MNT_15cm_HeLa_01                GLDVDSLVIEHIQVNK             29.816
# 20190429_QX6_ChDe_MA_HeLa_Br14_500ng_LC09                  AGVNTVTTLVENKK               29.593
# 20190430_QX6_ChDe_MA_HeLa_Br14_500ng_LC09                  GLDVDSLVIEHIQVNK             29.816
# 20190506_QE3_nLC3_DBJ_QC_MNT_HeLa_01                       GILADEDSSRPVWLK              29.179
# 20190506_QX7_ChDe_MA_HeLaBr14_500ng                        AGVNTVTTLVENKK               29.593
# 20190506_QX8_MiWi_MA_HeLa_500ng_old                        AIVAIENPADVSVISSR            30.189
# 20190510_QE1_nLC2_ANHO_QC_MNT_HELA_02                      VMTIAPGLFGTPLLTSLPEK         29.696
# 20190510_QE2_NLC1_GP_MNT_HELA_02                           HLAGLGLTEAIDK                29.364
# 20190515_QE4_LC12_AS_QC_MNT_HeLa_01_20190515230141         GILADEDSSRPVWLK              29.179
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                       GYLGPEQLPDCLK                29.535
# 20190522_QE10_nLC13_LiNi_QC_MNT_15cm_HeLa_01               VMTIAPGLFGTPLLTSLPEK         29.696
# 20190527_QE3_nLC3_DS_QC_MNT_HeLa_02                        SGGMSNELNNIISR               28.702
# 20190606_QE4_LC12_JE_QC_MNT_HeLa_03                        DHENIVIAK                    30.015
# 20190611_QX0_MaTa_MA_HeLa_500ng_LC07_1                     NPDDITQEEYGEFYK              28.744
# 20190617_QE1_nLC2_GP_QC_MNT_HELA_01_20190617213340         AAHSEGNTTAGLDMR              28.617
# 20190624_QX3_MaMu_MA_Hela_500ng_LC15                       TIAPALVSK                    32.646
# 20190628_QX6_AnPi_MA_HeLa_500ng_LC09                       AGVNTVTTLVENKK               29.593
# 20190629_QX4_JiYu_MA_HeLa_500ng_MAX_ALLOWED                SGGMSNELNNIISR               28.702
# 20190708_QX7_MaMu_MA_HeLa_Br14_500ng                       TIGGGDDSFNTFFSETGAGK         32.070
# 20190708_QX8_AnPi_MA_HeLa_BR14_500ng                       TIGGGDDSFNTFFSETGAGK         32.070
# 20190709_QE1_nLC13_ANHO_QC_MNT_HELA_02                     AAHSEGNTTAGLDMR              28.617
# 20190710_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_01                AGVNTVTTLVENKK               29.593
# 20190724_QX0_MePh_MA_HeLa_500ng_LC07_01                    DNHLLGTFDLTGIPPAPR           29.108
# 20190724_QX3_MiWi_MA_Hela_500ng_LC15                       DNHLLGTFDLTGIPPAPR           29.108
# 20190729_QX0_AsJa_MA_HeLa_500ng_LC07_01                    VNIIPLIAK                    28.579
# 20190731_QX1_LiSc_MA_HeLa_500ng_LC10                       YRVPDVLVADPPIAR              29.130
# 20190731_QX8_ChSc_MA_HeLa_500ng                            ELVTQQLPHLLK                 28.065
#
#                                                                                  replicates
# Sample ID                                                  peptide
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      AGKPVICATQMLESMIK            NaN
# 20181228_QE5_nLC5_OOE_QC_MNT_HELA_15cm_250ng_RO-007        EMEENFAVEAANYQDTIGR          NaN
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                           HLAGLGLTEAIDK                NaN
# 20190118_QE9_nLC9_NHS_MNT_HELA_50cm_04                     SQIFSTASDNQPTVTIK            NaN
# 20190128_QE3_nLC3_MJ_MNT_HeLa_01                           TIAPALVSK                    NaN
# 20190219_QE3_Evo2_UHG_QC_MNT_HELA_01_190219173213          EMEENFAVEAANYQDTIGR          NaN
# 20190220_QE3_nLC7_TSB_QC_MNT_HELA_02                       GILADEDSSRPVWLK              NaN
# 20190221_QE1_nLC2_ANHO_QC_MNT_HELA_02                      ISMPDFDLHLK                  NaN
# 20190225_QE9_nLC0_RS_MNT_Hela_01                           ELVTQQLPHLLK                 NaN
# 20190226_QE10_PhGe_Evosep_176min-30cmCol-HeLa_3            VVFVFGPDK                    NaN
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_14_25         EMEENFAVEAANYQDTIGR          NaN
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_14_27         VVFVFGPDK                    NaN
# 20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_15_24         IALGIPLPEIK                  NaN
# 20190226_QE1_nLC2_AB_QC_MNT_HELA_05                        VVHIMDFQR                    NaN
# 20190301_QE7_nLC7_DS_QC_MNT_HeLa_01                        LPNLTHLNLSGNK                NaN
# 20190305_QE4_LC12_JE-IAH_QC_MNT_HeLa_02                    GLDVDSLVIEHIQVNK             NaN
# 20190308_QE3_nLC5_MR_QC_MNT_HeLa_Easyctcdon_02             ELVTQQLPHLLK                 NaN
# 20190327_QE6_LC6_SCL_QC_MNT_Hela_02                        AGKPVICATQMLESMIK            NaN
# 20190417_QE1_nLC2_GP_MNT_HELA_01                           SYSPYDMLESIRK                NaN
# 20190423_QX7_JuSc_MA_HeLa_500ng_LC01                       SGGMSNELNNIISR               NaN
# 20190425_QX4_JoSw_MA_HeLa_500ng_BR13_standard_190425181909 AGVNTVTTLVENKK               NaN
# 20190425_QX8_JuSc_MA_HeLa_500ng_1                          LAAVDATVNQVLASR              NaN
# 20190426_QE10_nLC9_LiNi_QC_MNT_15cm_HeLa_01                GLDVDSLVIEHIQVNK             NaN
# 20190429_QX6_ChDe_MA_HeLa_Br14_500ng_LC09                  AGVNTVTTLVENKK               NaN
# 20190430_QX6_ChDe_MA_HeLa_Br14_500ng_LC09                  GLDVDSLVIEHIQVNK             NaN
# 20190506_QE3_nLC3_DBJ_QC_MNT_HeLa_01                       GILADEDSSRPVWLK              NaN
# 20190506_QX7_ChDe_MA_HeLaBr14_500ng                        AGVNTVTTLVENKK               NaN
# 20190506_QX8_MiWi_MA_HeLa_500ng_old                        AIVAIENPADVSVISSR            NaN
# 20190510_QE1_nLC2_ANHO_QC_MNT_HELA_02                      VMTIAPGLFGTPLLTSLPEK         NaN
# 20190510_QE2_NLC1_GP_MNT_HELA_02                           HLAGLGLTEAIDK                NaN
# 20190515_QE4_LC12_AS_QC_MNT_HeLa_01_20190515230141         GILADEDSSRPVWLK              NaN
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                       GYLGPEQLPDCLK                NaN
# 20190522_QE10_nLC13_LiNi_QC_MNT_15cm_HeLa_01               VMTIAPGLFGTPLLTSLPEK         NaN
# 20190527_QE3_nLC3_DS_QC_MNT_HeLa_02                        SGGMSNELNNIISR               NaN
# 20190606_QE4_LC12_JE_QC_MNT_HeLa_03                        DHENIVIAK                    NaN
# 20190611_QX0_MaTa_MA_HeLa_500ng_LC07_1                     NPDDITQEEYGEFYK              NaN
# 20190617_QE1_nLC2_GP_QC_MNT_HELA_01_20190617213340         AAHSEGNTTAGLDMR              NaN
# 20190624_QX3_MaMu_MA_Hela_500ng_LC15                       TIAPALVSK                    NaN
# 20190628_QX6_AnPi_MA_HeLa_500ng_LC09                       AGVNTVTTLVENKK               NaN
# 20190629_QX4_JiYu_MA_HeLa_500ng_MAX_ALLOWED                SGGMSNELNNIISR               NaN
# 20190708_QX7_MaMu_MA_HeLa_Br14_500ng                       TIGGGDDSFNTFFSETGAGK         NaN
# 20190708_QX8_AnPi_MA_HeLa_BR14_500ng                       TIGGGDDSFNTFFSETGAGK         NaN
# 20190709_QE1_nLC13_ANHO_QC_MNT_HELA_02                     AAHSEGNTTAGLDMR              NaN
# 20190710_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_01                AGVNTVTTLVENKK               NaN
# 20190724_QX0_MePh_MA_HeLa_500ng_LC07_01                    DNHLLGTFDLTGIPPAPR           NaN
# 20190724_QX3_MiWi_MA_Hela_500ng_LC15                       DNHLLGTFDLTGIPPAPR           NaN
# 20190729_QX0_AsJa_MA_HeLa_500ng_LC07_01                    VNIIPLIAK                    NaN
# 20190731_QX1_LiSc_MA_HeLa_500ng_LC10                       YRVPDVLVADPPIAR              NaN
# 20190731_QX8_ChSc_MA_HeLa_500ng                            ELVTQQLPHLLK                 NaN

# %% [markdown]
# ## Collaboritive filtering model

# %%
from fastai.collab import CollabDataLoaders, MSELossFlat, Learner
from fastai.collab import EmbeddingDotBias

analysis.collab = Analysis()
collab = analysis.collab
collab.columns = 'peptide,Sample ID,intensity'.split(',')

# %% [markdown]
# Create data view for collaborative filtering
#
# - currently a bit hacky as the splitter does not support predefinded indices (create custum subclass providing splits to internal methods?)
#
# - Use the [`CollabDataLoaders`](https://docs.fast.ai/collab.html#CollabDataLoaders)  similar to the [`TabularDataLoaders`](https://docs.fast.ai/tabular.data.html#TabularDataLoaders).
# - Use the [`IndexSplitter`](https://docs.fast.ai/data.transforms.html#IndexSplitter) and provide splits to whatever is used in `CollabDataLoaders`

# %%
collab.df_train = analysis.df_train.reset_index()
collab.df_valid = analysis.df_valid.reset_index()
collab.df_train.head()
# Out:
#                              Sample ID            peptide  intensity
# 0  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02    AAHSEGNTTAGLDMR     28.098
# 1  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          AFGYYGPLR     28.703
# 2  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02    AGGAAVVITEPEHTK     27.754
# 3  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02     AGVNTVTTLVENKK     28.355
# 4  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AIVAIENPADVSVISSR     29.292

# %%
collab.df_valid.head()
# Out:
#                               Sample ID                 peptide  intensity
# 0   20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK     30.289
# 1   20181219_QE3_nLC3_DS_QC_MNT_HeLa_02       AGKPVICATQMLESMIK     31.078
# 2  20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         AAHSEGNTTAGLDMR     28.132
# 3  20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01       AIVAIENPADVSVISSR     29.228
# 4  20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            GISDLAQHYLMR     28.584

# %%
assert (collab.df_train.intensity.isna().sum(),
        collab.df_valid.intensity.isna().sum()) == (0, 0), "Remove missing values."

# %% [markdown]
# Hacky part uses training data `Datasets` from dataloaders to recreate a custom `DataLoaders` instance

# %%
collab.dl_train = CollabDataLoaders.from_df(
    collab.df_train, valid_pct=0.0, user_name='Sample ID', item_name='peptide', rating_name='intensity', bs=args.batch_size, device=device)
collab.dl_valid = CollabDataLoaders.from_df(
    collab.df_valid, valid_pct=0.0, user_name='Sample ID', item_name='peptide', rating_name='intensity', bs=args.batch_size,
    shuffle=False, device=device)
collab.dl_train.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sample ID</th>
#       <th>peptide</th>
#       <th>intensity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20190527_QE2_NLC1_ANHO_MNT_HELA_01</td>
#       <td>DAGEGLLAVQITDPEGKPK</td>
#       <td>28.231</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20190411_QE1_nLC2_ANHO_MNT_QC_hela_01</td>
#       <td>TSIAIDTIINQK</td>
#       <td>29.126</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20190423_QE3_nLC5_DS_QC_MNT_HeLa_01</td>
#       <td>AGGAAVVITEPEHTK</td>
#       <td>27.697</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20190708_QE6_nLC4_JE_QC_MNT_HeLa_02</td>
#       <td>LASTLVHLGEYQAAVDGAR</td>
#       <td>30.767</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20190626_QE7_nLC7_DS_QC_MNT_HeLa_02</td>
#       <td>LPNLTHLNLSGNK</td>
#       <td>27.814</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>20190521_QX6_AsJa_MA_HeLa_Br14_500ng_LC09_20190522134621</td>
#       <td>MTNGFSGADLTEICQR</td>
#       <td>29.152</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>20190301_QE1_nLC2_ANHO_QC_MNT_HELA_01_20190303025443</td>
#       <td>ELVTQQLPHLLK</td>
#       <td>28.962</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>20190609_QX8_MiWi_MA_HeLa_BR14_500ng</td>
#       <td>DAGEGLLAVQITDPEGKPK</td>
#       <td>29.402</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>20190218_QE6_LC6_SCL_MVM_QC_MNT_Hela_04</td>
#       <td>TEFLSFMNTELAAFTK</td>
#       <td>30.257</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>20190426_QX1_JoMu_MA_HeLa_500ng_LC11</td>
#       <td>MAPYQGPDAVPGALDYK</td>
#       <td>28.635</td>
#     </tr>
#   </tbody>
# </table>

# %%
from fastai.data.core import DataLoaders
collab.dls = DataLoaders(collab.dl_train.train, collab.dl_valid.train)
if args.cuda:
    collab.dls.cuda()

# %%
collab.dl_valid.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sample ID</th>
#       <th>peptide</th>
#       <th>intensity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20190412_QE6_LC6_AS_QC_MNT_HeLa_03</td>
#       <td>AGVNTVTTLVENKK</td>
#       <td>30.608</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20190613_QE1_nLC2_GP_QC_MNT_HELA_01</td>
#       <td>AFGYYGPLR</td>
#       <td>29.384</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20190104_QE10_nLC0_LiNi_QC_MNT_HeLa_500_15cm_01_20190104155135</td>
#       <td>ELVTQQLPHLLK</td>
#       <td>28.244</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20190328_QE7_nLC3_RJC_MEM_QC_MNT_HeLa_01</td>
#       <td>DHENIVIAK</td>
#       <td>30.000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20190404_QE7_nLC3_AL_QC_MNT_HeLa_02</td>
#       <td>IALGIPLPEIK</td>
#       <td>28.777</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>20190611_QX0_MePh_MA_HeLa_500ng_LC07_3</td>
#       <td>LAAVDATVNQVLASR</td>
#       <td>31.447</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>20190323_QE8_nLC14_RS_QC_MNT_Hela_50cm</td>
#       <td>GLVLGPIHK</td>
#       <td>29.622</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>20190306_QE1_nLC2_ANHO_QC_MNT_HELA_01</td>
#       <td>DHENIVIAK</td>
#       <td>29.683</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>20190408_QE8_nLC14_AGF_QC_MNT_HeLa_50cm_01</td>
#       <td>YRVPDVLVADPPIAR</td>
#       <td>29.801</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>20190313_QE8_nLC14_LiNi_QC_MNT_50cm_HELA_03</td>
#       <td>AGGAAVVITEPEHTK</td>
#       <td>29.826</td>
#     </tr>
#   </tbody>
# </table>

# %%
len(collab.dls.classes['Sample ID']), len(collab.dls.classes['peptide'])
# Out:
# (998, 51)

# %%
len(collab.dls.train), len(collab.dls.valid)  # mini-batches
# Out:
# (1385, 155)

# %% [markdown]
# Alternatively to the hacky version, one could use a factory method, but there the sampling/Splitting methods would need to be implemented (not using [`RandomSplitter`](https://docs.fast.ai/data.transforms.html#RandomSplitter) somehow)
#
#  - [`TabDataLoader`](https://docs.fast.ai/tabular.core.html#TabDataLoader)
#  - uses [`TabularPandas`](https://docs.fast.ai/tabular.core.html#TabularPandas)
#
#  > Current problem: No custom splitter can be provided

# %% [markdown]
# ### Model

# %%
collab.model_args = {}
collab.model_args['n_samples'] = len(collab.dls.classes['Sample ID'])
collab.model_args['n_peptides'] = len(collab.dls.classes['peptide'])
collab.model_args['dim_latent_factors'] = latent_dim
collab.model_args['y_range'] = (
    int(analysis.df_train['intensity'].min()), int(analysis.df_train['intensity'].max())+1)

print("Args:")
pprint(collab.model_args)


# from vaep.models.collab import DotProductBias
# model = DotProductBias(**collab.model_args)
model = EmbeddingDotBias.from_classes(
    n_factors=collab.model_args['dim_latent_factors'], classes=collab.dls.classes, y_range=collab.model_args['y_range'])
learn = Learner(dls=collab.dls, model=model, loss_func=MSELossFlat())
if args.cuda:
    learn.cuda()
learn.summary()
# Out:
# Args:
# {'dim_latent_factors': 2,
#  'n_peptides': 51,
#  'n_samples': 998,
#  'y_range': (20, 35)}
# EmbeddingDotBias (Input shape: 32 x 2)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      32 x 2
# Embedding                                 1996       True
# Embedding                                 102        True
# ____________________________________________________________________________
#                      32 x 1
# Embedding                                 998        True
# Embedding                                 51         True
# ____________________________________________________________________________
#
# Total params: 3,147
# Total trainable params: 3,147
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001C5FB3F6040>
# Loss function: FlattenedLoss of MSELoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %% [markdown]
# ### Training

# %%
learn.fit_one_cycle(epochs_max, 5e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.029855</td>
#       <td>1.909574</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.842597</td>
#       <td>0.834803</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.651586</td>
#       <td>0.636348</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.530630</td>
#       <td>0.599810</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.625646</td>
#       <td>0.579045</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.499199</td>
#       <td>0.568514</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.540988</td>
#       <td>0.550777</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.503871</td>
#       <td>0.546028</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.455631</td>
#       <td>0.543652</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.464005</td>
#       <td>0.543202</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
from vaep.models import plot_loss
from fastai import learner
learner.Recorder.plot_loss = plot_loss

fig, ax = plt.subplots(figsize=(15, 8))
ax.set_title('Collab loss: Reconstruction loss.')
learn.recorder.plot_loss(skip_start=5, ax=ax)
vaep.io_images._savefig(fig, name='collab_training',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_training

# %% [markdown]
# ### Evaluation

# %%
collab.dls.valid_ds.items
# Out:
#        Sample ID  peptide  intensity
# 1,877        380        6     30.608
# 3,301        671        3     29.384
# 109           20       12     28.244
# 1,617        327       10     30.000
# 1,725        348       23     28.777
# ...          ...      ...        ...
# 733          147       21     29.046
# 2,978        597       30     31.593
# 3,968        804        5     32.331
# 2,394        482        7     30.388
# 2,892        580       44     27.303
#
# [4940 rows x 3 columns]

# %%
df_pred = df_pred.reset_index()
pred, target = learn.get_preds()
df_pred['intensity_pred_collab'] = pd.Series(
    pred.flatten().numpy(), index=collab.dls.valid.items.index)

npt.assert_almost_equal(
    actual=collab.dls.valid.items.intensity.to_numpy(),
    desired=target.numpy().flatten()
)


df_pred = analyzers.cast_object_to_category(df_pred)
df_pred.set_index(['Sample ID', 'peptide'], inplace=True)
df_pred
# Out:
#                                                              intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK     30.289
#                                      AGKPVICATQMLESMIK          31.078
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR            28.132
#                                      AIVAIENPADVSVISSR          29.228
#                                      GISDLAQHYLMR               28.584
# ...                                                                ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR          29.348
#                                      GLVLGPIHK                  30.325
#                                      GYLGPEQLPDCLK              28.443
#                                      LATQSNEITIPVTFESR          31.105
#                                      SYSPYDMLESIRK              32.088
#
#                                                              train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK        28.540
#                                      AGKPVICATQMLESMIK             32.096
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR               28.425
#                                      AIVAIENPADVSVISSR             30.157
#                                      GISDLAQHYLMR                  29.492
# ...                                                                   ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR             30.157
#                                      GLVLGPIHK                     29.962
#                                      GYLGPEQLPDCLK                 29.384
#                                      LATQSNEITIPVTFESR             31.342
#                                      SYSPYDMLESIRK                 31.373
#
#                                                              train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK         28.400
#                                      AGKPVICATQMLESMIK              31.657
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR                28.617
#                                      AIVAIENPADVSVISSR              30.189
#                                      GISDLAQHYLMR                   29.429
# ...                                                                    ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR              30.189
#                                      GLVLGPIHK                      29.875
#                                      GYLGPEQLPDCLK                  29.535
#                                      LATQSNEITIPVTFESR              31.373
#                                      SYSPYDMLESIRK                  30.940
#
#                                                              replicates  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK      29.274
#                                      AGKPVICATQMLESMIK           31.351
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR             26.228
#                                      AIVAIENPADVSVISSR           29.740
#                                      GISDLAQHYLMR                28.219
# ...                                                                 ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR           29.081
#                                      GLVLGPIHK                   30.316
#                                      GYLGPEQLPDCLK               28.884
#                                      LATQSNEITIPVTFESR           31.352
#                                      SYSPYDMLESIRK               32.325
#
#                                                              intensity_pred_collab
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK                 27.335
#                                      AGKPVICATQMLESMIK                      30.919
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR                        27.440
#                                      AIVAIENPADVSVISSR                      29.312
#                                      GISDLAQHYLMR                           28.493
# ...                                                                            ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR                      30.009
#                                      GLVLGPIHK                              29.936
#                                      GYLGPEQLPDCLK                          29.236
#                                      LATQSNEITIPVTFESR                      31.180
#                                      SYSPYDMLESIRK                          31.945
#
# [4940 rows x 5 columns]

# %%
assert (abs(target.reshape(-1) - pred.reshape(-1))).sum() / len(target) - \
    (df_pred.intensity - df_pred.intensity_pred_collab).abs().sum() / \
    len(df_pred) < 0.00001

# %% [markdown]
# ### Plot biases and embedding weigths
#
# - visualize relative order of samples and peptides

# %%
from collections import namedtuple
def get_bias(learner, indices, is_item=True) -> pd.Series:
    ret = learner.model.bias(indices.values, is_item=is_item) # user=sample
    return pd.Series(ret, index=indices)

# def get_weigths

CollabIDs = namedtuple("CollabIDs", "sample peptide")

collab.biases = CollabIDs(
    sample=get_bias(learn, indices=analysis.df_train.index.levels[0], is_item=False), # item=peptide
    peptide=get_bias(learn, indices=analysis.df_train.index.levels[1] )
)
collab.biases.sample.head()
# Out:
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02     0.081
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01    0.111
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01       0.281
# 20181222_QE9_nLC9_QC_50CM_HeLa1         0.121
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01   0.152
# dtype: float32

# %%
fig, ax = plt.subplots(figsize=(15, 15))
ax = collab.biases.sample.sort_values().plot(kind='line', rot=90, title='Sample biases', ax=ax)
vaep.io_images._savefig(fig, name='collab_bias_samples',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_bias_samples

# %%
fig, ax = plt.subplots(figsize=(15, 15))
_ = collab.biases.peptide.sort_values().plot(kind='line', rot=90, title='Sample biases', ax=ax)
vaep.io_images._savefig(fig, name='collab_bias_peptides',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_bias_peptides

# %%
def get_weight(learner, indices, is_item=True) -> pd.Series:
    ret = learner.model.weight(indices.values, is_item=is_item) # user=sample
    return pd.DataFrame(ret, index=indices, columns=[f'latent dimension {i+1}' for i in range(ret.shape[-1])])

collab.embeddings = CollabIDs(
    sample=get_weight(learn, indices=analysis.df_train.index.levels[0], is_item=False), # item=peptide
    peptide=get_weight(learn, indices=analysis.df_train.index.levels[1] )
)
collab.embeddings.sample.head()
# Out:
#                                        latent dimension 1  latent dimension 2
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                -0.146               0.118
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.064               0.127
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   0.030              -0.106
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -0.092               0.110
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              -0.042               0.294

# %%
fig, ax = plt.subplots(figsize=(15, 15))
analyzers.plot_date_map(df=collab.embeddings.sample, fig=fig, ax=ax,
                        dates=analysis.df_meta.date.loc[collab.embeddings.sample.index])
vaep.io_images._savefig(fig, name='collab_latent_by_date',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_latent_by_date

# %%
fig, ax = plt.subplots(figsize=(15, 15))
meta_col = 'ms_instrument'

df_ = collab.embeddings.sample
analyzers.seaborn_scatter(df=df_,
                          fig=fig,
                          ax=ax,
                          meta=analysis.df_meta[meta_col].loc[df_.index],
                          title='2D sample embedding weights by MS instrument')

vaep.io_images._savefig(fig, name='collab_latent_by_ms_instrument',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_latent_by_ms_instrument

# %% [markdown]
# ## Denoising Autoencoder (DAE)

# %% [markdown]
# ### Custom Transforms
#
# - [x] Shift standard normalized data around
#     - Error metrics won't be directly comparable afterwards

# %%
from fastai.tabular.all import *
from vaep.models import ae

from fastai.tabular.core import TabularPandas

# from fastai.callback.core import Callback

from fastai.data.core import DataLoaders

from fastai.learner import Learner
from fastai.losses import MSELossFlat


# https://docs.fast.ai/tabular.core.html#FillStrategy
# from fastai.tabular.core import FillMissing
# from fastai.tabular.core import TabularPandas

# %% [markdown]
# ### DataLoaders

# %%
# revert format
# undo using `stack`
analysis.df_train = analysis.df_train['intensity'].unstack()
analysis.df_valid = analysis.df_valid['intensity'].unstack()
analysis.df_valid.head()
# Out:
# peptide                                AAEAAAAPAESAAPAAGEEPSK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    30.289
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     NaN
#
# peptide                                AAHSEGNTTAGLDMR  AFGYYGPLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                NaN        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            28.132        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  NaN        NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    NaN        NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              NaN        NaN
#
# peptide                                AGGAAVVITEPEHTK  AGKPVICATQMLESMIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                NaN             31.078
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               NaN                NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  NaN                NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 28.353             31.092
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              NaN             32.277
#
# peptide                                AGVNTVTTLVENKK  AIVAIENPADVSVISSR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               NaN                NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              NaN             29.228
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 NaN                NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   NaN                NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01          28.370                NaN
#
# peptide                                ALDTMNFDVIK  DAGEGLLAVQITDPEGKPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02            NaN                  NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01           NaN                  NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01              NaN                  NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                NaN                  NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01          NaN               28.765
#
# peptide                                DHENIVIAK  ...  TIGGGDDSFNTFFSETGAGK  \
# Sample ID                                         ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          NaN  ...                   NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         NaN  ...                   NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01            NaN  ...                   NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1              NaN  ...                   NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        NaN  ...                   NaN
#
# peptide                                TSIAIDTIINQK  VFSGLVSTGLK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             NaN          NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            NaN          NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               NaN          NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 NaN          NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01           NaN          NaN
#
# peptide                                VMTIAPGLFGTPLLTSLPEK  VNIIPLIAK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     NaN        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN        NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN        NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN        NaN
#
# peptide                                VSHVSTGGGASLELLEGK  VVFVFGPDK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   NaN        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  NaN        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     NaN        NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       NaN        NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 NaN        NaN
#
# peptide                                VVHIMDFQR  YALYDATYETK  YRVPDVLVADPPIAR
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          NaN          NaN              NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         NaN          NaN              NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01         27.427          NaN              NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1              NaN          NaN           28.516
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        NaN          NaN              NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# Mean and std. dev. from training data

# %%
# norm = Normalize.from_stats(analysis.df_train.mean(), analysis.df_valid.std()) # copy interface?
NORMALIZER = Normalize  # dae.NormalizeShiftedMean

# %% [markdown]
# #### Training data
#
# procs passed to TabluarPandas are handled internally
#   1. not necessarily in order
#   2. with setup call (using current training data)

# %%
procs = [NORMALIZER, FillMissing(add_col=True)]
cont_names = list(analysis.df_train.columns)

to = TabularPandas(analysis.df_train, procs=procs, cont_names=cont_names)
print("Tabular object:", type(to))

to.items  # items reveals data in DataFrame
# Out:
# Tabular object: <class 'fastai.tabular.core.TabularPandas'>
# peptide                                       AAEAAAAPAESAAPAAGEEPSK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            0.106
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           1.744
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             -0.293
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                2.244
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          2.008
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  -0.409
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               0.861
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               1.041
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               0.895
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               0.745
#
# peptide                                       AAHSEGNTTAGLDMR  AFGYYGPLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    -0.252     -0.904
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   -0.085     -0.902
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      -2.162     -0.536
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        -0.291     -0.749
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  -0.218     -1.086
# ...                                                       ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            1.144      0.489
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        0.208      0.008
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        0.026     -0.392
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       -0.170     -0.376
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       -0.023     -0.260
#
# peptide                                       AGGAAVVITEPEHTK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    -0.875
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   -0.458
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       0.069
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         0.147
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  -1.243
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            0.307
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        0.158
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        0.314
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        0.547
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        0.147
#
# peptide                                       AGKPVICATQMLESMIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       0.286
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.599
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         0.088
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           0.286
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     0.286
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.514
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          0.115
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          0.572
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          0.566
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.634
#
# peptide                                       AGVNTVTTLVENKK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   -1.039
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  -1.133
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      0.166
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       -1.027
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  0.262
# ...                                                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          -3.160
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       0.297
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      -0.099
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       0.705
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       0.428
#
# peptide                                       AIVAIENPADVSVISSR  ALDTMNFDVIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      -0.804       -0.840
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.026       -0.805
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         0.002       -0.817
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          -0.321       -0.668
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    -0.516       -0.380
# ...                                                         ...          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.949        0.631
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         -1.431       -0.430
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         -0.935       -0.327
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         -1.052        0.067
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.026        0.101
#
# peptide                                       DAGEGLLAVQITDPEGKPK  DHENIVIAK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        -0.163     -0.478
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       -0.308     -0.285
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           0.285     -0.859
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            -0.417     -2.249
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       0.221     -0.541
# ...                                                           ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                0.221      0.549
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            0.979     -0.029
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            1.057      0.348
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            0.876      0.637
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            0.809      0.704
#
# peptide                                       ...  TIGGGDDSFNTFFSETGAGK_na  \
# Sample ID                                     ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02           ...                    False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01          ...                    False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01             ...                    False
# 20181222_QE9_nLC9_QC_50CM_HeLa1               ...                    False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         ...                    False
# ...                                           ...                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02  ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_01              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_02              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_03              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_04              ...                    False
#
# peptide                                       TSIAIDTIINQK_na  VFSGLVSTGLK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     False           False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    False           False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       False           False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         False           False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   False           False
# ...                                                       ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            False           False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         True           False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        False           False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         True           False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        False           False
#
# peptide                                       VMTIAPGLFGTPLLTSLPEK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                             False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                            False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                 False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           False
# ...                                                               ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                False
#
# peptide                                       VNIIPLIAK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                False
# ...                                                    ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     False
#
# peptide                                       VSHVSTGGGASLELLEGK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         False
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              False
#
# peptide                                       VVFVFGPDK_na  VVHIMDFQR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  False         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 False         False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    False          True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      False         False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                False         False
# ...                                                    ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         False          True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     False         False
#
# peptide                                       YALYDATYETK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  False
# ...                                                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       False
#
# peptide                                       YRVPDVLVADPPIAR_na
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      False
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           False
#
# [997 rows x 100 columns]

# %% [markdown]
# Better manuelly apply `Transforms` on `Tabluar` type

# %%
cont_names = list(analysis.df_train.columns)
to = TabularPandas(analysis.df_train, cont_names=cont_names, do_setup=False)

tf_norm = NORMALIZER()
_ = tf_norm.setups(to)  # returns to
tf_fillna = FillMissing(add_col=True)
_ = tf_fillna.setup(to)

print("Tabular object:", type(to))
# _ = (procs[0]).encodes(to)
to.items  # items reveals data in DataFrame
# Out:
# Tabular object: <class 'fastai.tabular.core.TabularPandas'>
# peptide                                       AAEAAAAPAESAAPAAGEEPSK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            0.112
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           1.662
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             -0.265
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                2.135
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          1.911
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  -0.375
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               0.827
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               0.997
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               0.859
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               0.717
#
# peptide                                       AAHSEGNTTAGLDMR  AFGYYGPLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    -0.247     -0.846
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   -0.092     -0.844
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      -2.030     -0.504
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        -0.284     -0.703
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  -0.215     -1.015
# ...                                                       ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            1.055      0.445
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        0.182     -0.001
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        0.012     -0.372
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       -0.170     -0.357
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       -0.034     -0.249
#
# peptide                                       AGGAAVVITEPEHTK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    -0.809
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   -0.415
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       0.083
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         0.156
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  -1.156
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            0.308
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        0.166
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        0.314
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        0.534
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        0.156
#
# peptide                                       AGKPVICATQMLESMIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       0.303
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.539
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         0.115
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           0.303
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     0.303
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.520
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          0.140
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          0.576
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          0.570
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.572
#
# peptide                                       AGVNTVTTLVENKK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   -0.936
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  -1.025
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      0.193
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       -0.925
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  0.283
# ...                                                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          -2.923
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       0.316
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      -0.056
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       0.698
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       0.438
#
# peptide                                       AIVAIENPADVSVISSR  ALDTMNFDVIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      -0.764       -0.787
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.028       -0.755
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        -0.001       -0.766
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          -0.307       -0.626
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    -0.491       -0.356
# ...                                                         ...          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.895        0.594
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         -1.357       -0.403
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         -0.888       -0.306
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         -0.999        0.064
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.028        0.096
#
# peptide                                       DAGEGLLAVQITDPEGKPK  DHENIVIAK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        -0.129     -0.454
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       -0.265     -0.272
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           0.296     -0.813
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            -0.369     -2.122
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       0.235     -0.513
# ...                                                           ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                0.235      0.514
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            0.952     -0.031
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            1.026      0.325
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            0.854      0.597
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            0.792      0.660
#
# peptide                                       ...  TIGGGDDSFNTFFSETGAGK_na  \
# Sample ID                                     ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02           ...                    False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01          ...                    False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01             ...                    False
# 20181222_QE9_nLC9_QC_50CM_HeLa1               ...                    False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         ...                    False
# ...                                           ...                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02  ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_01              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_02              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_03              ...                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_04              ...                    False
#
# peptide                                       TSIAIDTIINQK_na  VFSGLVSTGLK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     False           False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    False           False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       False           False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         False           False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   False           False
# ...                                                       ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            False           False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         True           False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        False           False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         True           False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        False           False
#
# peptide                                       VMTIAPGLFGTPLLTSLPEK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                             False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                            False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                 False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           False
# ...                                                               ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                False
#
# peptide                                       VNIIPLIAK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                False
# ...                                                    ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     False
#
# peptide                                       VSHVSTGGGASLELLEGK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         False
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              False
#
# peptide                                       VVFVFGPDK_na  VVHIMDFQR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  False         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 False         False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    False          True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      False         False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                False         False
# ...                                                    ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         False          True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     False         False
#
# peptide                                       YALYDATYETK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  False
# ...                                                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       False
#
# peptide                                       YRVPDVLVADPPIAR_na
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      False
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           False
#
# [997 rows x 100 columns]

# %% [markdown]
# Check mean and standard deviation after normalization

# %%
to.items.iloc[:, :10].describe()  # not perferct anymore as expected
# Out:
# peptide  AAEAAAAPAESAAPAAGEEPSK  AAHSEGNTTAGLDMR  AFGYYGPLR  AGGAAVVITEPEHTK  \
# count                   997.000          997.000    997.000          997.000
# mean                      0.012           -0.012     -0.008            0.017
# std                       0.946            0.934      0.928            0.945
# min                      -4.955           -3.157     -5.113           -3.704
# 25%                      -0.359           -0.413     -0.470           -0.322
# 50%                       0.112           -0.092     -0.056            0.156
# 75%                       0.410            0.779      0.448            0.559
# max                       3.466            1.814      2.366            1.891
#
# peptide  AGKPVICATQMLESMIK  AGVNTVTTLVENKK  AIVAIENPADVSVISSR  ALDTMNFDVIK  \
# count              997.000         997.000            997.000      997.000
# mean                 0.031           0.037             -0.003        0.001
# std                  0.952           0.937              0.947        0.939
# min                 -4.887          -5.067             -4.386       -4.598
# 25%                 -0.215          -0.099             -0.478       -0.448
# 50%                  0.303           0.283             -0.028        0.012
# 75%                  0.595           0.564              0.529        0.437
# max                  2.179           1.642              2.308        1.951
#
# peptide  DAGEGLLAVQITDPEGKPK  DHENIVIAK
# count                997.000    997.000
# mean                   0.026     -0.003
# std                    0.947      0.943
# min                   -5.263     -4.550
# 25%                   -0.316     -0.415
# 50%                    0.235     -0.030
# 75%                    0.668      0.547
# max                    1.698      2.118

# %% [markdown]
# Mask is added as type bool

# %%
to.items.dtypes.value_counts()
# Out:
# bool      50
# float64   50
# dtype: int64

# %% [markdown]
# with the suffix `_na` where `True` is indicating a missing value replaced by the `FillMissing` transformation

# %%
to.cont_names, to.cat_names
# Out:
# ((#50) ['AAEAAAAPAESAAPAAGEEPSK','AAHSEGNTTAGLDMR','AFGYYGPLR','AGGAAVVITEPEHTK','AGKPVICATQMLESMIK','AGVNTVTTLVENKK','AIVAIENPADVSVISSR','ALDTMNFDVIK','DAGEGLLAVQITDPEGKPK','DHENIVIAK'...],
#  (#50) ['AAEAAAAPAESAAPAAGEEPSK_na','AAHSEGNTTAGLDMR_na','AFGYYGPLR_na','AGGAAVVITEPEHTK_na','AGKPVICATQMLESMIK_na','AGVNTVTTLVENKK_na','AIVAIENPADVSVISSR_na','ALDTMNFDVIK_na','DAGEGLLAVQITDPEGKPK_na','DHENIVIAK_na'...])

# %%
assert len(to.valid) == 0

# %% [markdown]
# #### Validation data
#
# - reuse training data with different mask for evaluation
# - target data is the validation data
#     - switch between training and evaluation mode for setting comparison

# %%
_df_valid = TabularPandas(
    analysis.df_valid, cont_names=analysis.df_valid.columns.tolist())
# assert analysis.df_valid.isna().equals(y_valid.items.isna())
_df_valid = tf_norm.encodes(_df_valid)

# %%
_df_valid.items.iloc[:, :10].describe()
# Out:
# peptide  AAEAAAAPAESAAPAAGEEPSK  AAHSEGNTTAGLDMR  AFGYYGPLR  AGGAAVVITEPEHTK  \
# count                    99.000           97.000     95.000           99.000
# mean                      0.085           -0.285      0.041           -0.100
# std                       0.849            1.049      0.864            1.187
# min                      -2.066           -2.479     -2.672           -4.335
# 25%                      -0.399           -0.883     -0.494           -0.684
# 50%                       0.129           -0.231     -0.009            0.128
# 75%                       0.434            0.346      0.552            0.766
# max                       3.248            1.727      1.932            1.663
#
# peptide  AGKPVICATQMLESMIK  AGVNTVTTLVENKK  AIVAIENPADVSVISSR  ALDTMNFDVIK  \
# count              100.000          97.000             99.000       98.000
# mean                 0.016          -0.217             -0.160        0.143
# std                  0.871           1.124              0.986        0.923
# min                 -2.450          -3.723             -3.112       -2.562
# 25%                 -0.392          -0.585             -0.729       -0.394
# 50%                  0.277           0.123             -0.118        0.144
# 75%                  0.641           0.565              0.442        0.735
# max                  1.128           1.251              1.884        1.958
#
# peptide  DAGEGLLAVQITDPEGKPK  DHENIVIAK
# count                 99.000     99.000
# mean                  -0.009      0.083
# std                    0.928      1.071
# min                   -2.837     -3.770
# 25%                   -0.453     -0.421
# 50%                    0.084      0.013
# 75%                    0.606      0.864
# max                    1.775      2.453

# %%
# Validation dataset
# build validation DataFrame with mask according to validation data
# FillNA values in data as before, but do not add categorical columns (as this is done manuelly)
_valid_df = to.conts  # same data for predictions
_valid_df = _valid_df.join(analysis.df_valid.isna(), rsuffix='_na')  # mask
_valid_df = _valid_df.join(_df_valid.items, rsuffix='_val')  # target
_valid_df
# Out:
# peptide                                       AAEAAAAPAESAAPAAGEEPSK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            0.112
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           1.662
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             -0.265
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                2.135
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          1.911
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  -0.375
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               0.827
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               0.997
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               0.859
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               0.717
#
# peptide                                       AAHSEGNTTAGLDMR  AFGYYGPLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    -0.247     -0.846
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   -0.092     -0.844
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      -2.030     -0.504
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        -0.284     -0.703
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  -0.215     -1.015
# ...                                                       ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            1.055      0.445
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        0.182     -0.001
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        0.012     -0.372
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       -0.170     -0.357
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       -0.034     -0.249
#
# peptide                                       AGGAAVVITEPEHTK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    -0.809
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   -0.415
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       0.083
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         0.156
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  -1.156
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            0.308
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        0.166
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        0.314
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        0.534
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        0.156
#
# peptide                                       AGKPVICATQMLESMIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       0.303
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.539
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         0.115
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           0.303
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     0.303
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.520
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          0.140
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          0.576
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          0.570
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.572
#
# peptide                                       AGVNTVTTLVENKK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   -0.936
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  -1.025
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      0.193
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       -0.925
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  0.283
# ...                                                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          -2.923
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       0.316
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      -0.056
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       0.698
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       0.438
#
# peptide                                       AIVAIENPADVSVISSR  ALDTMNFDVIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      -0.764       -0.787
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.028       -0.755
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        -0.001       -0.766
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          -0.307       -0.626
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    -0.491       -0.356
# ...                                                         ...          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.895        0.594
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         -1.357       -0.403
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         -0.888       -0.306
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         -0.999        0.064
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.028        0.096
#
# peptide                                       DAGEGLLAVQITDPEGKPK  DHENIVIAK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        -0.129     -0.454
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       -0.265     -0.272
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           0.296     -0.813
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            -0.369     -2.122
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       0.235     -0.513
# ...                                                           ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                0.235      0.514
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            0.952     -0.031
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            1.026      0.325
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            0.854      0.597
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            0.792      0.660
#
# peptide                                       ...  TIGGGDDSFNTFFSETGAGK_val  \
# Sample ID                                     ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02           ...                       NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01          ...                       NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01             ...                       NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1               ...                       NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         ...                       NaN
# ...                                           ...                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02  ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04              ...                       NaN
#
# peptide                                       TSIAIDTIINQK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      NaN
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        -0.071
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         0.003
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           NaN
#
# peptide                                       VFSGLVSTGLK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     NaN
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          NaN
#
# peptide                                       VMTIAPGLFGTPLLTSLPEK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                                NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                               NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                  NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                    NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                              NaN
# ...                                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                   NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 0.307
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                   NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                   NaN
#
# peptide                                       VNIIPLIAK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN
# ...                                                     ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        NaN
#
# peptide                                       VSHVSTGGGASLELLEGK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                            NaN
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                 NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                 NaN
#
# peptide                                       VVFVFGPDK_val  VVHIMDFQR_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN         -0.531
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN            NaN
# ...                                                     ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            NaN          0.788
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        NaN            NaN
#
# peptide                                       YALYDATYETK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     NaN
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          NaN
#
# peptide                                       YRVPDVLVADPPIAR_val
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            -0.560
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         NaN
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                0.308
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              NaN
#
# [997 rows x 150 columns]

# %%
# [norm, FillMissing(add_col=False)]  # mask is provided explicitly
procs = None

cont_names = list(analysis.df_train.columns)
cat_names = [f'{s}_na' for s in cont_names]
y_names = [f'{s}_val' for s in cont_names]

splits = None
y_block = None
to_valid = TabularPandas(_valid_df, procs=procs, cat_names=cat_names, cont_names=cont_names,
                         y_names=y_names, splits=splits, y_block=y_block, do_setup=True)
to_valid.items
# Out:
# peptide                                       AAEAAAAPAESAAPAAGEEPSK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            0.112
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           1.662
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             -0.265
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                2.135
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          1.911
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  -0.375
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               0.827
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               0.997
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               0.859
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               0.717
#
# peptide                                       AAHSEGNTTAGLDMR  AFGYYGPLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    -0.247     -0.846
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   -0.092     -0.844
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      -2.030     -0.504
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        -0.284     -0.703
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  -0.215     -1.015
# ...                                                       ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            1.055      0.445
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        0.182     -0.001
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        0.012     -0.372
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       -0.170     -0.357
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       -0.034     -0.249
#
# peptide                                       AGGAAVVITEPEHTK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    -0.809
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   -0.415
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       0.083
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         0.156
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  -1.156
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            0.308
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        0.166
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        0.314
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        0.534
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        0.156
#
# peptide                                       AGKPVICATQMLESMIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       0.303
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.539
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         0.115
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           0.303
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     0.303
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.520
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          0.140
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          0.576
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          0.570
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.572
#
# peptide                                       AGVNTVTTLVENKK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   -0.936
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  -1.025
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      0.193
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       -0.925
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  0.283
# ...                                                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          -2.923
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       0.316
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      -0.056
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       0.698
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       0.438
#
# peptide                                       AIVAIENPADVSVISSR  ALDTMNFDVIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      -0.764       -0.787
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.028       -0.755
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        -0.001       -0.766
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          -0.307       -0.626
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    -0.491       -0.356
# ...                                                         ...          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.895        0.594
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         -1.357       -0.403
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         -0.888       -0.306
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         -0.999        0.064
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.028        0.096
#
# peptide                                       DAGEGLLAVQITDPEGKPK  DHENIVIAK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        -0.129     -0.454
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       -0.265     -0.272
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           0.296     -0.813
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            -0.369     -2.122
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       0.235     -0.513
# ...                                                           ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                0.235      0.514
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            0.952     -0.031
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            1.026      0.325
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            0.854      0.597
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            0.792      0.660
#
# peptide                                       ...  TIGGGDDSFNTFFSETGAGK_val  \
# Sample ID                                     ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02           ...                       NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01          ...                       NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01             ...                       NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1               ...                       NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         ...                       NaN
# ...                                           ...                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02  ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03              ...                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04              ...                       NaN
#
# peptide                                       TSIAIDTIINQK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      NaN
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        -0.071
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         0.003
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           NaN
#
# peptide                                       VFSGLVSTGLK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     NaN
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          NaN
#
# peptide                                       VMTIAPGLFGTPLLTSLPEK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                                NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                               NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                  NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                    NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                              NaN
# ...                                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                       NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                   NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 0.307
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                   NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                   NaN
#
# peptide                                       VNIIPLIAK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN
# ...                                                     ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        NaN
#
# peptide                                       VSHVSTGGGASLELLEGK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                            NaN
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                 NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                 NaN
#
# peptide                                       VVFVFGPDK_val  VVHIMDFQR_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN         -0.531
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN            NaN
# ...                                                     ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            NaN          0.788
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        NaN            NaN
#
# peptide                                       YALYDATYETK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     NaN
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          NaN
#
# peptide                                       YRVPDVLVADPPIAR_val
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            -0.560
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         NaN
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                0.308
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              NaN
#
# [997 rows x 150 columns]

# %%
stats_valid = to_valid.targ.iloc[:, :100].describe()
stats_valid
# Out:
# peptide  AAEAAAAPAESAAPAAGEEPSK_val  AAHSEGNTTAGLDMR_val  AFGYYGPLR_val  \
# count                        99.000               97.000         95.000
# mean                          0.085               -0.285          0.041
# std                           0.849                1.049          0.864
# min                          -2.066               -2.479         -2.672
# 25%                          -0.399               -0.883         -0.494
# 50%                           0.129               -0.231         -0.009
# 75%                           0.434                0.346          0.552
# max                           3.248                1.727          1.932
#
# peptide  AGGAAVVITEPEHTK_val  AGKPVICATQMLESMIK_val  AGVNTVTTLVENKK_val  \
# count                 99.000                100.000              97.000
# mean                  -0.100                  0.016              -0.217
# std                    1.187                  0.871               1.124
# min                   -4.335                 -2.450              -3.723
# 25%                   -0.684                 -0.392              -0.585
# 50%                    0.128                  0.277               0.123
# 75%                    0.766                  0.641               0.565
# max                    1.663                  1.128               1.251
#
# peptide  AIVAIENPADVSVISSR_val  ALDTMNFDVIK_val  DAGEGLLAVQITDPEGKPK_val  \
# count                   99.000           98.000                   99.000
# mean                    -0.160            0.143                   -0.009
# std                      0.986            0.923                    0.928
# min                     -3.112           -2.562                   -2.837
# 25%                     -0.729           -0.394                   -0.453
# 50%                     -0.118            0.144                    0.084
# 75%                      0.442            0.735                    0.606
# max                      1.884            1.958                    1.775
#
# peptide  DHENIVIAK_val  ...  TIGGGDDSFNTFFSETGAGK_val  TSIAIDTIINQK_val  \
# count           99.000  ...                   100.000            99.000
# mean             0.083  ...                    -0.045             0.103
# std              1.071  ...                     0.877             0.991
# min             -3.770  ...                    -3.003            -3.280
# 25%             -0.421  ...                    -0.517            -0.316
# 50%              0.013  ...                    -0.150             0.106
# 75%              0.864  ...                     0.521             0.604
# max              2.453  ...                     1.940             1.778
#
# peptide  VFSGLVSTGLK_val  VMTIAPGLFGTPLLTSLPEK_val  VNIIPLIAK_val  \
# count             99.000                    99.000         99.000
# mean               0.102                    -0.084         -0.069
# std                0.908                     0.852          1.006
# min               -3.092                    -2.327         -5.088
# 25%               -0.372                    -0.557         -0.321
# 50%               -0.082                    -0.006          0.137
# 75%                0.875                     0.409          0.540
# max                1.760                     1.460          1.214
#
# peptide  VSHVSTGGGASLELLEGK_val  VVFVFGPDK_val  VVHIMDFQR_val  \
# count                   100.000         99.000         98.000
# mean                      0.106         -0.054         -0.051
# std                       1.006          0.851          0.934
# min                      -4.218         -2.933         -2.770
# 25%                      -0.285         -0.524         -0.532
# 50%                       0.158         -0.160         -0.127
# 75%                       0.784          0.431          0.522
# max                       1.877          2.187          1.818
#
# peptide  YALYDATYETK_val  YRVPDVLVADPPIAR_val
# count            100.000               97.000
# mean              -0.024                0.139
# std                0.925                1.021
# min               -2.928               -3.967
# 25%               -0.487               -0.384
# 50%                0.233                0.304
# 75%                0.603                0.783
# max                1.707                2.443
#
# [8 rows x 50 columns]

# %%
# True = training data ("fill_na" transform sets mask to true in training data where values are replaced)
to_valid.cats
# Out:
# peptide                                       AAEAAAAPAESAAPAAGEEPSK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                               False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                               True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                  True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                    True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                              True
# ...                                                                 ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                       True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                   True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                   True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                   True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                   True
#
# peptide                                       AAHSEGNTTAGLDMR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       True
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            True
#
# peptide                                       AFGYYGPLR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 True
# ...                                                    ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                      True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                      True
#
# peptide                                       AGGAAVVITEPEHTK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       True
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           False
#
# peptide                                       AGKPVICATQMLESMIK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                          False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                              False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                        False
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              True
#
# peptide                                       AGVNTVTTLVENKK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     False
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           True
#
# peptide                                       AIVAIENPADVSVISSR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                         False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         True
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                             False
#
# peptide                                       ALDTMNFDVIK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   True
# ...                                                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        True
#
# peptide                                       DAGEGLLAVQITDPEGKPK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                             True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                            True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                 True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          False
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                   False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                True
#
# peptide                                       DHENIVIAK_na  ...  \
# Sample ID                                                   ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   True  ...
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  True  ...
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     True  ...
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       True  ...
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 True  ...
# ...                                                    ...  ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03                      True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04                      True  ...
#
# peptide                                       TIGGGDDSFNTFFSETGAGK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                            True
# ...                                                               ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                 True
#
# peptide                                       TSIAIDTIINQK_na  VFSGLVSTGLK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      True            True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     True            True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        True            True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          True            True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    True            True
# ...                                                       ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             True            True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        False            True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         True            True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        False            True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         True            True
#
# peptide                                       VMTIAPGLFGTPLLTSLPEK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                            True
# ...                                                               ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                 True
#
# peptide                                       VNIIPLIAK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 True
# ...                                                    ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                      True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                      True
#
# peptide                                       VSHVSTGGGASLELLEGK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          True
# ...                                                             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                   True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               True
#
# peptide                                       VVFVFGPDK_na  VVHIMDFQR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   True          True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  True          True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     True         False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       True          True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 True          True
# ...                                                    ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          True         False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                      True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                      True          True
#
# peptide                                       YALYDATYETK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   True
# ...                                                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        True
#
# peptide                                       YRVPDVLVADPPIAR_na
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       True
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            True
#
# [997 rows x 50 columns]

# %%
assert list(to_valid.cat_names) == list(
    _valid_df.select_dtypes(include='bool').columns)  # 'object'
assert to_valid.cats.equals(analysis.df_valid.isna().add_suffix('_na'))

# %% [markdown]
# ### Mix and match dataloaders
#
# - train dataloader in both TabularPandas objects used
# - train dataloader in dataloaders used in both case

# %%
args.batch_size
dl_train = to.dataloaders(shuffle_train=True, shuffle=False,
                          bs=args.batch_size).train  # , after_batch=after_batch)
dl_valid = to_valid.dataloaders(
    shuffle_train=False, shuffle=False, bs=args.batch_size).train

# %%
dls = DataLoaders(dl_train, dl_valid)
b = dls.train.one_batch()
[x.shape for x in b]  # cat, cont, target
# Out:
# [torch.Size([32, 50]), torch.Size([32, 50]), torch.Size([32, 0])]

# %%
dls = DataLoaders(dl_train, dl_valid)
b = dls.valid.one_batch()
[x.shape for x in b]  # cat, cont, target
# Out:
# [torch.Size([32, 50]), torch.Size([32, 50]), torch.Size([32, 50])]

# %% [markdown]
# ### Model
#
# - standard PyTorch Model from before

# %%
M = analysis.df_train.shape[-1]
model = ae.Autoencoder(n_features=M, n_neurons=int(
    M/2), last_decoder_activation=None, dim_latent=latent_dim)

# %% [markdown]
# ### Callbacks
#
# - controll training loop
#     - set what is data
#     - what should be used for evaluation (differs for training and evaluation mode)

# %%
ae.ModelAdapter
# Out:
# vaep.models.ae.ModelAdapter

# %% [markdown]
# ### Learner: Fastai Training Loop

# %%
learn = Learner(dls=dls, model=model,
                loss_func=MSELossFlat(), cbs=ae.ModelAdapter())

# %%
learn.show_training_loop()
# Out:
# Start Fit
#    - before_fit     : [TrainEvalCallback, Recorder, ProgressCallback]
#   Start Epoch Loop
#      - before_epoch   : [Recorder, ProgressCallback]
#     Start Train
#        - before_train   : [TrainEvalCallback, Recorder, ProgressCallback]
#       Start Batch Loop
#          - before_batch   : [ModelAdapter]
#          - after_pred     : [ModelAdapter]
#          - after_loss     : []
#          - before_backward: []
#          - before_step    : []
#          - after_step     : []
#          - after_cancel_batch: []
#          - after_batch    : [TrainEvalCallback, Recorder, ProgressCallback]
#       End Batch Loop
#     End Train
#      - after_cancel_train: [Recorder]
#      - after_train    : [Recorder, ProgressCallback]
#     Start Valid
#        - before_validate: [TrainEvalCallback, ModelAdapter, Recorder, ProgressCallback]
#       Start Batch Loop
#          - **CBs same as train batch**: []
#       End Batch Loop
#     End Valid
#      - after_cancel_validate: [Recorder]
#      - after_validate : [Recorder, ProgressCallback]
#   End Epoch Loop
#    - after_cancel_epoch: []
#    - after_epoch    : [Recorder]
# End Fit
#  - after_cancel_fit: []
#  - after_fit      : [ProgressCallback]

# %%
learn.summary()
# Out:
# Autoencoder (Input shape: 32 x 50)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      32 x 25
# Linear                                    1275       True
# Tanh
# ____________________________________________________________________________
#                      32 x 2
# Linear                                    52         True
# Tanh
# ____________________________________________________________________________
#                      32 x 25
# Linear                                    75         True
# Tanh
# ____________________________________________________________________________
#                      32 x 50
# Linear                                    1300       True
# ____________________________________________________________________________
#
# Total params: 2,702
# Total trainable params: 2,702
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001C5FB3F6040>
# Loss function: FlattenedLoss of MSELoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - ModelAdapter
#   - Recorder
#   - ProgressCallback

# %%
suggested_lr = learn.lr_find()
suggested_lr
# Out:
# SuggestedLRs(valley=0.009120108559727669)

# %% [markdown]
# ### Training

# %%
learn.fit_one_cycle(epochs_max, lr_max=suggested_lr.valley)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.911028</td>
#       <td>0.704362</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.634621</td>
#       <td>0.366147</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.470580</td>
#       <td>0.326207</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.393362</td>
#       <td>0.313587</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.350433</td>
#       <td>0.310503</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.328476</td>
#       <td>0.304156</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.312541</td>
#       <td>0.301301</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.301063</td>
#       <td>0.295687</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.293505</td>
#       <td>0.299071</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.289672</td>
#       <td>0.295375</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# learn.val_preds, learn.val_targets #

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.set_title('DAE loss: Reconstruction loss')
learn.recorder.plot_loss(skip_start=5, ax=ax)
vaep.io_images._savefig(fig, name='dae_training',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\dae_training

# %%
# L(zip(learn.recorder.iters, learn.recorder.values))

# %% [markdown]
# ### Evaluation

# %%
# reorder True: Only 500 predictions returned
pred, target = learn.get_preds(act=noop, concat_dim=0, reorder=False)
len(pred), len(target)
# Out:
# (4940, 4940)

# %% [markdown]
# MSE on transformed data is not too interesting for comparision between models if these use different standardizations

# %%
learn.loss_func(pred, target)  # MSE in transformed space not too interesting
# Out:
# TensorBase(0.2970)

# %%
# check target is in expected order
Y = dls.valid.targ

npt.assert_almost_equal(
    actual=target.numpy(),
    desired=Y.stack().to_numpy()
)

# %%
# import torch
# from fastai.tabular.core import TabularPandas

df_pred['intensity_pred_dae'] = ae.transform_preds(
    pred=pred, index=analysis.df_valid.stack().index, normalizer=tf_norm)
df_pred
# Out:
#                                                              intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK     30.289
#                                      AGKPVICATQMLESMIK          31.078
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR            28.132
#                                      AIVAIENPADVSVISSR          29.228
#                                      GISDLAQHYLMR               28.584
# ...                                                                ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR          29.348
#                                      GLVLGPIHK                  30.325
#                                      GYLGPEQLPDCLK              28.443
#                                      LATQSNEITIPVTFESR          31.105
#                                      SYSPYDMLESIRK              32.088
#
#                                                              train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK        28.540
#                                      AGKPVICATQMLESMIK             32.096
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR               28.425
#                                      AIVAIENPADVSVISSR             30.157
#                                      GISDLAQHYLMR                  29.492
# ...                                                                   ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR             30.157
#                                      GLVLGPIHK                     29.962
#                                      GYLGPEQLPDCLK                 29.384
#                                      LATQSNEITIPVTFESR             31.342
#                                      SYSPYDMLESIRK                 31.373
#
#                                                              train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK         28.400
#                                      AGKPVICATQMLESMIK              31.657
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR                28.617
#                                      AIVAIENPADVSVISSR              30.189
#                                      GISDLAQHYLMR                   29.429
# ...                                                                    ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR              30.189
#                                      GLVLGPIHK                      29.875
#                                      GYLGPEQLPDCLK                  29.535
#                                      LATQSNEITIPVTFESR              31.373
#                                      SYSPYDMLESIRK                  30.940
#
#                                                              replicates  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK      29.274
#                                      AGKPVICATQMLESMIK           31.351
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR             26.228
#                                      AIVAIENPADVSVISSR           29.740
#                                      GISDLAQHYLMR                28.219
# ...                                                                 ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR           29.081
#                                      GLVLGPIHK                   30.316
#                                      GYLGPEQLPDCLK               28.884
#                                      LATQSNEITIPVTFESR           31.352
#                                      SYSPYDMLESIRK               32.325
#
#                                                              intensity_pred_collab  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK                 27.335
#                                      AGKPVICATQMLESMIK                      30.919
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR                        27.440
#                                      AIVAIENPADVSVISSR                      29.312
#                                      GISDLAQHYLMR                           28.493
# ...                                                                            ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR                      30.009
#                                      GLVLGPIHK                              29.936
#                                      GYLGPEQLPDCLK                          29.236
#                                      LATQSNEITIPVTFESR                      31.180
#                                      SYSPYDMLESIRK                          31.945
#
#                                                              intensity_pred_dae
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK              27.395
#                                      AGKPVICATQMLESMIK                   30.632
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR                     27.151
#                                      AIVAIENPADVSVISSR                   29.291
#                                      GISDLAQHYLMR                        28.538
# ...                                                                         ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR                   29.926
#                                      GLVLGPIHK                           29.855
#                                      GYLGPEQLPDCLK                       29.134
#                                      LATQSNEITIPVTFESR                   31.147
#                                      SYSPYDMLESIRK                       32.025
#
# [4940 rows x 6 columns]

# %% [markdown]
# ### 2D plot of latent space
#
# - 2 dimensional latent space: just plot
# - more than 2 dimensional: PCA, etc

# %%
latent_space = []
for b in dls.valid:
    model_input = b[1]
    latent_space.append(model.encoder(model_input).detach().numpy())

df_dae_latent = build_df_from_pred_batches(latent_space,
                                           index=_df_valid.items.index,
                                           columns=[f'latent dimension {i+1}' for i in range(latent_dim)])
df_dae_latent.head()
# Out:
#                                        latent dimension 1  latent dimension 2
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                -0.253              -0.643
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.471              -0.745
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  -0.649              -0.806
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -0.403              -0.786
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              -0.541              -0.724

# %%
fig, ax = plt.subplots(figsize=(15, 15))
analyzers.plot_date_map(df=df_dae_latent, fig=fig, ax=ax,
                        dates=analysis.df_meta.date.loc[df_dae_latent.index])
vaep.io_images._savefig(fig, name='dae_latent_by_date',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\dae_latent_by_date

# %%
fig, ax = plt.subplots(figsize=(15, 15))

meta_col = 'ms_instrument'

analyzers.seaborn_scatter(df=df_dae_latent,
                          fig=fig,
                          ax=ax,
                          meta=analysis.df_meta[meta_col].loc[df_dae_latent.index],
                          title='by MS instrument')

vaep.io_images._savefig(
    fig, name=f'dae_latent_by_{meta_col}', folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\dae_latent_by_ms_instrument

# %% [markdown]
# ## Variational Autoencoder (VAE)

# %% [markdown]
# ### Scikit Learn MinMaxScaler
#
# - [docs](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html)

# %%
from vaep.transform import MinMaxScaler

args_vae = {}
args_vae['SCALER'] = MinMaxScaler
# select initial data: transformed vs not log transformed
scaler = args_vae['SCALER']().fit(analysis.df_train)
scaler.transform(analysis.df_valid.iloc[:5])
# Out:
# peptide                                AAEAAAAPAESAAPAAGEEPSK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     0.768
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     NaN
#
# peptide                                AAHSEGNTTAGLDMR  AFGYYGPLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                NaN        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01             0.589        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  NaN        NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    NaN        NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              NaN        NaN
#
# peptide                                AGGAAVVITEPEHTK  AGKPVICATQMLESMIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                NaN              0.635
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               NaN                NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  NaN                NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  0.598              0.636
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              NaN              0.752
#
# peptide                                AGVNTVTTLVENKK  AIVAIENPADVSVISSR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               NaN                NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              NaN              0.533
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 NaN                NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   NaN                NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01           0.617                NaN
#
# peptide                                ALDTMNFDVIK  DAGEGLLAVQITDPEGKPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02            NaN                  NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01           NaN                  NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01              NaN                  NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                NaN                  NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01          NaN                0.741
#
# peptide                                DHENIVIAK  ...  TIGGGDDSFNTFFSETGAGK  \
# Sample ID                                         ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          NaN  ...                   NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         NaN  ...                   NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01            NaN  ...                   NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1              NaN  ...                   NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        NaN  ...                   NaN
#
# peptide                                TSIAIDTIINQK  VFSGLVSTGLK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             NaN          NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            NaN          NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               NaN          NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 NaN          NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01           NaN          NaN
#
# peptide                                VMTIAPGLFGTPLLTSLPEK  VNIIPLIAK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     NaN        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN        NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN        NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN        NaN
#
# peptide                                VSHVSTGGGASLELLEGK  VVFVFGPDK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   NaN        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  NaN        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     NaN        NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       NaN        NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 NaN        NaN
#
# peptide                                VVHIMDFQR  YALYDATYETK  YRVPDVLVADPPIAR
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          NaN          NaN              NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         NaN          NaN              NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01          0.527          NaN              NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1              NaN          NaN            0.629
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        NaN          NaN              NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# ### DataLoaders
#
# - follow instructions for using plain PyTorch Datasets, see [tutorial](https://docs.fast.ai/tutorial.siamese.html#Preparing-the-data)

# %%
assert all(analysis.df_train.columns == analysis.df_valid.columns)
if not all(analysis.df.columns == analysis.df_train.columns):
    print("analysis.df columns are not the same as analysis.df_train")
    # ToDo: DataLoading has to be cleaned up
    # analysis.df = analysis.df_train.fillna(analysis.df_valid)
# Out:
# analysis.df columns are not the same as analysis.df_train

# %%
from vaep.io.datasets import PeptideDatasetInMemory

FILL_NA = 0.0

train_ds = PeptideDatasetInMemory(data=scaler.transform(
    analysis.df_train).to_numpy(dtype=None), fill_na=FILL_NA)
valid_ds = PeptideDatasetInMemory(data=scaler.transform(analysis.df_train.fillna(analysis.df_valid)).to_numpy(dtype=None),
                                  mask=analysis.df_valid.notna().to_numpy(), fill_na=FILL_NA)

assert (train_ds.peptides == valid_ds.peptides).all()

# %%
dls = DataLoaders.from_dsets(train_ds, valid_ds, n_inp=2)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %% [markdown]
# ### Model

# %%
from torch.nn import Sigmoid

M = analysis.df_train.shape[-1]
model = ae.VAE(n_features=M, n_neurons=int(
    M/2), last_encoder_activation=None, last_decoder_activation=Sigmoid, dim_latent=latent_dim)

# %% [markdown]
# ### Learner

# %%
learn = Learner(dls=dls,
                model=model,
                loss_func=ae.loss_fct_vae,
                cbs=ae.ModelAdapterVAE())

learn.show_training_loop()
learn.summary()
# Out:
# Start Fit
#    - before_fit     : [TrainEvalCallback, Recorder, ProgressCallback]
#   Start Epoch Loop
#      - before_epoch   : [Recorder, ProgressCallback]
#     Start Train
#        - before_train   : [TrainEvalCallback, Recorder, ProgressCallback]
#       Start Batch Loop
#          - before_batch   : [ModelAdapterVAE]
#          - after_pred     : [ModelAdapterVAE]
#          - after_loss     : []
#          - before_backward: []
#          - before_step    : []
#          - after_step     : []
#          - after_cancel_batch: []
#          - after_batch    : [TrainEvalCallback, Recorder, ProgressCallback]
#       End Batch Loop
#     End Train
#      - after_cancel_train: [Recorder]
#      - after_train    : [Recorder, ProgressCallback]
#     Start Valid
#        - before_validate: [TrainEvalCallback, Recorder, ProgressCallback]
#       Start Batch Loop
#          - **CBs same as train batch**: []
#       End Batch Loop
#     End Valid
#      - after_cancel_validate: [Recorder]
#      - after_validate : [Recorder, ProgressCallback]
#   End Epoch Loop
#    - after_cancel_epoch: []
#    - after_epoch    : [Recorder]
# End Fit
#  - after_cancel_fit: []
#  - after_fit      : [ProgressCallback]
# VAE (Input shape: 64 x 50)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      64 x 25
# Linear                                    75         True
# Tanh
# ____________________________________________________________________________
#                      64 x 50
# Linear                                    1300       True
# Sigmoid
# ____________________________________________________________________________
#                      64 x 25
# Linear                                    1275       True
# Tanh
# ____________________________________________________________________________
#                      64 x 4
# Linear                                    104        True
# ____________________________________________________________________________
#
# Total params: 2,754
# Total trainable params: 2,754
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001C5FB3F6040>
# Loss function: <function loss_fct_vae at 0x000001C5FB41D940>
#
# Callbacks:
#   - TrainEvalCallback
#   - ModelAdapterVAE
#   - Recorder
#   - ProgressCallback

# %% [markdown]
# ### Training

# %%
suggested_lr = learn.lr_find()
suggested_lr
# Out:
# SuggestedLRs(valley=0.00363078061491251)

# %%
learn.fit_one_cycle(epochs_max, lr_max=suggested_lr.valley)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1998.843506</td>
#       <td>215.697845</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1952.286743</td>
#       <td>210.012115</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1886.429810</td>
#       <td>202.741455</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1838.991699</td>
#       <td>194.510727</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1806.042480</td>
#       <td>194.245667</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1785.405518</td>
#       <td>195.073608</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1770.476685</td>
#       <td>195.526398</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1760.991211</td>
#       <td>196.397232</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1753.441895</td>
#       <td>196.331100</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1747.641113</td>
#       <td>196.356400</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.set_title('VAE loss: Reconstruction loss and Kullback-Leiber-Divergence for latent space')
learn.recorder.plot_loss(skip_start=5, ax=ax)
vaep.io_images._savefig(fig, name='vae_training',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\vae_training

# %% [markdown]
# ### Evaluation

# %%
# reorder True: Only 500 predictions returned
pred, target = learn.get_preds(act=noop, concat_dim=0, reorder=False)
len(pred), len(target)
# Out:
# (3, 4940)

# %%
len(pred[0])
# Out:
# 4940

# %%
learn.loss_func(pred, target)
# Out:
# tensor(3107.1572)

# %%
_pred = pd.Series(pred[0], index=analysis.df_valid.stack().index).unstack()
_pred = scaler.inverse_transform(_pred).stack()

df_pred['intensity_pred_vae'] = _pred
df_pred
# Out:
#                                                              intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK     30.289
#                                      AGKPVICATQMLESMIK          31.078
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR            28.132
#                                      AIVAIENPADVSVISSR          29.228
#                                      GISDLAQHYLMR               28.584
# ...                                                                ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR          29.348
#                                      GLVLGPIHK                  30.325
#                                      GYLGPEQLPDCLK              28.443
#                                      LATQSNEITIPVTFESR          31.105
#                                      SYSPYDMLESIRK              32.088
#
#                                                              train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK        28.540
#                                      AGKPVICATQMLESMIK             32.096
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR               28.425
#                                      AIVAIENPADVSVISSR             30.157
#                                      GISDLAQHYLMR                  29.492
# ...                                                                   ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR             30.157
#                                      GLVLGPIHK                     29.962
#                                      GYLGPEQLPDCLK                 29.384
#                                      LATQSNEITIPVTFESR             31.342
#                                      SYSPYDMLESIRK                 31.373
#
#                                                              train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK         28.400
#                                      AGKPVICATQMLESMIK              31.657
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR                28.617
#                                      AIVAIENPADVSVISSR              30.189
#                                      GISDLAQHYLMR                   29.429
# ...                                                                    ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR              30.189
#                                      GLVLGPIHK                      29.875
#                                      GYLGPEQLPDCLK                  29.535
#                                      LATQSNEITIPVTFESR              31.373
#                                      SYSPYDMLESIRK                  30.940
#
#                                                              replicates  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK      29.274
#                                      AGKPVICATQMLESMIK           31.351
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR             26.228
#                                      AIVAIENPADVSVISSR           29.740
#                                      GISDLAQHYLMR                28.219
# ...                                                                 ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR           29.081
#                                      GLVLGPIHK                   30.316
#                                      GYLGPEQLPDCLK               28.884
#                                      LATQSNEITIPVTFESR           31.352
#                                      SYSPYDMLESIRK               32.325
#
#                                                              intensity_pred_collab  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK                 27.335
#                                      AGKPVICATQMLESMIK                      30.919
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR                        27.440
#                                      AIVAIENPADVSVISSR                      29.312
#                                      GISDLAQHYLMR                           28.493
# ...                                                                            ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR                      30.009
#                                      GLVLGPIHK                              29.936
#                                      GYLGPEQLPDCLK                          29.236
#                                      LATQSNEITIPVTFESR                      31.180
#                                      SYSPYDMLESIRK                          31.945
#
#                                                              intensity_pred_dae  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK              27.395
#                                      AGKPVICATQMLESMIK                   30.632
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR                     27.151
#                                      AIVAIENPADVSVISSR                   29.291
#                                      GISDLAQHYLMR                        28.538
# ...                                                                         ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR                   29.926
#                                      GLVLGPIHK                           29.855
#                                      GYLGPEQLPDCLK                       29.134
#                                      LATQSNEITIPVTFESR                   31.147
#                                      SYSPYDMLESIRK                       32.025
#
#                                                              intensity_pred_vae
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AAEAAAAPAESAAPAAGEEPSK              28.424
#                                      AGKPVICATQMLESMIK                   31.769
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 AAHSEGNTTAGLDMR                     28.465
#                                      AIVAIENPADVSVISSR                   30.083
#                                      GISDLAQHYLMR                        29.364
# ...                                                                         ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AIVAIENPADVSVISSR                   30.262
#                                      GLVLGPIHK                           29.976
#                                      GYLGPEQLPDCLK                       29.595
#                                      LATQSNEITIPVTFESR                   31.467
#                                      SYSPYDMLESIRK                       31.064
#
# [4940 rows x 7 columns]

# %% [markdown]
# ### Add plot of latent space
#
# - 2 dimensional latent space: just plot
# - more than 2 dimensional: PCA, etc

# %%
latent_space = []
for b in dls.valid:
    model_input = b[0]
    b_mu, b_std = model.get_mu_and_logvar(model_input, detach=True)
    latent_space.append(b_mu)


df_vae_latent = build_df_from_pred_batches(latent_space,
                                           index=_df_valid.items.index,
                                           columns=[f'latent dimension {i+1}' for i in range(latent_dim)])
df_vae_latent.head()
# Out:
#                                        latent dimension 1  latent dimension 2
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                -0.026              -0.024
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                0.366               0.302
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   0.142               0.138
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     0.014              -0.001
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              -0.309              -0.274

# %%
fig, ax = plt.subplots(figsize=(15, 15))
analyzers.plot_date_map(df=df_vae_latent, fig=fig, ax=ax,
                        dates=analysis.df_meta.date.loc[df_vae_latent.index])
vaep.io_images._savefig(fig, name='vae_latent_by_date',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\vae_latent_by_date

# %%
fig, ax = plt.subplots(figsize=(15, 15))

meta_col = 'ms_instrument'

analyzers.seaborn_scatter(df=df_vae_latent,
                          fig=fig,
                          ax=ax,
                          meta=analysis.df_meta[meta_col].loc[df_vae_latent.index],
                          title='by MS instrument')

vaep.io_images._savefig(
    fig, name=f'vae_latent_by_{meta_col}', folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\vae_latent_by_ms_instrument

# %% [markdown]
# ## Compare the 3 models
#
# - replicates: replace NAs with neighbouring ("close") values
# - train average, median: Replace NA with average or median from training data

# %%
import sklearn.metrics as sklm
pred_columns = df_pred.columns[1:]
scoring = [('MSE', sklm.mean_squared_error),
           ('MAE', sklm.mean_absolute_error)]

y_true = df_pred['intensity']

metrics = {}
for col in pred_columns:
    _y_pred = df_pred[col].dropna()
    if len(df_pred[col]) > len(_y_pred):
        logger.info(
            f"Drop indices for {col}: {[(idx[0], idx[1]) for idx in df_pred[col].index.difference(_y_pred.index)]}")

    metrics[col] = dict(
        [(k, f(y_true=y_true.loc[_y_pred.index], y_pred=_y_pred))
         for k, f in scoring]
    )

metrics = pd.DataFrame(metrics)
metrics.to_csv(folder / f'exp_02_metrics.csv',
               float_format='{:.3f}'.format)
metrics.sort_values(by=[k for k, f in scoring], axis=1)
# Out:
# vaep - INFO     Drop indices for replicates: [('20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01', 'AGKPVICATQMLESMIK'), ('20181228_QE5_nLC5_OOE_QC_MNT_HELA_15cm_250ng_RO-007', 'EMEENFAVEAANYQDTIGR'), ('20181230_QE6_nLC6_CSC_QC_HeLa_03', 'HLAGLGLTEAIDK'), ('20190118_QE9_nLC9_NHS_MNT_HELA_50cm_04', 'SQIFSTASDNQPTVTIK'), ('20190128_QE3_nLC3_MJ_MNT_HeLa_01', 'TIAPALVSK'), ('20190219_QE3_Evo2_UHG_QC_MNT_HELA_01_190219173213', 'EMEENFAVEAANYQDTIGR'), ('20190220_QE3_nLC7_TSB_QC_MNT_HELA_02', 'GILADEDSSRPVWLK'), ('20190221_QE1_nLC2_ANHO_QC_MNT_HELA_02', 'ISMPDFDLHLK'), ('20190225_QE9_nLC0_RS_MNT_Hela_01', 'ELVTQQLPHLLK'), ('20190226_QE10_PhGe_Evosep_176min-30cmCol-HeLa_3', 'VVFVFGPDK'), ('20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_14_25', 'EMEENFAVEAANYQDTIGR'), ('20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_14_27', 'VVFVFGPDK'), ('20190226_QE10_PhGe_Evosep_88min-30cmCol-HeLa_15_24', 'IALGIPLPEIK'), ('20190226_QE1_nLC2_AB_QC_MNT_HELA_05', 'VVHIMDFQR'), ('20190301_QE7_nLC7_DS_QC_MNT_HeLa_01', 'LPNLTHLNLSGNK'), ('20190305_QE4_LC12_JE-IAH_QC_MNT_HeLa_02', 'GLDVDSLVIEHIQVNK'), ('20190308_QE3_nLC5_MR_QC_MNT_HeLa_Easyctcdon_02', 'ELVTQQLPHLLK'), ('20190327_QE6_LC6_SCL_QC_MNT_Hela_02', 'AGKPVICATQMLESMIK'), ('20190417_QE1_nLC2_GP_MNT_HELA_01', 'SYSPYDMLESIRK'), ('20190423_QX7_JuSc_MA_HeLa_500ng_LC01', 'SGGMSNELNNIISR'), ('20190425_QX4_JoSw_MA_HeLa_500ng_BR13_standard_190425181909', 'AGVNTVTTLVENKK'), ('20190425_QX8_JuSc_MA_HeLa_500ng_1', 'LAAVDATVNQVLASR'), ('20190426_QE10_nLC9_LiNi_QC_MNT_15cm_HeLa_01', 'GLDVDSLVIEHIQVNK'), ('20190429_QX6_ChDe_MA_HeLa_Br14_500ng_LC09', 'AGVNTVTTLVENKK'), ('20190430_QX6_ChDe_MA_HeLa_Br14_500ng_LC09', 'GLDVDSLVIEHIQVNK'), ('20190506_QE3_nLC3_DBJ_QC_MNT_HeLa_01', 'GILADEDSSRPVWLK'), ('20190506_QX7_ChDe_MA_HeLaBr14_500ng', 'AGVNTVTTLVENKK'), ('20190506_QX8_MiWi_MA_HeLa_500ng_old', 'AIVAIENPADVSVISSR'), ('20190510_QE1_nLC2_ANHO_QC_MNT_HELA_02', 'VMTIAPGLFGTPLLTSLPEK'), ('20190510_QE2_NLC1_GP_MNT_HELA_02', 'HLAGLGLTEAIDK'), ('20190515_QE4_LC12_AS_QC_MNT_HeLa_01_20190515230141', 'GILADEDSSRPVWLK'), ('20190515_QX4_JiYu_MA_HeLa_500ng_BR14', 'GYLGPEQLPDCLK'), ('20190522_QE10_nLC13_LiNi_QC_MNT_15cm_HeLa_01', 'VMTIAPGLFGTPLLTSLPEK'), ('20190527_QE3_nLC3_DS_QC_MNT_HeLa_02', 'SGGMSNELNNIISR'), ('20190606_QE4_LC12_JE_QC_MNT_HeLa_03', 'DHENIVIAK'), ('20190611_QX0_MaTa_MA_HeLa_500ng_LC07_1', 'NPDDITQEEYGEFYK'), ('20190617_QE1_nLC2_GP_QC_MNT_HELA_01_20190617213340', 'AAHSEGNTTAGLDMR'), ('20190624_QX3_MaMu_MA_Hela_500ng_LC15', 'TIAPALVSK'), ('20190628_QX6_AnPi_MA_HeLa_500ng_LC09', 'AGVNTVTTLVENKK'), ('20190629_QX4_JiYu_MA_HeLa_500ng_MAX_ALLOWED', 'SGGMSNELNNIISR'), ('20190708_QX7_MaMu_MA_HeLa_Br14_500ng', 'TIGGGDDSFNTFFSETGAGK'), ('20190708_QX8_AnPi_MA_HeLa_BR14_500ng', 'TIGGGDDSFNTFFSETGAGK'), ('20190709_QE1_nLC13_ANHO_QC_MNT_HELA_02', 'AAHSEGNTTAGLDMR'), ('20190710_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_01', 'AGVNTVTTLVENKK'), ('20190724_QX0_MePh_MA_HeLa_500ng_LC07_01', 'DNHLLGTFDLTGIPPAPR'), ('20190724_QX3_MiWi_MA_Hela_500ng_LC15', 'DNHLLGTFDLTGIPPAPR'), ('20190729_QX0_AsJa_MA_HeLa_500ng_LC07_01', 'VNIIPLIAK'), ('20190731_QX1_LiSc_MA_HeLa_500ng_LC10', 'YRVPDVLVADPPIAR'), ('20190731_QX8_ChSc_MA_HeLa_500ng', 'ELVTQQLPHLLK')]
#      intensity_pred_collab  intensity_pred_dae  replicates  \
# MSE                  0.543               0.570       1.517
# MAE                  0.453               0.470       0.855
#
#      intensity_pred_vae  train_average  train_median
# MSE               1.688          2.001         2.093
# MAE               0.958          1.052         1.035

# %% [markdown]
# Save final prediction values of validation data for later comparison.

# %%
df_pred.to_csv(folder /
               f"{config.FOLDER_DATA}_valid_pred.csv")

# %% [markdown]
# ## PCA plot for imputed and denoised data
#
# two setups:
#  - impute missing values
#  - additinally change observed values

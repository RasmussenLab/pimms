# %% [markdown]
# # Experiment 02
#
#
# The current approach for creating train, validation and test data sets is to split
# the data in long-format, i.e. one observation is an intensity value from one sample representing one peptide, into the desired splits. In this process missing values are not regarded.
#
# - [x] mask entries in larger dataset in long-format
# - [x] mask peptides based on their frequency in samples (probability of being observed)
# - [x] create *long-format* training data set without masked values for each model
#     - FNN based on embeddings of peptides and samples (long-format **without** missing values)
#     - Denoising AE (wide-format **with** missing values)
#     - VAE (wide-format **with** missing values)
# - [ ] restrict to only a training data split of consective data: Increase number of samples.
#     - focus on best reconstruction performance
#     - mean comparison
#
# ### Collaborative Filtering model
#
# - Cannot accomodate iid assumption of statistical test in current setup for embedding vectors.
#   - if pretrained model should be applied to an new batch of replicates (with a certain condition) one would need to find a way to initialize the sample embeddings without fine-tuning the model

# %%
import logging
from pprint import pprint
import seaborn
import numpy.testing as npt  # fastcore.test functionality

from pathlib import Path


import vaep.io_images
from vaep.pandas import interpolate
from vaep.model import build_df_from_pred_batches

from src.nb_imports import *
from src import metadata
from src.logging import setup_logger

logger = setup_logger(logger=logging.getLogger('vaep'))
logger.info("Experiment 02")

figures = {}  # collection of ax or figures
# Out:
# FOLDER_MQ_TXT_DATA = data\mq_out
# vaep - INFO     Experiment 02

# %%
# None takes all
N_SAMPLES: int = 1000
n_features: int = 50
ADD_TENSORBOARD: bool = False
FN_PEPTIDE_INTENSITIES: Path = (
    config.FOLDER_DATA / 'df_intensities_N07285_M01000')  # 90%
epochs_max = 10
batch_size = 32
latent_dim = 2
most_common: bool = False
most_uncommon: bool = False
out_folder: str = 'poster'
# write to read only config ? namedtuple?

# %%
# Parameters
n_feat = 500
n_epochs = 10
out_folder = "runs/2D"

# %%
BATCH_SIZE, EPOCHS = batch_size, epochs_max
folder = Path(out_folder) / f'feat_{n_features:04d}_epochs_{epochs_max:03d}'
print(f"{folder = }")

if most_common and most_uncommon:
    raise ValueError(f"Cannot be both True: {most_common = } and {most_uncommon = }")
# Out:
# folder = Path('runs/2D/feat_0050_epochs_010')

# %% [markdown]
# ## Raw data

# %%
FN_PEPTIDE_INTENSITIES = Path(FN_PEPTIDE_INTENSITIES)

# %%
analysis = AnalyzePeptides(fname=FN_PEPTIDE_INTENSITIES, nrows=None)
analysis.df.columns.name = 'peptide'
analysis.log_transform(np.log2)
analysis
# Out:
# AnalyzePeptides with attributes: M, N, df, index_col, is_log_transformed, is_wide_format, log_fct, stats

# %%
# some date are not possible in the indices
rename_indices_w_wrong_dates = {'20161131_LUMOS1_nLC13_AH_MNT_HeLa_long_03': '20161130_LUMOS1_nLC13_AH_MNT_HeLa_long_03',
                                '20180230_QE10_nLC0_MR_QC_MNT_Hela_12': '20180330_QE10_nLC0_MR_QC_MNT_Hela_12',
                                '20161131_LUMOS1_nLC13_AH_MNT_HeLa_long_01': '20161130_LUMOS1_nLC13_AH_MNT_HeLa_long_01',
                                '20180230_QE10_nLC0_MR_QC_MNT_Hela_11': '20180330_QE10_nLC0_MR_QC_MNT_Hela_11',
                                '20161131_LUMOS1_nLC13_AH_MNT_HeLa_long_02': '20161130_LUMOS1_nLC13_AH_MNT_HeLa_long_02'}
analysis.df.rename(index=rename_indices_w_wrong_dates, inplace=True)

# %% [markdown]
# ### Select N consecutive samples

# %%
analysis.get_consecutive_dates(n_samples=N_SAMPLES)
# Out:
# Get 1000 samples.
# Training data referenced unter: df_1000
# Updated attribute: df
# peptide                                       AAAAAAALQAK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                29.591
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               29.817
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  29.982
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    29.974
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              29.552
# ...                                                   ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02       31.517
# 20190805_QE1_nLC2_AB_MNT_HELA_01                   31.104
# 20190805_QE1_nLC2_AB_MNT_HELA_02                   31.248
# 20190805_QE1_nLC2_AB_MNT_HELA_03                   31.122
# 20190805_QE1_nLC2_AB_MNT_HELA_04                   30.814
#
# peptide                                       AAFDDAIAELDTLSEESYK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        31.264
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       31.354
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          31.211
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            30.238
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      31.966
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               32.278
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           31.747
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           31.923
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           31.802
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           31.892
#
# peptide                                       AAHSEGNTTAGLDMR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    28.098
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   28.132
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      24.357
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        28.022
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  28.165
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           30.832
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       28.999
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       28.643
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       28.260
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       28.546
#
# peptide                                       AAVATFLQSVQVPEFTPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       28.694
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      28.508
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         28.795
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           28.917
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     29.985
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              31.541
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          28.458
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          28.257
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          28.620
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          28.408
#
# peptide                                       AAVEEGIVLGGGCALLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      30.208
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     30.171
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        29.833
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          30.113
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    31.660
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             32.803
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         30.588
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         31.068
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         30.936
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         30.727
#
# peptide                                       AAVPSGASTGIYEALELR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       30.134
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      30.189
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         28.291
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           30.597
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     31.787
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              33.676
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          28.800
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          28.864
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          28.683
#
# peptide                                       AAVPSGASTGIYEALELRDNDK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           31.358
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          31.311
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                             32.533
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               31.781
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         31.915
# ...                                                              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  31.927
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              32.415
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              32.340
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              32.558
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              32.734
#
# peptide                                       ACANPAAGSVILLENLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      30.430
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     30.412
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        31.257
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          30.620
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    31.792
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             31.906
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         31.270
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         31.672
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         29.854
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         31.699
#
# peptide                                       ACGLVASNLNLKPGECLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       29.440
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      29.410
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         30.998
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           27.377
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     30.077
# ...                                                          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              27.631
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          30.077
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          31.636
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          31.661
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          31.578
#
# peptide                                       ADLINNLGTIAK  ...  VVFVFGPDK  \
# Sample ID                                                   ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 31.035  ...     29.047
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                31.034  ...     28.830
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   32.087  ...     29.325
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     31.457  ...     29.409
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               31.479  ...     29.341
# ...                                                    ...  ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02        33.747  ...     31.452
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    32.357  ...     29.504
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    32.466  ...     29.728
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    32.413  ...     29.755
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    32.284  ...     29.747
#
# peptide                                       VVFVFGPDKK  VYALPEDLVEVKPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               27.827          27.149
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              27.624          27.150
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 29.346          28.907
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   27.696          27.622
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                NaN          27.327
# ...                                                  ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02      28.512          29.634
# 20190805_QE1_nLC2_AB_MNT_HELA_01                  29.435          28.424
# 20190805_QE1_nLC2_AB_MNT_HELA_02                  29.741          28.667
# 20190805_QE1_nLC2_AB_MNT_HELA_03                  29.772          28.764
# 20190805_QE1_nLC2_AB_MNT_HELA_04                  29.809          29.158
#
# peptide                                       YADLTEDQLPSCESLK  YDDMAAAMK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     28.446     29.136
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    28.537     28.643
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       29.588     28.434
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         29.104     28.151
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   29.091     29.422
# ...                                                        ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            31.134     30.690
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        29.489     29.702
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        29.647     29.555
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        29.507     29.443
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        29.274     29.575
#
# peptide                                       YDDMAACMK  YDDMATCMK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02              28.936     27.337
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01             29.347     27.980
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                28.369     27.397
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  29.017     27.815
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            29.057     26.068
# ...                                                 ...        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02     30.142     29.881
# 20190805_QE1_nLC2_AB_MNT_HELA_01                 29.877     28.777
# 20190805_QE1_nLC2_AB_MNT_HELA_02                 29.709     28.592
# 20190805_QE1_nLC2_AB_MNT_HELA_03                 29.544     28.643
# 20190805_QE1_nLC2_AB_MNT_HELA_04                 29.545     28.487
#
# peptide                                       YLAEVACGDDRK  YLDEDTIYHLQPSGR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 28.873           27.724
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                29.179           27.444
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   29.143           27.233
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     29.317           28.027
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               29.129           27.474
# ...                                                    ...              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02        31.508           29.884
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    30.471           27.793
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    30.776           27.955
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    30.481           27.837
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    30.467           27.935
#
# peptide                                       YRVPDVLVADPPIAR
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    28.059
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   28.035
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      29.432
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        28.516
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  28.216
# ...                                                       ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           29.468
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       29.185
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       29.272
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       29.167
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       29.139
#
# [1000 rows x 1000 columns]

# %%
assert not analysis.df._is_view

# %% [markdown]
# ## Long format
#
# - Data in long format: (peptide, sample_id, intensity)
# - no missing values kept
# -

# %%
analysis.df_long.head()
# Out:
#                                                          intensity
# Sample ID                           peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02 AAAAAAALQAK             29.591
#                                     AAFDDAIAELDTLSEESYK     31.264
#                                     AAHSEGNTTAGLDMR         28.098
#                                     AAVATFLQSVQVPEFTPK      28.694
#                                     AAVEEGIVLGGGCALLR       30.208

# %%
assert analysis.df_long.isna().sum().sum(
) == 0, "There are still missing values in the long format."

# %%
analysis.df_wide.head()
# Out:
# peptide                                AAAAAAALQAK  AAFDDAIAELDTLSEESYK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02         29.591               31.264
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01        29.817               31.354
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01           29.982               31.211
# 20181222_QE9_nLC9_QC_50CM_HeLa1             29.974               30.238
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01       29.552               31.966
#
# peptide                                AAHSEGNTTAGLDMR  AAVATFLQSVQVPEFTPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             28.098              28.694
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            28.132              28.508
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               24.357              28.795
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 28.022              28.917
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01           28.165              29.985
#
# peptide                                AAVEEGIVLGGGCALLR  AAVPSGASTGIYEALELR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               30.208              30.134
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              30.171              30.189
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 29.833              28.291
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   30.113              30.597
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01             31.660              31.787
#
# peptide                                AAVPSGASTGIYEALELRDNDK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    31.358
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   31.311
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      32.533
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        31.781
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  31.915
#
# peptide                                ACANPAAGSVILLENLR  ACGLVASNLNLKPGECLR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02               30.430              29.440
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01              30.412              29.410
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 31.257              30.998
# 20181222_QE9_nLC9_QC_50CM_HeLa1                   30.620              27.377
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01             31.792              30.077
#
# peptide                                ADLINNLGTIAK  ...  VVFVFGPDK  \
# Sample ID                                            ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          31.035  ...     29.047
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         31.034  ...     28.830
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01            32.087  ...     29.325
# 20181222_QE9_nLC9_QC_50CM_HeLa1              31.457  ...     29.409
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        31.479  ...     29.341
#
# peptide                                VVFVFGPDKK  VYALPEDLVEVKPK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02        27.827          27.149
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01       27.624          27.150
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01          29.346          28.907
# 20181222_QE9_nLC9_QC_50CM_HeLa1            27.696          27.622
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01         NaN          27.327
#
# peptide                                YADLTEDQLPSCESLK  YDDMAAAMK  YDDMAACMK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02              28.446     29.136     28.936
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01             28.537     28.643     29.347
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                29.588     28.434     28.369
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  29.104     28.151     29.017
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            29.091     29.422     29.057
#
# peptide                                YDDMATCMK  YLAEVACGDDRK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02       27.337        28.873
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01      27.980        29.179
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01         27.397        29.143
# 20181222_QE9_nLC9_QC_50CM_HeLa1           27.815        29.317
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01     26.068        29.129
#
# peptide                                YLDEDTIYHLQPSGR  YRVPDVLVADPPIAR
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             27.724           28.059
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            27.444           28.035
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               27.233           29.432
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 28.027           28.516
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01           27.474           28.216
#
# [5 rows x 1000 columns]

# %%
assert analysis.df_wide.isna().sum().sum(
) > 0, "There are no missing values left in the wide format"

# %% [markdown]
# ### Sampling peptides by their frequency (important for later)
#
# - higher count, higher probability to be sampled into training data
# - missing peptides are sampled both into training as well as into validation dataset
# - everything not in training data is validation data

# %%
# freq_per_peptide = analysis.df.unstack().to_frame('intensity').reset_index(1, drop=True)
freq_per_peptide = analysis.df_long['intensity']
freq_per_peptide = freq_per_peptide.notna().groupby(level=1).sum()
print(f"{n_features = }")
# Out:
# n_features = 50

# %% [markdown]
# ### Selecting N
#  - most common
#  - most uncommon

# %%
freq_per_pepitde = freq_per_peptide.sort_values(ascending=False)

if most_common:
    freq_per_pepitde = freq_per_pepitde.iloc[:n_features]
elif most_uncommon:
    freq_per_pepitde = freq_per_pepitde.iloc[-n_features:]
else:
    freq_per_pepitde = freq_per_pepitde.sample(n_features)
    
assert len(freq_per_pepitde.index) == n_features

freq_per_pepitde
# Out:
# peptide
# VNVPVIGGHAGK                 990
# ELVYPPDYNPEGK                997
# HIMGQNVADYMR                 999
# SLEDQVEMLR                   982
# SLHDALCVIR                   995
# LMELHGEGSSSGK                992
# LMIEMDGTENK                  999
# ALPFWNEEIVPQIK               937
# TLHPDLGTDK                   997
# IVSRPEELREDDVGTGAGLLEIK      997
# KHPDASVNFSEFSK               998
# YADLTEDQLPSCESLK             998
# TEFLSFMNTELAAFTK             994
# NALESYAFNMK                  993
# IVVVTAGVR                    981
# VVVAENFDEIVNNENK             998
# NMDPLNDNIATLLHQSSDK          996
# LIAPVAEEEATVPNNK             997
# LVNHFVEEFK                   980
# GIHPTIISESFQK                999
# AMVSEFLK                     984
# AYHEQLSVAEITNACFEPANQMVK   1,000
# TAVVVGTITDDVR                999
# GLVEPVDVVDNADGTQTVNYVPSR     948
# DSYVGDEAQSK                  999
# TGTAEMSSILEER                999
# NAGVEGSLIVEK                 992
# YLTVAAVFR                    993
# LSVLGAITSVQQR                959
# NTDEMVELR                    996
# TLGILGLGR                    963
# GVNLPGAAVDLPAVSEK          1,000
# HQPTAIIAK                    980
# RLAPEYEAAATR                 953
# STGEAFVQFASQEIAEK            992
# RGEAHLAVNDFELAR              992
# IIQLLDDYPK                   963
# ILDQGEDFPASEMTR              993
# HELLQPFNVLYEK                996
# ELAPYDENWFYTR                956
# YDDMATCMK                    984
# IFVGGLSPDTPEEK               987
# LNNLVLFDK                    956
# SYCAEIAHNVSSK                990
# IVLLDSSLEYK                  987
# AHSSMVGVNLPQK              1,000
# VSFELFADK                    975
# RFPGYDSESK                   992
# NSVTPDMMEEMYK                993
# IYELAAGGTAVGTGLNTR           992
# Name: intensity, dtype: int64

# %%
analysis.df = analysis.df[freq_per_pepitde.index]
# ToDo: clean-up other attributes needs to be integrated
del analysis._df_long  # , analysis._df_wide
analysis.df_long
# Out:
#                                                         intensity
# Sample ID                           peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02 VNVPVIGGHAGK           27.985
#                                     ELVYPPDYNPEGK          26.558
#                                     HIMGQNVADYMR           28.806
#                                     SLEDQVEMLR             28.105
#                                     SLHDALCVIR             28.126
# ...                                                           ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04    IVLLDSSLEYK            28.844
#                                     AHSSMVGVNLPQK          28.602
#                                     RFPGYDSESK             28.980
#                                     NSVTPDMMEEMYK          28.778
#                                     IYELAAGGTAVGTGLNTR     26.758
#
# [49332 rows x 1 columns]

# %% [markdown]
# - biological stock differences in PCA plot. Show differences in models. Only see biological variance

# %% [markdown]
# ## PCA plot of raw data

# %%
fig = analysis.plot_pca()
# Out:
# vaep - ERROR    Could not find LC instrument in 20190418_QX8_JuSc_MA_HeLa_500ng_1
# vaep - ERROR    Could not find LC instrument in 20190422_QX8_JuSc_MA_HeLa_500ng_1
# vaep - ERROR    Could not find LC instrument in 20190425_QX8_JuSc_MA_HeLa_500ng_1
# vaep - ERROR    Could not find LC instrument in 20190501_QX8_MiWi_MA_HeLa_500ng_new
# vaep - ERROR    Could not find LC instrument in 20190502_QX7_ChDe_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190502_QX8_MiWi_MA_HeLa_500ng_new
# vaep - ERROR    Could not find LC instrument in 20190502_QX8_MiWi_MA_HeLa_500ng_old
# vaep - ERROR    Could not find LC instrument in 20190506_QX7_ChDe_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190506_QX8_MiWi_MA_HeLa_500ng_new
# vaep - ERROR    Could not find LC instrument in 20190506_QX8_MiWi_MA_HeLa_500ng_old
# vaep - ERROR    Could not find LC instrument in 20190514_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190520_QX4_JoSw_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190521_QX4_JoSw_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190524_QX4_JoSw_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190526_QX4_LiSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190527_QX4_IgPa_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190530_QX4_IgPa_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190603_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190606_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190607_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190611_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190615_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190617_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190617_QX8_IgPa_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng_190618125902
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng_190619010035
# vaep - ERROR    Could not find LC instrument in 20190618_QX4_JiYu_MA_HeLa_500ng_centroid
# vaep - ERROR    Could not find LC instrument in 20190621_QX4_JoMu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190621_QX4_JoMu_MA_HeLa_500ng_190621161214
# vaep - ERROR    Could not find LC instrument in 20190624_QX4_JiYu_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190629_QX4_JiYu_MA_HeLa_500ng_MAX_ALLOWED
# vaep - ERROR    Could not find LC instrument in 20190701_QX4_MePh_MA_HeLa_500ng_MAX_ALLOWED
# vaep - ERROR    Could not find LC instrument in 20190703_QX4_MaTa_MA_HeLa_500ng_MAX_ALLOWED
# vaep - ERROR    Could not find LC instrument in 20190706_QX4_MiWi_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190706_QX4_MiWi_MA_HeLa_500ng_190707003046
# vaep - ERROR    Could not find LC instrument in 20190717_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190718_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190719_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190722_QX4_StEb_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190722_QX8_ChSc_MA_HeLa_500ng_190722174431
# vaep - ERROR    Could not find LC instrument in 20190725_QX2_MePh_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190726_QX8_ChSc_MA_HeLa_500ng
# vaep - ERROR    Could not find LC instrument in 20190731_QX8_ChSc_MA_HeLa_500ng
# Created metadata DataFrame attribute `df_meta`.
# Added proportion of not NA values based on `df` intensities.

# %%
# ToDo add df_meta property
analysis.df_meta.describe()
# Out:
#        prop_not_na
# count    1,000.000
# mean         0.987
# std          0.020
# min          0.880
# 25%          0.980
# 50%          1.000
# 75%          1.000
# max          1.000

# %%
vaep.io_images._savefig(fig, folder /
                        f'pca_plot_raw_data_{analysis.fname_stub}')
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\pca_plot_raw_data_N01000_M00050

# %% [markdown]
# ## Train and Validation data
#
# - use mulitindex for obtaining validation split

# %%
# analysis._df_long = analysis.df_long.reset_index(
# ).set_index(['Sample ID', 'peptide'])
analysis.df_long
# Out:
#                                                         intensity
# Sample ID                           peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02 VNVPVIGGHAGK           27.985
#                                     ELVYPPDYNPEGK          26.558
#                                     HIMGQNVADYMR           28.806
#                                     SLEDQVEMLR             28.105
#                                     SLHDALCVIR             28.126
# ...                                                           ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04    IVLLDSSLEYK            28.844
#                                     AHSSMVGVNLPQK          28.602
#                                     RFPGYDSESK             28.980
#                                     NSVTPDMMEEMYK          28.778
#                                     IYELAAGGTAVGTGLNTR     26.758
#
# [49332 rows x 1 columns]

# %%
# df_long = analysis.df.unstack().to_frame('intensity').reset_index(1)
analysis.df_train = analysis.df_long.reset_index(0).groupby(
    by='Sample ID',
    level=0
).sample(frac=0.90,
         weights=freq_per_peptide,
         random_state=42)
analysis.df_train = analysis.df_train.reset_index().set_index([
    'Sample ID', 'peptide'])
analysis.df_train
# Out:
#                                                                       intensity
# Sample ID                                              peptide
# 20190411_QE6_LC6_AS_QC_MNT_HeLa_02                     AHSSMVGVNLPQK     29.949
# 20190730_QE1_nLC2_GP_MNT_HELA_02                       AHSSMVGVNLPQK     28.333
# 20190624_QE6_LC4_AS_QC_MNT_HeLa_01                     AHSSMVGVNLPQK     27.104
# 20190528_QX1_PhGe_MA_HeLa_DMSO_500ng_LC14_190528164924 AHSSMVGVNLPQK     32.006
# 20190208_QE2_NLC1_AB_QC_MNT_HELA_4                     AHSSMVGVNLPQK     30.812
# ...                                                                         ...
# 20190405_QE1_nLC2_GP_MNT_QC_hela_01                    YLTVAAVFR         30.268
# 20190706_QX4_MiWi_MA_HeLa_500ng                        YLTVAAVFR         32.232
# 20190527_QE4_LC12_AS_QC_MNT_HeLa_01                    YLTVAAVFR         30.311
# 20190514_QX6_ChDe_MA_HeLa_Br14_500ng_LC09              YLTVAAVFR         31.461
# 20190619_QE7_nLC7_AP_QC_MNT_HeLa_02                    YLTVAAVFR         30.368
#
# [44399 rows x 1 columns]

# %%
analysis.indices_valid = analysis.df_long.index.difference(
    analysis.df_train.index)
analysis.df_valid = analysis.df_long.loc[analysis.indices_valid]

# %%
assert len(analysis.df_long) == len(analysis.df_train) + len(analysis.df_valid)

# %% [markdown]
# Check that all samples are also in the validation data

# %%
assert analysis.df_train.index.levshape == (N_SAMPLES, n_features)

try:
    assert analysis.df_valid.index.levshape == (N_SAMPLES, n_features)
except AssertionError:
    print(f'Expected shape in validation: {(N_SAMPLES, n_features)}')
    print(f'Shape in validation: {analysis.df_valid.index.levshape}')

analysis.df_train = analysis.df_train.loc[analysis.df_valid.index.levels[0]]
analysis.df_train = analysis.df_train.reset_index().set_index(
    ['Sample ID', 'peptide'])  # update index categories (there is probably a better way)
N_SAMPLES = analysis.df_valid.index.levshape[0]
analysis.df_train.index.levshape, analysis.df_valid.index.levshape
# Out:
# Expected shape in validation: (1000, 50)
# Shape in validation: (990, 50)
# ((990, 50), (990, 50))

# %% [markdown]
# ## Setup DL
#
# - [ ] move all above to separate data notebook

# %%
import vaep.models as models
from vaep.models.cmd import get_args
from vaep.models import ae

args = get_args(batch_size=BATCH_SIZE, epochs=EPOCHS,
                no_cuda=False)  # data transfer to GPU seems slow
kwargs = {'num_workers': 2, 'pin_memory': True} if args.cuda else {}

# torch.manual_seed(args.seed)
device = torch.device("cuda" if args.cuda else "cpu")
device

print(f"{args = }", f"{device = }", sep='\n')
# Out:
# args = Namespace(batch_size=32, cuda=True, epochs=10, log_interval=10, no_cuda=False, seed=43)
# device = device(type='cuda')

# %% [markdown]
# Fastai default device for computation

# %%
import fastai.torch_core
print(f"{torch.cuda.is_available() = }")  # self-documenting python 3.8
fastai.torch_core.defaults
# Out:
# torch.cuda.is_available() = True
# namespace(cpus=12,
#           use_cuda=None,
#           activation=torch.nn.modules.activation.ReLU,
#           callbacks=[fastai.callback.core.TrainEvalCallback,
#                      fastai.learner.Recorder,
#                      fastai.callback.progress.ProgressCallback],
#           lr=0.001)

# %% [markdown]
# ### Comparison data
#
# - first impute first and last row (using n=3 replicate)
# - use pandas interpolate

# %%
analysis.median_train = analysis.df_train['intensity'].unstack().median()
analysis.median_train.name = 'train_median'
analysis.averag_train = analysis.df_train['intensity'].unstack().mean()
analysis.averag_train.name = 'train_average'

df_pred = analysis.df_valid.copy()

df_pred = df_pred.join(analysis.median_train, on='peptide')
df_pred = df_pred.join(analysis.averag_train, on='peptide')


_ = interpolate(wide_df=analysis.df_train['intensity'].unstack())
df_pred = df_pred.join(_)

df_pred
# Out:
#                                                                intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                29.899
#                                      DSYVGDEAQSK                  32.783
#                                      SLEDQVEMLR                   28.105
#                                      TLGILGLGR                    28.345
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK               29.217
# ...                                                                  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK             29.613
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK     31.539
#                                      IVSRPEELREDDVGTGAGLLEIK      30.671
#                                      LSVLGAITSVQQR                27.476
#                                      STGEAFVQFASQEIAEK            30.364
#
#                                                                train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                   30.250
#                                      DSYVGDEAQSK                     33.542
#                                      SLEDQVEMLR                      28.950
#                                      TLGILGLGR                       28.815
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                  31.081
# ...                                                                     ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                29.629
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK        31.468
#                                      IVSRPEELREDDVGTGAGLLEIK         29.922
#                                      LSVLGAITSVQQR                   27.545
#                                      STGEAFVQFASQEIAEK               30.274
#
#                                                                train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                    30.245
#                                      DSYVGDEAQSK                      33.310
#                                      SLEDQVEMLR                       28.810
#                                      TLGILGLGR                        28.585
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                   30.827
# ...                                                                      ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                 29.761
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK         31.570
#                                      IVSRPEELREDDVGTGAGLLEIK          30.016
#                                      LSVLGAITSVQQR                    27.684
#                                      STGEAFVQFASQEIAEK                30.238
#
#                                                                replicates
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                 30.008
#                                      DSYVGDEAQSK                   33.189
#                                      SLEDQVEMLR                    28.098
#                                      TLGILGLGR                     28.547
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                30.196
# ...                                                                   ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK              29.744
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK      31.623
#                                      IVSRPEELREDDVGTGAGLLEIK       30.115
#                                      LSVLGAITSVQQR                 27.425
#                                      STGEAFVQFASQEIAEK             30.494
#
# [4933 rows x 4 columns]

# %%
if any(df_pred.isna()):
    print("Consecutive NaNs are not imputed using replicates.")
    display(df_pred.loc[df_pred.isna().any(axis=1)])
# Out:
# Consecutive NaNs are not imputed using replicates.
#                                                                                    intensity  \
# Sample ID                                                peptide
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                         KHPDASVNFSEFSK               30.219
# 20190107_QE10_nLC0_KS_QC_MNT_HeLa_01                     GVNLPGAAVDLPAVSEK            31.313
# 20190110_QE8_nLC14_JM_QC_MNT_HeLa_02                     STGEAFVQFASQEIAEK            30.318
# 20190114_QE4_LC6_IAH_QC_MNT_HeLa_250ng_01                LVNHFVEEFK                   30.359
# 20190121_QE5_nLC5_AH_QC_MNT_HeLa_250ng_01                SLEDQVEMLR                   28.443
# 20190121_QE5_nLC5_AH_QC_MNT_HeLa_250ng_02                SLEDQVEMLR                   28.568
# 20190204_QE6_nLC6_MPL_QC_MNT_HeLa_01                     GVNLPGAAVDLPAVSEK            30.907
# 20190205_QE7_nLC7_MEM_QC_MNT_HeLa_03                     HQPTAIIAK                    33.074
# 20190205_QE7_nLC7_MEM_QC_MNT_HeLa_04                     HQPTAIIAK                    33.122
# 20190218_QE6_LC6_SCL_MVM_QC_MNT_Hela_03                  HQPTAIIAK                    31.785
# 20190219_QE2_NLC1_GP_QC_MNT_HELA_01                      VSFELFADK                    30.071
# 20190225_QE10_PhGe_Evosep_88min_HeLa_1_20190225173940    LVNHFVEEFK                   27.129
# 20190225_QE10_PhGe_Evosep_88min_HeLa_2                   LVNHFVEEFK                   27.446
# 20190225_QE9_nLC0_RS_MNT_Hela_02                         VSFELFADK                    29.607
# 20190228_QE4_LC12_JE_QC_MNT_HeLa_01                      VNVPVIGGHAGK                 26.222
# 20190301_QE1_nLC2_ANHO_QC_MNT_HELA_01_20190303025443     IIQLLDDYPK                   30.927
# 20190304_QE10_nLC0_KS_QC_MNT_HeLa_02                     LSVLGAITSVQQR                27.695
# 20190318_QE2_NLC1_AB_MNT_HELA_04                         AHSSMVGVNLPQK                27.985
# 20190402_QE6_LC6_AS_QC_MNT_HeLa_03                       YADLTEDQLPSCESLK             30.281
# 20190402_QE7_nLC3_AL_QC_MNT_HeLa_01                      YADLTEDQLPSCESLK             28.349
# 20190408_QE1_nLC2_GP_MNT_QC_hela_02_20190408131505       NAGVEGSLIVEK                 30.255
# 20190409_QE1_nLC2_ANHO_MNT_QC_hela_02                    ALPFWNEEIVPQIK               30.556
# 20190423_QX2_FlMe_MA_HeLa_500ng_LC05_CTCDoff             YADLTEDQLPSCESLK             31.712
# 20190423_QX7_JuSc_MA_HeLaBr14_500ng_LC02                 LNNLVLFDK                    32.189
# 20190425_QX4_JoSw_MA_HeLa_500ng_BR13_standard            YLTVAAVFR                    30.961
# 20190425_QX7_ChDe_MA_HeLaBr14_500ng_LC02                 RLAPEYEAAATR                 29.287
# 20190429_QX3_ChDe_MA_Hela_500ng_LC15_190429151336        LSVLGAITSVQQR                29.485
# 20190508_QE8_nLC14_ASD_QC_MNT_HeLa_01                    GLVEPVDVVDNADGTQTVNYVPSR     25.961
# 20190510_QE2_NLC1_GP_MNT_HELA_02                         KHPDASVNFSEFSK               29.617
# 20190513_QX2_SeVW_MA_HeLa_500ng_LC05_CTCDoff_1           SYCAEIAHNVSSK                30.987
# 20190513_QX7_ChDe_MA_HeLaBr14_500ng                      GLVEPVDVVDNADGTQTVNYVPSR     29.255
# 20190513_QX8_MiWi_MA_HeLa_BR14_500ng                     VSFELFADK                    33.204
# 20190514_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14              SYCAEIAHNVSSK                31.794
# 20190515_QX3_AsJa_MA_Hela_500ng_LC15                     IIQLLDDYPK                   31.893
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                     IIQLLDDYPK                   31.713
# 20190522_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14_190524170803 IVSRPEELREDDVGTGAGLLEIK      32.297
# 20190611_QX7_IgPa_MA_HeLa_Br14_500ng                     ALPFWNEEIVPQIK               32.525
# 20190618_QX4_JiYu_MA_HeLa_500ng_centroid                 TGTAEMSSILEER                27.211
# 20190624_QE10_nLC14_LiNi_QC_MNT_15cm_HeLa_CPH_01         NAGVEGSLIVEK                 30.486
# 20190625_QE6_LC4_AS_QC_MNT_HeLa_02                       RFPGYDSESK                   30.027
# 20190625_QE6_LC4_AS_QC_MNT_HeLa_03                       RFPGYDSESK                   28.646
# 20190625_QE8_nLC14_GP_QC_MNT_15cm_Hela_02                DSYVGDEAQSK                  34.087
# 20190627_QE9_nLC0_RG_MNT_Hela_MUC_50cm_1                 ALPFWNEEIVPQIK               29.664
# 20190628_QE8_nLC14_GP_QC_MNT_15cm_Hela_01                YDDMATCMK                    28.010
# 20190701_QX8_AnPi_MA_HeLa_BR14_500ng                     SYCAEIAHNVSSK                31.655
# 20190705_QX0_AnBr_MA_HeLa_500ng_LC07_01_190707104639     ALPFWNEEIVPQIK               32.939
# 20190708_QE9_nLC2_AGF_QC_MNT_HeLa_01_20190709092142      ALPFWNEEIVPQIK               31.120
# 20190712_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_01              ELAPYDENWFYTR                30.610
# 20190716_QE1_nLC13_ANHO_QC_MNT_HELA_01                   LVNHFVEEFK                   27.221
# 20190726_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_4thcolumn_1     VNVPVIGGHAGK                 30.991
# 20190801_QX3_StEb_MA_Hela_500ng_LC15                     NMDPLNDNIATLLHQSSDK          28.940
# 20190803_QX8_AnPi_MA_HeLa_BR14_500ng                     SLEDQVEMLR                   30.574
#
#                                                                                    train_median  \
# Sample ID                                                peptide
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                         KHPDASVNFSEFSK                  30.205
# 20190107_QE10_nLC0_KS_QC_MNT_HeLa_01                     GVNLPGAAVDLPAVSEK               31.238
# 20190110_QE8_nLC14_JM_QC_MNT_HeLa_02                     STGEAFVQFASQEIAEK               30.274
# 20190114_QE4_LC6_IAH_QC_MNT_HeLa_250ng_01                LVNHFVEEFK                      28.285
# 20190121_QE5_nLC5_AH_QC_MNT_HeLa_250ng_01                SLEDQVEMLR                      28.950
# 20190121_QE5_nLC5_AH_QC_MNT_HeLa_250ng_02                SLEDQVEMLR                      28.950
# 20190204_QE6_nLC6_MPL_QC_MNT_HeLa_01                     GVNLPGAAVDLPAVSEK               31.238
# 20190205_QE7_nLC7_MEM_QC_MNT_HeLa_03                     HQPTAIIAK                       32.208
# 20190205_QE7_nLC7_MEM_QC_MNT_HeLa_04                     HQPTAIIAK                       32.208
# 20190218_QE6_LC6_SCL_MVM_QC_MNT_Hela_03                  HQPTAIIAK                       32.208
# 20190219_QE2_NLC1_GP_QC_MNT_HELA_01                      VSFELFADK                       31.015
# 20190225_QE10_PhGe_Evosep_88min_HeLa_1_20190225173940    LVNHFVEEFK                      28.285
# 20190225_QE10_PhGe_Evosep_88min_HeLa_2                   LVNHFVEEFK                      28.285
# 20190225_QE9_nLC0_RS_MNT_Hela_02                         VSFELFADK                       31.015
# 20190228_QE4_LC12_JE_QC_MNT_HeLa_01                      VNVPVIGGHAGK                    27.439
# 20190301_QE1_nLC2_ANHO_QC_MNT_HELA_01_20190303025443     IIQLLDDYPK                      30.289
# 20190304_QE10_nLC0_KS_QC_MNT_HeLa_02                     LSVLGAITSVQQR                   27.545
# 20190318_QE2_NLC1_AB_MNT_HELA_04                         AHSSMVGVNLPQK                   30.250
# 20190402_QE6_LC6_AS_QC_MNT_HeLa_03                       YADLTEDQLPSCESLK                29.916
# 20190402_QE7_nLC3_AL_QC_MNT_HeLa_01                      YADLTEDQLPSCESLK                29.916
# 20190408_QE1_nLC2_GP_MNT_QC_hela_02_20190408131505       NAGVEGSLIVEK                    30.729
# 20190409_QE1_nLC2_ANHO_MNT_QC_hela_02                    ALPFWNEEIVPQIK                  31.081
# 20190423_QX2_FlMe_MA_HeLa_500ng_LC05_CTCDoff             YADLTEDQLPSCESLK                29.916
# 20190423_QX7_JuSc_MA_HeLaBr14_500ng_LC02                 LNNLVLFDK                       30.242
# 20190425_QX4_JoSw_MA_HeLa_500ng_BR13_standard            YLTVAAVFR                       30.440
# 20190425_QX7_ChDe_MA_HeLaBr14_500ng_LC02                 RLAPEYEAAATR                    28.819
# 20190429_QX3_ChDe_MA_Hela_500ng_LC15_190429151336        LSVLGAITSVQQR                   27.545
# 20190508_QE8_nLC14_ASD_QC_MNT_HeLa_01                    GLVEPVDVVDNADGTQTVNYVPSR        27.146
# 20190510_QE2_NLC1_GP_MNT_HELA_02                         KHPDASVNFSEFSK                  30.205
# 20190513_QX2_SeVW_MA_HeLa_500ng_LC05_CTCDoff_1           SYCAEIAHNVSSK                   30.573
# 20190513_QX7_ChDe_MA_HeLaBr14_500ng                      GLVEPVDVVDNADGTQTVNYVPSR        27.146
# 20190513_QX8_MiWi_MA_HeLa_BR14_500ng                     VSFELFADK                       31.015
# 20190514_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14              SYCAEIAHNVSSK                   30.573
# 20190515_QX3_AsJa_MA_Hela_500ng_LC15                     IIQLLDDYPK                      30.289
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                     IIQLLDDYPK                      30.289
# 20190522_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14_190524170803 IVSRPEELREDDVGTGAGLLEIK         29.922
# 20190611_QX7_IgPa_MA_HeLa_Br14_500ng                     ALPFWNEEIVPQIK                  31.081
# 20190618_QX4_JiYu_MA_HeLa_500ng_centroid                 TGTAEMSSILEER                   30.089
# 20190624_QE10_nLC14_LiNi_QC_MNT_15cm_HeLa_CPH_01         NAGVEGSLIVEK                    30.729
# 20190625_QE6_LC4_AS_QC_MNT_HeLa_02                       RFPGYDSESK                      29.007
# 20190625_QE6_LC4_AS_QC_MNT_HeLa_03                       RFPGYDSESK                      29.007
# 20190625_QE8_nLC14_GP_QC_MNT_15cm_Hela_02                DSYVGDEAQSK                     33.542
# 20190627_QE9_nLC0_RG_MNT_Hela_MUC_50cm_1                 ALPFWNEEIVPQIK                  31.081
# 20190628_QE8_nLC14_GP_QC_MNT_15cm_Hela_01                YDDMATCMK                       28.358
# 20190701_QX8_AnPi_MA_HeLa_BR14_500ng                     SYCAEIAHNVSSK                   30.573
# 20190705_QX0_AnBr_MA_HeLa_500ng_LC07_01_190707104639     ALPFWNEEIVPQIK                  31.081
# 20190708_QE9_nLC2_AGF_QC_MNT_HeLa_01_20190709092142      ALPFWNEEIVPQIK                  31.081
# 20190712_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_01              ELAPYDENWFYTR                   29.427
# 20190716_QE1_nLC13_ANHO_QC_MNT_HELA_01                   LVNHFVEEFK                      28.285
# 20190726_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_4thcolumn_1     VNVPVIGGHAGK                    27.439
# 20190801_QX3_StEb_MA_Hela_500ng_LC15                     NMDPLNDNIATLLHQSSDK             29.917
# 20190803_QX8_AnPi_MA_HeLa_BR14_500ng                     SLEDQVEMLR                      28.950
#
#                                                                                    train_average  \
# Sample ID                                                peptide
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                         KHPDASVNFSEFSK                   30.232
# 20190107_QE10_nLC0_KS_QC_MNT_HeLa_01                     GVNLPGAAVDLPAVSEK                31.486
# 20190110_QE8_nLC14_JM_QC_MNT_HeLa_02                     STGEAFVQFASQEIAEK                30.238
# 20190114_QE4_LC6_IAH_QC_MNT_HeLa_250ng_01                LVNHFVEEFK                       29.359
# 20190121_QE5_nLC5_AH_QC_MNT_HeLa_250ng_01                SLEDQVEMLR                       28.810
# 20190121_QE5_nLC5_AH_QC_MNT_HeLa_250ng_02                SLEDQVEMLR                       28.810
# 20190204_QE6_nLC6_MPL_QC_MNT_HeLa_01                     GVNLPGAAVDLPAVSEK                31.486
# 20190205_QE7_nLC7_MEM_QC_MNT_HeLa_03                     HQPTAIIAK                        32.028
# 20190205_QE7_nLC7_MEM_QC_MNT_HeLa_04                     HQPTAIIAK                        32.028
# 20190218_QE6_LC6_SCL_MVM_QC_MNT_Hela_03                  HQPTAIIAK                        32.028
# 20190219_QE2_NLC1_GP_QC_MNT_HELA_01                      VSFELFADK                        31.382
# 20190225_QE10_PhGe_Evosep_88min_HeLa_1_20190225173940    LVNHFVEEFK                       29.359
# 20190225_QE10_PhGe_Evosep_88min_HeLa_2                   LVNHFVEEFK                       29.359
# 20190225_QE9_nLC0_RS_MNT_Hela_02                         VSFELFADK                        31.382
# 20190228_QE4_LC12_JE_QC_MNT_HeLa_01                      VNVPVIGGHAGK                     28.314
# 20190301_QE1_nLC2_ANHO_QC_MNT_HELA_01_20190303025443     IIQLLDDYPK                       30.334
# 20190304_QE10_nLC0_KS_QC_MNT_HeLa_02                     LSVLGAITSVQQR                    27.684
# 20190318_QE2_NLC1_AB_MNT_HELA_04                         AHSSMVGVNLPQK                    30.245
# 20190402_QE6_LC6_AS_QC_MNT_HeLa_03                       YADLTEDQLPSCESLK                 30.035
# 20190402_QE7_nLC3_AL_QC_MNT_HeLa_01                      YADLTEDQLPSCESLK                 30.035
# 20190408_QE1_nLC2_GP_MNT_QC_hela_02_20190408131505       NAGVEGSLIVEK                     30.952
# 20190409_QE1_nLC2_ANHO_MNT_QC_hela_02                    ALPFWNEEIVPQIK                   30.827
# 20190423_QX2_FlMe_MA_HeLa_500ng_LC05_CTCDoff             YADLTEDQLPSCESLK                 30.035
# 20190423_QX7_JuSc_MA_HeLaBr14_500ng_LC02                 LNNLVLFDK                        30.313
# 20190425_QX4_JoSw_MA_HeLa_500ng_BR13_standard            YLTVAAVFR                        30.569
# 20190425_QX7_ChDe_MA_HeLaBr14_500ng_LC02                 RLAPEYEAAATR                     28.546
# 20190429_QX3_ChDe_MA_Hela_500ng_LC15_190429151336        LSVLGAITSVQQR                    27.684
# 20190508_QE8_nLC14_ASD_QC_MNT_HeLa_01                    GLVEPVDVVDNADGTQTVNYVPSR         27.151
# 20190510_QE2_NLC1_GP_MNT_HELA_02                         KHPDASVNFSEFSK                   30.232
# 20190513_QX2_SeVW_MA_HeLa_500ng_LC05_CTCDoff_1           SYCAEIAHNVSSK                    30.489
# 20190513_QX7_ChDe_MA_HeLaBr14_500ng                      GLVEPVDVVDNADGTQTVNYVPSR         27.151
# 20190513_QX8_MiWi_MA_HeLa_BR14_500ng                     VSFELFADK                        31.382
# 20190514_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14              SYCAEIAHNVSSK                    30.489
# 20190515_QX3_AsJa_MA_Hela_500ng_LC15                     IIQLLDDYPK                       30.334
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                     IIQLLDDYPK                       30.334
# 20190522_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14_190524170803 IVSRPEELREDDVGTGAGLLEIK          30.016
# 20190611_QX7_IgPa_MA_HeLa_Br14_500ng                     ALPFWNEEIVPQIK                   30.827
# 20190618_QX4_JiYu_MA_HeLa_500ng_centroid                 TGTAEMSSILEER                    30.100
# 20190624_QE10_nLC14_LiNi_QC_MNT_15cm_HeLa_CPH_01         NAGVEGSLIVEK                     30.952
# 20190625_QE6_LC4_AS_QC_MNT_HeLa_02                       RFPGYDSESK                       29.082
# 20190625_QE6_LC4_AS_QC_MNT_HeLa_03                       RFPGYDSESK                       29.082
# 20190625_QE8_nLC14_GP_QC_MNT_15cm_Hela_02                DSYVGDEAQSK                      33.310
# 20190627_QE9_nLC0_RG_MNT_Hela_MUC_50cm_1                 ALPFWNEEIVPQIK                   30.827
# 20190628_QE8_nLC14_GP_QC_MNT_15cm_Hela_01                YDDMATCMK                        28.418
# 20190701_QX8_AnPi_MA_HeLa_BR14_500ng                     SYCAEIAHNVSSK                    30.489
# 20190705_QX0_AnBr_MA_HeLa_500ng_LC07_01_190707104639     ALPFWNEEIVPQIK                   30.827
# 20190708_QE9_nLC2_AGF_QC_MNT_HeLa_01_20190709092142      ALPFWNEEIVPQIK                   30.827
# 20190712_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_01              ELAPYDENWFYTR                    29.245
# 20190716_QE1_nLC13_ANHO_QC_MNT_HELA_01                   LVNHFVEEFK                       29.359
# 20190726_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_4thcolumn_1     VNVPVIGGHAGK                     28.314
# 20190801_QX3_StEb_MA_Hela_500ng_LC15                     NMDPLNDNIATLLHQSSDK              29.589
# 20190803_QX8_AnPi_MA_HeLa_BR14_500ng                     SLEDQVEMLR                       28.810
#
#                                                                                    replicates
# Sample ID                                                peptide
# 20181230_QE6_nLC6_CSC_QC_HeLa_03                         KHPDASVNFSEFSK                   NaN
# 20190107_QE10_nLC0_KS_QC_MNT_HeLa_01                     GVNLPGAAVDLPAVSEK                NaN
# 20190110_QE8_nLC14_JM_QC_MNT_HeLa_02                     STGEAFVQFASQEIAEK                NaN
# 20190114_QE4_LC6_IAH_QC_MNT_HeLa_250ng_01                LVNHFVEEFK                       NaN
# 20190121_QE5_nLC5_AH_QC_MNT_HeLa_250ng_01                SLEDQVEMLR                       NaN
# 20190121_QE5_nLC5_AH_QC_MNT_HeLa_250ng_02                SLEDQVEMLR                       NaN
# 20190204_QE6_nLC6_MPL_QC_MNT_HeLa_01                     GVNLPGAAVDLPAVSEK                NaN
# 20190205_QE7_nLC7_MEM_QC_MNT_HeLa_03                     HQPTAIIAK                        NaN
# 20190205_QE7_nLC7_MEM_QC_MNT_HeLa_04                     HQPTAIIAK                        NaN
# 20190218_QE6_LC6_SCL_MVM_QC_MNT_Hela_03                  HQPTAIIAK                        NaN
# 20190219_QE2_NLC1_GP_QC_MNT_HELA_01                      VSFELFADK                        NaN
# 20190225_QE10_PhGe_Evosep_88min_HeLa_1_20190225173940    LVNHFVEEFK                       NaN
# 20190225_QE10_PhGe_Evosep_88min_HeLa_2                   LVNHFVEEFK                       NaN
# 20190225_QE9_nLC0_RS_MNT_Hela_02                         VSFELFADK                        NaN
# 20190228_QE4_LC12_JE_QC_MNT_HeLa_01                      VNVPVIGGHAGK                     NaN
# 20190301_QE1_nLC2_ANHO_QC_MNT_HELA_01_20190303025443     IIQLLDDYPK                       NaN
# 20190304_QE10_nLC0_KS_QC_MNT_HeLa_02                     LSVLGAITSVQQR                    NaN
# 20190318_QE2_NLC1_AB_MNT_HELA_04                         AHSSMVGVNLPQK                    NaN
# 20190402_QE6_LC6_AS_QC_MNT_HeLa_03                       YADLTEDQLPSCESLK                 NaN
# 20190402_QE7_nLC3_AL_QC_MNT_HeLa_01                      YADLTEDQLPSCESLK                 NaN
# 20190408_QE1_nLC2_GP_MNT_QC_hela_02_20190408131505       NAGVEGSLIVEK                     NaN
# 20190409_QE1_nLC2_ANHO_MNT_QC_hela_02                    ALPFWNEEIVPQIK                   NaN
# 20190423_QX2_FlMe_MA_HeLa_500ng_LC05_CTCDoff             YADLTEDQLPSCESLK                 NaN
# 20190423_QX7_JuSc_MA_HeLaBr14_500ng_LC02                 LNNLVLFDK                        NaN
# 20190425_QX4_JoSw_MA_HeLa_500ng_BR13_standard            YLTVAAVFR                        NaN
# 20190425_QX7_ChDe_MA_HeLaBr14_500ng_LC02                 RLAPEYEAAATR                     NaN
# 20190429_QX3_ChDe_MA_Hela_500ng_LC15_190429151336        LSVLGAITSVQQR                    NaN
# 20190508_QE8_nLC14_ASD_QC_MNT_HeLa_01                    GLVEPVDVVDNADGTQTVNYVPSR         NaN
# 20190510_QE2_NLC1_GP_MNT_HELA_02                         KHPDASVNFSEFSK                   NaN
# 20190513_QX2_SeVW_MA_HeLa_500ng_LC05_CTCDoff_1           SYCAEIAHNVSSK                    NaN
# 20190513_QX7_ChDe_MA_HeLaBr14_500ng                      GLVEPVDVVDNADGTQTVNYVPSR         NaN
# 20190513_QX8_MiWi_MA_HeLa_BR14_500ng                     VSFELFADK                        NaN
# 20190514_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14              SYCAEIAHNVSSK                    NaN
# 20190515_QX3_AsJa_MA_Hela_500ng_LC15                     IIQLLDDYPK                       NaN
# 20190515_QX4_JiYu_MA_HeLa_500ng_BR14                     IIQLLDDYPK                       NaN
# 20190522_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14_190524170803 IVSRPEELREDDVGTGAGLLEIK          NaN
# 20190611_QX7_IgPa_MA_HeLa_Br14_500ng                     ALPFWNEEIVPQIK                   NaN
# 20190618_QX4_JiYu_MA_HeLa_500ng_centroid                 TGTAEMSSILEER                    NaN
# 20190624_QE10_nLC14_LiNi_QC_MNT_15cm_HeLa_CPH_01         NAGVEGSLIVEK                     NaN
# 20190625_QE6_LC4_AS_QC_MNT_HeLa_02                       RFPGYDSESK                       NaN
# 20190625_QE6_LC4_AS_QC_MNT_HeLa_03                       RFPGYDSESK                       NaN
# 20190625_QE8_nLC14_GP_QC_MNT_15cm_Hela_02                DSYVGDEAQSK                      NaN
# 20190627_QE9_nLC0_RG_MNT_Hela_MUC_50cm_1                 ALPFWNEEIVPQIK                   NaN
# 20190628_QE8_nLC14_GP_QC_MNT_15cm_Hela_01                YDDMATCMK                        NaN
# 20190701_QX8_AnPi_MA_HeLa_BR14_500ng                     SYCAEIAHNVSSK                    NaN
# 20190705_QX0_AnBr_MA_HeLa_500ng_LC07_01_190707104639     ALPFWNEEIVPQIK                   NaN
# 20190708_QE9_nLC2_AGF_QC_MNT_HeLa_01_20190709092142      ALPFWNEEIVPQIK                   NaN
# 20190712_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_01              ELAPYDENWFYTR                    NaN
# 20190716_QE1_nLC13_ANHO_QC_MNT_HELA_01                   LVNHFVEEFK                       NaN
# 20190726_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_4thcolumn_1     VNVPVIGGHAGK                     NaN
# 20190801_QX3_StEb_MA_Hela_500ng_LC15                     NMDPLNDNIATLLHQSSDK              NaN
# 20190803_QX8_AnPi_MA_HeLa_BR14_500ng                     SLEDQVEMLR                       NaN

# %% [markdown]
# ## Collaboritive filtering model

# %%
from fastai.collab import CollabDataLoaders, MSELossFlat, Learner
from fastai.collab import EmbeddingDotBias

analysis.collab = Analysis()
collab = analysis.collab
collab.columns = 'peptide,Sample ID,intensity'.split(',')

# %% [markdown]
# Create data view for collaborative filtering
#
# - currently a bit hacky as the splitter does not support predefinded indices (create custum subclass providing splits to internal methods?)
#
# - Use the [`CollabDataLoaders`](https://docs.fast.ai/collab.html#CollabDataLoaders)  similar to the [`TabularDataLoaders`](https://docs.fast.ai/tabular.data.html#TabularDataLoaders).
# - Use the [`IndexSplitter`](https://docs.fast.ai/data.transforms.html#IndexSplitter) and provide splits to whatever is used in `CollabDataLoaders`

# %%
collab.df_train = analysis.df_train.reset_index()
collab.df_valid = analysis.df_valid.reset_index()
collab.df_train.head()
# Out:
#                              Sample ID                   peptide  intensity
# 0  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02            ALPFWNEEIVPQIK     29.497
# 1  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  AMVSEFLK     28.042
# 2  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AYHEQLSVAEITNACFEPANQMVK     30.245
# 3  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             ELAPYDENWFYTR     27.436
# 4  20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             ELVYPPDYNPEGK     26.558

# %%
collab.df_valid.head()
# Out:
#                               Sample ID         peptide  intensity
# 0   20181219_QE3_nLC3_DS_QC_MNT_HeLa_02   AHSSMVGVNLPQK     29.899
# 1   20181219_QE3_nLC3_DS_QC_MNT_HeLa_02     DSYVGDEAQSK     32.783
# 2   20181219_QE3_nLC3_DS_QC_MNT_HeLa_02      SLEDQVEMLR     28.105
# 3   20181219_QE3_nLC3_DS_QC_MNT_HeLa_02       TLGILGLGR     28.345
# 4  20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01  ALPFWNEEIVPQIK     29.217

# %%
assert (collab.df_train.intensity.isna().sum(),
        collab.df_valid.intensity.isna().sum()) == (0, 0), "Remove missing values."

# %% [markdown]
# Hacky part uses training data `Datasets` from dataloaders to recreate a custom `DataLoaders` instance

# %%
collab.dl_train = CollabDataLoaders.from_df(
    collab.df_train, valid_pct=0.0, user_name='Sample ID', item_name='peptide', rating_name='intensity', bs=args.batch_size, device=device)
collab.dl_valid = CollabDataLoaders.from_df(
    collab.df_valid, valid_pct=0.0, user_name='Sample ID', item_name='peptide', rating_name='intensity', bs=args.batch_size,
    shuffle=False, device=device)
collab.dl_train.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sample ID</th>
#       <th>peptide</th>
#       <th>intensity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20190412_QE6_LC6_AS_QC_MNT_HeLa_01</td>
#       <td>LNNLVLFDK</td>
#       <td>30.486</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20190718_QE9_nLC9_NHS_MNT_HELA_50cm_01</td>
#       <td>YDDMATCMK</td>
#       <td>26.540</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20190621_QX2_SeVW_MA_HeLa_500ng_LC05</td>
#       <td>HELLQPFNVLYEK</td>
#       <td>30.399</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20190422_QX8_JuSc_MA_HeLa_500ng_1</td>
#       <td>KHPDASVNFSEFSK</td>
#       <td>30.495</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20190205_QE7_nLC7_MEM_QC_MNT_HeLa_03</td>
#       <td>SLHDALCVIR</td>
#       <td>30.043</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>20190702_QE3_nLC5_GF_QC_MNT_Hela_01</td>
#       <td>NTDEMVELR</td>
#       <td>27.828</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>20190417_QE4_LC12_JE-IAH_QC_MNT_HeLa_03</td>
#       <td>VSFELFADK</td>
#       <td>30.373</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>20190211_QE4_nLC12_SIS_QC_MNT_Hela_2</td>
#       <td>RFPGYDSESK</td>
#       <td>28.667</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>20190618_QX3_LiSc_MA_Hela_500ng_LC15</td>
#       <td>NTDEMVELR</td>
#       <td>30.943</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>20190528_QX6_AsJa_MA_HeLa_Br14_500ng_LC09</td>
#       <td>HIMGQNVADYMR</td>
#       <td>30.559</td>
#     </tr>
#   </tbody>
# </table>

# %%
from fastai.data.core import DataLoaders
collab.dls = DataLoaders(collab.dl_train.train, collab.dl_valid.train)
if args.cuda:
    collab.dls.cuda()

# %%
collab.dl_valid.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sample ID</th>
#       <th>peptide</th>
#       <th>intensity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20190606_QE4_LC12_JE_QC_MNT_HeLa_03</td>
#       <td>RGEAHLAVNDFELAR</td>
#       <td>28.706</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20190510_QE2_NLC1_GP_MNT_HELA_02</td>
#       <td>TLGILGLGR</td>
#       <td>28.640</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20190726_QE7_nLC7_MEM_QC_MNT_HeLa_03</td>
#       <td>AYHEQLSVAEITNACFEPANQMVK</td>
#       <td>31.619</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20190621_QX4_JoMu_MA_HeLa_500ng_190621161214</td>
#       <td>TGTAEMSSILEER</td>
#       <td>31.227</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20190225_QE10_PhGe_Evosep_88min_HeLa_6</td>
#       <td>AHSSMVGVNLPQK</td>
#       <td>29.437</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>20190626_QE7_nLC7_DS_QC_MNT_HeLa_02</td>
#       <td>VNVPVIGGHAGK</td>
#       <td>26.298</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>20190626_QX6_ChDe_MA_HeLa_500ng_LC09</td>
#       <td>TEFLSFMNTELAAFTK</td>
#       <td>32.885</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>20190803_QE9_nLC13_RG_SA_HeLa_50cm_350ng</td>
#       <td>YDDMATCMK</td>
#       <td>28.988</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>20190715_QE2_NLC1_ANHO_MNT_HELA_02</td>
#       <td>LMIEMDGTENK</td>
#       <td>32.776</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>20190712_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_01</td>
#       <td>AHSSMVGVNLPQK</td>
#       <td>31.777</td>
#     </tr>
#   </tbody>
# </table>

# %%
len(collab.dls.classes['Sample ID']), len(collab.dls.classes['peptide'])
# Out:
# (991, 51)

# %%
len(collab.dls.train), len(collab.dls.valid)  # mini-batches
# Out:
# (1372, 155)

# %% [markdown]
# Alternatively to the hacky version, one could use a factory method, but there the sampling/Splitting methods would need to be implemented (not using [`RandomSplitter`](https://docs.fast.ai/data.transforms.html#RandomSplitter) somehow)
#
#  - [`TabDataLoader`](https://docs.fast.ai/tabular.core.html#TabDataLoader)
#  - uses [`TabularPandas`](https://docs.fast.ai/tabular.core.html#TabularPandas)
#
#  > Current problem: No custom splitter can be provided

# %% [markdown]
# ### Model

# %%
collab.model_args = {}
collab.model_args['n_samples'] = len(collab.dls.classes['Sample ID'])
collab.model_args['n_peptides'] = len(collab.dls.classes['peptide'])
collab.model_args['dim_latent_factors'] = latent_dim
collab.model_args['y_range'] = (
    int(analysis.df_train['intensity'].min()), int(analysis.df_train['intensity'].max())+1)

print("Args:")
pprint(collab.model_args)


# from vaep.models.collab import DotProductBias
# model = DotProductBias(**collab.model_args)
model = EmbeddingDotBias.from_classes(
    n_factors=collab.model_args['dim_latent_factors'], classes=collab.dls.classes, y_range=collab.model_args['y_range'])
learn = Learner(dls=collab.dls, model=model, loss_func=MSELossFlat())
if args.cuda:
    learn.cuda()
learn.summary()
# Out:
# Args:
# {'dim_latent_factors': 2,
#  'n_peptides': 51,
#  'n_samples': 991,
#  'y_range': (20, 36)}
# EmbeddingDotBias (Input shape: 32 x 2)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      32 x 2
# Embedding                                 1982       True
# Embedding                                 102        True
# ____________________________________________________________________________
#                      32 x 1
# Embedding                                 991        True
# Embedding                                 51         True
# ____________________________________________________________________________
#
# Total params: 3,126
# Total trainable params: 3,126
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001CBC0506040>
# Loss function: FlattenedLoss of MSELoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %% [markdown]
# ### Training

# %%
learn.fit_one_cycle(epochs_max, 5e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.746584</td>
#       <td>1.643620</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.664948</td>
#       <td>0.672359</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.571682</td>
#       <td>0.615115</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.514574</td>
#       <td>0.563398</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.547034</td>
#       <td>0.532022</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.461233</td>
#       <td>0.518302</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.432974</td>
#       <td>0.509214</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.416380</td>
#       <td>0.506805</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.377849</td>
#       <td>0.502489</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.439591</td>
#       <td>0.502159</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
from vaep.models import plot_loss
from fastai import learner
learner.Recorder.plot_loss = plot_loss

fig, ax = plt.subplots(figsize=(15, 8))
ax.set_title('Collab loss: Reconstruction loss.')
learn.recorder.plot_loss(skip_start=5, ax=ax)
vaep.io_images._savefig(fig, name='collab_training',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_training

# %% [markdown]
# ### Evaluation

# %%
collab.dls.valid_ds.items
# Out:
#        Sample ID  peptide  intensity
# 3,161        634       34     28.706
# 2,512        502       43     28.640
# 4,616        928        4     31.619
# 3,556        717       42     31.227
# 1,136        217        1     29.437
# ...          ...      ...        ...
# 9              3       10     31.245
# 484           97        3     27.915
# 2,518        503       37     27.225
# 1,407        276       44     32.527
# 1,068        204       45     28.599
#
# [4933 rows x 3 columns]

# %%
df_pred = df_pred.reset_index()
pred, target = learn.get_preds()
df_pred['intensity_pred_collab'] = pd.Series(
    pred.flatten().numpy(), index=collab.dls.valid.items.index)

npt.assert_almost_equal(
    actual=collab.dls.valid.items.intensity.to_numpy(),
    desired=target.numpy().flatten()
)


df_pred = analyzers.cast_object_to_category(df_pred)
df_pred.set_index(['Sample ID', 'peptide'], inplace=True)
df_pred
# Out:
#                                                                intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                29.899
#                                      DSYVGDEAQSK                  32.783
#                                      SLEDQVEMLR                   28.105
#                                      TLGILGLGR                    28.345
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK               29.217
# ...                                                                  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK             29.613
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK     31.539
#                                      IVSRPEELREDDVGTGAGLLEIK      30.671
#                                      LSVLGAITSVQQR                27.476
#                                      STGEAFVQFASQEIAEK            30.364
#
#                                                                train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                   30.250
#                                      DSYVGDEAQSK                     33.542
#                                      SLEDQVEMLR                      28.950
#                                      TLGILGLGR                       28.815
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                  31.081
# ...                                                                     ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                29.629
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK        31.468
#                                      IVSRPEELREDDVGTGAGLLEIK         29.922
#                                      LSVLGAITSVQQR                   27.545
#                                      STGEAFVQFASQEIAEK               30.274
#
#                                                                train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                    30.245
#                                      DSYVGDEAQSK                      33.310
#                                      SLEDQVEMLR                       28.810
#                                      TLGILGLGR                        28.585
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                   30.827
# ...                                                                      ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                 29.761
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK         31.570
#                                      IVSRPEELREDDVGTGAGLLEIK          30.016
#                                      LSVLGAITSVQQR                    27.684
#                                      STGEAFVQFASQEIAEK                30.238
#
#                                                                replicates  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                 30.008
#                                      DSYVGDEAQSK                   33.189
#                                      SLEDQVEMLR                    28.098
#                                      TLGILGLGR                     28.547
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                30.196
# ...                                                                   ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK              29.744
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK      31.623
#                                      IVSRPEELREDDVGTGAGLLEIK       30.115
#                                      LSVLGAITSVQQR                 27.425
#                                      STGEAFVQFASQEIAEK             30.494
#
#                                                                intensity_pred_collab
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                            29.380
#                                      DSYVGDEAQSK                              32.801
#                                      SLEDQVEMLR                               27.852
#                                      TLGILGLGR                                27.590
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                           30.150
# ...                                                                              ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                         29.211
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK                 31.089
#                                      IVSRPEELREDDVGTGAGLLEIK                  29.536
#                                      LSVLGAITSVQQR                            27.084
#                                      STGEAFVQFASQEIAEK                        30.053
#
# [4933 rows x 5 columns]

# %%
assert (abs(target.reshape(-1) - pred.reshape(-1))).sum() / len(target) - \
    (df_pred.intensity - df_pred.intensity_pred_collab).abs().sum() / \
    len(df_pred) < 0.00001

# %% [markdown]
# ### Plot biases and embedding weigths
#
# - visualize relative order of samples and peptides

# %%
from collections import namedtuple
def get_bias(learner, indices, is_item=True) -> pd.Series:
    ret = learner.model.bias(indices.values, is_item=is_item) # user=sample
    return pd.Series(ret, index=indices)

# def get_weigths

CollabIDs = namedtuple("CollabIDs", "sample peptide")

collab.biases = CollabIDs(
    sample=get_bias(learn, indices=analysis.df_train.index.levels[0], is_item=False), # item=peptide
    peptide=get_bias(learn, indices=analysis.df_train.index.levels[1] )
)
collab.biases.sample.head()
# Out:
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02     0.036
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01    0.062
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01       0.184
# 20181222_QE9_nLC9_QC_50CM_HeLa1         0.110
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01   0.162
# dtype: float32

# %%
fig, ax = plt.subplots(figsize=(15, 15))
ax = collab.biases.sample.sort_values().plot(kind='line', rot=90, title='Sample biases', ax=ax)
vaep.io_images._savefig(fig, name='collab_bias_samples',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_bias_samples

# %%
fig, ax = plt.subplots(figsize=(15, 15))
_ = collab.biases.peptide.sort_values().plot(kind='line', rot=90, title='Sample biases', ax=ax)
vaep.io_images._savefig(fig, name='collab_bias_peptides',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_bias_peptides

# %%
def get_weight(learner, indices, is_item=True) -> pd.Series:
    ret = learner.model.weight(indices.values, is_item=is_item) # user=sample
    return pd.DataFrame(ret, index=indices, columns=[f'latent dimension {i+1}' for i in range(ret.shape[-1])])

collab.embeddings = CollabIDs(
    sample=get_weight(learn, indices=analysis.df_train.index.levels[0], is_item=False), # item=peptide
    peptide=get_weight(learn, indices=analysis.df_train.index.levels[1] )
)
collab.embeddings.sample.head()
# Out:
#                                        latent dimension 1  latent dimension 2
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                -0.231              -0.116
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.230              -0.149
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   0.077               0.057
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -0.041              -0.205
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              -0.059              -0.077

# %%
fig, ax = plt.subplots(figsize=(15, 15))
analyzers.plot_date_map(df=collab.embeddings.sample, fig=fig, ax=ax,
                        dates=analysis.df_meta.date.loc[collab.embeddings.sample.index])
vaep.io_images._savefig(fig, name='collab_latent_by_date',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_latent_by_date

# %%
fig, ax = plt.subplots(figsize=(15, 15))
meta_col = 'ms_instrument'

df_ = collab.embeddings.sample
analyzers.seaborn_scatter(df=df_,
                          fig=fig,
                          ax=ax,
                          meta=analysis.df_meta[meta_col].loc[df_.index],
                          title='2D sample embedding weights by MS instrument')

vaep.io_images._savefig(fig, name='collab_latent_by_ms_instrument',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\collab_latent_by_ms_instrument

# %% [markdown]
# ## Denoising Autoencoder (DAE)

# %% [markdown]
# ### Custom Transforms
#
# - [x] Shift standard normalized data around
#     - Error metrics won't be directly comparable afterwards

# %%
from fastai.tabular.all import *
from vaep.models import ae

from fastai.tabular.core import TabularPandas

# from fastai.callback.core import Callback

from fastai.data.core import DataLoaders

from fastai.learner import Learner
from fastai.losses import MSELossFlat


# https://docs.fast.ai/tabular.core.html#FillStrategy
# from fastai.tabular.core import FillMissing
# from fastai.tabular.core import TabularPandas

# %% [markdown]
# ### DataLoaders

# %%
# revert format
# undo using `stack`
analysis.df_train = analysis.df_train['intensity'].unstack()
analysis.df_valid = analysis.df_valid['intensity'].unstack()
analysis.df_valid.head()
# Out:
# peptide                                AHSSMVGVNLPQK  ALPFWNEEIVPQIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02           29.899             NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01             NaN          29.217
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                NaN             NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  NaN             NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            NaN             NaN
#
# peptide                                AMVSEFLK  AYHEQLSVAEITNACFEPANQMVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02         NaN                       NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01        NaN                       NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01           NaN                       NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1             NaN                    30.178
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01       NaN                       NaN
#
# peptide                                DSYVGDEAQSK  ELAPYDENWFYTR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02         32.783            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01           NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01              NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01       32.954            NaN
#
# peptide                                ELVYPPDYNPEGK  GIHPTIISESFQK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02              NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01          26.450            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            NaN            NaN
#
# peptide                                GLVEPVDVVDNADGTQTVNYVPSR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    28.494
#
# peptide                                GVNLPGAAVDLPAVSEK  ...  \
# Sample ID                                                 ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  NaN  ...
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 NaN  ...
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                 31.245  ...
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      NaN  ...
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                NaN  ...
#
# peptide                                TEFLSFMNTELAAFTK  TGTAEMSSILEER  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               NaN         29.912
#
# peptide                                TLGILGLGR  TLHPDLGTDK  VNVPVIGGHAGK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02       28.345         NaN           NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         NaN         NaN           NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01            NaN         NaN           NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1              NaN         NaN           NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        NaN         NaN           NaN
#
# peptide                                VSFELFADK  VVVAENFDEIVNNENK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          NaN               NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         NaN               NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01            NaN               NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1              NaN               NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        NaN               NaN
#
# peptide                                YADLTEDQLPSCESLK  YDDMATCMK  YLTVAAVFR
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 NaN        NaN        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                NaN        NaN        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   NaN        NaN        NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     NaN        NaN     30.452
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               NaN        NaN        NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# Mean and std. dev. from training data

# %%
# norm = Normalize.from_stats(analysis.df_train.mean(), analysis.df_valid.std()) # copy interface?
NORMALIZER = Normalize  # dae.NormalizeShiftedMean

# %% [markdown]
# #### Training data
#
# procs passed to TabluarPandas are handled internally
#   1. not necessarily in order
#   2. with setup call (using current training data)

# %%
procs = [NORMALIZER, FillMissing(add_col=True)]
cont_names = list(analysis.df_train.columns)

to = TabularPandas(analysis.df_train, procs=procs, cont_names=cont_names)
print("Tabular object:", type(to))

to.items  # items reveals data in DataFrame
# Out:
# Tabular object: <class 'fastai.tabular.core.TabularPandas'>
# peptide                                       AHSSMVGVNLPQK  ALPFWNEEIVPQIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   0.004          -1.021
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 -0.186           0.160
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    -0.248           0.021
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       0.105          -1.198
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                -0.142           0.033
# ...                                                     ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         -0.222           0.720
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      0.583          -0.071
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      0.391           0.160
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     -1.705           0.067
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     -1.502          -3.233
#
# peptide                                       AMVSEFLK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             -0.843
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            -1.063
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               -1.083
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 -0.791
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            0.552
# ...                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02     0.263
# 20190805_QE1_nLC2_AB_MNT_HELA_01                -0.047
# 20190805_QE1_nLC2_AB_MNT_HELA_02                -0.073
# 20190805_QE1_nLC2_AB_MNT_HELA_03                -2.988
# 20190805_QE1_nLC2_AB_MNT_HELA_04                 0.041
#
# peptide                                       AYHEQLSVAEITNACFEPANQMVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                             -1.000
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                            -0.965
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               -0.733
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                 -0.070
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           -0.528
# ...                                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     1.474
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 0.097
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 0.049
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                -0.070
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                -0.070
#
# peptide                                       DSYVGDEAQSK  ELAPYDENWFYTR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 0.197         -1.528
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.430         -1.560
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   0.156         -0.526
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -0.031         -0.972
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               0.197          0.527
# ...                                                   ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02        0.216          0.683
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    0.259         -0.140
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    0.463          0.212
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    0.389          0.043
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    0.170         -0.058
#
# peptide                                       ELVYPPDYNPEGK  GIHPTIISESFQK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  -1.082         -1.328
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 -0.079         -1.195
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     0.880         -0.647
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       0.430         -1.200
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                -0.571         -1.153
# ...                                                     ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          0.695          0.519
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     -0.744         -0.155
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     -0.262         -0.048
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     -0.079         -0.007
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     -0.348         -0.051
#
# peptide                                       GLVEPVDVVDNADGTQTVNYVPSR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              0.895
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             0.715
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               -0.080
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  1.129
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           -0.003
# ...                                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                    -0.003
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                -0.364
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                -0.414
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                -0.756
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                -1.005
#
# peptide                                       GVNLPGAAVDLPAVSEK  ...  \
# Sample ID                                                        ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      -0.768  ...
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.760  ...
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        -0.169  ...
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           0.024  ...
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    -0.212  ...
# ...                                                         ...  ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.902  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         -0.626  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         -0.672  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         -0.700  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.530  ...
#
# peptide                                       TEFLSFMNTELAAFTK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       False
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            False
#
# peptide                                       TGTAEMSSILEER_na  TLGILGLGR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      False          True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     False         False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        False         False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          False         False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     True         False
# ...                                                        ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          True         False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          True         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         False         False
#
# peptide                                       TLHPDLGTDK_na  VNVPVIGGHAGK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   False            False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  False            False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     False            False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       False            False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 False            False
# ...                                                     ...              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          False             True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      False            False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      False            False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                      False            False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                      False            False
#
# peptide                                       VSFELFADK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                False
# ...                                                    ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                      True
#
# peptide                                       VVVAENFDEIVNNENK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       False
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            False
#
# peptide                                       YADLTEDQLPSCESLK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       False
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            False
#
# peptide                                       YDDMATCMK_na  YLTVAAVFR_na
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  False         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 False         False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    False         False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      False          True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                False         False
# ...                                                    ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     False         False
#
# [990 rows x 100 columns]

# %% [markdown]
# Better manuelly apply `Transforms` on `Tabluar` type

# %%
cont_names = list(analysis.df_train.columns)
to = TabularPandas(analysis.df_train, cont_names=cont_names, do_setup=False)

tf_norm = NORMALIZER()
_ = tf_norm.setups(to)  # returns to
tf_fillna = FillMissing(add_col=True)
_ = tf_fillna.setup(to)

print("Tabular object:", type(to))
# _ = (procs[0]).encodes(to)
to.items  # items reveals data in DataFrame
# Out:
# Tabular object: <class 'fastai.tabular.core.TabularPandas'>
# peptide                                       AHSSMVGVNLPQK  ALPFWNEEIVPQIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   0.004          -0.912
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 -0.176           0.175
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    -0.235           0.046
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       0.100          -1.074
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                -0.134           0.058
# ...                                                     ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         -0.210           0.690
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      0.553          -0.038
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      0.371           0.175
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     -1.617           0.089
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     -1.424          -2.947
#
# peptide                                       AMVSEFLK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             -0.775
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            -0.983
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               -1.001
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 -0.726
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            0.539
# ...                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02     0.267
# 20190805_QE1_nLC2_AB_MNT_HELA_01                -0.025
# 20190805_QE1_nLC2_AB_MNT_HELA_02                -0.049
# 20190805_QE1_nLC2_AB_MNT_HELA_03                -2.796
# 20190805_QE1_nLC2_AB_MNT_HELA_04                 0.058
#
# peptide                                       AYHEQLSVAEITNACFEPANQMVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                             -0.956
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                            -0.923
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               -0.703
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                 -0.074
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           -0.508
# ...                                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     1.391
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 0.085
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 0.039
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                -0.074
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                -0.074
#
# peptide                                       DSYVGDEAQSK  ELAPYDENWFYTR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 0.208         -1.398
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.387         -1.427
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   0.170         -0.468
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -0.008         -0.882
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               0.208          0.508
# ...                                                   ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02        0.226          0.653
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    0.268         -0.110
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    0.461          0.217
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    0.391          0.060
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    0.183         -0.034
#
# peptide                                       ELVYPPDYNPEGK  GIHPTIISESFQK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  -1.033         -1.268
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 -0.083         -1.141
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     0.824         -0.623
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       0.398         -1.147
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                -0.549         -1.102
# ...                                                     ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          0.650          0.483
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     -0.713         -0.156
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     -0.257         -0.054
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     -0.083         -0.016
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     -0.338         -0.057
#
# peptide                                       GLVEPVDVVDNADGTQTVNYVPSR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              0.826
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             0.660
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               -0.074
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  1.043
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           -0.004
# ...                                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                    -0.004
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                -0.337
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                -0.383
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                -0.699
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                -0.929
#
# peptide                                       GVNLPGAAVDLPAVSEK  ...  \
# Sample ID                                                        ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      -0.747  ...
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.740  ...
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        -0.179  ...
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           0.005  ...
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    -0.220  ...
# ...                                                         ...  ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.839  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         -0.613  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         -0.656  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         -0.682  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.521  ...
#
# peptide                                       TEFLSFMNTELAAFTK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       False
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            False
#
# peptide                                       TGTAEMSSILEER_na  TLGILGLGR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      False          True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     False         False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        False         False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                          False         False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     True         False
# ...                                                        ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          True         False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          True         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         False         False
#
# peptide                                       TLHPDLGTDK_na  VNVPVIGGHAGK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   False            False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  False            False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     False            False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       False            False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 False            False
# ...                                                     ...              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          False             True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      False            False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      False            False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                      False            False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                      False            False
#
# peptide                                       VSFELFADK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                False
# ...                                                    ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                      True
#
# peptide                                       VVVAENFDEIVNNENK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       False
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            False
#
# peptide                                       YADLTEDQLPSCESLK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                       False
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            False
#
# peptide                                       YDDMATCMK_na  YLTVAAVFR_na
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  False         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 False         False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    False         False
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      False          True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                False         False
# ...                                                    ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     False         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     False         False
#
# [990 rows x 100 columns]

# %% [markdown]
# Check mean and standard deviation after normalization

# %%
to.items.iloc[:, :10].describe()  # not perferct anymore as expected
# Out:
# peptide  AHSSMVGVNLPQK  ALPFWNEEIVPQIK  AMVSEFLK  AYHEQLSVAEITNACFEPANQMVK  \
# count          990.000         990.000   990.000                   990.000
# mean             0.000           0.028     0.019                    -0.007
# std              0.949           0.921     0.943                     0.949
# min             -4.657          -6.112    -5.117                    -3.437
# 25%             -0.425          -0.308    -0.335                    -0.474
# 50%              0.004           0.175     0.167                    -0.074
# 75%              0.568           0.564     0.555                     0.437
# max              2.222           2.078     2.686                     2.761
#
# peptide  DSYVGDEAQSK  ELAPYDENWFYTR  ELVYPPDYNPEGK  GIHPTIISESFQK  \
# count        990.000        990.000        990.000        990.000
# mean           0.021          0.020         -0.009         -0.009
# std            0.950          0.928          0.947          0.948
# min           -6.591         -5.496         -4.020         -4.384
# 25%           -0.181         -0.328         -0.558         -0.481
# 50%            0.208          0.141         -0.083         -0.088
# 75%            0.533          0.536          0.699          0.524
# max            1.699          1.936          2.185          2.044
#
# peptide  GLVEPVDVVDNADGTQTVNYVPSR  GVNLPGAAVDLPAVSEK
# count                     990.000            990.000
# mean                       -0.001             -0.018
# std                         0.924              0.950
# min                        -4.563             -4.854
# 25%                        -0.515             -0.584
# 50%                        -0.004             -0.179
# 75%                         0.548              0.609
# max                         2.134              2.462

# %% [markdown]
# Mask is added as type bool

# %%
to.items.dtypes.value_counts()
# Out:
# float64   50
# bool      50
# dtype: int64

# %% [markdown]
# with the suffix `_na` where `True` is indicating a missing value replaced by the `FillMissing` transformation

# %%
to.cont_names, to.cat_names
# Out:
# ((#50) ['AHSSMVGVNLPQK','ALPFWNEEIVPQIK','AMVSEFLK','AYHEQLSVAEITNACFEPANQMVK','DSYVGDEAQSK','ELAPYDENWFYTR','ELVYPPDYNPEGK','GIHPTIISESFQK','GLVEPVDVVDNADGTQTVNYVPSR','GVNLPGAAVDLPAVSEK'...],
#  (#50) ['AHSSMVGVNLPQK_na','ALPFWNEEIVPQIK_na','AMVSEFLK_na','AYHEQLSVAEITNACFEPANQMVK_na','DSYVGDEAQSK_na','ELAPYDENWFYTR_na','ELVYPPDYNPEGK_na','GIHPTIISESFQK_na','GLVEPVDVVDNADGTQTVNYVPSR_na','GVNLPGAAVDLPAVSEK_na'...])

# %%
assert len(to.valid) == 0

# %% [markdown]
# #### Validation data
#
# - reuse training data with different mask for evaluation
# - target data is the validation data
#     - switch between training and evaluation mode for setting comparison

# %%
_df_valid = TabularPandas(
    analysis.df_valid, cont_names=analysis.df_valid.columns.tolist())
# assert analysis.df_valid.isna().equals(y_valid.items.isna())
_df_valid = tf_norm.encodes(_df_valid)

# %%
_df_valid.items.iloc[:, :10].describe()
# Out:
# peptide  AHSSMVGVNLPQK  ALPFWNEEIVPQIK  AMVSEFLK  AYHEQLSVAEITNACFEPANQMVK  \
# count          100.000          94.000    98.000                   100.000
# mean             0.037           0.017    -0.015                    -0.083
# std              1.019           0.933     1.094                     1.026
# min             -2.711          -3.268    -4.378                    -3.530
# 25%             -0.629          -0.431    -0.392                    -0.583
# 50%              0.040           0.204     0.143                    -0.011
# 75%              0.759           0.655     0.693                     0.568
# max              1.850           1.659     2.128                     2.095
#
# peptide  DSYVGDEAQSK  ELAPYDENWFYTR  ELVYPPDYNPEGK  GIHPTIISESFQK  \
# count        100.000         96.000        100.000        100.000
# mean           0.022          0.030          0.093          0.065
# std            0.844          0.898          1.051          1.072
# min           -3.215         -2.460         -3.230         -4.345
# 25%           -0.262         -0.442         -0.486         -0.501
# 50%            0.155          0.053          0.060          0.004
# 75%            0.560          0.648          0.904          0.934
# max            1.584          1.847          1.939          1.912
#
# peptide  GLVEPVDVVDNADGTQTVNYVPSR  GVNLPGAAVDLPAVSEK
# count                      95.000            100.000
# mean                        0.229              0.012
# std                         0.864              1.082
# min                        -2.342             -2.847
# 25%                        -0.415             -0.670
# 50%                         0.178             -0.130
# 75%                         0.979              1.065
# max                         2.038              2.148

# %%
# Validation dataset
# build validation DataFrame with mask according to validation data
# FillNA values in data as before, but do not add categorical columns (as this is done manuelly)
_valid_df = to.conts  # same data for predictions
_valid_df = _valid_df.join(analysis.df_valid.isna(), rsuffix='_na')  # mask
_valid_df = _valid_df.join(_df_valid.items, rsuffix='_val')  # target
_valid_df
# Out:
# peptide                                       AHSSMVGVNLPQK  ALPFWNEEIVPQIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   0.004          -0.912
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 -0.176           0.175
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    -0.235           0.046
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       0.100          -1.074
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                -0.134           0.058
# ...                                                     ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         -0.210           0.690
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      0.553          -0.038
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      0.371           0.175
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     -1.617           0.089
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     -1.424          -2.947
#
# peptide                                       AMVSEFLK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             -0.775
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            -0.983
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               -1.001
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 -0.726
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            0.539
# ...                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02     0.267
# 20190805_QE1_nLC2_AB_MNT_HELA_01                -0.025
# 20190805_QE1_nLC2_AB_MNT_HELA_02                -0.049
# 20190805_QE1_nLC2_AB_MNT_HELA_03                -2.796
# 20190805_QE1_nLC2_AB_MNT_HELA_04                 0.058
#
# peptide                                       AYHEQLSVAEITNACFEPANQMVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                             -0.956
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                            -0.923
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               -0.703
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                 -0.074
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           -0.508
# ...                                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     1.391
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 0.085
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 0.039
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                -0.074
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                -0.074
#
# peptide                                       DSYVGDEAQSK  ELAPYDENWFYTR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 0.208         -1.398
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.387         -1.427
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   0.170         -0.468
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -0.008         -0.882
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               0.208          0.508
# ...                                                   ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02        0.226          0.653
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    0.268         -0.110
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    0.461          0.217
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    0.391          0.060
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    0.183         -0.034
#
# peptide                                       ELVYPPDYNPEGK  GIHPTIISESFQK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  -1.033         -1.268
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 -0.083         -1.141
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     0.824         -0.623
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       0.398         -1.147
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                -0.549         -1.102
# ...                                                     ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          0.650          0.483
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     -0.713         -0.156
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     -0.257         -0.054
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     -0.083         -0.016
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     -0.338         -0.057
#
# peptide                                       GLVEPVDVVDNADGTQTVNYVPSR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              0.826
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             0.660
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               -0.074
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  1.043
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           -0.004
# ...                                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                    -0.004
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                -0.337
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                -0.383
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                -0.699
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                -0.929
#
# peptide                                       GVNLPGAAVDLPAVSEK  ...  \
# Sample ID                                                        ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      -0.747  ...
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.740  ...
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        -0.179  ...
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           0.005  ...
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    -0.220  ...
# ...                                                         ...  ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.839  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         -0.613  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         -0.656  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         -0.682  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.521  ...
#
# peptide                                       TEFLSFMNTELAAFTK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          NaN
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                   NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               NaN
#
# peptide                                       TGTAEMSSILEER_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    -0.169
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         -0.319
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         -0.041
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            NaN
#
# peptide                                       TLGILGLGR_val  TLHPDLGTDK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  -0.243             NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN             NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN             NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN             NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN             NaN
# ...                                                     ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            NaN             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        NaN             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        NaN             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        NaN             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        NaN             NaN
#
# peptide                                       VNVPVIGGHAGK_val  VSFELFADK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      NaN            NaN
# ...                                                        ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             1.213            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           NaN            NaN
#
# peptide                                       VVVAENFDEIVNNENK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          NaN
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                   NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            -0.110
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               NaN
#
# peptide                                       YADLTEDQLPSCESLK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          NaN
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                   NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               NaN
#
# peptide                                       YDDMATCMK_val  YLTVAAVFR_val
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN         -0.088
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN            NaN
# ...                                                     ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        NaN            NaN
#
# [990 rows x 150 columns]

# %%
# [norm, FillMissing(add_col=False)]  # mask is provided explicitly
procs = None

cont_names = list(analysis.df_train.columns)
cat_names = [f'{s}_na' for s in cont_names]
y_names = [f'{s}_val' for s in cont_names]

splits = None
y_block = None
to_valid = TabularPandas(_valid_df, procs=procs, cat_names=cat_names, cont_names=cont_names,
                         y_names=y_names, splits=splits, y_block=y_block, do_setup=True)
to_valid.items
# Out:
# peptide                                       AHSSMVGVNLPQK  ALPFWNEEIVPQIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   0.004          -0.912
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 -0.176           0.175
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                    -0.235           0.046
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       0.100          -1.074
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                -0.134           0.058
# ...                                                     ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02         -0.210           0.690
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      0.553          -0.038
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      0.371           0.175
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     -1.617           0.089
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     -1.424          -2.947
#
# peptide                                       AMVSEFLK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02             -0.775
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01            -0.983
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01               -1.001
# 20181222_QE9_nLC9_QC_50CM_HeLa1                 -0.726
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            0.539
# ...                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02     0.267
# 20190805_QE1_nLC2_AB_MNT_HELA_01                -0.025
# 20190805_QE1_nLC2_AB_MNT_HELA_02                -0.049
# 20190805_QE1_nLC2_AB_MNT_HELA_03                -2.796
# 20190805_QE1_nLC2_AB_MNT_HELA_04                 0.058
#
# peptide                                       AYHEQLSVAEITNACFEPANQMVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                             -0.956
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                            -0.923
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               -0.703
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                 -0.074
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           -0.508
# ...                                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                     1.391
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                 0.085
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                 0.039
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                -0.074
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                -0.074
#
# peptide                                       DSYVGDEAQSK  ELAPYDENWFYTR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 0.208         -1.398
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.387         -1.427
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   0.170         -0.468
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -0.008         -0.882
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               0.208          0.508
# ...                                                   ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02        0.226          0.653
# 20190805_QE1_nLC2_AB_MNT_HELA_01                    0.268         -0.110
# 20190805_QE1_nLC2_AB_MNT_HELA_02                    0.461          0.217
# 20190805_QE1_nLC2_AB_MNT_HELA_03                    0.391          0.060
# 20190805_QE1_nLC2_AB_MNT_HELA_04                    0.183         -0.034
#
# peptide                                       ELVYPPDYNPEGK  GIHPTIISESFQK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  -1.033         -1.268
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 -0.083         -1.141
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     0.824         -0.623
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       0.398         -1.147
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                -0.549         -1.102
# ...                                                     ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          0.650          0.483
# 20190805_QE1_nLC2_AB_MNT_HELA_01                     -0.713         -0.156
# 20190805_QE1_nLC2_AB_MNT_HELA_02                     -0.257         -0.054
# 20190805_QE1_nLC2_AB_MNT_HELA_03                     -0.083         -0.016
# 20190805_QE1_nLC2_AB_MNT_HELA_04                     -0.338         -0.057
#
# peptide                                       GLVEPVDVVDNADGTQTVNYVPSR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                              0.826
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                             0.660
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                               -0.074
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                  1.043
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                           -0.004
# ...                                                                ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                    -0.004
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                -0.337
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                -0.383
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                -0.699
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                -0.929
#
# peptide                                       GVNLPGAAVDLPAVSEK  ...  \
# Sample ID                                                        ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      -0.747  ...
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     -0.740  ...
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                        -0.179  ...
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           0.005  ...
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    -0.220  ...
# ...                                                         ...  ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              0.839  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         -0.613  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_02                         -0.656  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         -0.682  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04                         -0.521  ...
#
# peptide                                       TEFLSFMNTELAAFTK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          NaN
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                   NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               NaN
#
# peptide                                       TGTAEMSSILEER_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    -0.169
# ...                                                         ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         -0.319
# 20190805_QE1_nLC2_AB_MNT_HELA_02                            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         -0.041
# 20190805_QE1_nLC2_AB_MNT_HELA_04                            NaN
#
# peptide                                       TLGILGLGR_val  TLHPDLGTDK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  -0.243             NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN             NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN             NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN             NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN             NaN
# ...                                                     ...             ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            NaN             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        NaN             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        NaN             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        NaN             NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        NaN             NaN
#
# peptide                                       VNVPVIGGHAGK_val  VSFELFADK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                       NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      NaN            NaN
# ...                                                        ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02             1.213            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                           NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           NaN            NaN
#
# peptide                                       VVVAENFDEIVNNENK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          NaN
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                   NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            -0.110
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               NaN
#
# peptide                                       YADLTEDQLPSCESLK_val  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                           NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                              NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                          NaN
# ...                                                            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                   NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                               NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                               NaN
#
# peptide                                       YDDMATCMK_val  YLTVAAVFR_val
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                     NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         NaN         -0.088
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                   NaN            NaN
# ...                                                     ...            ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        NaN            NaN
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        NaN            NaN
#
# [990 rows x 150 columns]

# %%
stats_valid = to_valid.targ.iloc[:, :100].describe()
stats_valid
# Out:
# peptide  AHSSMVGVNLPQK_val  ALPFWNEEIVPQIK_val  AMVSEFLK_val  \
# count              100.000              94.000        98.000
# mean                 0.037               0.017        -0.015
# std                  1.019               0.933         1.094
# min                 -2.711              -3.268        -4.378
# 25%                 -0.629              -0.431        -0.392
# 50%                  0.040               0.204         0.143
# 75%                  0.759               0.655         0.693
# max                  1.850               1.659         2.128
#
# peptide  AYHEQLSVAEITNACFEPANQMVK_val  DSYVGDEAQSK_val  ELAPYDENWFYTR_val  \
# count                         100.000          100.000             96.000
# mean                           -0.083            0.022              0.030
# std                             1.026            0.844              0.898
# min                            -3.530           -3.215             -2.460
# 25%                            -0.583           -0.262             -0.442
# 50%                            -0.011            0.155              0.053
# 75%                             0.568            0.560              0.648
# max                             2.095            1.584              1.847
#
# peptide  ELVYPPDYNPEGK_val  GIHPTIISESFQK_val  GLVEPVDVVDNADGTQTVNYVPSR_val  \
# count              100.000            100.000                        95.000
# mean                 0.093              0.065                         0.229
# std                  1.051              1.072                         0.864
# min                 -3.230             -4.345                        -2.342
# 25%                 -0.486             -0.501                        -0.415
# 50%                  0.060              0.004                         0.178
# 75%                  0.904              0.934                         0.979
# max                  1.939              1.912                         2.038
#
# peptide  GVNLPGAAVDLPAVSEK_val  ...  TEFLSFMNTELAAFTK_val  TGTAEMSSILEER_val  \
# count                  100.000  ...                99.000            100.000
# mean                     0.012  ...                 0.065             -0.132
# std                      1.082  ...                 1.044              1.154
# min                     -2.847  ...                -5.080             -4.509
# 25%                     -0.670  ...                -0.338             -0.614
# 50%                     -0.130  ...                 0.193              0.012
# 75%                      1.065  ...                 0.758              0.560
# max                      2.148  ...                 1.640              1.842
#
# peptide  TLGILGLGR_val  TLHPDLGTDK_val  VNVPVIGGHAGK_val  VSFELFADK_val  \
# count           96.000         100.000            99.000         97.000
# mean            -0.085          -0.046            -0.077          0.081
# std              1.020           0.995             1.060          1.031
# min             -3.358          -2.913            -2.016         -4.380
# 25%             -0.496          -0.550            -0.885         -0.521
# 50%              0.252          -0.006            -0.388         -0.243
# 75%              0.566           0.727             1.078          1.118
# max              1.695           1.563             1.796          1.806
#
# peptide  VVVAENFDEIVNNENK_val  YADLTEDQLPSCESLK_val  YDDMATCMK_val  \
# count                 100.000               100.000         98.000
# mean                    0.021                -0.021          0.122
# std                     1.016                 1.049          0.909
# min                    -2.806                -3.860         -3.574
# 25%                    -0.611                -0.630         -0.373
# 50%                    -0.097                -0.083          0.061
# 75%                     0.614                 0.712          0.823
# max                     2.140                 2.136          1.936
#
# peptide  YLTVAAVFR_val
# count           99.000
# mean             0.126
# std              0.911
# min             -1.749
# 25%             -0.424
# 50%             -0.032
# 75%              0.983
# max              1.989
#
# [8 rows x 50 columns]

# %%
# True = training data ("fill_na" transform sets mask to true in training data where values are replaced)
to_valid.cats
# Out:
# peptide                                       AHSSMVGVNLPQK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                      False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     True
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          True
#
# peptide                                       ALPFWNEEIVPQIK_na  AMVSEFLK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                        True         True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      False         True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                          True         True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                            True         True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                      True         True
# ...                                                         ...          ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02               True         True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                           True         True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          False         True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                           True         True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                           True         True
#
# peptide                                       AYHEQLSVAEITNACFEPANQMVK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                                  True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                                 True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                    True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                     False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                                True
# ...                                                                   ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                         True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                     True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                     True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                    False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                    False
#
# peptide                                       DSYVGDEAQSK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                    True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                       True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                         True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  False
# ...                                                      ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02            True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                        True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                        True
#
# peptide                                       ELAPYDENWFYTR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     True
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          True
#
# peptide                                       ELVYPPDYNPEGK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                     False
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     True
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          True
#
# peptide                                       GIHPTIISESFQK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     True
# ...                                                        ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                          True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          True
#
# peptide                                       GLVEPVDVVDNADGTQTVNYVPSR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                                  True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                                 True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                                    True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                                      True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                               False
# ...                                                                   ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                        False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                                     True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                                     True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                                     True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                                     True
#
# peptide                                       GVNLPGAAVDLPAVSEK_na  ...  \
# Sample ID                                                           ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                           True  ...
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                          True  ...
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            False  ...
# 20181222_QE9_nLC9_QC_50CM_HeLa1                               True  ...
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                         True  ...
# ...                                                            ...  ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                  True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_01                              True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_02                              True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03                              True  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_04                              True  ...
#
# peptide                                       TEFLSFMNTELAAFTK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                          True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                         True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                              True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                        True
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                             True
#
# peptide                                       TGTAEMSSILEER_na  TLGILGLGR_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                       True         False
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                      True          True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                         True          True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                           True          True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                    False          True
# ...                                                        ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02              True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                         False          True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                          True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                         False          True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                          True          True
#
# peptide                                       TLHPDLGTDK_na  VNVPVIGGHAGK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                    True             True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                   True             True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                      True             True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                        True             True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                  True             True
# ...                                                     ...              ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02           True            False
# 20190805_QE1_nLC2_AB_MNT_HELA_01                       True             True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                       True             True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                       True             True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                       True             True
#
# peptide                                       VSFELFADK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 True
# ...                                                    ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                      True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                      True
#
# peptide                                       VVVAENFDEIVNNENK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                          True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                         True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                              True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                        True
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                            False
# 20190805_QE1_nLC2_AB_MNT_HELA_04                             True
#
# peptide                                       YADLTEDQLPSCESLK_na  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                          True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                         True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                            True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                              True
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                        True
# ...                                                           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02                 True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                             True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                             True
#
# peptide                                       YDDMATCMK_na  YLTVAAVFR_na
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                   True          True
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                  True          True
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                     True          True
# 20181222_QE9_nLC9_QC_50CM_HeLa1                       True         False
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                 True          True
# ...                                                    ...           ...
# 20190805_QE10_nLC0_LiNi_MNT_45cm_HeLa_MUC_02          True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_01                      True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_02                      True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_03                      True          True
# 20190805_QE1_nLC2_AB_MNT_HELA_04                      True          True
#
# [990 rows x 50 columns]

# %%
assert list(to_valid.cat_names) == list(
    _valid_df.select_dtypes(include='bool').columns)  # 'object'
assert to_valid.cats.equals(analysis.df_valid.isna().add_suffix('_na'))

# %% [markdown]
# ### Mix and match dataloaders
#
# - train dataloader in both TabularPandas objects used
# - train dataloader in dataloaders used in both case

# %%
args.batch_size
dl_train = to.dataloaders(shuffle_train=True, shuffle=False,
                          bs=args.batch_size).train  # , after_batch=after_batch)
dl_valid = to_valid.dataloaders(
    shuffle_train=False, shuffle=False, bs=args.batch_size).train

# %%
dls = DataLoaders(dl_train, dl_valid)
b = dls.train.one_batch()
[x.shape for x in b]  # cat, cont, target
# Out:
# [torch.Size([32, 50]), torch.Size([32, 50]), torch.Size([32, 0])]

# %%
dls = DataLoaders(dl_train, dl_valid)
b = dls.valid.one_batch()
[x.shape for x in b]  # cat, cont, target
# Out:
# [torch.Size([32, 50]), torch.Size([32, 50]), torch.Size([32, 50])]

# %% [markdown]
# ### Model
#
# - standard PyTorch Model from before

# %%
M = analysis.df_train.shape[-1]
model = ae.Autoencoder(n_features=M, n_neurons=int(
    M/2), last_decoder_activation=None, dim_latent=latent_dim)

# %% [markdown]
# ### Callbacks
#
# - controll training loop
#     - set what is data
#     - what should be used for evaluation (differs for training and evaluation mode)

# %%
ae.ModelAdapter
# Out:
# vaep.models.ae.ModelAdapter

# %% [markdown]
# ### Learner: Fastai Training Loop

# %%
learn = Learner(dls=dls, model=model,
                loss_func=MSELossFlat(), cbs=ae.ModelAdapter())

# %%
learn.show_training_loop()
# Out:
# Start Fit
#    - before_fit     : [TrainEvalCallback, Recorder, ProgressCallback]
#   Start Epoch Loop
#      - before_epoch   : [Recorder, ProgressCallback]
#     Start Train
#        - before_train   : [TrainEvalCallback, Recorder, ProgressCallback]
#       Start Batch Loop
#          - before_batch   : [ModelAdapter]
#          - after_pred     : [ModelAdapter]
#          - after_loss     : []
#          - before_backward: []
#          - before_step    : []
#          - after_step     : []
#          - after_cancel_batch: []
#          - after_batch    : [TrainEvalCallback, Recorder, ProgressCallback]
#       End Batch Loop
#     End Train
#      - after_cancel_train: [Recorder]
#      - after_train    : [Recorder, ProgressCallback]
#     Start Valid
#        - before_validate: [TrainEvalCallback, ModelAdapter, Recorder, ProgressCallback]
#       Start Batch Loop
#          - **CBs same as train batch**: []
#       End Batch Loop
#     End Valid
#      - after_cancel_validate: [Recorder]
#      - after_validate : [Recorder, ProgressCallback]
#   End Epoch Loop
#    - after_cancel_epoch: []
#    - after_epoch    : [Recorder]
# End Fit
#  - after_cancel_fit: []
#  - after_fit      : [ProgressCallback]

# %%
learn.summary()
# Out:
# Autoencoder (Input shape: 32 x 50)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      32 x 25
# Linear                                    1275       True
# Tanh
# ____________________________________________________________________________
#                      32 x 2
# Linear                                    52         True
# Tanh
# ____________________________________________________________________________
#                      32 x 25
# Linear                                    75         True
# Tanh
# ____________________________________________________________________________
#                      32 x 50
# Linear                                    1300       True
# ____________________________________________________________________________
#
# Total params: 2,702
# Total trainable params: 2,702
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001CBC0506040>
# Loss function: FlattenedLoss of MSELoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - ModelAdapter
#   - Recorder
#   - ProgressCallback

# %%
suggested_lr = learn.lr_find()
suggested_lr
# Out:
# SuggestedLRs(valley=0.007585775572806597)

# %% [markdown]
# ### Training

# %%
learn.fit_one_cycle(epochs_max, lr_max=suggested_lr.valley)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.999554</td>
#       <td>0.817122</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.692016</td>
#       <td>0.399036</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.492404</td>
#       <td>0.321330</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.391310</td>
#       <td>0.311825</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.338603</td>
#       <td>0.302370</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.308028</td>
#       <td>0.294634</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.289118</td>
#       <td>0.291346</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.277582</td>
#       <td>0.286686</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.269348</td>
#       <td>0.287499</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.264055</td>
#       <td>0.288058</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# learn.val_preds, learn.val_targets #

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.set_title('DAE loss: Reconstruction loss')
learn.recorder.plot_loss(skip_start=5, ax=ax)
vaep.io_images._savefig(fig, name='dae_training',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\dae_training

# %%
# L(zip(learn.recorder.iters, learn.recorder.values))

# %% [markdown]
# ### Evaluation

# %%
# reorder True: Only 500 predictions returned
pred, target = learn.get_preds(act=noop, concat_dim=0, reorder=False)
len(pred), len(target)
# Out:
# (4933, 4933)

# %% [markdown]
# MSE on transformed data is not too interesting for comparision between models if these use different standardizations

# %%
learn.loss_func(pred, target)  # MSE in transformed space not too interesting
# Out:
# TensorBase(0.2884)

# %%
# check target is in expected order
Y = dls.valid.targ

npt.assert_almost_equal(
    actual=target.numpy(),
    desired=Y.stack().to_numpy()
)

# %%
# import torch
# from fastai.tabular.core import TabularPandas

df_pred['intensity_pred_dae'] = ae.transform_preds(
    pred=pred, index=analysis.df_valid.stack().index, normalizer=tf_norm)
df_pred
# Out:
#                                                                intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                29.899
#                                      DSYVGDEAQSK                  32.783
#                                      SLEDQVEMLR                   28.105
#                                      TLGILGLGR                    28.345
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK               29.217
# ...                                                                  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK             29.613
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK     31.539
#                                      IVSRPEELREDDVGTGAGLLEIK      30.671
#                                      LSVLGAITSVQQR                27.476
#                                      STGEAFVQFASQEIAEK            30.364
#
#                                                                train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                   30.250
#                                      DSYVGDEAQSK                     33.542
#                                      SLEDQVEMLR                      28.950
#                                      TLGILGLGR                       28.815
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                  31.081
# ...                                                                     ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                29.629
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK        31.468
#                                      IVSRPEELREDDVGTGAGLLEIK         29.922
#                                      LSVLGAITSVQQR                   27.545
#                                      STGEAFVQFASQEIAEK               30.274
#
#                                                                train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                    30.245
#                                      DSYVGDEAQSK                      33.310
#                                      SLEDQVEMLR                       28.810
#                                      TLGILGLGR                        28.585
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                   30.827
# ...                                                                      ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                 29.761
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK         31.570
#                                      IVSRPEELREDDVGTGAGLLEIK          30.016
#                                      LSVLGAITSVQQR                    27.684
#                                      STGEAFVQFASQEIAEK                30.238
#
#                                                                replicates  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                 30.008
#                                      DSYVGDEAQSK                   33.189
#                                      SLEDQVEMLR                    28.098
#                                      TLGILGLGR                     28.547
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                30.196
# ...                                                                   ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK              29.744
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK      31.623
#                                      IVSRPEELREDDVGTGAGLLEIK       30.115
#                                      LSVLGAITSVQQR                 27.425
#                                      STGEAFVQFASQEIAEK             30.494
#
#                                                                intensity_pred_collab  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                            29.380
#                                      DSYVGDEAQSK                              32.801
#                                      SLEDQVEMLR                               27.852
#                                      TLGILGLGR                                27.590
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                           30.150
# ...                                                                              ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                         29.211
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK                 31.089
#                                      IVSRPEELREDDVGTGAGLLEIK                  29.536
#                                      LSVLGAITSVQQR                            27.084
#                                      STGEAFVQFASQEIAEK                        30.053
#
#                                                                intensity_pred_dae
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                         29.453
#                                      DSYVGDEAQSK                           32.745
#                                      SLEDQVEMLR                            27.936
#                                      TLGILGLGR                             28.133
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                        30.167
# ...                                                                           ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                      29.232
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK              31.205
#                                      IVSRPEELREDDVGTGAGLLEIK               29.588
#                                      LSVLGAITSVQQR                         27.249
#                                      STGEAFVQFASQEIAEK                     30.145
#
# [4933 rows x 6 columns]

# %% [markdown]
# ### 2D plot of latent space
#
# - 2 dimensional latent space: just plot
# - more than 2 dimensional: PCA, etc

# %%
latent_space = []
for b in dls.valid:
    model_input = b[1]
    latent_space.append(model.encoder(model_input).detach().numpy())

df_dae_latent = build_df_from_pred_batches(latent_space,
                                           index=_df_valid.items.index,
                                           columns=[f'latent dimension {i+1}' for i in range(latent_dim)])
df_dae_latent.head()
# Out:
#                                        latent dimension 1  latent dimension 2
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                -0.526               0.257
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.318               0.146
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  -0.744               0.578
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -0.362               0.302
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01              -0.675               0.523

# %%
fig, ax = plt.subplots(figsize=(15, 15))
analyzers.plot_date_map(df=df_dae_latent, fig=fig, ax=ax,
                        dates=analysis.df_meta.date.loc[df_dae_latent.index])
vaep.io_images._savefig(fig, name='dae_latent_by_date',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\dae_latent_by_date

# %%
fig, ax = plt.subplots(figsize=(15, 15))

meta_col = 'ms_instrument'

analyzers.seaborn_scatter(df=df_dae_latent,
                          fig=fig,
                          ax=ax,
                          meta=analysis.df_meta[meta_col].loc[df_dae_latent.index],
                          title='by MS instrument')

vaep.io_images._savefig(
    fig, name=f'dae_latent_by_{meta_col}', folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\dae_latent_by_ms_instrument

# %% [markdown]
# ## Variational Autoencoder (VAE)

# %% [markdown]
# ### Scikit Learn MinMaxScaler
#
# - [docs](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html)

# %%
from vaep.transform import MinMaxScaler

args_vae = {}
args_vae['SCALER'] = MinMaxScaler
# select initial data: transformed vs not log transformed
scaler = args_vae['SCALER']().fit(analysis.df_train)
scaler.transform(analysis.df_valid.iloc[:5])
# Out:
# peptide                                AHSSMVGVNLPQK  ALPFWNEEIVPQIK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02            0.633             NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01             NaN           0.612
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                NaN             NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  NaN             NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            NaN             NaN
#
# peptide                                AMVSEFLK  AYHEQLSVAEITNACFEPANQMVK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02         NaN                       NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01        NaN                       NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01           NaN                       NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1             NaN                     0.393
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01       NaN                       NaN
#
# peptide                                DSYVGDEAQSK  ELAPYDENWFYTR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          0.738            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01           NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01              NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        0.756            NaN
#
# peptide                                ELVYPPDYNPEGK  GIHPTIISESFQK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02              NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01           0.466            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                  NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01            NaN            NaN
#
# peptide                                GLVEPVDVVDNADGTQTVNYVPSR  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                         NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                           NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                             NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                     0.824
#
# peptide                                GVNLPGAAVDLPAVSEK  ...  \
# Sample ID                                                 ...
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                  NaN  ...
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                 NaN  ...
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                  0.640  ...
# 20181222_QE9_nLC9_QC_50CM_HeLa1                      NaN  ...
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01                NaN  ...
#
# peptide                                TEFLSFMNTELAAFTK  TGTAEMSSILEER  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 NaN            NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                NaN            NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   NaN            NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     NaN            NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               NaN          0.669
#
# peptide                                TLGILGLGR  TLHPDLGTDK  VNVPVIGGHAGK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02        0.733         NaN           NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         NaN         NaN           NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01            NaN         NaN           NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1              NaN         NaN           NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        NaN         NaN           NaN
#
# peptide                                VSFELFADK  VVVAENFDEIVNNENK  \
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02          NaN               NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01         NaN               NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01            NaN               NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1              NaN               NaN
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01        NaN               NaN
#
# peptide                                YADLTEDQLPSCESLK  YDDMATCMK  YLTVAAVFR
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                 NaN        NaN        NaN
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01                NaN        NaN        NaN
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   NaN        NaN        NaN
# 20181222_QE9_nLC9_QC_50CM_HeLa1                     NaN        NaN      0.634
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               NaN        NaN        NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# ### DataLoaders
#
# - follow instructions for using plain PyTorch Datasets, see [tutorial](https://docs.fast.ai/tutorial.siamese.html#Preparing-the-data)

# %%
assert all(analysis.df_train.columns == analysis.df_valid.columns)
if not all(analysis.df.columns == analysis.df_train.columns):
    print("analysis.df columns are not the same as analysis.df_train")
    # ToDo: DataLoading has to be cleaned up
    # analysis.df = analysis.df_train.fillna(analysis.df_valid)
# Out:
# analysis.df columns are not the same as analysis.df_train

# %%
from vaep.io.datasets import PeptideDatasetInMemory

FILL_NA = 0.0

train_ds = PeptideDatasetInMemory(data=scaler.transform(
    analysis.df_train).to_numpy(dtype=None), fill_na=FILL_NA)
valid_ds = PeptideDatasetInMemory(data=scaler.transform(analysis.df_train.fillna(analysis.df_valid)).to_numpy(dtype=None),
                                  mask=analysis.df_valid.notna().to_numpy(), fill_na=FILL_NA)

assert (train_ds.peptides == valid_ds.peptides).all()

# %%
dls = DataLoaders.from_dsets(train_ds, valid_ds, n_inp=2)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %% [markdown]
# ### Model

# %%
from torch.nn import Sigmoid

M = analysis.df_train.shape[-1]
model = ae.VAE(n_features=M, n_neurons=int(
    M/2), last_encoder_activation=None, last_decoder_activation=Sigmoid, dim_latent=latent_dim)

# %% [markdown]
# ### Learner

# %%
learn = Learner(dls=dls,
                model=model,
                loss_func=ae.loss_fct_vae,
                cbs=ae.ModelAdapterVAE())

learn.show_training_loop()
learn.summary()
# Out:
# Start Fit
#    - before_fit     : [TrainEvalCallback, Recorder, ProgressCallback]
#   Start Epoch Loop
#      - before_epoch   : [Recorder, ProgressCallback]
#     Start Train
#        - before_train   : [TrainEvalCallback, Recorder, ProgressCallback]
#       Start Batch Loop
#          - before_batch   : [ModelAdapterVAE]
#          - after_pred     : [ModelAdapterVAE]
#          - after_loss     : []
#          - before_backward: []
#          - before_step    : []
#          - after_step     : []
#          - after_cancel_batch: []
#          - after_batch    : [TrainEvalCallback, Recorder, ProgressCallback]
#       End Batch Loop
#     End Train
#      - after_cancel_train: [Recorder]
#      - after_train    : [Recorder, ProgressCallback]
#     Start Valid
#        - before_validate: [TrainEvalCallback, Recorder, ProgressCallback]
#       Start Batch Loop
#          - **CBs same as train batch**: []
#       End Batch Loop
#     End Valid
#      - after_cancel_validate: [Recorder]
#      - after_validate : [Recorder, ProgressCallback]
#   End Epoch Loop
#    - after_cancel_epoch: []
#    - after_epoch    : [Recorder]
# End Fit
#  - after_cancel_fit: []
#  - after_fit      : [ProgressCallback]
# VAE (Input shape: 64 x 50)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      64 x 25
# Linear                                    75         True
# Tanh
# ____________________________________________________________________________
#                      64 x 50
# Linear                                    1300       True
# Sigmoid
# ____________________________________________________________________________
#                      64 x 25
# Linear                                    1275       True
# Tanh
# ____________________________________________________________________________
#                      64 x 4
# Linear                                    104        True
# ____________________________________________________________________________
#
# Total params: 2,754
# Total trainable params: 2,754
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x000001CBC0506040>
# Loss function: <function loss_fct_vae at 0x000001CBC0524940>
#
# Callbacks:
#   - TrainEvalCallback
#   - ModelAdapterVAE
#   - Recorder
#   - ProgressCallback

# %% [markdown]
# ### Training

# %%
suggested_lr = learn.lr_find()
suggested_lr
# Out:
# SuggestedLRs(valley=0.0020892962347716093)

# %%
learn.fit_one_cycle(epochs_max, lr_max=suggested_lr.valley)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2030.367920</td>
#       <td>221.667953</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2000.650146</td>
#       <td>214.327179</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1950.947998</td>
#       <td>207.411331</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1903.320557</td>
#       <td>203.803909</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1865.540894</td>
#       <td>202.047745</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1838.540039</td>
#       <td>200.467682</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1819.487061</td>
#       <td>197.413116</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1805.375244</td>
#       <td>198.887466</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1795.638062</td>
#       <td>198.276871</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1787.440063</td>
#       <td>198.039719</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.set_title('VAE loss: Reconstruction loss and Kullback-Leiber-Divergence for latent space')
learn.recorder.plot_loss(skip_start=5, ax=ax)
vaep.io_images._savefig(fig, name='vae_training',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\vae_training

# %% [markdown]
# ### Evaluation

# %%
# reorder True: Only 500 predictions returned
pred, target = learn.get_preds(act=noop, concat_dim=0, reorder=False)
len(pred), len(target)
# Out:
# (3, 4933)

# %%
len(pred[0])
# Out:
# 4933

# %%
learn.loss_func(pred, target)
# Out:
# tensor(3108.5349)

# %%
_pred = pd.Series(pred[0], index=analysis.df_valid.stack().index).unstack()
_pred = scaler.inverse_transform(_pred).stack()

df_pred['intensity_pred_vae'] = _pred
df_pred
# Out:
#                                                                intensity  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                29.899
#                                      DSYVGDEAQSK                  32.783
#                                      SLEDQVEMLR                   28.105
#                                      TLGILGLGR                    28.345
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK               29.217
# ...                                                                  ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK             29.613
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK     31.539
#                                      IVSRPEELREDDVGTGAGLLEIK      30.671
#                                      LSVLGAITSVQQR                27.476
#                                      STGEAFVQFASQEIAEK            30.364
#
#                                                                train_median  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                   30.250
#                                      DSYVGDEAQSK                     33.542
#                                      SLEDQVEMLR                      28.950
#                                      TLGILGLGR                       28.815
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                  31.081
# ...                                                                     ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                29.629
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK        31.468
#                                      IVSRPEELREDDVGTGAGLLEIK         29.922
#                                      LSVLGAITSVQQR                   27.545
#                                      STGEAFVQFASQEIAEK               30.274
#
#                                                                train_average  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                    30.245
#                                      DSYVGDEAQSK                      33.310
#                                      SLEDQVEMLR                       28.810
#                                      TLGILGLGR                        28.585
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                   30.827
# ...                                                                      ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                 29.761
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK         31.570
#                                      IVSRPEELREDDVGTGAGLLEIK          30.016
#                                      LSVLGAITSVQQR                    27.684
#                                      STGEAFVQFASQEIAEK                30.238
#
#                                                                replicates  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                 30.008
#                                      DSYVGDEAQSK                   33.189
#                                      SLEDQVEMLR                    28.098
#                                      TLGILGLGR                     28.547
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                30.196
# ...                                                                   ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK              29.744
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK      31.623
#                                      IVSRPEELREDDVGTGAGLLEIK       30.115
#                                      LSVLGAITSVQQR                 27.425
#                                      STGEAFVQFASQEIAEK             30.494
#
#                                                                intensity_pred_collab  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                            29.380
#                                      DSYVGDEAQSK                              32.801
#                                      SLEDQVEMLR                               27.852
#                                      TLGILGLGR                                27.590
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                           30.150
# ...                                                                              ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                         29.211
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK                 31.089
#                                      IVSRPEELREDDVGTGAGLLEIK                  29.536
#                                      LSVLGAITSVQQR                            27.084
#                                      STGEAFVQFASQEIAEK                        30.053
#
#                                                                intensity_pred_dae  \
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                         29.453
#                                      DSYVGDEAQSK                           32.745
#                                      SLEDQVEMLR                            27.936
#                                      TLGILGLGR                             28.133
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                        30.167
# ...                                                                           ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                      29.232
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK              31.205
#                                      IVSRPEELREDDVGTGAGLLEIK               29.588
#                                      LSVLGAITSVQQR                         27.249
#                                      STGEAFVQFASQEIAEK                     30.145
#
#                                                                intensity_pred_vae
# Sample ID                            peptide
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02  AHSSMVGVNLPQK                         30.340
#                                      DSYVGDEAQSK                           32.688
#                                      SLEDQVEMLR                            28.863
#                                      TLGILGLGR                             28.478
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01 ALPFWNEEIVPQIK                        30.949
# ...                                                                           ...
# 20190805_QE1_nLC2_AB_MNT_HELA_03     VVVAENFDEIVNNENK                      29.719
# 20190805_QE1_nLC2_AB_MNT_HELA_04     AYHEQLSVAEITNACFEPANQMVK              31.596
#                                      IVSRPEELREDDVGTGAGLLEIK               30.063
#                                      LSVLGAITSVQQR                         27.673
#                                      STGEAFVQFASQEIAEK                     30.304
#
# [4933 rows x 7 columns]

# %% [markdown]
# ### Add plot of latent space
#
# - 2 dimensional latent space: just plot
# - more than 2 dimensional: PCA, etc

# %%
latent_space = []
for b in dls.valid:
    model_input = b[0]
    b_mu, b_std = model.get_mu_and_logvar(model_input, detach=True)
    latent_space.append(b_mu)


df_vae_latent = build_df_from_pred_batches(latent_space,
                                           index=_df_valid.items.index,
                                           columns=[f'latent dimension {i+1}' for i in range(latent_dim)])
df_vae_latent.head()
# Out:
#                                        latent dimension 1  latent dimension 2
# Sample ID
# 20181219_QE3_nLC3_DS_QC_MNT_HeLa_02                -0.117              -0.239
# 20181219_QE3_nLC3_TSB_QC_MNT_HeLa_01               -0.150              -0.235
# 20181221_QE8_nLC0_NHS_MNT_HeLa_01                   0.042              -0.039
# 20181222_QE9_nLC9_QC_50CM_HeLa1                    -0.034              -0.083
# 20181223_QE7_nLC7_RJC_MEM_MNT_HeLa_01               0.045              -0.163

# %%
fig, ax = plt.subplots(figsize=(15, 15))
analyzers.plot_date_map(df=df_vae_latent, fig=fig, ax=ax,
                        dates=analysis.df_meta.date.loc[df_vae_latent.index])
vaep.io_images._savefig(fig, name='vae_latent_by_date',
                        folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\vae_latent_by_date

# %%
fig, ax = plt.subplots(figsize=(15, 15))

meta_col = 'ms_instrument'

analyzers.seaborn_scatter(df=df_vae_latent,
                          fig=fig,
                          ax=ax,
                          meta=analysis.df_meta[meta_col].loc[df_vae_latent.index],
                          title='by MS instrument')

vaep.io_images._savefig(
    fig, name=f'vae_latent_by_{meta_col}', folder=folder)
# Out:
# vaep.io_images - INFO     Saved Figures to runs\2D\feat_0050_epochs_010\vae_latent_by_ms_instrument

# %% [markdown]
# ## Compare the 3 models
#
# - replicates: replace NAs with neighbouring ("close") values
# - train average, median: Replace NA with average or median from training data

# %%
import sklearn.metrics as sklm
pred_columns = df_pred.columns[1:]
scoring = [('MSE', sklm.mean_squared_error),
           ('MAE', sklm.mean_absolute_error)]

y_true = df_pred['intensity']

metrics = {}
for col in pred_columns:
    _y_pred = df_pred[col].dropna()
    if len(df_pred[col]) > len(_y_pred):
        logger.info(
            f"Drop indices for {col}: {[(idx[0], idx[1]) for idx in df_pred[col].index.difference(_y_pred.index)]}")

    metrics[col] = dict(
        [(k, f(y_true=y_true.loc[_y_pred.index], y_pred=_y_pred))
         for k, f in scoring]
    )

metrics = pd.DataFrame(metrics)
metrics.to_csv(folder / f'exp_02_metrics.csv',
               float_format='{:.3f}'.format)
metrics.sort_values(by=[k for k, f in scoring], axis=1)
# Out:
# vaep - INFO     Drop indices for replicates: [('20181230_QE6_nLC6_CSC_QC_HeLa_03', 'KHPDASVNFSEFSK'), ('20190107_QE10_nLC0_KS_QC_MNT_HeLa_01', 'GVNLPGAAVDLPAVSEK'), ('20190110_QE8_nLC14_JM_QC_MNT_HeLa_02', 'STGEAFVQFASQEIAEK'), ('20190114_QE4_LC6_IAH_QC_MNT_HeLa_250ng_01', 'LVNHFVEEFK'), ('20190121_QE5_nLC5_AH_QC_MNT_HeLa_250ng_01', 'SLEDQVEMLR'), ('20190121_QE5_nLC5_AH_QC_MNT_HeLa_250ng_02', 'SLEDQVEMLR'), ('20190204_QE6_nLC6_MPL_QC_MNT_HeLa_01', 'GVNLPGAAVDLPAVSEK'), ('20190205_QE7_nLC7_MEM_QC_MNT_HeLa_03', 'HQPTAIIAK'), ('20190205_QE7_nLC7_MEM_QC_MNT_HeLa_04', 'HQPTAIIAK'), ('20190218_QE6_LC6_SCL_MVM_QC_MNT_Hela_03', 'HQPTAIIAK'), ('20190219_QE2_NLC1_GP_QC_MNT_HELA_01', 'VSFELFADK'), ('20190225_QE10_PhGe_Evosep_88min_HeLa_1_20190225173940', 'LVNHFVEEFK'), ('20190225_QE10_PhGe_Evosep_88min_HeLa_2', 'LVNHFVEEFK'), ('20190225_QE9_nLC0_RS_MNT_Hela_02', 'VSFELFADK'), ('20190228_QE4_LC12_JE_QC_MNT_HeLa_01', 'VNVPVIGGHAGK'), ('20190301_QE1_nLC2_ANHO_QC_MNT_HELA_01_20190303025443', 'IIQLLDDYPK'), ('20190304_QE10_nLC0_KS_QC_MNT_HeLa_02', 'LSVLGAITSVQQR'), ('20190318_QE2_NLC1_AB_MNT_HELA_04', 'AHSSMVGVNLPQK'), ('20190402_QE6_LC6_AS_QC_MNT_HeLa_03', 'YADLTEDQLPSCESLK'), ('20190402_QE7_nLC3_AL_QC_MNT_HeLa_01', 'YADLTEDQLPSCESLK'), ('20190408_QE1_nLC2_GP_MNT_QC_hela_02_20190408131505', 'NAGVEGSLIVEK'), ('20190409_QE1_nLC2_ANHO_MNT_QC_hela_02', 'ALPFWNEEIVPQIK'), ('20190423_QX2_FlMe_MA_HeLa_500ng_LC05_CTCDoff', 'YADLTEDQLPSCESLK'), ('20190423_QX7_JuSc_MA_HeLaBr14_500ng_LC02', 'LNNLVLFDK'), ('20190425_QX4_JoSw_MA_HeLa_500ng_BR13_standard', 'YLTVAAVFR'), ('20190425_QX7_ChDe_MA_HeLaBr14_500ng_LC02', 'RLAPEYEAAATR'), ('20190429_QX3_ChDe_MA_Hela_500ng_LC15_190429151336', 'LSVLGAITSVQQR'), ('20190508_QE8_nLC14_ASD_QC_MNT_HeLa_01', 'GLVEPVDVVDNADGTQTVNYVPSR'), ('20190510_QE2_NLC1_GP_MNT_HELA_02', 'KHPDASVNFSEFSK'), ('20190513_QX2_SeVW_MA_HeLa_500ng_LC05_CTCDoff_1', 'SYCAEIAHNVSSK'), ('20190513_QX7_ChDe_MA_HeLaBr14_500ng', 'GLVEPVDVVDNADGTQTVNYVPSR'), ('20190513_QX8_MiWi_MA_HeLa_BR14_500ng', 'VSFELFADK'), ('20190514_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14', 'SYCAEIAHNVSSK'), ('20190515_QX3_AsJa_MA_Hela_500ng_LC15', 'IIQLLDDYPK'), ('20190515_QX4_JiYu_MA_HeLa_500ng_BR14', 'IIQLLDDYPK'), ('20190522_QX0_MaPe_MA_HeLa_500ng_LC07_1_BR14_190524170803', 'IVSRPEELREDDVGTGAGLLEIK'), ('20190611_QX7_IgPa_MA_HeLa_Br14_500ng', 'ALPFWNEEIVPQIK'), ('20190618_QX4_JiYu_MA_HeLa_500ng_centroid', 'TGTAEMSSILEER'), ('20190624_QE10_nLC14_LiNi_QC_MNT_15cm_HeLa_CPH_01', 'NAGVEGSLIVEK'), ('20190625_QE6_LC4_AS_QC_MNT_HeLa_02', 'RFPGYDSESK'), ('20190625_QE6_LC4_AS_QC_MNT_HeLa_03', 'RFPGYDSESK'), ('20190625_QE8_nLC14_GP_QC_MNT_15cm_Hela_02', 'DSYVGDEAQSK'), ('20190627_QE9_nLC0_RG_MNT_Hela_MUC_50cm_1', 'ALPFWNEEIVPQIK'), ('20190628_QE8_nLC14_GP_QC_MNT_15cm_Hela_01', 'YDDMATCMK'), ('20190701_QX8_AnPi_MA_HeLa_BR14_500ng', 'SYCAEIAHNVSSK'), ('20190705_QX0_AnBr_MA_HeLa_500ng_LC07_01_190707104639', 'ALPFWNEEIVPQIK'), ('20190708_QE9_nLC2_AGF_QC_MNT_HeLa_01_20190709092142', 'ALPFWNEEIVPQIK'), ('20190712_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_01', 'ELAPYDENWFYTR'), ('20190716_QE1_nLC13_ANHO_QC_MNT_HELA_01', 'LVNHFVEEFK'), ('20190726_QE10_nLC0_LiNi_QC_45cm_HeLa_MUC_4thcolumn_1', 'VNVPVIGGHAGK'), ('20190801_QX3_StEb_MA_Hela_500ng_LC15', 'NMDPLNDNIATLLHQSSDK'), ('20190803_QX8_AnPi_MA_HeLa_BR14_500ng', 'SLEDQVEMLR')]
#      intensity_pred_collab  intensity_pred_dae  replicates  \
# MSE                  0.502               0.542       1.505
# MAE                  0.434               0.463       0.854
#
#      intensity_pred_vae  train_average  train_median
# MSE               1.980          2.023         2.099
# MAE               1.065          1.067         1.052

# %% [markdown]
# Save final prediction values of validation data for later comparison.

# %%
df_pred.to_csv(folder /
               f"{config.FOLDER_DATA}_valid_pred.csv")

# %% [markdown]
# ## PCA plot for imputed and denoised data
#
# two setups:
#  - impute missing values
#  - additinally change observed values
